# %%
import os, sys, time, glob, random, argparse
import numpy as np
from copy import deepcopy
import torch
import torch.nn as nn

# XAutoDL 
from xautodl.config_utils import load_config, dict2config, configure2str
from xautodl.datasets import get_datasets, get_nas_search_loaders
from xautodl.procedures import (
    prepare_seed,
    prepare_logger,
    save_checkpoint,
    copy_checkpoint,
    get_optim_scheduler,
)
from xautodl.utils import get_model_infos, obtain_accuracy
from xautodl.log_utils import AverageMeter, time_string, convert_secs2time
from xautodl.models import get_cell_based_tiny_net, get_search_spaces

# NB201
from nas_201_api import NASBench201API as API

import tqdm
# Out:
# 2022-10-12 16:19:56.970551: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
parser = argparse.ArgumentParser("Random search for NAS.")
parser.add_argument("--data_path", type=str, default='../cifar.python', help="The path to dataset")
parser.add_argument("--dataset", type=str, default='cifar10',choices=["cifar10", "cifar100", "ImageNet16-120"], help="Choose between Cifar10/100 and ImageNet-16.")

# channels and number-of-cells
parser.add_argument("--search_space_name", type=str, default='nas-bench-201', help="The search space name.")
parser.add_argument("--config_path", type=str, default='../configs/nas-benchmark/algos/RANDOM.config', help="The path to the configuration.")
# parser.add_argument("--config_path", type=str, default='./MY.config', help="The path to the configuration.")
parser.add_argument("--max_nodes", type=int, default=4, help="The maximum number of nodes.")
parser.add_argument("--channel", type=int, default=16, help="The number of channels.")
parser.add_argument("--num_cells", type=int, default=5, help="The number of cells in one stage.")
parser.add_argument("--select_num", type=int, default=100, help="The number of selected architectures to evaluate.")
parser.add_argument("--track_running_stats", type=int, default=0, choices=[0, 1], help="Whether use track_running_stats or not in the BN layer.")
# log
parser.add_argument("--workers", type=int, default=4, help="number of data loading workers")
parser.add_argument("--save_dir", type=str, default='./tmp/', help="Folder to save checkpoints and log.")
parser.add_argument("--arch_nas_dataset", type=str, default='../NAS-Bench-201-v1_1-096897.pth', help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--print_freq", type=int, default=200, help="print frequency (default: 200)")
parser.add_argument("--rand_seed", type=int, default=None, help="manual seed")
args = parser.parse_args(args=[])
if args.rand_seed is None or args.rand_seed < 0:
    args.rand_seed = random.randint(1, 100000)

    
print(args.rand_seed)
print(args)
xargs=args
# Out:
# 54826
# Namespace(arch_nas_dataset='../NAS-Bench-201-v1_1-096897.pth', channel=16, config_path='../configs/nas-benchmark/algos/RANDOM.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=200, rand_seed=54826, save_dir='./tmp/', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
assert torch.cuda.is_available(), "CUDA is not available."
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.set_num_threads(xargs.workers)
prepare_seed(xargs.rand_seed)
logger = prepare_logger(args)
# Out:
# Main Function with logger : Logger(dir=tmp, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : ../NAS-Bench-201-v1_1-096897.pth
# channel          : 16
# config_path      : ../configs/nas-benchmark/algos/RANDOM.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 200
# rand_seed        : 54826
# save_dir         : ./tmp/
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None

# %% [markdown]
# # Main

# %%
train_data, valid_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(xargs.config_path, {"class_num": class_num, "xshape": xshape}, logger)
search_loader, _, valid_loader = get_nas_search_loaders(train_data,
                                                        valid_data,
                                                        xargs.dataset,
                                                        "../configs/nas-benchmark/",
                                                        (config.batch_size, config.test_batch_size),
                                                        xargs.workers)
logger.log("||||||| {:10s} ||||||| Search-Loader-Num={:}, Valid-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(search_loader), len(valid_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": bool(xargs.track_running_stats),
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))
if xargs.arch_nas_dataset is None:
    api = None
else:
    api = API(xargs.arch_nas_dataset)
logger.log("{:} create API = {:} done".format(time_string(), api))

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)
network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

logger.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ../configs/nas-benchmark/algos/RANDOM.config
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Search-Loader-Num=391, Valid-Loader-Num=49, batch size=64
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.025
#     lr: 0.025
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=250, current::epoch=0, iter=0.00, type=cosine, T-max=250, eta-min=0.001)
# criterion   : CrossEntropyLoss()
# try to create the NAS-Bench-201 api from ../NAS-Bench-201-v1_1-096897.pth
# [2022-10-12 16:20:28] create API = NASBench201API(15625/15625 architectures, file=NAS-Bench-201-v1_1-096897.pth) done

# %%
# 10 ep weights
network_dict = torch.load("./10ep_supernet_weights.pth")
network.load_state_dict(network_dict)

# network_dict = torch.load("../results/three_metrics/test/checkpoint/seed-68228-basic.pth")['search_model']
# search_model.load_state_dict(network_dict)
# Out:
# <All keys matched successfully>

# %%
def valid_acc_metric(network, inputs, targets):
    with torch.no_grad():
        network.eval()
        _, logits = network(inputs)
        val_top1, val_top5 = obtain_accuracy(
            logits.data, targets.data, topk=(1, 5)
        )
    return val_top1.item()

def acc_confidence_robustness_metrics(network, inputs, targets):
    with torch.no_grad():
        network.eval()
        # accuracy
        _, logits = network(inputs)
        val_top1, val_top5 = obtain_accuracy(logits.data, targets.data, topk=(1, 5))
        acc = val_top1
        # confidence
        prob = torch.nn.functional.softmax(logits, dim=1)
        one_hot_idx = torch.nn.functional.one_hot(targets)
        confidence = (prob[one_hot_idx==1].sum()) / inputs.size(0) * 100 # in percent
        # robustness
        _, noisy_logits = network(inputs + torch.randn_like(inputs)*0.1)
        kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
        robustness = -kl_loss(torch.nn.functional.log_softmax(noisy_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
        
        return acc.item(), confidence.item(), robustness.item()
    
def step_sim_metric(network, criterion, inputs, targets):
    original_dict = deepcopy(network.state_dict())
    optim_large_step = torch.optim.SGD(network.parameters(), lr=0.1)
    
    # single large step
    network.train()
    optim_large_step.zero_grad()
    _, logits = network(inputs)
    base_loss = criterion(logits, targets)
    base_loss.backward()
    optim_large_step.step()
    large_step_dict = deepcopy(network.state_dict())
    
    # multiple small steps
    network.load_state_dict(original_dict)
    optim_small_step = torch.optim.SGD(network.parameters(), lr=0.01)
    for i in range(10):
        optim_small_step.zero_grad()
        _, logits = network(inputs)
        base_loss = criterion(logits, targets)
        base_loss.backward()
        optim_small_step.step()
    small_step_dict = deepcopy(network.state_dict())
    
    # resume
    network.load_state_dict(original_dict)
    network.eval()
    
    for key in large_step_dict.keys():
#         if 'classifier' in key:
#             large_step = large_step_dict[key] - original_dict[key]
#             small_step = small_step_dict[key] - original_dict[key]
#             score = torch.nn.functional.cosine_similarity(large_step, small_step, dim=1)
#             score = score.mean().item() * 100 # in percent
#             break
        if 'stem.0.weight' in key:
            large_step = large_step_dict[key] - original_dict[key]
            small_step = small_step_dict[key] - original_dict[key]
            co, ci, kh, kw = large_step.size()
            large_step = large_step.view(co, -1)
            small_step = small_step.view(co, -1)
            score = torch.nn.functional.cosine_similarity(large_step, small_step, dim=1)
            score = score.mean().item() * 100 # in percent
            break
            
    return score
    

def search_find_best_my(xloader, network, criterion, n_samples):
    archs, metric_accs, metric_steps, metric_confidences, metric_robustnesses = [], [], [], [], []
    loader_iter = iter(xloader)
    for i in tqdm.tqdm(range(n_samples)):
        arch = network.module.random_genotype(True)
        try:
            inputs, targets = next(loader_iter)
        except:
            loader_iter = iter(xloader)
            inputs, targets = next(loader_iter)
        inputs, targets = inputs.cuda(non_blocking=True), targets.cuda(non_blocking=True)
#         valid_acc = valid_acc_metric(network, inputs, targets)
        valid_acc, confidence, robustness = acc_confidence_robustness_metrics(network, inputs, targets)
        step_sim = step_sim_metric(network, criterion, inputs, targets)

        archs.append(arch)
        metric_accs.append(valid_acc)
        metric_steps.append(step_sim)
        metric_confidences.append(confidence)
        metric_robustnesses.append(robustness)

    return archs, metric_accs, metric_steps, metric_confidences, metric_robustnesses

    
archs, metric_accs, metric_steps, metric_confidences, metric_robustnesses = search_find_best_my(valid_loader, network, criterion, 250)
# Out:
# 100%|██████████| 250/250 [09:32<00:00,  2.29s/it]

# %%
import scipy.stats as stats
rank_accs, rank_steps, rank_confidences, rank_robustnesses = stats.rankdata(metric_accs), stats.rankdata(metric_steps), stats.rankdata(metric_confidences), stats.rankdata(metric_robustnesses)
rank_agg = rank_accs+rank_steps+rank_confidences-rank_robustnesses
# rank_agg = rank_robustnesses
best_idx = np.argmax(rank_agg)


best_arch, best_acc, best_step, best_conf, best_robust = archs[best_idx], metric_accs[best_idx], metric_steps[best_idx], metric_confidences[best_idx], metric_robustnesses[best_idx]
# log
print("RANDOM-NAS finds the best one : {:} with accuracy={:.2f}%, step_sim={:.2f}%, confidence={:.3f}%, robustness={:.3f}".format(best_arch, best_acc, best_step, best_conf, best_robust))
if api is not None:
    print("{:}".format(api.query_by_arch(best_arch, "200")))
# Out:
# RANDOM-NAS finds the best one : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|) with accuracy=31.25%, step_sim=98.48%, confidence=19.739%, robustness=-0.000
# Call query_info_str_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|) and hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=5786
# cifar10-valid  FLOP= 82.49 M, Params=0.587 MB, latency=17.63 ms.
# cifar10-valid  train : [loss = 0.003, top1 = 99.96%], valid : [loss = 0.544, top1 = 89.08%]
# cifar10        FLOP= 82.49 M, Params=0.587 MB, latency=17.63 ms.
# cifar10        train : [loss = 0.004, top1 = 99.93%], test  : [loss = 0.358, top1 = 92.81%]
# cifar100       FLOP= 82.50 M, Params=0.593 MB, latency=15.28 ms.
# cifar100       train : [loss = 0.089, top1 = 98.49%], valid : [loss = 1.470, top1 = 68.26%], test : [loss = 1.479, top1 = 68.39%]
# ImageNet16-120 FLOP= 20.63 M, Params=0.595 MB, latency=20.73 ms.
# ImageNet16-120 train : [loss = 1.825, top1 = 51.57%], valid : [loss = 2.371, top1 = 40.48%], test : [loss = 2.384, top1 = 41.05%]

# %%
def get_valid_acc_from_api(api, arch):
    # print(api.query_by_arch(arch, "200"))
    index = api.query_index_by_arch(arch)
    results = api.query_by_index(index, 'cifar10-valid', '200') # a dict of all trials for 1st net on cifar100, where the key is the seed
    acc = 0
    for seed, result in results.items():
        acc = acc + result.get_eval('valid')['accuracy']
    acc = acc / len(results)
    return acc

api_valid_accs = [get_valid_acc_from_api(api, a) for a in archs]
# Out:
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10681, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10681, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6108, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6108, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=213, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=213, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=5158, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5158, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=907, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=907, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1135, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1135, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6538, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6538, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3683, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3683, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5914, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5914, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=9811, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9811, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1933, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1933, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10165, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10165, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=6727, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6727, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=2607, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2607, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=12369, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12369, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=8516, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8516, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=5619, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5619, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=4262, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4262, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=12515, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12515, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=9136, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9136, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=6105, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6105, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2570, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2570, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=11353, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11353, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=2104, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2104, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3158, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3158, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7481, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7481, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=533, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=533, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=1312, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1312, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5620, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5620, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5307, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5307, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=12776, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12776, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=14550, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14550, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6098, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6098, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14955, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14955, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=869, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=869, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=4887, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4887, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=8781, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8781, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3119, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3119, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=147, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=147, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=12682, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12682, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=8965, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8965, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|none~1|none~2|)
# Call query_by_index with arch_index=5849, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5849, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=11462, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11462, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=10736, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10736, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=9100, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9100, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=8609, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8609, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=4208, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4208, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=7593, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7593, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14106, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14106, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5129, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5129, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3555, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3555, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=11591, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11591, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2030, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2030, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10403, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10403, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10468, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10468, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=13197, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13197, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5391, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5391, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=9644, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9644, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=4731, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4731, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=1319, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1319, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12357, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12357, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=1049, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1049, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|skip_connect~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=12286, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12286, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|none~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10742, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10742, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=4292, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4292, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=11417, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11417, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=519, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=519, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=10293, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10293, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5017, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5017, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=3374, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3374, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=5275, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5275, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=6936, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6936, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=8645, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8645, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=13998, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13998, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2487, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2487, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5061, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5061, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3137, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3137, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=11733, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11733, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=3086, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3086, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13879, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13879, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=10357, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10357, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10117, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10117, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|none~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=15581, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15581, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1826, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1826, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3167, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3167, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=11589, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11589, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=7384, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7384, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=7967, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7967, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9807, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9807, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2149, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2149, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13886, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13886, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=38, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=38, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=15530, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15530, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11924, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11924, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=4107, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4107, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=15170, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15170, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|skip_connect~1|+|none~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=12268, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12268, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=1625, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1625, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=1483, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1483, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=4524, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4524, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=432, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=432, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11205, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11205, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=11946, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11946, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1443, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1443, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7022, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7022, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2926, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2926, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|none~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=14230, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14230, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=4255, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4255, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=9946, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9946, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10223, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10223, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=2230, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2230, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=8177, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8177, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4081, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4081, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11213, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11213, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4236, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4236, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1008, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1008, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6546, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6546, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=13506, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13506, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=3761, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3761, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2322, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2322, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=4696, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4696, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5786, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5786, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2424, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2424, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=10532, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10532, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_1x1~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=5438, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5438, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=7802, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7802, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=15423, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15423, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=8821, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8821, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=8756, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8756, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13127, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13127, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=6878, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6878, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5055, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5055, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3304, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3304, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13782, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13782, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14917, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14917, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10935, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10935, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=2129, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2129, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=4414, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4414, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3968, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3968, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=12559, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12559, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1400, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1400, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=6936, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6936, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11206, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11206, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=8108, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8108, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=4931, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4931, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=6003, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6003, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=1922, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1922, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=9740, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9740, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1096, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1096, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10193, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10193, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|none~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=13538, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13538, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=8295, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8295, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11768, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11768, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3035, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3035, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=13813, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13813, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|none~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3989, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3989, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=3894, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3894, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1896, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1896, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=11662, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11662, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=11089, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11089, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1908, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1908, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8849, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8849, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2036, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2036, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=15576, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15576, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=5826, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5826, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12157, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12157, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=15548, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15548, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=528, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=528, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=3561, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3561, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=8699, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8699, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4714, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4714, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=14368, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14368, hp=200
# ...
# Call query_by_index with arch_index=809, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=809, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1088, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1088, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=3589, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3589, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10656, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10656, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=14580, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14580, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|none~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=12740, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12740, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=2300, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2300, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5449, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5449, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=3133, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3133, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13764, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13764, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=4494, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4494, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=2381, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2381, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|none~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13500, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13500, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=8240, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8240, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=7237, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7237, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5821, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5821, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=9784, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9784, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1236, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1236, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9124, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9124, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=15337, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15337, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=8333, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8333, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4690, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4690, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|none~2|)
# Call query_by_index with arch_index=2002, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2002, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=9591, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9591, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2880, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2880, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8570, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8570, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6934, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6934, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=1422, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1422, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=3966, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3966, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=15018, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15018, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=15603, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15603, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=7157, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7157, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=9784, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9784, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=14231, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14231, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6747, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6747, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5696, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5696, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=8281, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8281, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3595, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3595, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|none~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8640, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8640, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=866, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=866, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=202, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=202, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=15401, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15401, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10588, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10588, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=3249, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3249, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2085, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2085, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4366, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4366, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=12951, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12951, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=7089, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7089, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=2932, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2932, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13224, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13224, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=892, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=892, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=8732, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8732, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=14323, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14323, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=2064, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2064, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=8573, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8573, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5590, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5590, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9548, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9548, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=9198, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9198, hp=200

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

x = stats.rankdata(metric_accs)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(metric_steps)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(metric_confidences)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(metric_robustnesses)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(rank_agg)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)
# Out:
# 0.09983427919475477 0.019542577003612532
# -0.1185599306143643 0.005234984079911465
# 0.06268474492375711 0.13985992266888306
# -0.295917875598454 3.188224362275952e-12
# 0.21728231247242483 3.1447908751620445e-07

# %%
for i in range(100):
    print(metric_robustnesses[i])
    print(api_valid_accs[i])
    print("\n\n")
# Out:
# -0.00020010120351798832
# 85.96400000854493
#
#
#
# -0.00014117738464847207
# 88.21866665934245
#
#
#
# -0.0002899380633607507
# 88.34666665527344
#
#
#
# -5.5707751016598195e-05
# 85.85333333170574
#
#
#
# -0.00021784842829219997
# 88.25199999593099
#
#
#
# -9.908249921863899e-05
# 88.98266666097004
#
#
#
# -0.0009359907708130777
# 88.58199998657227
#
#
#
# -0.00016039732145145535
# 86.8540000048828
#
#
#
# -0.00021757851936854422
# 88.7373333227539
#
#
#
# -9.819550905376673e-05
# 79.47399998657227
#
#
#
# -0.00019506984972395003
# 89.11199999837238
#
#
#
# -0.00012911071826238185
# 91.33399998291014
#
#
#
# -0.00032769382232800126
# 87.9839999983724
#
#
#
# -0.00016244665312115103
# 88.08933333984375
#
#
#
# -6.969066453166306e-05
# 89.23999998168945
#
#
#
# -0.000648053246550262
# 86.86000001953126
#
#
#
# -0.00017052848124876618
# 89.6579999987793
#
#
#
# -0.0001776044664438814
# 88.67999999267577
#
#
#
# -0.0002497307432349771
# 88.30799998901367
#
#
#
# -9.818145917961374e-05
# 89.16399999104817
#
#
#
# -0.00026468321448192
# 89.57599999511719
#
#
#
# -0.00024187784583773464
# 89.33066666097005
#
#
#
# -9.939386654878035e-05
# 89.67199999511719
#
#
#
# -0.00014511350309476256
# 86.25466666748048
#
#
#
# -0.00013134728942532092
# 88.68266666992189
#
#
#
# -6.101552571635693e-05
# 84.44000000976563
#
#
#
# -5.5929198424564674e-05
# 85.63466665201823
#
#
#
# -4.940275539411232e-05
# 78.13333332926433
#
#
#
# -0.00019452752894721925
# 88.31599997802735
#
#
#
# -0.00010543692042119801
# 87.81400000488281
#
#
#
# -0.00012860371498391032
# 90.70599998046876
#
#
#
# -2.3387490728055127e-05
# 84.18400000854493
#
#
#
# -0.00013910094276070595
# 87.74600000854491
#
#
#
# -0.00023577907995786518
# 89.03733332845053
#
#
#
# -0.00016835056885611266
# 91.2199999991862
#
#
#
# -0.0003588560502976179
# 88.99600000000001
#
#
#
# -0.00025335559621453285
# 85.8386666829427
#
#
#
# -0.0005954394582659006
# 89.44800000976562
#
#
#
# -0.00016380906163249165
# 89.13333333821613
#
#
#
# -0.00021497003035619855
# 88.84999998291016
#
#
#
# -6.278140062931925e-05
# 87.05466665283204
#
#
#
# -0.000664478400722146
# 86.00600000732422
#
#
#
# -0.0002317949547432363
# 88.6560000024414
#
#
#
# -0.00022574365721084177
# 86.03866667643229
#
#
#
# -0.000180189119419083
# 87.66599998779296
#
#
#
# -0.0005444699199870229
# 88.9859999975586
#
#
#
# -0.00010056275641545653
# 91.13999998779298
#
#
#
# -0.00010368955554440618
# 88.91199998046875
#
#
#
# -0.0001634970831219107
# 89.36799998616537
#
#
#
# -0.00015495849947910756
# 86.50533332519531
#
#
#
# -8.470086322631687e-05
# 89.32799999755859
#
#
#
# -0.00012011223589070141
# 87.50266665120444
#
#
#
# -0.00014307630772236735
# 91.0173333186849
#
#
#
# -2.2439300664700568e-05
# 84.37599999511718
#
#
#
# -0.00021567160729318857
# 88.85199998616535
#
#
#
# -9.212247096002102e-05
# 88.6920000024414
#
#
#
# -9.96772726580275e-08
# 9.711999998881021
#
#
#
# -0.0011797480983659625
# 86.62199999755859
#
#
#
# -9.621828212402761e-05
# 87.85866666829428
#
#
#
# -0.00013497003237716854
# 85.30533334391276
#
#
#
# -0.00012501372839324176
# 87.4919999987793
#
#
#
# -0.0005877435905858874
# 89.34933332926433
#
#
#
# -2.118908378179185e-05
# 84.28399999023438
#
#
#
# -0.00010884981020353734
# 88.7580000024414
#
#
#
# -0.00013674241199623793
# 85.61333333170573
#
#
#
# -7.713650848018005e-05
# 86.92000000732422
#
#
#
# -0.00011674861889332533
# 86.72399999267577
#
#
#
# -2.349595342820976e-05
# 84.3946666414388
#
#
#
# -0.00014968984760344028
# 78.97599999633789
#
#
#
# -2.206084900535643e-05
# 84.30600001098632
#
#
#
# -2.14514002436772e-05
# 84.34666665445963
#
#
#
# -0.00018163814092986286
# 83.15599997558593
#
#
#
# -6.4848929469008e-05
# 68.64799998291016
#
#
#
# -4.930354771204293e-05
# 72.25800001342773
#
#
#
# -0.0006996546871960163
# 87.76666666585287
#
#
#
# -0.0001112656609620899
# 85.3580000024414
#
#
#
# -0.00037560821510851383
# 88.33466666422527
#
#
#
# -9.801341366255656e-05
# 90.53999997924805
#
#
#
# -0.0001384988718200475
# 89.30399998779296
#
#
#
# -0.0005832444876432419
# 89.51599998860677
#
#
#
# -4.744888792629354e-05
# 78.06399999267578
#
#
#
# -0.00022121798247098923
# 88.26999999267578
#
#
#
# -5.234890340943821e-05
# 78.56799999674479
#
#
#
# -0.00015447371697518975
# 85.53333331380207
#
#
#
# -0.00019528993288986385
# 89.67866665608723
#
#
#
# -5.19006498507224e-05
# 84.38666665934245
#
#
#
# -0.00014225716586224735
# 90.89199998046875
#
#
#
# -6.650213617831469e-05
# 81.27466666178384
#
#
#
# -0.0001847698586061597
# 87.9519999934896
#
#
#
# -0.00029409449780359864
# 89.12000000081382
#
#
#
# -5.407146454672329e-05
# 83.27600001139324
#
#
#
# -0.0006522968178614974
# 88.69466665283203
#
#
#
# -0.00023696021526120603
# 87.3139999975586
#
#
#
# -0.00015198611072264612
# 85.4559999987793
#
#
#
# -0.0018435074016451836
# 88.612
#
#
#
# -0.0012215254828333855
# 87.78800000488282
#
#
#
# -2.277916792081669e-05
# 84.16399998046876
#
#
#
# -0.0001221706042997539
# 88.4120000024414
#
#
#
# -0.0001579143718117848
# 85.58533333740235
#
#
#
# -4.267104668542743e-05
# 78.08533332763672
