# %%
import os, sys, time, glob, random, argparse
import numpy as np
from copy import deepcopy
import torch
import torch.nn as nn
import time
import tqdm
import scipy.stats as stats
import matplotlib.pyplot as plt
import pickle

# XAutoDL 
from xautodl.config_utils import load_config, dict2config, configure2str
from xautodl.datasets import get_datasets, get_nas_search_loaders
from xautodl.procedures import (
    prepare_seed,
    prepare_logger,
    save_checkpoint,
    copy_checkpoint,
    get_optim_scheduler,
)
from xautodl.utils import get_model_infos, obtain_accuracy
from xautodl.log_utils import AverageMeter, time_string, convert_secs2time
from xautodl.models import get_search_spaces

# API
from nats_bench import create

# custom modules
from custom.tss_model import TinyNetwork
from xautodl.models.cell_searchs.genotypes import Structure
from ZeroShotProxy import *

os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# 2023-11-07 16:32:20.083944: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-07 16:32:20.130483: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-07 16:32:20.849707: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
parser = argparse.ArgumentParser("Training-free NAS on NATSBench (TSS)")
parser.add_argument("--data_path", type=str, default='./cifar.python', help="The path to dataset")
parser.add_argument("--dataset", type=str, default='cifar10',choices=["cifar10", "cifar100", "ImageNet16-120"], help="Choose between Cifar10/100 and ImageNet-16.")

# channels and number-of-cells
parser.add_argument("--search_space", type=str, default='tss', help="The search space name.")
parser.add_argument("--config_path", type=str, default='./configs/nas-benchmark/algos/weight-sharing.config', help="The path to the configuration.")
parser.add_argument("--max_nodes", type=int, default=4, help="The maximum number of nodes.")
parser.add_argument("--channel", type=int, default=16, help="The number of channels.")
parser.add_argument("--num_cells", type=int, default=5, help="The number of cells in one stage.")
parser.add_argument("--affine", type=int, default=1, choices=[0, 1], help="Whether use affine=True or False in the BN layer.")
parser.add_argument("--track_running_stats", type=int, default=0, choices=[0, 1], help="Whether use track_running_stats or not in the BN layer.")

# log
parser.add_argument("--print_freq", type=int, default=200, help="print frequency (default: 200)")

# custom
parser.add_argument("--gpu", type=int, default=0, help="")
parser.add_argument("--workers", type=int, default=2, help="number of data loading workers")
parser.add_argument("--api_data_path", type=str, default="./api_data/NATS-tss-v1_0-3ffb9-simple/", help="")
parser.add_argument("--save_dir", type=str, default='./results/tmp', help="Folder to save checkpoints and log.")
parser.add_argument('--zero_shot_score', type=str, default='etf', choices=['etf','zico','zen','gradnorm','naswot','synflow','snip','grasp','te_nas','gradsign'])
parser.add_argument("--rand_seed", type=int, default=1, help="manual seed (we use 1-to-5)")
args = parser.parse_args(args=[])

if args.rand_seed is None or args.rand_seed < 0:
    args.rand_seed = random.randint(1, 100000)

print(args.rand_seed)
print(args)
xargs=args
# Out:
# 1
# Namespace(data_path='./cifar.python', dataset='cifar10', search_space='tss', config_path='./configs/nas-benchmark/algos/weight-sharing.config', max_nodes=4, channel=16, num_cells=5, affine=1, track_running_stats=0, print_freq=200, gpu=0, workers=2, api_data_path='./api_data/NATS-tss-v1_0-3ffb9-simple/', save_dir='./results/tmp', zero_shot_score='etf', rand_seed=1)

# %%
assert torch.cuda.is_available(), "CUDA is not available."
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.set_num_threads(xargs.workers)
prepare_seed(xargs.rand_seed)
logger = prepare_logger(args)
# Out:
# Main Function with logger : Logger(dir=results/tmp, use-tf=False, writer=None)
# Arguments : -------------------------------
# data_path        : ./cifar.python
# dataset          : cifar10
# search_space     : tss
# config_path      : ./configs/nas-benchmark/algos/weight-sharing.config
# max_nodes        : 4
# channel          : 16
# num_cells        : 5
# affine           : 1
# track_running_stats : 0
# print_freq       : 200
# gpu              : 0
# workers          : 2
# api_data_path    : ./api_data/NATS-tss-v1_0-3ffb9-simple/
# save_dir         : ./results/tmp
# zero_shot_score  : etf
# rand_seed        : 1
# Python  Version  : 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
# Pillow  Version  : 9.4.0
# PyTorch Version  : 2.0.1
# cuDNN   Version  : 8500
# CUDA available   : True
# CUDA GPU numbers : 1
# CUDA_VISIBLE_DEVICES : 1

# %%
## API
api = create(xargs.api_data_path, xargs.search_space, fast_mode=True, verbose=False)
logger.log("Create API = {:} done".format(api))

## data
train_data, valid_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(xargs.config_path, {"class_num": class_num, "xshape": xshape}, logger)
search_loader, train_loader, valid_loader = get_nas_search_loaders(train_data,
                                                                   valid_data,
                                                                   xargs.dataset,
                                                                   "./configs/nas-benchmark/",
                                                                   (config.batch_size, config.test_batch_size),
                                                                   xargs.workers,)
logger.log("||||||| {:10s} ||||||| Search-Loader-Num={:}, Valid-Loader-Num={:}, batch size={:}".format(xargs.dataset, len(search_loader), len(valid_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

## model
search_space = get_search_spaces(xargs.search_space, "nats-bench")
logger.log("search space : {:}".format(search_space))

device = torch.device('cuda:{}'.format(xargs.gpu))
# Out:
# Create API = NATStopology(0/15625 architectures, fast_mode=True, file=) done
# Files already downloaded and verified
# Files already downloaded and verified
# ./configs/nas-benchmark/algos/weight-sharing.config
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=100, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Search-Loader-Num=391, Valid-Loader-Num=49, batch size=64
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=100, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# search space : ['none', 'skip_connect', 'nor_conv_1x1', 'nor_conv_3x3', 'avg_pool_3x3']

# %%
def random_genotype(max_nodes, op_names):
        genotypes = []
        for i in range(1, max_nodes):
            xlist = []
            for j in range(i):
                node_str = "{:}<-{:}".format(i, j)
                op_name = random.choice(op_names)
                xlist.append((op_name, j))
            genotypes.append(tuple(xlist))
        arch = Structure(genotypes)
        return arch

real_input_metrics = ['zico', 'snip', 'grasp', 'te_nas', 'gradsign']
    
def search_find_best(xargs, xloader, n_samples = None, archs = None):
    logger.log("Searching with {}".format(xargs.zero_shot_score.lower()))
    score_fn_name = "compute_{}_score".format(xargs.zero_shot_score.lower())
    score_fn = globals().get(score_fn_name)
    input_, target_ = next(iter(xloader))
    resolution = input_.size(2)
    batch_size = input_.size(0)
    zero_shot_score_dict = None
    arch_list = []
    trainloader = train_loader if xargs.zero_shot_score.lower() in real_input_metrics else None
        
    if archs is None and n_samples is not None:
        all_time = []
        all_mem = []
        start = torch.cuda.Event(enable_timing=True)
        end = torch.cuda.Event(enable_timing=True)
        for i in tqdm.tqdm(range(n_samples)):
            torch.cuda.empty_cache()
            torch.cuda.reset_peak_memory_stats()
            # random sampling
            arch = random_genotype(xargs.max_nodes, search_space)
            network = TinyNetwork(xargs.channel, xargs.num_cells, arch, class_num)
            network = network.to(device)
            network.train()

            start.record()
            

            info_dict = score_fn.compute_nas_score(network, gpu=xargs.gpu, trainloader=trainloader, resolution=resolution, batch_size=batch_size)

            end.record()
            torch.cuda.synchronize()
            all_time.append(start.elapsed_time(end))
#             all_mem.append(torch.cuda.max_memory_reserved())
            all_mem.append(torch.cuda.max_memory_allocated())

            arch_list.append(arch)
            if zero_shot_score_dict is None: # initialize dict
                zero_shot_score_dict = dict()
                for k in info_dict.keys():
                    zero_shot_score_dict[k] = []
            for k, v in info_dict.items():
                zero_shot_score_dict[k].append(v)

        logger.log("------Runtime------")
        logger.log("All: {:.5f} ms".format(np.mean(all_time)))
        logger.log("------Avg Mem------")
        logger.log("All: {:.5f} GB".format(np.mean(all_mem)/1e9))
        logger.log("------Max Mem------")
        logger.log("All: {:.5f} GB".format(np.max(all_mem)/1e9))
        
    elif archs is not None and n_samples is None:
        all_time = []
        all_mem = []
        start = torch.cuda.Event(enable_timing=True)
        end = torch.cuda.Event(enable_timing=True)
        for arch in tqdm.tqdm(archs):
            torch.cuda.empty_cache()
            torch.cuda.reset_peak_memory_stats()
            network = TinyNetwork(xargs.channel, xargs.num_cells, arch, class_num)
            network = network.to(device)
            network.train()

            start.record()
            

            info_dict = score_fn.compute_nas_score(network, gpu=xargs.gpu, trainloader=trainloader, resolution=resolution, batch_size=batch_size)

            end.record()
            torch.cuda.synchronize()
            all_time.append(start.elapsed_time(end))
#             all_mem.append(torch.cuda.max_memory_reserved())
            all_mem.append(torch.cuda.max_memory_allocated())

            arch_list.append(arch)
            if zero_shot_score_dict is None: # initialize dict
                zero_shot_score_dict = dict()
                for k in info_dict.keys():
                    zero_shot_score_dict[k] = []
            for k, v in info_dict.items():
                zero_shot_score_dict[k].append(v)

        logger.log("------Runtime------")
        logger.log("All: {:.5f} ms".format(np.mean(all_time)))
        logger.log("------Avg Mem------")
        logger.log("All: {:.5f} GB".format(np.mean(all_mem)/1e9))
        logger.log("------Max Mem------")
        logger.log("All: {:.5f} GB".format(np.max(all_mem)/1e9))
        
    return arch_list, zero_shot_score_dict

# %%
# ######### search across random N archs #########
# archs, results = search_find_best(xargs, train_loader, n_samples=3000)

######### search across N archs uniformly sampled according to test acc. #########
def uniform_sample_archs(search_space, xargs, api, n_samples=1000, dataset='ImageNet16-120'):
    arch = random_genotype(xargs.max_nodes, search_space)
    search_space = get_search_spaces(xargs.search_space, "nats-bench")
    archs = arch.gen_all(search_space, xargs.max_nodes, False)
    
    def get_results_from_api(api, arch, dataset='cifar10'):
        dataset_candidates = ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120']
        assert dataset in dataset_candidates
        index = api.query_index_by_arch(arch)
        api._prepare_info(index)
        archresult = api.arch2infos_dict[index]['200']

        if dataset == 'cifar10-valid':
            acc = archresult.get_metrics(dataset, 'x-valid', iepoch=None, is_random=False)['accuracy']
        elif dataset == 'cifar10':
            acc = archresult.get_metrics(dataset, 'ori-test', iepoch=None, is_random=False)['accuracy']
        else:
            acc = archresult.get_metrics(dataset, 'x-test', iepoch=None, is_random=False)['accuracy']

        return acc

    accs = []
    for a in archs:
        accs.append(get_results_from_api(api, a, dataset))
    interval = len(archs) // n_samples
    sorted_indices = np.argsort(accs)
    new_archs = []
    for i, idx in enumerate(sorted_indices):
        if i % interval == 0:
            new_archs.append(archs[idx])
    archs = new_archs
    
    return archs

if os.path.exists("./tss_uniform_arch.pickle"):
    with open("./tss_uniform_arch.pickle", "rb") as fp:
        uniform_archs = pickle.load(fp)
else:
    uniform_archs = uniform_sample_archs(search_space, xargs, api, 1000, 'ImageNet16-120')
    with open("./tss_uniform_arch.pickle", "wb") as fp:
        pickle.dump(uniform_archs, fp)
archs, results = search_find_best(xargs, train_loader, archs=uniform_archs)


# ######### search across all archs #########
# def generate_all_archs(search_space, xargs):
#     arch = random_genotype(xargs.max_nodes, search_space)
#     archs = arch.gen_all(search_space, xargs.max_nodes, False)
#     return archs

# if os.path.exists("./tss_all_arch.pickle"):
#     with open("./tss_all_arch.pickle", "rb") as fp:
#         all_archs = pickle.load(fp)
# else:
#     all_archs = generate_all_archs(search_space, xargs)
#     with open("./tss_all_arch.pickle", "wb") as fp:
#         pickle.dump(all_archs, fp)

# # archs, results = search_find_best(xargs, train_loader, archs=all_archs)

# ####
# result_path = "./{}_all_arch.pickle".format(args.zero_shot_score)
# if os.path.exists(result_path):
#     print("results already exists")
#     with open(result_path, "rb") as fp:
#         results = pickle.load(fp)
#     archs = all_archs
# else:
#     archs, results = search_find_best(xargs, train_loader, archs=all_archs)
#     with open(result_path, "wb") as fp:
#         pickle.dump(results, fp)
# Out:
# Searching with etf
# 100%|██████████| 1042/1042 [01:09<00:00, 14.91it/s]
# ------Runtime------
# All: 39.10659 ms
# ------Avg Mem------
# All: 0.28355 GB
# ------Max Mem------
# All: 0.53034 GB

# %%
def get_results_from_api(api, arch, dataset='cifar10'):
    dataset_candidates = ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120']
    assert dataset in dataset_candidates
    index = api.query_index_by_arch(arch)
    api._prepare_info(index)
    archresult = api.arch2infos_dict[index]['200']
    
    if dataset == 'cifar10-valid':
        acc = archresult.get_metrics(dataset, 'x-valid', iepoch=None, is_random=False)['accuracy']
    elif dataset == 'cifar10':
        acc = archresult.get_metrics(dataset, 'ori-test', iepoch=None, is_random=False)['accuracy']
    else:
        acc = archresult.get_metrics(dataset, 'x-test', iepoch=None, is_random=False)['accuracy']
    flops = archresult.get_compute_costs(dataset)['flops']
    params = archresult.get_compute_costs(dataset)['params']
    
    return acc, flops, params

api_valid_accs, api_flops, api_params = [], [], []
for a in archs:
#     valid_acc, flops, params = get_results_from_api(api, a, 'cifar10')
#     valid_acc, flops, params = get_results_from_api(api, a, 'cifar100')
    valid_acc, flops, params = get_results_from_api(api, a, 'ImageNet16-120')
    api_valid_accs.append(valid_acc)
    api_flops.append(flops)
    api_params.append(params)
    
print("Maximum acc: {}% \n Info".format(np.max(api_valid_accs)))
best_idx = np.argmax(api_valid_accs)
best_arch = archs[best_idx]
if api is not None:
    print("{:}".format(api.query_by_arch(best_arch, "200")))
# Out:
# Maximum acc: 46.599999908447266%
#  Info
# |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=8449
# cifar10-valid  FLOP=117.88 M, Params=0.830 MB, latency=18.19 ms.
# cifar10-valid  train : [loss = 0.002 & top1 = 99.99%], valid : [loss = 0.418 & top1 = 91.20%]
# cifar10        FLOP=117.88 M, Params=0.830 MB, latency=18.19 ms.
# cifar10        train : [loss = 0.002 & top1 = 99.97%], test  : [loss = 0.287 & top1 = 93.94%]
# cifar100       FLOP=117.89 M, Params=0.836 MB, latency=20.39 ms.
# cifar100       train : [loss = 0.030 & top1 = 99.67%], valid : [loss = 1.286 & top1 = 72.15%], test : [loss = 1.261 & top1 = 72.10%]
# ImageNet16-120 FLOP= 29.48 M, Params=0.838 MB, latency=17.02 ms.
# ImageNet16-120 train : [loss = 1.286 & top1 = 64.64%], valid : [loss = 2.169 & top1 = 46.50%], test : [loss = 2.201 & top1 = 46.60%]

# %%
fig_scale = 1.1

if xargs.zero_shot_score.lower() == 'etf':
    rank_agg = None
    l = len(api_flops)
    rank_agg = np.log(stats.rankdata(api_flops) / l)
    for k in results.keys():
        print(k)
        if rank_agg is None:
            rank_agg = np.log( stats.rankdata(results[k]) / l)
        else:
            rank_agg = rank_agg + np.log( stats.rankdata(results[k]) / l)


    best_idx = np.argmax(rank_agg)

    best_arch, acc = archs[best_idx], api_valid_accs[best_idx]
    if api is not None:
        print("{:}".format(api.query_by_arch(best_arch, "200")))


    x = stats.rankdata(rank_agg)
    y = stats.rankdata(api_valid_accs)
    kendalltau = stats.kendalltau(x, y)
    spearmanr = stats.spearmanr(x, y)
    pearsonr = stats.pearsonr(x, y)
    print("aggregated: {}\t{}\t{}\t".format(kendalltau[0], pearsonr[0], spearmanr[0]))
    plt.figure(figsize=(4*fig_scale,3*fig_scale))
    plt.scatter(x, y, linewidths=0.1)
    best_idx = np.argmax(rank_agg)
    plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
    plt.title("Rank_agg_etf")
    plt.show()
    
elif xargs.zero_shot_score.lower() == 'te_nas':
    rank_agg = None
    for k in results.keys():
        print(k)
        if rank_agg is None:
            rank_agg = stats.rankdata(results[k])
        else:
            rank_agg = rank_agg + stats.rankdata(results[k])


    best_idx = np.argmax(rank_agg)

    best_arch, acc = archs[best_idx], api_valid_accs[best_idx]
    if api is not None:
        print("{:}".format(api.query_by_arch(best_arch, "200")))


    x = stats.rankdata(rank_agg)
    y = stats.rankdata(api_valid_accs)
    kendalltau = stats.kendalltau(x, y)
    spearmanr = stats.spearmanr(x, y)
    pearsonr = stats.pearsonr(x, y)
    print("aggregated: {}\t{}\t{}\t".format(kendalltau[0], pearsonr[0], spearmanr[0]))
    plt.figure(figsize=(4*fig_scale,3*fig_scale))
    plt.scatter(x, y, linewidths=0.1)
    best_idx = np.argmax(rank_agg)
    plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
    plt.title("Rank_agg_te_nas")
    plt.show()

# for each
# metrics = {'FLOPs':api_flops, 'Params':api_params}
metrics = {}
for k, v in results.items():
    metrics[k] = v

    print(k)
    best_idx = np.argmax(v)

    best_arch, acc = archs[best_idx], api_valid_accs[best_idx]
    if api is not None:
        print("{:}".format(api.query_by_arch(best_arch, "200")))


for k in metrics.keys():
    x = stats.rankdata(metrics[k])
    y = stats.rankdata(api_valid_accs)
    kendalltau = stats.kendalltau(x, y)
    spearmanr = stats.spearmanr(x, y)
    pearsonr = stats.pearsonr(x, y)
    print("{}: {}\t{}\t{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
    plt.figure(figsize=(4*fig_scale,3*fig_scale))
    plt.scatter(x, y, linewidths=0.1)
    best_idx = np.argmax(metrics[k])
    plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
    plt.title("Rank_{}".format(k))
    plt.show()

# %%
# import seaborn as sn
# import pandas as pd
# import matplotlib.pyplot as plt
# import copy

# metrics = copy.deepcopy(results)

# metrics['accuracy'] = api_valid_accs
# metrics['complexity'] = api_flops

# # keys = ['accuracy', 'expressivity', 'progressivity', 'trainability', 'complexity']
# # key_names = ['Acc.', r"$s^{\mathcal{E}}$", r"$s^{\mathcal{P}}$", r"$s^{\mathcal{T}}$", r"$s^{\mathcal{C}}$"]
# keys = ['expressivity', 'progressivity', 'trainability', 'complexity']
# key_names = [r"$s^{\mathcal{E}}$", r"$s^{\mathcal{P}}$", r"$s^{\mathcal{T}}$", r"$s^{\mathcal{C}}$"]
# print(keys)

# matrix = np.zeros((len(keys),len(keys)))

# for i in range(len(keys)):
#     for j in range(len(keys)):
#         x = stats.rankdata(metrics[keys[i]])
#         y = stats.rankdata(metrics[keys[j]])
#         kendalltau = stats.kendalltau(x, y)[0]
#         matrix[i,j] = kendalltau

# print(matrix)
        
# df_cm = pd.DataFrame(matrix, index = [i for i in key_names], columns = [i for i in key_names])
# plt.figure(figsize=(6,3))
# sn.set(font_scale=1.9) # for label size
# ax = sn.heatmap(df_cm, annot=True, annot_kws={"size": 17}, cmap='GnBu') # font size
# cbar = ax.collections[0].colorbar
# cbar.ax.tick_params(labelsize=16)
# plt.yticks(rotation=0) 
# plt.savefig('confusion_matrix.pdf', bbox_inches = 'tight', pad_inches = 0)
# plt.show()

# %%
# ##############################################################################
# # for each vs acc
# for k in results.keys():
#     x = stats.rankdata(results[k])
#     y = stats.rankdata(api_valid_accs)
#     kendalltau = stats.kendalltau(x, y)
#     spearmanr = stats.spearmanr(x, y)
#     pearsonr = stats.pearsonr(x, y)
#     print("{} vs. Acc: KT-{}\tPCC-{}\tSPR-{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
#     plt.figure(figsize=(4*fig_scale,3*fig_scale))
#     plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(results[k])
#     plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
#     plt.title("{} vs. Acc".format(k))
#     plt.show()
    
# # for each+params vs acc
# for k in results.keys():
#     l = len(results[k])
#     x = np.log(stats.rankdata(results[k])/l) + np.log(stats.rankdata(api_params)/l)
#     x = stats.rankdata(x)
#     y = stats.rankdata(api_valid_accs)
#     kendalltau = stats.kendalltau(x, y)
#     spearmanr = stats.spearmanr(x, y)
#     pearsonr = stats.pearsonr(x, y)
#     print("{}+Params vs. Acc: KT-{}\tPCC-{}\tSPR-{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
#     plt.figure(figsize=(4*fig_scale,3*fig_scale))
#     plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(results[k])
#     plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
#     plt.title("{}+Params vs. Acc".format(k))
#     plt.show()
    
# # for each+params vs acc
# for k in results.keys():
#     l = len(results[k])
#     x = np.log(stats.rankdata(results[k])/l) + np.log(stats.rankdata(api_flops)/l)
#     x = stats.rankdata(x)
#     y = stats.rankdata(api_valid_accs)
#     kendalltau = stats.kendalltau(x, y)
#     spearmanr = stats.spearmanr(x, y)
#     pearsonr = stats.pearsonr(x, y)
#     print("{}+FLOPs vs. Acc: KT-{}\tPCC-{}\tSPR-{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
#     plt.figure(figsize=(4*fig_scale,3*fig_scale))
#     plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(results[k])
#     plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
#     plt.title("{}+FLOPs vs. Acc".format(k))
#     plt.show()

# ##############################################################################
# # for each vs flops
# for k in results.keys():
#     x = stats.rankdata(results[k])
#     y = stats.rankdata(api_flops)
#     kendalltau = stats.kendalltau(x, y)
#     spearmanr = stats.spearmanr(x, y)
#     pearsonr = stats.pearsonr(x, y)
#     print("{} vs. FLOPs: KT-{}\tPCC-{}\tSPR-{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
#     plt.figure(figsize=(4*fig_scale,3*fig_scale))
#     plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(results[k])
#     plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
#     plt.title("{} vs. FLOPs".format(k))
#     plt.show()
    
# # for each+params vs flops
# for k in results.keys():
#     l = len(results[k])
#     x = np.log(stats.rankdata(results[k])/l) + np.log(stats.rankdata(api_params)/l)
#     x = stats.rankdata(x)
#     y = stats.rankdata(api_flops)
#     kendalltau = stats.kendalltau(x, y)
#     spearmanr = stats.spearmanr(x, y)
#     pearsonr = stats.pearsonr(x, y)
#     print("{}+Params vs. FLOPs: KT-{}\tPCC-{}\tSPR-{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
#     plt.figure(figsize=(4*fig_scale,3*fig_scale))
#     plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(results[k])
#     plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
#     plt.title("{}+Params vs. FLOPs".format(k))
#     plt.show()
    
# # for each+flops vs flops
# for k in results.keys():
#     l = len(results[k])
#     x = np.log(stats.rankdata(results[k])/l) + np.log(stats.rankdata(api_flops)/l)
#     x = stats.rankdata(x)
#     y = stats.rankdata(api_flops)
#     kendalltau = stats.kendalltau(x, y)
#     spearmanr = stats.spearmanr(x, y)
#     pearsonr = stats.pearsonr(x, y)
#     print("{}+FLOPs vs. FLOPs: KT-{}\tPCC-{}\tSPR-{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
#     plt.figure(figsize=(4*fig_scale,3*fig_scale))
#     plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(results[k])
#     plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
#     plt.title("{}+FLOPs vs. FLOPs".format(k))
#     plt.show()

# ##############################################################################
# # for each vs params
# for k in results.keys():
#     x = stats.rankdata(results[k])
#     y = stats.rankdata(api_params)
#     kendalltau = stats.kendalltau(x, y)
#     spearmanr = stats.spearmanr(x, y)
#     pearsonr = stats.pearsonr(x, y)
#     print("{} vs. Params: KT-{}\tPCC-{}\tSPR-{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
#     plt.figure(figsize=(4*fig_scale,3*fig_scale))
#     plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(results[k])
#     plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
#     plt.title("{} vs. Params".format(k))
#     plt.show()
    
# # for each+params vs params
# for k in results.keys():
#     l = len(results[k])
#     x = np.log(stats.rankdata(results[k])/l) + np.log(stats.rankdata(api_params)/l)
#     x = stats.rankdata(x)
#     y = stats.rankdata(api_params)
#     kendalltau = stats.kendalltau(x, y)
#     spearmanr = stats.spearmanr(x, y)
#     pearsonr = stats.pearsonr(x, y)
#     print("{}+Params vs. Params: KT-{}\tPCC-{}\tSPR-{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
#     plt.figure(figsize=(4*fig_scale,3*fig_scale))
#     plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(results[k])
#     plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
#     plt.title("{}+Params vs. Params".format(k))
#     plt.show()
    
# # for each+flops vs params
# for k in results.keys():
#     l = len(results[k])
#     x = np.log(stats.rankdata(results[k])/l) + np.log(stats.rankdata(api_flops)/l)
#     x = stats.rankdata(x)
#     y = stats.rankdata(api_params)
#     kendalltau = stats.kendalltau(x, y)
#     spearmanr = stats.spearmanr(x, y)
#     pearsonr = stats.pearsonr(x, y)
#     print("{}+FLOPs vs. Params: KT-{}\tPCC-{}\tSPR-{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
#     plt.figure(figsize=(4*fig_scale,3*fig_scale))
#     plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(results[k])
#     plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
#     plt.title("{}+FLOPs vs. Params".format(k))
#     plt.show()

# %%
fig_scale = 1.1
kk = 3

# for each
metrics = {'complexity':api_flops}
# metrics = {}
for k, v in results.items():
    metrics[k] = v

for k,v in metrics.items():
    print(k)
#     best_idx = np.argmax(v)
    best_idx = (-np.array(v)).argsort()[:kk]
    best_idx = best_idx[-1]

    best_arch, acc = archs[best_idx], api_valid_accs[best_idx]
    if api is not None:
        print("{:}".format(api.query_by_arch(best_arch, "200")))
        for key in metrics:
            print("top-% of {}: {}".format(key, (len(rank_agg) - stats.rankdata(metrics[key])[best_idx]) / len(rank_agg)))


for k in metrics.keys():
    x = stats.rankdata(metrics[k])
    y = stats.rankdata(api_valid_accs)
    kendalltau = stats.kendalltau(x, y)
    spearmanr = stats.spearmanr(x, y)
    pearsonr = stats.pearsonr(x, y)
    print("{}: {}\t{}\t{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
    plt.figure(figsize=(4*fig_scale,3*fig_scale))
    plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(metrics[k])
    best_idx = (-np.array(metrics[k])).argsort()[:kk]
    best_idx = best_idx[-1]
    plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
    plt.title("Rank_{}".format(k))
    plt.show()
    
    
# aggregate
if xargs.zero_shot_score.lower() == 'etf':
    rank_agg = None
    l = len(api_flops)
    rank_agg = np.log(stats.rankdata(api_flops) / l)
    for k in results.keys():
        print(k)
        if rank_agg is None:
            rank_agg = np.log( stats.rankdata(results[k]) / l)
        else:
            rank_agg = rank_agg + np.log( stats.rankdata(results[k]) / l)


#     best_idx = np.argmax(rank_agg)
    best_idx = (-rank_agg).argsort()[:kk]
    best_idx = best_idx[-1]

    best_arch, acc = archs[best_idx], api_valid_accs[best_idx]
    if api is not None:
        print("{:}".format(api.query_by_arch(best_arch, "200")))
        for key in metrics:
            print("top-% of {}: {}".format(key, (len(rank_agg) - stats.rankdata(metrics[key])[best_idx]) / len(rank_agg)))


    x = stats.rankdata(rank_agg)
    y = stats.rankdata(api_valid_accs)
    kendalltau = stats.kendalltau(x, y)
    spearmanr = stats.spearmanr(x, y)
    pearsonr = stats.pearsonr(x, y)
    print("aggregated: {}\t{}\t{}\t".format(kendalltau[0], pearsonr[0], spearmanr[0]))
    plt.figure(figsize=(4*fig_scale,3*fig_scale))
    plt.scatter(x, y, linewidths=0.1)
    plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
    plt.title("Rank_agg_etf")
    plt.show()
# Out:
# complexity
# |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=2954
# cifar10-valid  FLOP=157.21 M, Params=1.101 MB, latency=21.75 ms.
# cifar10-valid  train : [loss = 0.002 & top1 = 99.99%], valid : [loss = 0.497 & top1 = 89.94%]
# cifar10        FLOP=157.21 M, Params=1.101 MB, latency=21.75 ms.
# cifar10        train : [loss = 0.003 & top1 = 99.96%], test  : [loss = 0.315 & top1 = 93.34%]
# cifar100       FLOP=157.21 M, Params=1.107 MB, latency=22.06 ms.
# cifar100       train : [loss = 0.040 & top1 = 99.61%], valid : [loss = 1.318 & top1 = 70.35%], test : [loss = 1.345 & top1 = 70.52%]
# ImageNet16-120 FLOP= 39.31 M, Params=1.109 MB, latency=20.10 ms.
# ImageNet16-120 train : [loss = 1.815 & top1 = 51.81%], valid : [loss = 2.289 & top1 = 41.40%], test : [loss = 2.252 & top1 = 42.90%]
# top-% of complexity: 0.0019193857965451055
# top-% of expressivity: 0.04894433781190019
# top-% of progressivity: 0.1746641074856046
# top-% of trainability: 0.5547024952015355
# expressivity
# |none~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=2055
# cifar10-valid  FLOP= 47.10 M, Params=0.344 MB, latency=15.42 ms.
# cifar10-valid  train : [loss = 0.007 & top1 = 99.91%], valid : [loss = 0.514 & top1 = 88.65%]
# cifar10        FLOP= 47.10 M, Params=0.344 MB, latency=15.42 ms.
# cifar10        train : [loss = 0.013 & top1 = 99.74%], test  : [loss = 0.331 & top1 = 91.93%]
# cifar100       FLOP= 47.11 M, Params=0.350 MB, latency=15.04 ms.
# cifar100       train : [loss = 0.349 & top1 = 90.44%], valid : [loss = 1.277 & top1 = 67.17%], test : [loss = 1.306 & top1 = 66.99%]
# ImageNet16-120 FLOP= 11.78 M, Params=0.351 MB, latency=12.58 ms.
# ImageNet16-120 train : [loss = 2.140 & top1 = 44.41%], valid : [loss = 2.417 & top1 = 38.77%], test : [loss = 2.441 & top1 = 38.89%]
# top-% of complexity: 0.5738963531669866
# top-% of expressivity: 0.0019193857965451055
# top-% of progressivity: 0.0892514395393474
# top-% of trainability: 0.6170825335892515
# progressivity
# |nor_conv_1x1~0|+|none~0|none~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=2324
# cifar10-valid  FLOP= 51.04 M, Params=0.372 MB, latency=17.64 ms.
# cifar10-valid  train : [loss = 0.004 & top1 = 99.97%], valid : [loss = 0.441 & top1 = 89.92%]
# cifar10        FLOP= 51.04 M, Params=0.372 MB, latency=17.64 ms.
# cifar10        train : [loss = 0.008 & top1 = 99.87%], test  : [loss = 0.292 & top1 = 92.88%]
# cifar100       FLOP= 51.04 M, Params=0.378 MB, latency=16.82 ms.
# cifar100       train : [loss = 0.197 & top1 = 95.37%], valid : [loss = 1.252 & top1 = 69.43%], test : [loss = 1.256 & top1 = 69.31%]
# ImageNet16-120 FLOP= 12.77 M, Params=0.379 MB, latency=15.60 ms.
# ImageNet16-120 train : [loss = 1.831 & top1 = 51.43%], valid : [loss = 2.256 & top1 = 43.12%], test : [loss = 2.293 & top1 = 42.44%]
# top-% of complexity: 0.43378119001919385
# top-% of expressivity: 0.1890595009596929
# top-% of progressivity: 0.0019193857965451055
# top-% of trainability: 0.14395393474088292
# trainability
# |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=5635
# cifar10-valid  FLOP= 51.04 M, Params=0.372 MB, latency=17.96 ms.
# cifar10-valid  train : [loss = 0.004 & top1 = 99.95%], valid : [loss = 0.558 & top1 = 88.62%]
# cifar10        FLOP= 51.04 M, Params=0.372 MB, latency=17.96 ms.
# cifar10        train : [loss = 0.007 & top1 = 99.87%], test  : [loss = 0.369 & top1 = 91.96%]
# cifar100       FLOP= 51.04 M, Params=0.378 MB, latency=16.54 ms.
# cifar100       train : [loss = 0.163 & top1 = 96.57%], valid : [loss = 1.385 & top1 = 67.43%], test : [loss = 1.422 & top1 = 67.24%]
# ImageNet16-120 FLOP= 12.77 M, Params=0.379 MB, latency=15.89 ms.
# ImageNet16-120 train : [loss = 1.943 & top1 = 48.83%], valid : [loss = 2.427 & top1 = 39.44%], test : [loss = 2.454 & top1 = 39.59%]
# top-% of complexity: 0.43378119001919385
# top-% of expressivity: 0.45297504798464494
# top-% of progressivity: 0.29942418426103645
# top-% of trainability: 0.0019193857965451055
# complexity: 0.5020245107328081	0.6756210904177504	0.6756210904177503
# expressivity: 0.5274816823888762	0.7248062939500678	0.7248062939500677
# progressivity: 0.4977304324439072	0.6776981089731572	0.6776981089731572
# trainability: 0.3976251909712097	0.5595435922544738	0.5595435922544739
# expressivity
# progressivity
# trainability
# |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=8058
# cifar10-valid  FLOP=121.82 M, Params=0.858 MB, latency=21.34 ms.
# cifar10-valid  train : [loss = 0.002 & top1 = 99.97%], valid : [loss = 0.503 & top1 = 89.96%]
# cifar10        FLOP=121.82 M, Params=0.858 MB, latency=21.34 ms.
# cifar10        train : [loss = 0.003 & top1 = 99.96%], test  : [loss = 0.302 & top1 = 93.57%]
# cifar100       FLOP=121.82 M, Params=0.864 MB, latency=20.61 ms.
# cifar100       train : [loss = 0.065 & top1 = 99.09%], valid : [loss = 1.312 & top1 = 70.31%], test : [loss = 1.306 & top1 = 70.49%]
# ImageNet16-120 FLOP= 30.46 M, Params=0.866 MB, latency=22.67 ms.
# ImageNet16-120 train : [loss = 1.560 & top1 = 57.88%], valid : [loss = 2.158 & top1 = 44.84%], test : [loss = 2.163 & top1 = 45.83%]
# top-% of complexity: 0.019673704414587333
# top-% of expressivity: 0.07005758157389635
# top-% of progressivity: 0.08829174664107485
# top-% of trainability: 0.0345489443378119
# aggregated: 0.7145575468024875	0.8943891046679245	0.8943891046679244

# %%
fig_scale = 1.1
kk = 2

key1 = 'complexity'
key2 = 'expressivity'

rank_agg = stats.rankdata(metrics[key1]) + stats.rankdata(-np.array(metrics[key2]))


#     best_idx = np.argmax(rank_agg)
best_idx = (-rank_agg).argsort()[:kk]
best_idx = best_idx[-1]

best_arch, acc = archs[best_idx], api_valid_accs[best_idx]
if api is not None:
    print("{:}".format(api.query_by_arch(best_arch, "200")))


x = stats.rankdata(rank_agg)
y = stats.rankdata(api_valid_accs)
kendalltau = stats.kendalltau(x, y)
spearmanr = stats.spearmanr(x, y)
pearsonr = stats.pearsonr(x, y)
print("aggregated: {}\t{}\t{}\t".format(kendalltau[0], pearsonr[0], spearmanr[0]))
plt.figure(figsize=(4*fig_scale,3*fig_scale))
plt.scatter(x, y, linewidths=0.1)
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
plt.title("Rank_agg_etf")
plt.show()


print((len(rank_agg) - stats.rankdata(metrics[key1])[best_idx]) / len(rank_agg))
print((len(rank_agg) - stats.rankdata(metrics[key2])[best_idx]) / len(rank_agg))
# Out:
# |none~0|+|none~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|skip_connect~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=9437
# cifar10-valid  FLOP= 78.56 M, Params=0.559 MB, latency=15.95 ms.
# cifar10-valid  train : [loss = 2.302 & top1 = 10.29%], valid : [loss = 2.303 & top1 = 9.71%]
# cifar10        FLOP= 78.56 M, Params=0.559 MB, latency=15.95 ms.
# cifar10        train : [loss = 2.303 & top1 = 10.00%], test  : [loss = 2.303 & top1 = 10.00%]
# cifar100       FLOP= 78.57 M, Params=0.565 MB, latency=15.83 ms.
# cifar100       train : [loss = 4.605 & top1 = 1.00%], valid : [loss = 4.605 & top1 = 1.00%], test : [loss = 4.605 & top1 = 1.00%]
# ImageNet16-120 FLOP= 19.65 M, Params=0.567 MB, latency=14.82 ms.
# ImageNet16-120 train : [loss = 4.783 & top1 = 0.86%], valid : [loss = 4.792 & top1 = 0.83%], test : [loss = 4.792 & top1 = 0.83%]
# aggregated: -0.03403696729798561	-0.05652361549845596	-0.05652361549845596
# 0.29750479846449135
# 0.9779270633397313

# %%
rank_agg = None
l = len(api_flops)
rank_agg = np.log(stats.rankdata(api_flops) / l)
for k in results.keys():
    print(k)
    if rank_agg is None:
        rank_agg = np.log( stats.rankdata(results[k]) / l)
    else:
        rank_agg = rank_agg + np.log( stats.rankdata(results[k]) / l)


best_idx = (-np.array(results['expressivity'])).argsort()[:1]
best_idx = best_idx[-1]

best_arch, acc = archs[best_idx], api_valid_accs[best_idx]
if api is not None:
    print("{:}".format(api.query_by_arch(best_arch, "200")))


x = stats.rankdata(rank_agg)
y = stats.rankdata(api_valid_accs)
kendalltau = stats.kendalltau(x, y)
spearmanr = stats.spearmanr(x, y)
pearsonr = stats.pearsonr(x, y)
print("aggregated: {}\t{}\t{}\t".format(kendalltau[0], pearsonr[0], spearmanr[0]))
plt.figure(figsize=(4*fig_scale,3*fig_scale))
plt.scatter(x, y, linewidths=0.1)
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
plt.title("Rank_agg_etf")
plt.show()

# for each
metrics = {'complexity':api_flops}
# metrics = {}
for k, v in results.items():
    metrics[k] = v

for k,v in metrics.items():
    print(k)
#     best_idx = np.argmax(v)
#     best_idx = (-np.array(v)).argsort()[:kk]
#     best_idx = best_idx[-1]

    best_arch, acc = archs[best_idx], api_valid_accs[best_idx]
    if api is not None:
        print("{:}".format(api.query_by_arch(best_arch, "200")))


for k in metrics.keys():
    x = stats.rankdata(metrics[k])
    y = stats.rankdata(api_valid_accs)
    kendalltau = stats.kendalltau(x, y)
    spearmanr = stats.spearmanr(x, y)
    pearsonr = stats.pearsonr(x, y)
    print("{}: {}\t{}\t{}\t".format(k, kendalltau[0], pearsonr[0], spearmanr[0]))
    plt.figure(figsize=(4*fig_scale,3*fig_scale))
    plt.scatter(x, y, linewidths=0.1)
#     best_idx = np.argmax(metrics[k])
#     best_idx = (-np.array(metrics[k])).argsort()[:kk]
#     best_idx = best_idx[-1]
    plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=0.1)
    plt.title("Rank_{}".format(k))
    plt.show()
# Out:
# expressivity
# progressivity
# trainability
# |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|none~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=10108
# cifar10-valid  FLOP= 86.43 M, Params=0.615 MB, latency=20.76 ms.
# cifar10-valid  train : [loss = 0.007 & top1 = 99.91%], valid : [loss = 0.512 & top1 = 88.77%]
# cifar10        FLOP= 86.43 M, Params=0.615 MB, latency=20.76 ms.
# cifar10        train : [loss = 0.013 & top1 = 99.74%], test  : [loss = 0.327 & top1 = 91.94%]
# cifar100       FLOP= 86.43 M, Params=0.621 MB, latency=20.19 ms.
# cifar100       train : [loss = 0.338 & top1 = 90.80%], valid : [loss = 1.284 & top1 = 67.24%], test : [loss = 1.283 & top1 = 67.23%]
# ImageNet16-120 FLOP= 21.61 M, Params=0.623 MB, latency=23.98 ms.
# ImageNet16-120 train : [loss = 2.121 & top1 = 44.80%], valid : [loss = 2.409 & top1 = 39.18%], test : [loss = 2.412 & top1 = 39.03%]
# aggregated: 0.7145575468024875	0.8943891046679245	0.8943891046679244
# complexity
# |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|none~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=10108
# cifar10-valid  FLOP= 86.43 M, Params=0.615 MB, latency=20.76 ms.
# cifar10-valid  train : [loss = 0.007 & top1 = 99.91%], valid : [loss = 0.512 & top1 = 88.77%]
# cifar10        FLOP= 86.43 M, Params=0.615 MB, latency=20.76 ms.
# cifar10        train : [loss = 0.013 & top1 = 99.74%], test  : [loss = 0.327 & top1 = 91.94%]
# cifar100       FLOP= 86.43 M, Params=0.621 MB, latency=20.19 ms.
# cifar100       train : [loss = 0.338 & top1 = 90.80%], valid : [loss = 1.284 & top1 = 67.24%], test : [loss = 1.283 & top1 = 67.23%]
# ImageNet16-120 FLOP= 21.61 M, Params=0.623 MB, latency=23.98 ms.
# ImageNet16-120 train : [loss = 2.121 & top1 = 44.80%], valid : [loss = 2.409 & top1 = 39.18%], test : [loss = 2.412 & top1 = 39.03%]
# expressivity
# |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|none~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=10108
# cifar10-valid  FLOP= 86.43 M, Params=0.615 MB, latency=20.76 ms.
# cifar10-valid  train : [loss = 0.007 & top1 = 99.91%], valid : [loss = 0.512 & top1 = 88.77%]
# cifar10        FLOP= 86.43 M, Params=0.615 MB, latency=20.76 ms.
# cifar10        train : [loss = 0.013 & top1 = 99.74%], test  : [loss = 0.327 & top1 = 91.94%]
# cifar100       FLOP= 86.43 M, Params=0.621 MB, latency=20.19 ms.
# cifar100       train : [loss = 0.338 & top1 = 90.80%], valid : [loss = 1.284 & top1 = 67.24%], test : [loss = 1.283 & top1 = 67.23%]
# ImageNet16-120 FLOP= 21.61 M, Params=0.623 MB, latency=23.98 ms.
# ImageNet16-120 train : [loss = 2.121 & top1 = 44.80%], valid : [loss = 2.409 & top1 = 39.18%], test : [loss = 2.412 & top1 = 39.03%]
# progressivity
# |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|none~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=10108
# cifar10-valid  FLOP= 86.43 M, Params=0.615 MB, latency=20.76 ms.
# cifar10-valid  train : [loss = 0.007 & top1 = 99.91%], valid : [loss = 0.512 & top1 = 88.77%]
# cifar10        FLOP= 86.43 M, Params=0.615 MB, latency=20.76 ms.
# cifar10        train : [loss = 0.013 & top1 = 99.74%], test  : [loss = 0.327 & top1 = 91.94%]
# cifar100       FLOP= 86.43 M, Params=0.621 MB, latency=20.19 ms.
# cifar100       train : [loss = 0.338 & top1 = 90.80%], valid : [loss = 1.284 & top1 = 67.24%], test : [loss = 1.283 & top1 = 67.23%]
# ImageNet16-120 FLOP= 21.61 M, Params=0.623 MB, latency=23.98 ms.
# ImageNet16-120 train : [loss = 2.121 & top1 = 44.80%], valid : [loss = 2.409 & top1 = 39.18%], test : [loss = 2.412 & top1 = 39.03%]
# trainability
# |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|none~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=10108
# cifar10-valid  FLOP= 86.43 M, Params=0.615 MB, latency=20.76 ms.
# cifar10-valid  train : [loss = 0.007 & top1 = 99.91%], valid : [loss = 0.512 & top1 = 88.77%]
# cifar10        FLOP= 86.43 M, Params=0.615 MB, latency=20.76 ms.
# cifar10        train : [loss = 0.013 & top1 = 99.74%], test  : [loss = 0.327 & top1 = 91.94%]
# cifar100       FLOP= 86.43 M, Params=0.621 MB, latency=20.19 ms.
# cifar100       train : [loss = 0.338 & top1 = 90.80%], valid : [loss = 1.284 & top1 = 67.24%], test : [loss = 1.283 & top1 = 67.23%]
# ImageNet16-120 FLOP= 21.61 M, Params=0.623 MB, latency=23.98 ms.
# ImageNet16-120 train : [loss = 2.121 & top1 = 44.80%], valid : [loss = 2.409 & top1 = 39.18%], test : [loss = 2.412 & top1 = 39.03%]
# complexity: 0.5020245107328081	0.6756210904177504	0.6756210904177503
# expressivity: 0.5274816823888762	0.7248062939500678	0.7248062939500677
# progressivity: 0.4977304324439072	0.6776981089731572	0.6776981089731572
# trainability: 0.3976251909712097	0.5595435922544738	0.5595435922544739
