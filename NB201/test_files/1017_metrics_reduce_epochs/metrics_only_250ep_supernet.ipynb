# %%
import os, sys, time, glob, random, argparse
import numpy as np
from copy import deepcopy
import torch
import torch.nn as nn

# XAutoDL 
from xautodl.config_utils import load_config, dict2config, configure2str
from xautodl.datasets import get_datasets, get_nas_search_loaders
from xautodl.procedures import (
    prepare_seed,
    prepare_logger,
    save_checkpoint,
    copy_checkpoint,
    get_optim_scheduler,
)
from xautodl.utils import get_model_infos, obtain_accuracy
from xautodl.log_utils import AverageMeter, time_string, convert_secs2time
from xautodl.models import get_cell_based_tiny_net, get_search_spaces

# NB201
from nas_201_api import NASBench201API as API

import tqdm
# Out:
# 2022-10-12 16:59:43.209261: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
parser = argparse.ArgumentParser("Random search for NAS.")
parser.add_argument("--data_path", type=str, default='../cifar.python', help="The path to dataset")
parser.add_argument("--dataset", type=str, default='cifar10',choices=["cifar10", "cifar100", "ImageNet16-120"], help="Choose between Cifar10/100 and ImageNet-16.")

# channels and number-of-cells
parser.add_argument("--search_space_name", type=str, default='nas-bench-201', help="The search space name.")
parser.add_argument("--config_path", type=str, default='../configs/nas-benchmark/algos/RANDOM.config', help="The path to the configuration.")
# parser.add_argument("--config_path", type=str, default='./MY.config', help="The path to the configuration.")
parser.add_argument("--max_nodes", type=int, default=4, help="The maximum number of nodes.")
parser.add_argument("--channel", type=int, default=16, help="The number of channels.")
parser.add_argument("--num_cells", type=int, default=5, help="The number of cells in one stage.")
parser.add_argument("--select_num", type=int, default=100, help="The number of selected architectures to evaluate.")
parser.add_argument("--track_running_stats", type=int, default=0, choices=[0, 1], help="Whether use track_running_stats or not in the BN layer.")
# log
parser.add_argument("--workers", type=int, default=4, help="number of data loading workers")
parser.add_argument("--save_dir", type=str, default='./tmp/', help="Folder to save checkpoints and log.")
parser.add_argument("--arch_nas_dataset", type=str, default='../NAS-Bench-201-v1_1-096897.pth', help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--print_freq", type=int, default=200, help="print frequency (default: 200)")
parser.add_argument("--rand_seed", type=int, default=None, help="manual seed")
args = parser.parse_args(args=[])
if args.rand_seed is None or args.rand_seed < 0:
    args.rand_seed = random.randint(1, 100000)

    
print(args.rand_seed)
print(args)
xargs=args
# Out:
# 68469
# Namespace(arch_nas_dataset='../NAS-Bench-201-v1_1-096897.pth', channel=16, config_path='../configs/nas-benchmark/algos/RANDOM.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=200, rand_seed=68469, save_dir='./tmp/', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
assert torch.cuda.is_available(), "CUDA is not available."
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.set_num_threads(xargs.workers)
prepare_seed(xargs.rand_seed)
logger = prepare_logger(args)
# Out:
# Main Function with logger : Logger(dir=tmp, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : ../NAS-Bench-201-v1_1-096897.pth
# channel          : 16
# config_path      : ../configs/nas-benchmark/algos/RANDOM.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 200
# rand_seed        : 68469
# save_dir         : ./tmp/
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None

# %% [markdown]
# # Main

# %%
train_data, valid_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(xargs.config_path, {"class_num": class_num, "xshape": xshape}, logger)
search_loader, _, valid_loader = get_nas_search_loaders(train_data,
                                                        valid_data,
                                                        xargs.dataset,
                                                        "../configs/nas-benchmark/",
                                                        (config.batch_size, config.test_batch_size),
                                                        xargs.workers)
logger.log("||||||| {:10s} ||||||| Search-Loader-Num={:}, Valid-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(search_loader), len(valid_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": bool(xargs.track_running_stats),
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))
if xargs.arch_nas_dataset is None:
    api = None
else:
    api = API(xargs.arch_nas_dataset)
logger.log("{:} create API = {:} done".format(time_string(), api))

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)
network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

logger.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ../configs/nas-benchmark/algos/RANDOM.config
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Search-Loader-Num=391, Valid-Loader-Num=49, batch size=64
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.025
#     lr: 0.025
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=250, current::epoch=0, iter=0.00, type=cosine, T-max=250, eta-min=0.001)
# criterion   : CrossEntropyLoss()
# try to create the NAS-Bench-201 api from ../NAS-Bench-201-v1_1-096897.pth
# [2022-10-12 17:00:27] create API = NASBench201API(15625/15625 architectures, file=NAS-Bench-201-v1_1-096897.pth) done

# %%
# 250 ep weights
network_dict = torch.load("./250ep_supernet_weights.pth")
network.load_state_dict(network_dict)

# network_dict = torch.load("../results/three_metrics/test/checkpoint/seed-68228-basic.pth")['search_model']
# search_model.load_state_dict(network_dict)
# Out:
# <All keys matched successfully>

# %%
def valid_acc_metric(network, inputs, targets):
    with torch.no_grad():
        network.eval()
        _, logits = network(inputs)
        val_top1, val_top5 = obtain_accuracy(
            logits.data, targets.data, topk=(1, 5)
        )
    return val_top1.item()

def acc_confidence_robustness_metrics(network, inputs, targets):
    with torch.no_grad():
        network.eval()
        # accuracy
        _, logits = network(inputs)
        val_top1, val_top5 = obtain_accuracy(logits.data, targets.data, topk=(1, 5))
        acc = val_top1
        # confidence
        prob = torch.nn.functional.softmax(logits, dim=1)
        one_hot_idx = torch.nn.functional.one_hot(targets)
        confidence = (prob[one_hot_idx==1].sum()) / inputs.size(0) * 100 # in percent
        # robustness
        _, noisy_logits = network(inputs + torch.randn_like(inputs)*0.1)
        kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
        robustness = -kl_loss(torch.nn.functional.log_softmax(noisy_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
        
        return acc.item(), confidence.item(), robustness.item()
    
def step_sim_metric(network, criterion, inputs, targets):
    original_dict = deepcopy(network.state_dict())
    optim_large_step = torch.optim.SGD(network.parameters(), lr=0.1)
    
    # single large step
    network.train()
    optim_large_step.zero_grad()
    _, logits = network(inputs)
    base_loss = criterion(logits, targets)
    base_loss.backward()
    optim_large_step.step()
    large_step_dict = deepcopy(network.state_dict())
    
    # multiple small steps
    network.load_state_dict(original_dict)
    optim_small_step = torch.optim.SGD(network.parameters(), lr=0.01)
    for i in range(10):
        optim_small_step.zero_grad()
        _, logits = network(inputs)
        base_loss = criterion(logits, targets)
        base_loss.backward()
        optim_small_step.step()
    small_step_dict = deepcopy(network.state_dict())
    
    # resume
    network.load_state_dict(original_dict)
    network.eval()
    
    for key in large_step_dict.keys():
#         if 'classifier' in key:
#             large_step = large_step_dict[key] - original_dict[key]
#             small_step = small_step_dict[key] - original_dict[key]
#             score = torch.nn.functional.cosine_similarity(large_step, small_step, dim=1)
#             score = score.mean().item() * 100 # in percent
#             break
        if 'stem.0.weight' in key:
            large_step = large_step_dict[key] - original_dict[key]
            small_step = small_step_dict[key] - original_dict[key]
            co, ci, kh, kw = large_step.size()
            large_step = large_step.view(co, -1)
            small_step = small_step.view(co, -1)
            score = torch.nn.functional.cosine_similarity(large_step, small_step, dim=1)
            score = score.mean().item() * 100 # in percent
            break
            
    return score
    

def search_find_best_my(xloader, network, criterion, n_samples):
    archs, metric_accs, metric_steps, metric_confidences, metric_robustnesses = [], [], [], [], []
    loader_iter = iter(xloader)
    for i in tqdm.tqdm(range(n_samples)):
        arch = network.module.random_genotype(True)
        try:
            inputs, targets = next(loader_iter)
        except:
            loader_iter = iter(xloader)
            inputs, targets = next(loader_iter)
        inputs, targets = inputs.cuda(non_blocking=True), targets.cuda(non_blocking=True)
#         valid_acc = valid_acc_metric(network, inputs, targets)
        valid_acc, confidence, robustness = acc_confidence_robustness_metrics(network, inputs, targets)
        step_sim = step_sim_metric(network, criterion, inputs, targets)

        archs.append(arch)
        metric_accs.append(valid_acc)
        metric_steps.append(step_sim)
        metric_confidences.append(confidence)
        metric_robustnesses.append(robustness)

    return archs, metric_accs, metric_steps, metric_confidences, metric_robustnesses

    
archs, metric_accs, metric_steps, metric_confidences, metric_robustnesses = search_find_best_my(valid_loader, network, criterion, 250)
# Out:
# 100%|██████████| 250/250 [07:35<00:00,  1.82s/it]

# %%
import scipy.stats as stats
rank_accs, rank_steps, rank_confidences, rank_robustnesses = stats.rankdata(metric_accs), stats.rankdata(metric_steps), stats.rankdata(metric_confidences), stats.rankdata(metric_robustnesses)
rank_agg = rank_accs+rank_steps+rank_confidences-rank_robustnesses
rank_agg = rank_accs+rank_confidences-rank_robustnesses
best_idx = np.argmax(rank_agg)


best_arch, best_acc, best_step, best_conf, best_robust = archs[best_idx], metric_accs[best_idx], metric_steps[best_idx], metric_confidences[best_idx], metric_robustnesses[best_idx]
# log
print("RANDOM-NAS finds the best one : {:} with accuracy={:.2f}%, step_sim={:.2f}%, confidence={:.3f}%, robustness={:.3f}".format(best_arch, best_acc, best_step, best_conf, best_robust))
if api is not None:
    print("{:}".format(api.query_by_arch(best_arch, "200")))
# Out:
# RANDOM-NAS finds the best one : Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|) with accuracy=60.16%, step_sim=73.68%, confidence=48.421%, robustness=-0.037
# Call query_info_str_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|) and hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=8590
# cifar10-valid  FLOP=117.88 M, Params=0.830 MB, latency=19.78 ms.
# cifar10-valid  train : [loss = 0.002, top1 = 99.98%], valid : [loss = 0.529, top1 = 89.72%]
# cifar10        FLOP=117.88 M, Params=0.830 MB, latency=19.78 ms.
# cifar10        train : [loss = 0.003, top1 = 99.94%], test  : [loss = 0.334, top1 = 93.15%]
# cifar100       FLOP=117.89 M, Params=0.836 MB, latency=17.61 ms.
# cifar100       train : [loss = 0.070, top1 = 98.87%], valid : [loss = 1.357, top1 = 69.66%], test : [loss = 1.367, top1 = 69.65%]
# ImageNet16-120 FLOP= 29.48 M, Params=0.838 MB, latency=19.66 ms.
# ImageNet16-120 train : [loss = 1.661, top1 = 55.46%], valid : [loss = 2.192, top1 = 44.22%], test : [loss = 2.232, top1 = 43.85%]

# %%
def get_valid_acc_from_api(api, arch):
    # print(api.query_by_arch(arch, "200"))
    index = api.query_index_by_arch(arch)
    results = api.query_by_index(index, 'cifar10-valid', '200') # a dict of all trials for 1st net on cifar100, where the key is the seed
    acc = 0
    for seed, result in results.items():
        acc = acc + result.get_eval('valid')['accuracy']
    acc = acc / len(results)
    return acc

api_valid_accs = [get_valid_acc_from_api(api, a) for a in archs]
# Out:
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=14351, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14351, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=15280, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15280, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=15172, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15172, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=9085, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9085, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=11190, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11190, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=4903, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4903, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=12875, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12875, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=10535, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10535, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|none~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=14675, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14675, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=10554, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10554, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10756, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10756, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=10514, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10514, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=6804, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6804, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|none~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=8675, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8675, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|skip_connect~1|+|none~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=7676, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7676, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=921, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=921, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=7537, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7537, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13706, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13706, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=9226, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9226, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=14468, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14468, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=14577, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14577, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=5960, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5960, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9493, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9493, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=13179, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13179, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2392, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2392, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5701, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5701, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=442, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=442, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3787, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3787, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9048, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9048, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=14038, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14038, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=3189, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3189, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=1331, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1331, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8009, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8009, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=13357, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13357, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=6193, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6193, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=8018, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8018, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8016, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8016, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13638, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13638, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=305, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=305, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1574, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1574, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1807, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1807, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10288, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10288, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5488, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5488, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=10578, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10578, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12778, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12778, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=4149, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4149, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=1515, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1515, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10202, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10202, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6864, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6864, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2261, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2261, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=790, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=790, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12342, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12342, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=13509, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13509, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1556, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1556, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5292, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5292, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=1857, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1857, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3349, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3349, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14039, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14039, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13776, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13776, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13336, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13336, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3137, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3137, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8817, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8817, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=14642, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14642, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=5371, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5371, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=4528, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4528, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=14464, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14464, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=313, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=313, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2434, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2434, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=4263, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4263, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12125, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12125, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6262, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6262, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=1257, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1257, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=6560, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6560, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=8040, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8040, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=4137, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4137, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=11112, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11112, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=4680, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4680, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2682, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2682, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7077, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7077, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=777, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=777, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12698, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12698, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|none~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=4333, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4333, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=6370, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6370, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=3642, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3642, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=2964, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2964, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|none~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=14030, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14030, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=6542, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6542, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=14783, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14783, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|none~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7283, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7283, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10789, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10789, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=14505, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14505, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6546, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6546, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5567, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5567, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=5263, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5263, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9451, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9451, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=3802, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3802, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7881, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7881, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=1331, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1331, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7229, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7229, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=11256, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11256, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=9787, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9787, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=15028, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15028, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=920, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=920, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|none~1|+|nor_conv_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=9824, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9824, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8471, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8471, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14430, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14430, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1686, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1686, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8849, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8849, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11829, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11829, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=14378, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14378, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2970, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2970, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12884, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12884, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=13971, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13971, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13396, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13396, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=4557, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4557, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=4631, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4631, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=5415, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5415, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=14250, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14250, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=12579, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12579, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=7963, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7963, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3057, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3057, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12769, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12769, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8131, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8131, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=3260, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3260, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=563, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=563, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=9846, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9846, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3551, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3551, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|none~1|none~2|)
# Call query_by_index with arch_index=4862, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4862, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=15181, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15181, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=8881, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8881, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|none~2|)
# Call query_by_index with arch_index=11581, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11581, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|none~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7142, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7142, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13524, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13524, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=3463, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3463, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=5225, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5225, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=9260, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9260, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2329, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2329, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=7867, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7867, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|none~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13120, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13120, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=6771, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6771, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=3870, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3870, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5521, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5521, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=10278, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10278, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=12968, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12968, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=9677, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9677, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=11628, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11628, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=8582, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8582, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2096, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2096, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=5158, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5158, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7535, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7535, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=14944, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14944, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|skip_connect~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=1104, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1104, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|none~1|none~2|)
# Call query_by_index with arch_index=2565, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2565, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=14631, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14631, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13230, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13230, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=9670, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9670, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7889, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7889, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=8497, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8497, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=10215, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10215, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=9069, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9069, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=4055, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4055, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=11864, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11864, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=10413, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10413, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1916, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1916, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10213, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10213, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4563, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4563, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12625, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12625, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5516, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5516, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2930, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2930, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6434, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6434, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=7300, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7300, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=2793, dataname=cifar10-valid, hp=200
# ...
# Call query_meta_info_by_index with arch_index=2510, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=140, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=140, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11753, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11753, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9667, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9667, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3363, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3363, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13625, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13625, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10306, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10306, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13986, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13986, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=11389, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11389, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=2611, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2611, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=11136, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11136, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|none~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=816, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=816, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=11410, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11410, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5673, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5673, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=9866, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9866, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2848, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2848, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=5013, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5013, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=769, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=769, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=9116, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9116, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=7583, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7583, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14032, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14032, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|none~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=2578, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2578, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7945, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7945, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|none~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=15335, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15335, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=9054, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9054, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13100, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13100, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=3729, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3729, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=2104, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2104, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10850, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10850, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=4102, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4102, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=15464, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15464, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=3879, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3879, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=8590, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8590, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=4329, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4329, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|none~1|none~2|)
# Call query_by_index with arch_index=6448, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6448, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10355, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10355, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4828, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4828, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=7892, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7892, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8682, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8682, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3485, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3485, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=2481, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2481, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=3560, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3560, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8742, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8742, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=3869, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3869, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12159, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12159, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=5640, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5640, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12461, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12461, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=700, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=700, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12023, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12023, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=139, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=139, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=14523, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14523, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=8788, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8788, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=156, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=156, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2957, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2957, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=15022, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15022, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1958, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1958, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14762, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14762, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6353, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6353, hp=200

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

x = stats.rankdata(metric_accs)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(metric_steps)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(metric_confidences)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(metric_robustnesses)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(rank_agg)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)
# Out:
# 0.5482783245585516 6.256539155125381e-38
# 0.2014881094131254 2.0976239798945065e-06
# 0.517896157573573 3.2179832439311253e-34
# -0.5671814750061291 1.1289878630147562e-40
# 0.6108352634325391 6.87468798690986e-47

# %%
for i in range(100):
    print(metric_robustnesses[i])
    print(api_valid_accs[i])
    print("\n\n")
# Out:
# -0.001906641642563045
# 80.90399998046875
#
#
#
# -0.026249829679727554
# 87.38666666503906
#
#
#
# -0.019661961123347282
# 87.00400000976562
#
#
#
# -0.007951337844133377
# 83.56400001098632
#
#
#
# -0.012038255110383034
# 88.732
#
#
#
# -0.025033865123987198
# 85.99800000732422
#
#
#
# -0.022478267550468445
# 87.86533332763672
#
#
#
# -0.009542634710669518
# 86.27066667317708
#
#
#
# -0.008005068637430668
# 85.9679999975586
#
#
#
# -0.017294108867645264
# 89.01599998128255
#
#
#
# -0.029859591275453568
# 85.72599999877929
#
#
#
# -0.025877607986330986
# 89.1319999934896
#
#
#
# -0.03525691479444504
# 90.81599997070313
#
#
#
# -0.038931041955947876
# 87.52200000488281
#
#
#
# -0.01445743814110756
# 88.72599998168945
#
#
#
# -0.030319994315505028
# 89.53599999267578
#
#
#
# -0.020330240949988365
# 87.2173333211263
#
#
#
# -0.03612416237592697
# 88.48933333170572
#
#
#
# -0.0038140369579195976
# 77.66399997558594
#
#
#
# -0.03381376713514328
# 89.26666666259764
#
#
#
# -2.8937831302755512e-05
# 72.26000001342774
#
#
#
# -0.02253459393978119
# 87.53066666178385
#
#
#
# -0.03471370041370392
# 91.00799998168947
#
#
#
# 8.94562930398024e-08
# 9.711999999186197
#
#
#
# -0.03196306154131889
# 88.24399998779296
#
#
#
# -0.01114894449710846
# 87.99799999023438
#
#
#
# -2.9059548978693783e-05
# 71.78266666503906
#
#
#
# -0.023396756500005722
# 89.45866666829427
#
#
#
# -0.02422158233821392
# 89.86599998291015
#
#
#
# -3.2440821087220684e-05
# 71.53866666910808
#
#
#
# -0.02030538208782673
# 86.51200000813803
#
#
#
# -0.010612801648676395
# 85.56666664550782
#
#
#
# -0.012436697259545326
# 83.60666666178385
#
#
#
# -0.022037528455257416
# 86.20999998779297
#
#
#
# -0.024060215801000595
# 88.73799999633789
#
#
#
# -0.016050677746534348
# 86.80133334309896
#
#
#
# -0.01808862015604973
# 84.61000001098633
#
#
#
# -0.01064701285213232
# 80.86399998535157
#
#
#
# -0.0005948321195319295
# 77.34800001586913
#
#
#
# -4.999206430511549e-05
# 84.3306666829427
#
#
#
# -0.02979975938796997
# 87.34533334309896
#
#
#
# -0.004148013889789581
# 85.98000000854492
#
#
#
# -0.01934492588043213
# 88.70799998860677
#
#
#
# -0.035155415534973145
# 89.54399999511719
#
#
#
# -0.011178417131304741
# 89.368
#
#
#
# -0.016626344993710518
# 87.09599999511718
#
#
#
# -0.005058371461927891
# 84.41199998616537
#
#
#
# -0.02860802598297596
# 85.47400001464842
#
#
#
# -0.025027882307767868
# 89.7319999987793
#
#
#
# -0.03306207060813904
# 87.36799999348959
#
#
#
# -0.032042086124420166
# 88.73999999104818
#
#
#
# -0.019688483327627182
# 87.87999999511719
#
#
#
# -0.02458818443119526
# 87.55599999023438
#
#
#
# -0.032382782548666
# 91.13199998209636
#
#
#
# -0.04270622134208679
# 91.42266665120444
#
#
#
# -0.0038884759414941072
# 76.02799999023438
#
#
#
# -3.0104622055660002e-05
# 72.42200000244141
#
#
#
# -0.025403300300240517
# 89.9559999951172
#
#
#
# -0.010994852520525455
# 85.856000004069
#
#
#
# -0.0345856212079525
# 89.52400001098633
#
#
#
# -0.023728713393211365
# 88.33466666422527
#
#
#
# -0.01429613959044218
# 88.63399998901367
#
#
#
# -0.01746552810072899
# 83.01999998046875
#
#
#
# -0.025909598916769028
# 87.38399999633789
#
#
#
# -0.012305047363042831
# 85.95199997070313
#
#
#
# -0.008821586146950722
# 87.12266665934244
#
#
#
# -2.615481207612902e-05
# 71.94399999389648
#
#
#
# -0.0007507963455282152
# 65.94266666178386
#
#
#
# -0.055117715150117874
# 87.35200000732422
#
#
#
# -0.022773198783397675
# 89.53399999633788
#
#
#
# -0.026189632713794708
# 89.55733332682291
#
#
#
# -0.014217119663953781
# 85.46133333251953
#
#
#
# -2.685083200049121e-05
# 71.08533334716797
#
#
#
# -0.004025055095553398
# 75.37599998942058
#
#
#
# -0.03155756741762161
# 89.01999999267578
#
#
#
# -0.030869197100400925
# 88.40533333902995
#
#
#
# -0.02748188003897667
# 89.04666666097005
#
#
#
# -0.012468677014112473
# 87.18666666829427
#
#
#
# -0.010038545355200768
# 87.77333333170573
#
#
#
# -4.815491411136463e-05
# 84.51000001464844
#
#
#
# -0.027552226558327675
# 88.90400001708984
#
#
#
# -0.00428309990093112
# 79.72133332763673
#
#
#
# -0.0005907207378186285
# 76.76266665120443
#
#
#
# -0.025382861495018005
# 89.46533332763671
#
#
#
# -0.004276648163795471
# 81.07799999267579
#
#
#
# -7.638812530785799e-05
# 58.20399999572754
#
#
#
# -0.026474928483366966
# 87.67066665852865
#
#
#
# -0.000581202213652432
# 70.89066665771485
#
#
#
# -0.019783589988946915
# 84.7453333194987
#
#
#
# -0.02502344362437725
# 86.26600000976563
#
#
#
# -0.020144090056419373
# 85.34933334228515
#
#
#
# -0.04122532159090042
# 89.02800000732422
#
#
#
# -0.02840711548924446
# 88.38266665364584
#
#
#
# -0.020049571990966797
# 88.52199998657227
#
#
#
# -0.04359791800379753
# 89.90199999755859
#
#
#
# -0.030177969485521317
# 88.93999998535156
#
#
#
# -0.0016176755307242274
# 68.98400000122069
#
#
#
# -0.010318986140191555
# 85.56666664550782
#
#
#
# -0.012264476157724857
# 85.4500000073242
#
#
#
# -0.013452399522066116
# 85.46400001220704
