# %%
import os, sys, time, glob, random, argparse
import numpy as np
from copy import deepcopy
import torch
import torch.nn as nn

# XAutoDL 
from xautodl.config_utils import load_config, dict2config, configure2str
from xautodl.datasets import get_datasets, get_nas_search_loaders
from xautodl.procedures import (
    prepare_seed,
    prepare_logger,
    save_checkpoint,
    copy_checkpoint,
    get_optim_scheduler,
)
from xautodl.utils import get_model_infos, obtain_accuracy
from xautodl.log_utils import AverageMeter, time_string, convert_secs2time
from xautodl.models import get_cell_based_tiny_net, get_search_spaces

# NB201
from nas_201_api import NASBench201API as API

import torchvision.transforms as transforms
from PIL import Image

import tqdm

from xautodl.models.cell_searchs.search_cells import NAS201SearchCell
# Out:
# 2022-11-04 05:17:29.806179: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
parser = argparse.ArgumentParser("Random search for NAS.")
parser.add_argument("--data_path", type=str, default='../cifar.python', help="The path to dataset")
parser.add_argument("--dataset", type=str, default='cifar10',choices=["cifar10", "cifar100", "ImageNet16-120"], help="Choose between Cifar10/100 and ImageNet-16.")

# channels and number-of-cells
parser.add_argument("--search_space_name", type=str, default='nas-bench-201', help="The search space name.")
parser.add_argument("--config_path", type=str, default='../configs/nas-benchmark/algos/RANDOM.config', help="The path to the configuration.")
# parser.add_argument("--config_path", type=str, default='./MY.config', help="The path to the configuration.")
parser.add_argument("--max_nodes", type=int, default=4, help="The maximum number of nodes.")
parser.add_argument("--channel", type=int, default=16, help="The number of channels.")
parser.add_argument("--num_cells", type=int, default=5, help="The number of cells in one stage.")
parser.add_argument("--select_num", type=int, default=100, help="The number of selected architectures to evaluate.")
parser.add_argument("--track_running_stats", type=int, default=0, choices=[0, 1], help="Whether use track_running_stats or not in the BN layer.")
# log
parser.add_argument("--workers", type=int, default=4, help="number of data loading workers")
parser.add_argument("--save_dir", type=str, default='./tmp/', help="Folder to save checkpoints and log.")
parser.add_argument("--arch_nas_dataset", type=str, default='../NAS-Bench-201-v1_1-096897.pth', help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--print_freq", type=int, default=200, help="print frequency (default: 200)")
parser.add_argument("--rand_seed", type=int, default=None, help="manual seed")
args = parser.parse_args(args=[])
if args.rand_seed is None or args.rand_seed < 0:
    args.rand_seed = random.randint(1, 100000)

    
print(args.rand_seed)
print(args)
xargs=args
# Out:
# 50480
# Namespace(arch_nas_dataset='../NAS-Bench-201-v1_1-096897.pth', channel=16, config_path='../configs/nas-benchmark/algos/RANDOM.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=200, rand_seed=50480, save_dir='./tmp/', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
assert torch.cuda.is_available(), "CUDA is not available."
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.set_num_threads(xargs.workers)
prepare_seed(xargs.rand_seed)
logger = prepare_logger(args)
# Out:
# Main Function with logger : Logger(dir=tmp, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : ../NAS-Bench-201-v1_1-096897.pth
# channel          : 16
# config_path      : ../configs/nas-benchmark/algos/RANDOM.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 200
# rand_seed        : 50480
# save_dir         : ./tmp/
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None

# %% [markdown]
# # Main

# %%
train_data, valid_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(xargs.config_path, {"class_num": class_num, "xshape": xshape}, logger)
search_loader, _, valid_loader = get_nas_search_loaders(train_data,
                                                        valid_data,
                                                        xargs.dataset,
                                                        "../configs/nas-benchmark/",
                                                        (config.batch_size, config.test_batch_size),
                                                        xargs.workers)
logger.log("||||||| {:10s} ||||||| Search-Loader-Num={:}, Valid-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(search_loader), len(valid_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": bool(xargs.track_running_stats),
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))
if xargs.arch_nas_dataset is None:
    api = None
else:
    api = API(xargs.arch_nas_dataset)
logger.log("{:} create API = {:} done".format(time_string(), api))

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)
network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

logger.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ../configs/nas-benchmark/algos/RANDOM.config
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Search-Loader-Num=391, Valid-Loader-Num=49, batch size=64
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.025
#     lr: 0.025
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=250, current::epoch=0, iter=0.00, type=cosine, T-max=250, eta-min=0.001)
# criterion   : CrossEntropyLoss()
# try to create the NAS-Bench-201 api from ../NAS-Bench-201-v1_1-096897.pth
# [2022-11-04 05:17:59] create API = NASBench201API(15625/15625 architectures, file=NAS-Bench-201-v1_1-096897.pth) done

# %%
for layer in search_model.modules():
    if hasattr(layer, 'reset_parameters'):
        layer.reset_parameters()


# network_dict = torch.load("./25ep_step_supernet_weights.pth")
# network_dict = torch.load("./250ep_supernet_weights.pth")
network_dict = torch.load("./25ep_cosine_supernet_weights.pth")
network.load_state_dict(network_dict,strict=False)


# network_dict = torch.load("../1020_cell_wise_random_supernet_train/cell_wise_25ep_step.pth")
# network_dict = torch.load("../1020_cell_wise_random_supernet_train/cell_wise_250ep_cosine.pth")
# network_dict = torch.load("./25ep_cosine_supernet_weights.pth")
# search_model.load_state_dict(network_dict)
# Out:
# <All keys matched successfully>

# %%
mean = [x / 255 for x in [125.3, 123.0, 113.9]]
std = [x / 255 for x in [63.0, 62.1, 66.7]]
inv_normalize = transforms.Normalize(
   mean= [-m/s for m, s in zip(mean, std)],
   std= [1/s for s in std]
)
t_list = [inv_normalize,
          transforms.ColorJitter(0.2, 0.2, 0.2, 0.2),
#           transforms.RandomHorizontalFlip(p=1),
          transforms.RandomAffine(
            degrees=0, translate=(0.1, 0.1),
            scale=(0.9, 1.1), shear=0),
          transforms.Normalize(mean, std),]
random_transform = transforms.Compose(t_list)

def acc_confidence_robustness_metrics(network, inputs, targets):
    with torch.no_grad():
        # accuracy
        network.train()
        _, logits = network(inputs)
        val_top1, val_top5 = obtain_accuracy(logits.data, targets.data, topk=(1, 5))
        acc = val_top1
        # confidence
        prob = torch.nn.functional.softmax(logits, dim=1)
        ###
        one_hot_idx = torch.nn.functional.one_hot(targets)
        confidence = (prob[one_hot_idx==1].sum()) / inputs.size(0) * 100 # in percent
        ###
#         confidence = prob.max(dim=1)[0].sum() / inputs.size(0) * 100 # in percent
        ###
        # sensitivity
        _, noisy_logits = network(inputs + torch.randn_like(inputs)*0.1)
        kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
        sensitivity = kl_loss(torch.nn.functional.log_softmax(noisy_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
        
        # robustness
        original_weights = deepcopy(network.state_dict())
        for m in network.modules():
            if isinstance(m, NAS201SearchCell):
                for p in m.parameters():
                    p.add_(torch.randn_like(p) * p.std()*0.3)
#         for p in network.parameters():
#             p.add_(torch.randn_like(p) * p.std() * 0.3)
            
        _, noisy_logits = network(inputs)
        kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
        robustness = -kl_loss(torch.nn.functional.log_softmax(noisy_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
        network.load_state_dict(original_weights)
        
        
#         inputs_transform = random_transform(inputs)
#         import matplotlib.pyplot as plt
#         tmp = inputs[0].permute(1,2,0).cpu().numpy()
#         print(tmp.min(), tmp.max())
#         plt.imshow(tmp)
#         plt.show()
#         tmp = inputs_transform[0].permute(1,2,0).cpu().numpy()
#         print(tmp.min(), tmp.max())
#         plt.imshow(tmp)
#         plt.show()
#         asd
#         _, transformed_logits = network(inputs_transform)
#         kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
#         generalization = -kl_loss(torch.nn.functional.log_softmax(transformed_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
        
        return acc.item(), confidence.item(), sensitivity.item(), robustness.item()
    
def step_sim_metric(network, criterion, inputs, targets):
    original_dict = deepcopy(network.state_dict())
    optim_large_step = torch.optim.SGD(network.parameters(), lr=0.025)
    
    # single large step
    network.train()
    optim_large_step.zero_grad()
    _, logits = network(inputs)
    base_loss = criterion(logits, targets)
    base_loss.backward()
    optim_large_step.step()
#     _, logits_large_step = network(inputs)
    large_step_dict = deepcopy(network.state_dict())
    
    # multiple small steps
    network.load_state_dict(original_dict)
    optim_small_step = torch.optim.SGD(network.parameters(), lr=0.025/3)
    for i in range(3):
        optim_small_step.zero_grad()
        _, logits = network(inputs)
        base_loss = criterion(logits, targets)
        base_loss.backward()
        optim_small_step.step()
#     _, logits_small_step = network(inputs)
    small_step_dict = deepcopy(network.state_dict())
    ####
#     kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
#     step_sim = -kl_loss(torch.nn.functional.log_softmax(logits_small_step, dim=1), torch.nn.functional.softmax(logits_large_step, dim=1))
#     step_sim = step_sim.item()
    ###
    scores = []
    for key in large_step_dict.keys():
        if ('weight' in key) and (original_dict[key].dim()==4):
            if (original_dict[key] != large_step_dict[key]).sum():
                large_step = large_step_dict[key] - original_dict[key]
                small_step = small_step_dict[key] - original_dict[key]
                co, ci, kh, kw = large_step.size()
                large_step = large_step.view(co, -1)
                small_step = small_step.view(co, -1)
                score = torch.nn.functional.cosine_similarity(large_step, small_step, dim=1)
                score = score.mean().item() * 100 # in percent
                scores.append(score)
    if len(scores)==0:
        step_sim = 0
    else:
        step_sim = np.mean(scores)
    
    # resume
    network.load_state_dict(original_dict)
            
    return step_sim

def search_find_best_my(xloader, network, criterion, n_samples):
    archs, metric_accs, metric_confidences, metric_sensitivities, metric_robustnesses, metric_step_sims = [], [], [], [], [], []
    loader_iter = iter(xloader)
    for i in tqdm.tqdm(range(n_samples)):
        arch = network.module.random_genotype(True)
        try:
            inputs, targets = next(loader_iter)
        except:
            loader_iter = iter(xloader)
            inputs, targets = next(loader_iter)
        inputs, targets = inputs.cuda(non_blocking=True), targets.cuda(non_blocking=True)
        valid_acc, confidence, sensitivity, robustness = acc_confidence_robustness_metrics(network, inputs, targets)
        step_sim = step_sim_metric(network, criterion, inputs, targets)

        archs.append(arch)
        metric_accs.append(valid_acc)
        metric_confidences.append(confidence)
        metric_sensitivities.append(sensitivity)
        metric_robustnesses.append(robustness)
        metric_step_sims.append(step_sim)

    return archs, metric_accs, metric_confidences, metric_sensitivities, metric_robustnesses, metric_step_sims
    # fittedness / confidence / responsiveness / (negative) over-fittedness / linearness

    
archs, metric_accs, metric_confidences, metric_sensitivities, metric_robustnesses, metric_step_sims = search_find_best_my(valid_loader, network, criterion, 1000)
# Out:
# 100%|██████████| 1000/1000 [19:20<00:00,  1.16s/it]

# %%
# ###full search
# from xautodl.models.cell_searchs.genotypes import Structure

# def search_find_best_my(xloader, network, criterion, all_archs):
#     archs, metric_accs, metric_confidences, metric_sensitivities, metric_robustnesses, metric_step_sims = [], [], [], [], [], []
#     loader_iter = iter(xloader)
#     n_samples = len(all_archs)
#     for i in tqdm.tqdm(range(n_samples)):
#         arch = Structure.str2structure(all_archs[i])
#         network.arch_cache = arch
#         try:
#             inputs, targets = next(loader_iter)
#         except:
#             loader_iter = iter(xloader)
#             inputs, targets = next(loader_iter)
#         inputs, targets = inputs.cuda(non_blocking=True), targets.cuda(non_blocking=True)
#         valid_acc, confidence, sensitivity, robustness = acc_confidence_robustness_metrics(network, inputs, targets)
#         step_sim = step_sim_metric(network, criterion, inputs, targets)

#         archs.append(arch)
#         metric_accs.append(valid_acc)
#         metric_confidences.append(confidence)
#         metric_sensitivities.append(sensitivity)
#         metric_robustnesses.append(robustness)
#         metric_step_sims.append(step_sim)

#     return archs, metric_accs, metric_confidences, metric_sensitivities, metric_robustnesses, metric_step_sims
#     # fittedness / confidence / responsiveness / (negative) over-fittedness / linearness

    
# archs, metric_accs, metric_confidences, metric_sensitivities, metric_robustnesses, metric_step_sims = search_find_best_my(valid_loader, network, criterion, api.meta_archs)

# %%
import scipy.stats as stats
rank_accs, rank_confidences, rank_sensitivities, rank_robustnesses, rank_step_sims = stats.rankdata(metric_accs), stats.rankdata(metric_confidences), stats.rankdata(metric_sensitivities), stats.rankdata(metric_robustnesses), stats.rankdata(metric_step_sims)
# rank_agg = rank_accs + rank_confidences + rank_sensitivities + rank_robustnesses + rank_step_sims
l = len(rank_accs)
rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l)+np.log(rank_step_sims/l)
##############################
# rank_agg = rank_accs # 1
# rank_agg = rank_accs+rank_confidences # 2-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l) # 2-2
# rank_agg = rank_accs+rank_sensitivities # 3-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_sensitivities/l) # 3-2
# rank_agg = rank_accs+rank_robustnesses # 4-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_robustnesses/l) # 4-2
# rank_agg = rank_accs+rank_step_sims # 5-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_step_sims/l) # 5-2
# rank_agg = rank_accs+rank_sensitivities+rank_step_sims # 6-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_sensitivities/l)+np.log(rank_step_sims/l) # 6-2
# rank_agg = rank_accs+rank_confidences+rank_sensitivities # 7-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_sensitivities/l) # 7-2
# rank_agg = rank_accs+rank_confidences+rank_step_sims # 8-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_step_sims/l) # 8-2
# rank_agg = rank_accs+rank_sensitivities+rank_robustnesses # 9-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l) # 9-2
# rank_agg = rank_accs+rank_sensitivities+rank_step_sims # 10-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_sensitivities/l)+np.log(rank_step_sims/l) # 10-2
# rank_agg = rank_accs+rank_confidences+rank_sensitivities+rank_step_sims # 11-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_sensitivities/l)+np.log(rank_step_sims/l) # 11-2
# rank_agg = rank_sensitivities+rank_robustnesses+rank_step_sims # 12-1
rank_agg = np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l)+np.log(rank_step_sims/l) # 12-2
# rank_agg = rank_accs + rank_confidences + rank_sensitivities + rank_robustnesses + rank_step_sims # 13-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l)+np.log(rank_step_sims/l) # 13-2
# rank_agg = rank_accs + rank_sensitivities + rank_robustnesses # 14-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l) # 14-2
# rank_agg = rank_accs + rank_robustnesses + rank_step_sims # 15-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_robustnesses/l)+np.log(rank_step_sims/l) # 15-2
# rank_agg = rank_accs + rank_confidences + rank_sensitivities + rank_robustnesses # 16-1
# rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l) # 16-2

# rank_agg = rank_confidences + rank_sensitivities + rank_robustnesses + rank_step_sims # ?-1
# rank_agg = np.log(rank_confidences/l)+np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l)+np.log(rank_step_sims/l) # ?-2
# rank_agg = np.log(rank_sensitivities/l) # 
# rank_agg = np.log(rank_sensitivities/l)+np.log(rank_step_sims/l) # 
# rank_agg = np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l) # 
# rank_agg = np.log(rank_robustnesses/l)+np.log(rank_step_sims/l) # 
##############################
best_idx = np.argmax(rank_agg)

best_arch, best_acc, best_conf, best_sensitivity, best_robust, best_step_sim = archs[best_idx], metric_accs[best_idx], metric_confidences[best_idx], metric_sensitivities[best_idx], metric_robustnesses[best_idx], metric_step_sims[best_idx]
# log
print("RANDOM-NAS finds the best one : {:} with accuracy={:.2f}%, confidence={:.3f}%, sensitivity={:.3f}, robustness={:.3f}, step_sim={:.3f}".format(best_arch, best_acc, best_conf, best_sensitivity, best_robust, best_step_sim))
if api is not None:
    print("{:}".format(api.query_by_arch(best_arch, "200")))

# idx = np.argsort(rank_agg)[-5:]

# for best_idx in reversed(idx):
#     best_arch, best_acc, best_conf, best_sensitivity, best_robust = archs[best_idx], metric_accs[best_idx], metric_confidences[best_idx], metric_sensitivities[best_idx], metric_robustnesses[best_idx]
#     # log
#     print("RANDOM-NAS finds the best one : {:} with accuracy={:.2f}%, confidence={:.3f}%, sensitivity={:.3f}, robustness={:.3f}".format(best_arch, best_acc, best_conf, best_sensitivity, best_robust))
#     if api is not None:
#         print("{:}".format(api.query_by_arch(best_arch, "200")))

x = stats.rankdata(rank_agg)
y = stats.rankdata(api_valid_accs)
# y = api_valid_accs
plt.scatter(x, y)
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("rank_agg")
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)
# Out:
# RANDOM-NAS finds the best one : Structure(4 nodes with |none~0|+|none~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|) with accuracy=37.89%, confidence=23.135%, sensitivity=0.001, robustness=-0.004, step_sim=99.770
# Call query_info_str_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|) and hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# |none~0|+|none~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=11233
# cifar10-valid  FLOP= 47.10 M, Params=0.344 MB, latency=15.69 ms.
# cifar10-valid  train : [loss = 0.007, top1 = 99.89%], valid : [loss = 0.531, top1 = 88.26%]
# cifar10        FLOP= 47.10 M, Params=0.344 MB, latency=15.69 ms.
# cifar10        train : [loss = 0.013, top1 = 99.76%], test  : [loss = 0.333, top1 = 92.08%]
# cifar100       FLOP= 47.11 M, Params=0.350 MB, latency=14.11 ms.
# cifar100       train : [loss = 0.359, top1 = 90.21%], valid : [loss = 1.296, top1 = 67.58%], test : [loss = 1.306, top1 = 67.20%]
# ImageNet16-120 FLOP= 11.78 M, Params=0.351 MB, latency=13.75 ms.
# ImageNet16-120 train : [loss = 2.127, top1 = 44.71%], valid : [loss = 2.401, top1 = 38.77%], test : [loss = 2.403, top1 = 39.97%]
# 0.2455797531273706 2.9815229540837248e-31

# %%
def get_valid_acc_from_api(api, arch):
    # print(api.query_by_arch(arch, "200"))
    index = api.query_index_by_arch(arch)
    results = api.query_by_index(index, 'cifar10-valid', '200') # a dict of all trials for 1st net on cifar100, where the key is the seed
    acc = 0
    for seed, result in results.items():
        acc = acc + result.get_eval('valid')['accuracy']
    acc = acc / len(results)
    return acc

api_valid_accs = [get_valid_acc_from_api(api, a) for a in archs]
# Out:
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2682, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2682, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=3886, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3886, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14025, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14025, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=617, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=617, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=5943, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5943, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10133, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10133, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=3308, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3308, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=12088, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12088, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=12892, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12892, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6872, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6872, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13996, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13996, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7160, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7160, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8330, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8330, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=6020, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6020, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=14316, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14316, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=9877, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9877, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=3029, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3029, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=11697, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11697, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=11601, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11601, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10928, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10928, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5011, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5011, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7122, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7122, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3119, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3119, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2323, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2323, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13256, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13256, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=10075, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10075, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|nor_conv_1x1~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=8873, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8873, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1470, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1470, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7727, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7727, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=1092, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1092, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1978, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1978, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=4406, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4406, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=482, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=482, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8296, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8296, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=2293, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2293, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8559, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8559, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5945, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5945, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13469, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13469, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=9628, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9628, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|skip_connect~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=7371, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7371, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1661, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1661, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7203, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7203, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13784, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13784, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2781, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2781, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=8034, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8034, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10658, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10658, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=15186, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15186, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3757, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3757, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12823, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12823, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7634, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7634, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=9182, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9182, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=10132, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10132, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=7711, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7711, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5449, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5449, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13064, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13064, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|none~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=2796, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2796, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=869, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=869, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=3918, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3918, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6687, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6687, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=9519, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9519, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=11034, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11034, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14044, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14044, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=15316, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15316, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5329, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5329, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2036, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2036, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8536, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8536, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=201, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=201, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10898, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10898, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12094, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12094, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=2481, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2481, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=2205, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2205, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2916, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2916, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=5208, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5208, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6833, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6833, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5577, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5577, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=461, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=461, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=7595, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7595, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=12408, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12408, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=4522, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4522, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=10866, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10866, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5081, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5081, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13940, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13940, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12396, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12396, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3858, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3858, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1915, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1915, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10061, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10061, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7028, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7028, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=3263, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3263, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6441, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6441, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=11481, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11481, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=5691, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5691, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=15394, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15394, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=3011, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3011, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11655, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11655, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6009, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6009, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=7041, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7041, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=14157, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14157, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13396, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13396, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=10610, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10610, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8345, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8345, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=1409, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1409, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13332, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13332, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2735, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2735, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=12951, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12951, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1896, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1896, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=3513, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3513, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=11011, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11011, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=10831, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10831, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=14864, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14864, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12357, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12357, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=12733, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12733, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=8811, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8811, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=13186, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13186, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10971, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10971, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|none~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=1722, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1722, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=11091, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11091, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=14557, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14557, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4586, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4586, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8138, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8138, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1608, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1608, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=12751, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12751, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6314, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6314, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10564, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10564, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=4916, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4916, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=7498, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7498, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9663, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9663, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=4569, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4569, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=12941, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12941, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=14826, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14826, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=2675, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2675, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13845, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13845, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13737, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13737, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=11214, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11214, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=761, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=761, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=5943, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5943, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=9645, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9645, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=4149, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4149, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=5783, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5783, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13135, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13135, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=8511, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8511, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=4105, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4105, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9851, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9851, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1436, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1436, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=12534, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12534, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=5461, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5461, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=1238, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1238, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1887, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1887, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=595, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=595, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=917, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=917, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=15517, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15517, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=6076, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6076, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=5561, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5561, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2406, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2406, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|none~1|none~2|)
# Call query_by_index with arch_index=9380, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9380, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=9492, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9492, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10394, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10394, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5966, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5966, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13654, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13654, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6585, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6585, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=10812, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10812, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8356, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8356, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=14034, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14034, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=452, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=452, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=8858, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8858, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=11094, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11094, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10726, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10726, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8617, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8617, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=609, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=609, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=15245, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15245, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=14109, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14109, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=3245, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3245, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=7822, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7822, hp=200
# ...
# Call query_by_index with arch_index=13384, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13384, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=1157, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1157, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=3457, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3457, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=11165, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11165, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=4587, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4587, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2864, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2864, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7164, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7164, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=14772, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14772, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6760, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6760, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11840, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11840, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=8780, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8780, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=732, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=732, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=5817, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5817, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|none~0|none~1|none~2|)
# Call query_by_index with arch_index=4071, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4071, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=4696, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4696, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4563, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4563, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1298, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1298, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1444, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1444, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=1321, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1321, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=11817, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=11817, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=13633, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13633, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1269, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1269, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=14427, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14427, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12087, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12087, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=15468, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15468, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=6442, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6442, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7926, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7926, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=15144, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15144, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5177, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5177, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=4946, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=4946, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=15294, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=15294, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=964, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=964, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=2090, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2090, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9858, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=9858, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|none~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=1722, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1722, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=6303, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6303, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1336, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1336, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3069, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3069, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6537, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=6537, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=7236, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=7236, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|none~2|)
# Call query_by_index with arch_index=10757, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10757, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=3740, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=3740, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=14878, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14878, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=5464, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=5464, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=1671, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1671, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=1465, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1465, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2030, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=2030, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14869, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14869, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|none~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=14549, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=14549, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10086, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10086, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12935, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12935, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=1873, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=1873, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13107, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13107, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13436, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=13436, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12907, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=12907, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10399, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10399, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=10207, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=10207, hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|none~1|+|none~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8527, dataname=cifar10-valid, hp=200
# Call query_meta_info_by_index with arch_index=8527, hp=200

# %%
for tmp_a in archs:
# tmp_a = archs[0]
    tmp_i = api.query_index_by_arch(tmp_a)
    tmp = api.query_by_index(tmp_i, 'cifar10', '200')
    for v in tmp.values():
        print(v.get_eval("ori-test")['accuracy'])
        break
# Out:
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2682, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2682, hp=200
# 89.95
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=3886, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3886, hp=200
# 91.53
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14025, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14025, hp=200
# 84.54
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=617, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=617, hp=200
# 92.02
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=5943, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5943, hp=200
# 80.54
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10133, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10133, hp=200
# 89.02
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=3308, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3308, hp=200
# 92.12
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=12088, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12088, hp=200
# 90.58
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=12892, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12892, hp=200
# 89.13
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6872, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6872, hp=200
# 93.26
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13996, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13996, hp=200
# 91.16
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7160, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7160, hp=200
# 92.18
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8330, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8330, hp=200
# 91.94
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=6020, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6020, hp=200
# 91.72
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=14316, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14316, hp=200
# 91.91
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=9877, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=9877, hp=200
# 91.68
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=3029, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3029, hp=200
# 89.11
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=11697, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11697, hp=200
# 87.0
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=11601, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11601, hp=200
# 93.07
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10928, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10928, hp=200
# 92.13
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5011, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5011, hp=200
# 93.37
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7122, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7122, hp=200
# 79.66
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=3119, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3119, hp=200
# 93.24
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2323, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2323, hp=200
# 92.33
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13256, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13256, hp=200
# 92.48
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=10075, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10075, hp=200
# 88.4
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|nor_conv_1x1~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=8873, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8873, hp=200
# 89.05
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1470, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1470, hp=200
# 89.36
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7727, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7727, hp=200
# 89.31
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=1092, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1092, hp=200
# 80.45
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1978, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1978, hp=200
# 84.72
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=4406, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4406, hp=200
# 87.78
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=482, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=482, hp=200
# 88.19
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8296, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8296, hp=200
# 92.97
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=2293, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2293, hp=200
# 79.37
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8559, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8559, hp=200
# 90.27
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5945, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5945, hp=200
# 92.26
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13469, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13469, hp=200
# 78.52
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=9628, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=9628, hp=200
# 86.59
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|skip_connect~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=7371, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7371, hp=200
# 10.0
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1661, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1661, hp=200
# 91.88
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7203, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7203, hp=200
# 92.74
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13784, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13784, hp=200
# 89.16
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2781, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2781, hp=200
# 91.32
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=8034, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8034, hp=200
# 91.2
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10658, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10658, hp=200
# 93.62
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=15186, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=15186, hp=200
# 93.1
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3757, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3757, hp=200
# 91.55
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12823, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12823, hp=200
# 88.99
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7634, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7634, hp=200
# 86.42
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=9182, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=9182, hp=200
# 86.44
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=10132, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10132, hp=200
# 86.38
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=7711, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7711, hp=200
# 75.43
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5449, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5449, hp=200
# 83.57
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13064, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13064, hp=200
# 88.87
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|none~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=2796, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2796, hp=200
# 10.0
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=869, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=869, hp=200
# 94.16
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=3918, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3918, hp=200
# 80.25
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6687, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6687, hp=200
# 93.2
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=9519, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=9519, hp=200
# 69.03
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=11034, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11034, hp=200
# 89.64
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14044, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14044, hp=200
# 89.67
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=15316, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=15316, hp=200
# 92.23
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5329, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5329, hp=200
# 86.48
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2036, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2036, hp=200
# 85.36
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8536, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8536, hp=200
# 93.0
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=201, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=201, hp=200
# 86.41
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=10898, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10898, hp=200
# 90.97
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12094, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12094, hp=200
# 75.4
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=2481, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2481, hp=200
# 86.77
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=2205, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2205, hp=200
# 79.1
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2916, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2916, hp=200
# 89.93
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=5208, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5208, hp=200
# 90.42
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6833, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6833, hp=200
# 91.5
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5577, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5577, hp=200
# 91.61
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=461, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=461, hp=200
# 91.15
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=7595, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7595, hp=200
# 92.25
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=12408, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12408, hp=200
# 71.05
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=4522, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4522, hp=200
# 92.26
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=10866, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10866, hp=200
# 91.08
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5081, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5081, hp=200
# 93.35
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13940, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13940, hp=200
# 91.2
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12396, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12396, hp=200
# 92.12
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3858, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3858, hp=200
# 93.13
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1915, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1915, hp=200
# 90.67
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10061, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10061, hp=200
# 90.45
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7028, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7028, hp=200
# 55.21
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=3263, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3263, hp=200
# 92.91
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6441, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6441, hp=200
# 91.3
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=11481, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11481, hp=200
# 75.51
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=5691, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5691, hp=200
# 89.53
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=15394, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=15394, hp=200
# 92.07
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=3011, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3011, hp=200
# 92.01
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11655, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11655, hp=200
# 91.98
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6009, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6009, hp=200
# 92.75
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=7041, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7041, hp=200
# 88.2
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=14157, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14157, hp=200
# 87.93
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13396, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13396, hp=200
# 91.77
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=10610, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10610, hp=200
# 87.75
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8345, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8345, hp=200
# 87.8
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=1409, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1409, hp=200
# 86.31
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13332, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13332, hp=200
# 69.65
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=2735, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2735, hp=200
# 90.14
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|none~1|none~2|)
# Call query_by_index with arch_index=12951, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12951, hp=200
# 75.85
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1896, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1896, hp=200
# 93.65
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=3513, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3513, hp=200
# 86.61
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=11011, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11011, hp=200
# 92.05
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=10831, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10831, hp=200
# 90.89
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=14864, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14864, hp=200
# 90.96
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12357, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12357, hp=200
# 91.1
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=12733, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12733, hp=200
# 89.83
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=8811, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8811, hp=200
# 75.71
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=13186, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13186, hp=200
# 87.19
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10971, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10971, hp=200
# 86.72
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|none~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=1722, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1722, hp=200
# 80.53
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=11091, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11091, hp=200
# 88.98
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=14557, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14557, hp=200
# 86.29
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4586, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4586, hp=200
# 88.56
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8138, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8138, hp=200
# 73.47
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1608, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1608, hp=200
# 89.84
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=12751, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12751, hp=200
# 89.66
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6314, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6314, hp=200
# 87.24
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10564, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10564, hp=200
# 93.25
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=4916, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4916, hp=200
# 92.33
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=7498, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7498, hp=200
# 87.55
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9663, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=9663, hp=200
# 92.91
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=4569, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4569, hp=200
# 79.38
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=12941, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12941, hp=200
# 75.79
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=14826, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14826, hp=200
# 91.13
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=2675, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2675, hp=200
# 92.0
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=13845, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13845, hp=200
# 84.15
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13737, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13737, hp=200
# 92.59
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=11214, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11214, hp=200
# 86.76
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=761, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=761, hp=200
# 90.9
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=5943, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5943, hp=200
# 80.54
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=9645, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=9645, hp=200
# 10.0
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=4149, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4149, hp=200
# 90.08
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=5783, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5783, hp=200
# 92.45
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=13135, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13135, hp=200
# 87.37
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=8511, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8511, hp=200
# 87.05
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=4105, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4105, hp=200
# 93.25
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9851, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=9851, hp=200
# 93.24
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1436, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1436, hp=200
# 89.64
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=12534, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12534, hp=200
# 91.65
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=5461, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5461, hp=200
# 76.25
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=1238, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1238, hp=200
# 87.77
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=1887, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1887, hp=200
# 89.84
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=595, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=595, hp=200
# 88.73
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=917, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=917, hp=200
# 89.63
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=15517, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=15517, hp=200
# 90.09
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=6076, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6076, hp=200
# 86.39
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=5561, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5561, hp=200
# 90.65
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2406, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2406, hp=200
# 92.27
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|none~1|none~2|)
# Call query_by_index with arch_index=9380, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=9380, hp=200
# 88.95
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=9492, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=9492, hp=200
# 90.51
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10394, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10394, hp=200
# 90.2
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=5966, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5966, hp=200
# 93.17
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13654, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13654, hp=200
# 92.82
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6585, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6585, hp=200
# 93.28
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=10812, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10812, hp=200
# 86.59
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8356, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8356, hp=200
# 92.16
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=14034, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14034, hp=200
# 76.61
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=452, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=452, hp=200
# 84.5
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=8858, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8858, hp=200
# 91.83
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=11094, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11094, hp=200
# 79.73
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10726, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10726, hp=200
# 87.21
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=8617, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8617, hp=200
# 92.36
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=609, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=609, hp=200
# 93.1
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=15245, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=15245, hp=200
# 89.11
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=14109, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14109, hp=200
# 86.85
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=3245, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3245, hp=200
# 79.37
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=7822, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7822, hp=200
# 88.05
# ...
# Call query_by_index with arch_index=13384, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13384, hp=200
# 88.74
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=1157, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1157, hp=200
# 91.97
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=3457, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3457, hp=200
# 90.64
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=11165, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11165, hp=200
# 91.08
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=4587, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4587, hp=200
# 86.96
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=2864, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2864, hp=200
# 88.58
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=7164, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7164, hp=200
# 87.77
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=14772, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14772, hp=200
# 68.16
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=6760, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6760, hp=200
# 86.63
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=11840, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11840, hp=200
# 80.42
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=8780, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8780, hp=200
# 88.48
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=732, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=732, hp=200
# 93.24
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|)
# Call query_by_index with arch_index=5817, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5817, hp=200
# 92.5
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|none~0|none~1|none~2|)
# Call query_by_index with arch_index=4071, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4071, hp=200
# 10.0
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=4696, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4696, hp=200
# 92.56
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=4563, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4563, hp=200
# 90.29
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=1298, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1298, hp=200
# 92.04
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1444, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1444, hp=200
# 90.44
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=1321, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1321, hp=200
# 89.9
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=11817, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=11817, hp=200
# 86.58
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|none~2|)
# Call query_by_index with arch_index=13633, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13633, hp=200
# 80.27
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1269, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1269, hp=200
# 90.32
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=14427, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14427, hp=200
# 91.1
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=12087, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12087, hp=200
# 85.18
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=15468, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=15468, hp=200
# 92.01
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=6442, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6442, hp=200
# 68.0
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=7926, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7926, hp=200
# 93.08
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=15144, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=15144, hp=200
# 93.63
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=5177, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5177, hp=200
# 86.19
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=4946, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=4946, hp=200
# 93.85
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=15294, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=15294, hp=200
# 92.46
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=964, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=964, hp=200
# 85.14
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|none~1|none~2|)
# Call query_by_index with arch_index=2090, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2090, hp=200
# 86.61
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=9858, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=9858, hp=200
# 92.38
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|none~0|nor_conv_1x1~1|none~2|)
# Call query_by_index with arch_index=1722, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1722, hp=200
# 80.53
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|none~1|skip_connect~2|)
# Call query_by_index with arch_index=6303, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6303, hp=200
# 80.27
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=1336, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1336, hp=200
# 89.73
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|skip_connect~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=3069, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3069, hp=200
# 91.57
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=6537, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=6537, hp=200
# 90.84
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=7236, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=7236, hp=200
# 92.89
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|none~2|)
# Call query_by_index with arch_index=10757, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10757, hp=200
# 88.64
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=3740, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=3740, hp=200
# 91.95
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=14878, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14878, hp=200
# 93.12
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=5464, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=5464, hp=200
# 52.56
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|skip_connect~2|)
# Call query_by_index with arch_index=1671, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1671, hp=200
# 87.54
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|)
# Call query_by_index with arch_index=1465, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1465, hp=200
# 88.92
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=2030, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=2030, hp=200
# 93.93
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=14869, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14869, hp=200
# 91.78
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|none~0|none~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=14549, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=14549, hp=200
# 84.33
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# Call query_by_index with arch_index=10086, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10086, hp=200
# 93.62
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|skip_connect~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12935, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12935, hp=200
# 56.96
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|none~2|)
# Call query_by_index with arch_index=1873, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=1873, hp=200
# 91.99
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13107, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13107, hp=200
# 92.35
# Call query_index_by_arch with arch=Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Call query_by_index with arch_index=13436, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=13436, hp=200
# 93.2
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=12907, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=12907, hp=200
# 88.53
# Call query_index_by_arch with arch=Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=10399, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10399, hp=200
# 82.96
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|none~2|)
# Call query_by_index with arch_index=10207, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=10207, hp=200
# 91.08
# Call query_index_by_arch with arch=Structure(4 nodes with |none~0|+|nor_conv_3x3~0|none~1|+|none~0|none~1|avg_pool_3x3~2|)
# Call query_by_index with arch_index=8527, dataname=cifar10, hp=200
# Call query_meta_info_by_index with arch_index=8527, hp=200
# 87.84

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

x = stats.rankdata(np.array(metric_accs),"max")
# x = metric_accs
y = stats.rankdata(api_valid_accs,"max")
# y = api_valid_accs
plt.scatter(x, y)
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("metric_accs")
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(metric_confidences)
y = stats.rankdata(api_valid_accs)
plt.scatter(x, y)
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("metric_confidences")
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(metric_sensitivities)
# x = metric_sensitivities
y = stats.rankdata(api_valid_accs)
# y = api_valid_accs
plt.scatter(x, y)
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("metric_sensitivities")
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(metric_robustnesses)
# x = metric_robustnesses
y = stats.rankdata(api_valid_accs)
# y = api_valid_accs
plt.scatter(x, y)
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("metric_robustnesses")
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(metric_step_sims)
# x = metric_robustnesses
y = stats.rankdata(api_valid_accs)
# y = api_valid_accs
plt.scatter(x, y)
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("metric_step_sims")
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)

x = stats.rankdata(rank_agg)
y = stats.rankdata(api_valid_accs)
# y = api_valid_accs
plt.scatter(x, y)
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("rank_agg")
plt.show()
tau, p_value = stats.kendalltau(x, y)
print(tau, p_value)
# Out:
# 0.051244730311808886 0.01577306355465375
# 0.028910934763232123 0.1710384391963894
# 0.39627444273817075 1.6349299072884993e-78
# -0.21340072828500753 5.410381273082775e-24
# 0.18707508384565924 8.306430231384518e-19
# 0.051244730311808886 0.01577306355465375

# %%
np.max(np.array(metric_accs))
# Out:
# 73.046875

# %%
ratio = 0.7
med = np.sort(api_valid_accs)[int(len(api_valid_accs)*ratio)]
pos_idx = api_valid_accs > med
neg_idx = api_valid_accs <= med

# ratio = 0.5
# target = metric_accs
# med = np.median(target)
# med = np.sort(target)[int(len(target)*ratio)]
# pos_idx = target > med
# neg_idx = target <= med

# target = metric_confidences
# pruned_target = np.array(target)[pos_idx]
# med = np.median(pruned_target)
# med = np.sort(pruned_target)[int(len(pruned_target)*ratio)]
# pos_idx_tmp = target > med
# neg_idx_tmp = target <= med
# pos_idx = pos_idx & pos_idx_tmp
# neg_idx = neg_idx | neg_idx_tmp

# target = metric_sensitivities
# pruned_target = np.array(target)[pos_idx]
# med = np.median(pruned_target)
# med = np.sort(pruned_target)[int(len(pruned_target)*ratio)]
# pos_idx_tmp = target > med
# neg_idx_tmp = target <= med
# pos_idx = pos_idx & pos_idx_tmp
# neg_idx = neg_idx | neg_idx_tmp

# target = metric_robustnesses
# pruned_target = np.array(target)[pos_idx]
# med = np.median(pruned_target)
# med = np.sort(pruned_target)[int(len(pruned_target)*ratio)]
# pos_idx_tmp = target > med
# neg_idx_tmp = target <= med
# pos_idx = pos_idx & pos_idx_tmp
# neg_idx = neg_idx | neg_idx_tmp

# target = metric_step_sims
# pruned_target = np.array(target)[pos_idx]
# med = np.median(pruned_target)
# med = np.sort(pruned_target)[int(len(pruned_target)*ratio)]
# pos_idx_tmp = target > med
# neg_idx_tmp = target <= med
# pos_idx = pos_idx & pos_idx_tmp
# neg_idx = neg_idx | neg_idx_tmp

# from itertools import compress
# archs_pruned = list(compress(archs, pos_idx))
# metrics_pruned = [np.array(metric_accs)[pos_idx], np.array(metric_confidences)[pos_idx], np.array(metric_sensitivities)[pos_idx], np.array(metric_robustnesses)[pos_idx], np.array(metric_step_sims)[pos_idx]]
# ranks_pruned = []
# for metric in metrics_pruned:
#     ranks_pruned.append(stats.rankdata(metric))
# rank_agg_pruned = None
# for rank in ranks_pruned:
#     if rank_agg_pruned is None:
#         rank_agg_pruned = np.log(rank / len(rank))
#     else:
#         rank_agg_pruned += np.log(rank / len(rank))
# # print(rank)
# # print(rank_agg_pruned)
# # rank_agg_pruned = ranks_pruned[3]
# best_idx_pruned = np.argmax(rank_agg_pruned)
# best_arch_pruned = archs_pruned[best_idx_pruned]

# for i, a in enumerate(archs):
#     if a==best_arch_pruned:
#         best_idx = i
#         break
# print(best_arch_pruned)
# print(best_idx)

x = stats.rankdata(metric_accs)
y = stats.rankdata(api_valid_accs)
# plt.scatter(x[neg_idx], y[neg_idx])
plt.scatter(x[pos_idx], y[pos_idx])
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("metric_accs")
plt.show()
# tau, p_value = stats.kendalltau(x, y)
tau, p_value = stats.kendalltau(x[pos_idx], y[pos_idx])
print(tau, p_value)

x = stats.rankdata(metric_confidences)
y = stats.rankdata(api_valid_accs)
# plt.scatter(x[neg_idx], y[neg_idx])
plt.scatter(x[pos_idx], y[pos_idx])
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("metric_confidences")
plt.show()
# tau, p_value = stats.kendalltau(x, y)
tau, p_value = stats.kendalltau(x[pos_idx], y[pos_idx])
print(tau, p_value)

x = stats.rankdata(metric_sensitivities)
y = stats.rankdata(api_valid_accs)
# plt.scatter(x[neg_idx], y[neg_idx])
plt.scatter(x[pos_idx], y[pos_idx])
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("metric_sensitivities")
plt.show()
# tau, p_value = stats.kendalltau(x, y)
tau, p_value = stats.kendalltau(x[pos_idx], y[pos_idx])
print(tau, p_value)

x = stats.rankdata(metric_robustnesses)
y = stats.rankdata(api_valid_accs)
# plt.scatter(x[neg_idx], y[neg_idx])
plt.scatter(x[pos_idx], y[pos_idx])
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("metric_robustnesses")
plt.show()
# tau, p_value = stats.kendalltau(x, y)
tau, p_value = stats.kendalltau(x[pos_idx], y[pos_idx])
print(tau, p_value)

x = stats.rankdata(metric_step_sims)
y = stats.rankdata(api_valid_accs)
# plt.scatter(x[neg_idx], y[neg_idx])
plt.scatter(x[pos_idx], y[pos_idx])
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("metric_step_sims")
plt.show()
# tau, p_value = stats.kendalltau(x, y)
tau, p_value = stats.kendalltau(x[pos_idx], y[pos_idx])
print(tau, p_value)

x = stats.rankdata(rank_agg)
y = stats.rankdata(api_valid_accs)
# plt.scatter(x[neg_idx], y[neg_idx])
plt.scatter(x[pos_idx], y[pos_idx])
plt.scatter(x[best_idx], y[best_idx], c="r", linewidths=4)
plt.title("rank_agg")
plt.show()
# tau, p_value = stats.kendalltau(x, y)
tau, p_value = stats.kendalltau(x[pos_idx], y[pos_idx])
print(tau, p_value)

best_arch, best_acc, best_conf, best_sensitivity, best_robust, best_step_sim = archs[best_idx], metric_accs[best_idx], metric_confidences[best_idx], metric_sensitivities[best_idx], metric_robustnesses[best_idx], metric_step_sims[best_idx]
# log
print("RANDOM-NAS finds the best one : {:} with accuracy={:.2f}%, confidence={:.3f}%, sensitivity={:.3f}, robustness={:.3f}, generalization={:.3f}".format(best_arch, best_acc, best_conf, best_sensitivity, best_robust, best_step_sim))
if api is not None:
    print("{:}".format(api.query_by_arch(best_arch, "200")))
# Out:
# 0.10666174806542678 0.00642318769176811
# 0.07271625288462522 0.060825568079198936
# -0.03482028657735527 0.3693283061077216
# 0.12331904201767406 0.0014758228180777398
# 0.3152234969907448 4.398543379048995e-16
# 0.23646813573132366 1.0835372874495853e-09
# RANDOM-NAS finds the best one : Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|) with accuracy=69.34%, confidence=58.270%, sensitivity=0.034, robustness=-0.016, generalization=99.096
# Call query_info_str_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|) and hp=200
# Call query_index_by_arch with arch=Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|)
# |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|
# datasets : ['cifar10-valid', 'cifar10', 'cifar100', 'ImageNet16-120'], extra-info : arch-index=6111
# cifar10-valid  FLOP=153.27 M, Params=1.073 MB, latency=20.22 ms.
# cifar10-valid  train : [loss = 0.001, top1 = 99.99%], valid : [loss = 0.414, top1 = 91.61%]
# cifar10        FLOP=153.27 M, Params=1.073 MB, latency=20.22 ms.
# cifar10        train : [loss = 0.002, top1 = 99.99%], test  : [loss = 0.262, top1 = 94.37%]
# cifar100       FLOP=153.28 M, Params=1.079 MB, latency=19.56 ms.
# cifar100       train : [loss = 0.018, top1 = 99.87%], valid : [loss = 1.256, top1 = 72.75%], test : [loss = 1.231, top1 = 73.22%]
# ImageNet16-120 FLOP= 38.33 M, Params=1.081 MB, latency=18.26 ms.
# ImageNet16-120 train : [loss = 1.114, top1 = 69.02%], valid : [loss = 2.222, top1 = 45.56%], test : [loss = 2.249, top1 = 46.71%]
