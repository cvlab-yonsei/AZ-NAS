# %%
import os, sys, time, glob, random, argparse
import numpy as np
from copy import deepcopy
import torch
import torch.nn as nn

# XAutoDL 
from xautodl.config_utils import load_config, dict2config, configure2str
from xautodl.datasets import get_datasets, get_nas_search_loaders
from xautodl.procedures import (
    prepare_seed,
    prepare_logger,
    save_checkpoint,
    copy_checkpoint,
    get_optim_scheduler,
)
from xautodl.utils import get_model_infos, obtain_accuracy
from xautodl.log_utils import AverageMeter, time_string, convert_secs2time
from xautodl.models import get_search_spaces

from custom_models import get_cell_based_tiny_net

# NB201
from nas_201_api import NASBench201API as API
# Out:
# 2022-10-20 06:01:20.422830: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
parser = argparse.ArgumentParser("Random search for NAS.")
parser.add_argument("--data_path", type=str, default='../cifar.python', help="The path to dataset")
parser.add_argument("--dataset", type=str, default='cifar10',choices=["cifar10", "cifar100", "ImageNet16-120"], help="Choose between Cifar10/100 and ImageNet-16.")

# channels and number-of-cells
parser.add_argument("--search_space_name", type=str, default='nas-bench-201', help="The search space name.")
parser.add_argument("--config_path", type=str, default='./MY.config', help="The path to the configuration.")
parser.add_argument("--max_nodes", type=int, default=4, help="The maximum number of nodes.")
parser.add_argument("--channel", type=int, default=16, help="The number of channels.")
parser.add_argument("--num_cells", type=int, default=5, help="The number of cells in one stage.")
parser.add_argument("--select_num", type=int, default=100, help="The number of selected architectures to evaluate.")
parser.add_argument("--track_running_stats", type=int, default=0, choices=[0, 1], help="Whether use track_running_stats or not in the BN layer.")
# log
parser.add_argument("--workers", type=int, default=4, help="number of data loading workers")
parser.add_argument("--save_dir", type=str, default='./tmp', help="Folder to save checkpoints and log.")
# parser.add_argument("--arch_nas_dataset", type=str, default='../NAS-Bench-201-v1_1-096897.pth', help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--arch_nas_dataset", type=str, default=None, help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--print_freq", type=int, default=100, help="print frequency (default: 200)")
parser.add_argument("--rand_seed", type=int, default=None, help="manual seed")
args = parser.parse_args(args=[])
if args.rand_seed is None or args.rand_seed < 0:
    args.rand_seed = random.randint(1, 100000)

    
print(args.rand_seed)
print(args)
xargs=args
# Out:
# 27924
# Namespace(arch_nas_dataset=None, channel=16, config_path='./MY.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=100, rand_seed=27924, save_dir='./tmp', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
assert torch.cuda.is_available(), "CUDA is not available."
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.set_num_threads(xargs.workers)
prepare_seed(xargs.rand_seed)
logger = prepare_logger(args)
# Out:
# Main Function with logger : Logger(dir=tmp, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : None
# channel          : 16
# config_path      : ./MY.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 100
# rand_seed        : 27924
# save_dir         : ./tmp
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None

# %%
def search_func(xloader, network, criterion, scheduler, w_optimizer, epoch_str, print_freq, logger):
    data_time, batch_time = AverageMeter(), AverageMeter()
    base_losses, base_top1, base_top5 = AverageMeter(), AverageMeter(), AverageMeter()
    network.train()
    end = time.time()
    for step, (base_inputs, base_targets, arch_inputs, arch_targets) in enumerate(
        xloader
    ):
        scheduler.update(None, 1.0 * step / len(xloader))
        base_targets = base_targets.cuda(non_blocking=True)
        arch_targets = arch_targets.cuda(non_blocking=True)
        # measure data loading time
        data_time.update(time.time() - end)

        # update the weights
        ### sample a cell-wise randomized network
        network.module.random_genotype_per_cell(True)
        ###
        w_optimizer.zero_grad()
        _, logits = network(base_inputs)
        base_loss = criterion(logits, base_targets)
        base_loss.backward()
        nn.utils.clip_grad_norm_(network.parameters(), 5)
        w_optimizer.step()
        # record
        base_prec1, base_prec5 = obtain_accuracy(
            logits.data, base_targets.data, topk=(1, 5)
        )
        base_losses.update(base_loss.item(), base_inputs.size(0))
        base_top1.update(base_prec1.item(), base_inputs.size(0))
        base_top5.update(base_prec5.item(), base_inputs.size(0))

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if step % print_freq == 0 or step + 1 == len(xloader):
            Sstr = (
                "*SEARCH* "
                + time_string()
                + " [{:}][{:03d}/{:03d}]".format(epoch_str, step, len(xloader))
            )
            Tstr = "Time {batch_time.val:.2f} ({batch_time.avg:.2f}) Data {data_time.val:.2f} ({data_time.avg:.2f})".format(
                batch_time=batch_time, data_time=data_time
            )
            Wstr = "Base [Loss {loss.val:.3f} ({loss.avg:.3f})  Prec@1 {top1.val:.2f} ({top1.avg:.2f}) Prec@5 {top5.val:.2f} ({top5.avg:.2f})]".format(
                loss=base_losses, top1=base_top1, top5=base_top5
            )
            logger.log(Sstr + " " + Tstr + " " + Wstr)
    return base_losses.avg, base_top1.avg, base_top5.avg


def valid_func(xloader, network, criterion):
    data_time, batch_time = AverageMeter(), AverageMeter()
    arch_losses, arch_top1, arch_top5 = AverageMeter(), AverageMeter(), AverageMeter()
    network.eval()
    end = time.time()
    with torch.no_grad():
        for step, (arch_inputs, arch_targets) in enumerate(xloader):
            arch_targets = arch_targets.cuda(non_blocking=True)
            # measure data loading time
            data_time.update(time.time() - end)
            # prediction

            network.module.random_genotype_per_cell(True)
            _, logits = network(arch_inputs)
            arch_loss = criterion(logits, arch_targets)
            # record
            arch_prec1, arch_prec5 = obtain_accuracy(
                logits.data, arch_targets.data, topk=(1, 5)
            )
            arch_losses.update(arch_loss.item(), arch_inputs.size(0))
            arch_top1.update(arch_prec1.item(), arch_inputs.size(0))
            arch_top5.update(arch_prec5.item(), arch_inputs.size(0))
            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()
    return arch_losses.avg, arch_top1.avg, arch_top5.avg


def search_find_best(xloader, network, n_samples):
    with torch.no_grad():
        network.eval()
        archs, valid_accs = [], []
        # print ('obtain the top-{:} architectures'.format(n_samples))
        loader_iter = iter(xloader)
        for i in range(n_samples):
            arch = network.module.random_genotype_per_cell(True)
            try:
                inputs, targets = next(loader_iter)
            except:
                loader_iter = iter(xloader)
                inputs, targets = next(loader_iter)

            _, logits = network(inputs)
            val_top1, val_top5 = obtain_accuracy(
                logits.cpu().data, targets.data, topk=(1, 5)
            )

            archs.append(arch)
            valid_accs.append(val_top1.item())

        best_idx = np.argmax(valid_accs)
        best_arch, best_valid_acc = archs[best_idx], valid_accs[best_idx]
        return best_arch, best_valid_acc

# %%
train_data, valid_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(xargs.config_path, {"class_num": class_num, "xshape": xshape}, logger)
search_loader, _, valid_loader = get_nas_search_loaders(train_data,
                                                        valid_data,
                                                        xargs.dataset,
                                                        "../configs/nas-benchmark/",
                                                        (config.batch_size, config.test_batch_size),
                                                        xargs.workers)
logger.log("||||||| {:10s} ||||||| Search-Loader-Num={:}, Valid-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(search_loader), len(valid_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": bool(xargs.track_running_stats),
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))
if xargs.arch_nas_dataset is None:
    api = None
else:
    api = API(xargs.arch_nas_dataset)
logger.log("{:} create API = {:} done".format(time_string(), api))

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)
network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

if last_info.exists():  # automatically resume from previous checkpoint
    logger.log(
        "=> loading checkpoint of the last-info '{:}' start".format(last_info)
    )
    last_info = torch.load(last_info)
    start_epoch = last_info["epoch"]
    checkpoint = torch.load(last_info["last_checkpoint"])
    genotypes = checkpoint["genotypes"]
    valid_accuracies = checkpoint["valid_accuracies"]
    search_model.load_state_dict(checkpoint["search_model"])
    w_scheduler.load_state_dict(checkpoint["w_scheduler"])
    w_optimizer.load_state_dict(checkpoint["w_optimizer"])
    logger.log(
        "=> loading checkpoint of the last-info '{:}' start with {:}-th epoch.".format(
            last_info, start_epoch
        )
    )
else:
    logger.log("=> do not find the last-info file : {:}".format(last_info))
    start_epoch, valid_accuracies, genotypes = 0, {"best": -1}, {}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ./MY.config
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Search-Loader-Num=391, Valid-Loader-Num=49, batch size=64
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.025
#     lr: 0.025
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=250, current::epoch=0, iter=0.00, type=cosine, T-max=250, eta-min=0.001)
# criterion   : CrossEntropyLoss()
# [2022-10-20 06:01:37] create API = None done
# => do not find the last-info file : tmp/seed-27924-last-info.pth

# %%
# start training
start_time, search_time, epoch_time, total_epoch = (
    time.time(),
    AverageMeter(),
    AverageMeter(),
    config.epochs + config.warmup,
)
for epoch in range(start_epoch, total_epoch):
    w_scheduler.update(epoch, 0.0)
    need_time = "Time Left: {:}".format(
        convert_secs2time(epoch_time.val * (total_epoch - epoch), True)
    )
    epoch_str = "{:03d}-{:03d}".format(epoch, total_epoch)
    logger.log(
        "\n[Search the {:}-th epoch] {:}, LR={:}".format(
            epoch_str, need_time, min(w_scheduler.get_lr())
        )
    )

    # selected_arch = search_find_best(valid_loader, network, criterion, xargs.select_num)
    search_w_loss, search_w_top1, search_w_top5 = search_func(
        search_loader,
        network,
        criterion,
        w_scheduler,
        w_optimizer,
        epoch_str,
        xargs.print_freq,
        logger,
    )
    search_time.update(time.time() - start_time)
    logger.log(
        "[{:}] searching : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%, time-cost={:.1f} s".format(
            epoch_str, search_w_loss, search_w_top1, search_w_top5, search_time.sum
        )
    )
    valid_a_loss, valid_a_top1, valid_a_top5 = valid_func(
        valid_loader, network, criterion
    )
    logger.log(
        "[{:}] evaluate  : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%".format(
            epoch_str, valid_a_loss, valid_a_top1, valid_a_top5
        )
    )
    cur_arch, cur_valid_acc = search_find_best(
        valid_loader, network, xargs.select_num
    )
    logger.log(
        "[{:}] find-the-best : {:}, accuracy@1={:.2f}%".format(
            epoch_str, cur_arch, cur_valid_acc
        )
    )
    genotypes[epoch] = cur_arch
    # check the best accuracy
    valid_accuracies[epoch] = valid_a_top1
    if valid_a_top1 > valid_accuracies["best"]:
        valid_accuracies["best"] = valid_a_top1
        find_best = True
    else:
        find_best = False

    # save checkpoint
    save_path = save_checkpoint(
        {
            "epoch": epoch + 1,
            "args": deepcopy(xargs),
            "search_model": search_model.state_dict(),
            "w_optimizer": w_optimizer.state_dict(),
            "w_scheduler": w_scheduler.state_dict(),
            "genotypes": genotypes,
            "valid_accuracies": valid_accuracies,
        },
        model_base_path,
        logger,
    )
    last_info = save_checkpoint(
        {
            "epoch": epoch + 1,
            "args": deepcopy(args),
            "last_checkpoint": save_path,
        },
        logger.path("info"),
        logger,
    )
    if find_best:
        logger.log(
            "<<<--->>> The {:}-th epoch : find the highest validation accuracy : {:.2f}%.".format(
                epoch_str, valid_a_top1
            )
        )
        copy_checkpoint(model_base_path, model_best_path, logger)
    if api is not None:
        logger.log("{:}".format(api.query_by_arch(genotypes[epoch], "200")))
    # measure elapsed time
    epoch_time.update(time.time() - start_time)
    start_time = time.time()

logger.log("\n" + "-" * 200)
logger.log("Pre-searching costs {:.1f} s".format(search_time.sum))
start_time = time.time()
best_arch, best_acc = search_find_best(valid_loader, network, xargs.select_num)
search_time.update(time.time() - start_time)
logger.log(
    "RANDOM-NAS finds the best one : {:} with accuracy={:.2f}%, with {:.1f} s.".format(
        best_arch, best_acc, search_time.sum
    )
)
if api is not None:
    logger.log("{:}".format(api.query_by_arch(best_arch, "200")))
logger.close()
# Out:
# [Search the 000-250-th epoch] Time Left: [00:00:00], LR=0.025
# *SEARCH* [2022-10-20 06:01:43] [000-250][000/391] Time 2.90 (2.90) Data 0.17 (0.17) Base [Loss 2.344 (2.344)  Prec@1 7.81 (7.81) Prec@5 46.88 (46.88)]
# *SEARCH* [2022-10-20 06:01:54] [000-250][100/391] Time 0.08 (0.14) Data 0.00 (0.00) Base [Loss 2.361 (2.318)  Prec@1 14.06 (10.04) Prec@5 46.88 (50.56)]
# *SEARCH* [2022-10-20 06:02:04] [000-250][200/391] Time 0.19 (0.12) Data 0.00 (0.00) Base [Loss 2.330 (2.313)  Prec@1 10.94 (10.41) Prec@5 37.50 (51.66)]
# *SEARCH* [2022-10-20 06:02:17] [000-250][300/391] Time 0.19 (0.12) Data 0.00 (0.00) Base [Loss 2.257 (2.309)  Prec@1 14.06 (10.76) Prec@5 57.81 (52.19)]
# *SEARCH* [2022-10-20 06:02:29] [000-250][390/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 2.330 (2.304)  Prec@1 10.00 (10.98) Prec@5 47.50 (52.71)]
# [000-250] searching : loss=2.30, accuracy@1=10.98%, accuracy@5=52.71%, time-cost=48.7 s
# [000-250] evaluate  : loss=2.30, accuracy@1=11.09%, accuracy@5=53.30%
# [000-250] find-the-best : [Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|none~1|+|skip_connect~0|none~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|skip_connect~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|skip_connect~2|)], accuracy@1=16.80%
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 000-250-th epoch : find the highest validation accuracy : 11.09%.
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 001-250-th epoch] Time Left: [04:19:25], LR=0.024999052530445796
# *SEARCH* [2022-10-20 06:02:43] [001-250][000/391] Time 0.37 (0.37) Data 0.28 (0.28) Base [Loss 2.314 (2.314)  Prec@1 12.50 (12.50) Prec@5 62.50 (62.50)]
# *SEARCH* [2022-10-20 06:02:51] [001-250][100/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 2.231 (2.286)  Prec@1 14.06 (12.30) Prec@5 53.12 (53.65)]
# *SEARCH* [2022-10-20 06:02:59] [001-250][200/391] Time 0.08 (0.08) Data 0.00 (0.00) Base [Loss 2.254 (2.284)  Prec@1 9.38 (11.91) Prec@5 57.81 (54.63)]
# *SEARCH* [2022-10-20 06:03:08] [001-250][300/391] Time 0.07 (0.08) Data 0.00 (0.00) Base [Loss 2.295 (2.283)  Prec@1 12.50 (12.11) Prec@5 56.25 (54.98)]
# *SEARCH* [2022-10-20 06:03:15] [001-250][390/391] Time 0.07 (0.08) Data 0.00 (0.00) Base [Loss 2.246 (2.282)  Prec@1 12.50 (12.23) Prec@5 65.00 (55.37)]
# [001-250] searching : loss=2.28, accuracy@1=12.23%, accuracy@5=55.37%, time-cost=81.4 s
# [001-250] evaluate  : loss=2.28, accuracy@1=12.36%, accuracy@5=55.62%
# [001-250] find-the-best : [Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|none~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|none~2|), Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)], accuracy@1=19.14%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 001-250-th epoch : find the highest validation accuracy : 12.36%.
# Find tmp/checkpoint/seed-27924-best.pth exist, delete is at first before saving
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 002-250-th epoch] Time Left: [03:22:11], LR=0.024996210271399602
# *SEARCH* [2022-10-20 06:03:32] [002-250][000/391] Time 0.37 (0.37) Data 0.28 (0.28) Base [Loss 2.254 (2.254)  Prec@1 21.88 (21.88) Prec@5 68.75 (68.75)]
# *SEARCH* [2022-10-20 06:03:40] [002-250][100/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 2.304 (2.271)  Prec@1 15.62 (12.73) Prec@5 53.12 (55.55)]
# *SEARCH* [2022-10-20 06:03:49] [002-250][200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 2.287 (2.270)  Prec@1 7.81 (12.55) Prec@5 60.94 (56.30)]
# *SEARCH* [2022-10-20 06:03:57] [002-250][300/391] Time 0.14 (0.09) Data 0.00 (0.00) Base [Loss 2.297 (2.270)  Prec@1 9.38 (12.96) Prec@5 56.25 (56.37)]
# *SEARCH* [2022-10-20 06:04:04] [002-250][390/391] Time 0.07 (0.08) Data 0.00 (0.00) Base [Loss 2.319 (2.266)  Prec@1 17.50 (12.98) Prec@5 47.50 (56.72)]
# [002-250] searching : loss=2.27, accuracy@1=12.98%, accuracy@5=56.72%, time-cost=114.6 s
# [002-250] evaluate  : loss=2.26, accuracy@1=12.56%, accuracy@5=57.33%
# [002-250] find-the-best : [Structure(4 nodes with |none~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|none~1|skip_connect~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|skip_connect~1|skip_connect~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|none~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|none~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|none~2|)], accuracy@1=17.38%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 002-250-th epoch : find the highest validation accuracy : 12.56%.
# Find tmp/checkpoint/seed-27924-best.pth exist, delete is at first before saving
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 003-250-th epoch] Time Left: [03:15:43], LR=0.02499147367168707
# *SEARCH* [2022-10-20 06:04:19] [003-250][000/391] Time 0.49 (0.49) Data 0.35 (0.35) Base [Loss 2.168 (2.168)  Prec@1 15.62 (15.62) Prec@5 65.62 (65.62)]
# *SEARCH* [2022-10-20 06:04:32] [003-250][100/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 2.318 (2.267)  Prec@1 4.69 (12.55) Prec@5 48.44 (56.82)]
# *SEARCH* [2022-10-20 06:04:47] [003-250][200/391] Time 0.14 (0.14) Data 0.00 (0.00) Base [Loss 2.203 (2.262)  Prec@1 21.88 (12.92) Prec@5 67.19 (57.48)]
# *SEARCH* [2022-10-20 06:05:02] [003-250][300/391] Time 0.21 (0.14) Data 0.00 (0.00) Base [Loss 2.305 (2.251)  Prec@1 6.25 (13.56) Prec@5 54.69 (58.88)]
# *SEARCH* [2022-10-20 06:05:15] [003-250][390/391] Time 0.14 (0.14) Data 0.00 (0.00) Base [Loss 2.304 (2.249)  Prec@1 10.00 (13.65) Prec@5 47.50 (59.11)]
# [003-250] searching : loss=2.25, accuracy@1=13.65%, accuracy@5=59.11%, time-cost=171.1 s
# [003-250] evaluate  : loss=2.24, accuracy@1=13.76%, accuracy@5=60.13%
# [003-250] find-the-best : [Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|none~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|none~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)], accuracy@1=19.73%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 003-250-th epoch : find the highest validation accuracy : 13.76%.
# Find tmp/checkpoint/seed-27924-best.pth exist, delete is at first before saving
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 004-250-th epoch] Time Left: [04:53:31], LR=0.024984843479272212
# *SEARCH* [2022-10-20 06:05:31] [004-250][000/391] Time 0.38 (0.38) Data 0.27 (0.27) Base [Loss 2.174 (2.174)  Prec@1 20.31 (20.31) Prec@5 67.19 (67.19)]
# *SEARCH* [2022-10-20 06:05:40] [004-250][100/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 2.401 (2.225)  Prec@1 10.94 (15.04) Prec@5 57.81 (61.82)]
# *SEARCH* [2022-10-20 06:05:55] [004-250][200/391] Time 0.21 (0.12) Data 0.00 (0.00) Base [Loss 2.173 (2.228)  Prec@1 14.06 (14.93) Prec@5 65.62 (60.95)]
# *SEARCH* [2022-10-20 06:06:09] [004-250][300/391] Time 0.21 (0.13) Data 0.00 (0.00) Base [Loss 2.192 (2.226)  Prec@1 12.50 (14.62) Prec@5 67.19 (61.43)]
# *SEARCH* [2022-10-20 06:06:18] [004-250][390/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 2.184 (2.227)  Prec@1 20.00 (14.40) Prec@5 65.00 (61.29)]
# [004-250] searching : loss=2.23, accuracy@1=14.40%, accuracy@5=61.29%, time-cost=218.6 s
# [004-250] evaluate  : loss=2.23, accuracy@1=14.21%, accuracy@5=61.72%
# [004-250] find-the-best : [Structure(4 nodes with |none~0|+|none~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|none~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|skip_connect~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)], accuracy@1=20.90%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 004-250-th epoch : find the highest validation accuracy : 14.21%.
# Find tmp/checkpoint/seed-27924-best.pth exist, delete is at first before saving
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 005-250-th epoch] Time Left: [04:10:58], LR=0.02497632074113926
# *SEARCH* [2022-10-20 06:06:32] [005-250][000/391] Time 0.38 (0.38) Data 0.28 (0.28) Base [Loss 2.321 (2.321)  Prec@1 15.62 (15.62) Prec@5 45.31 (45.31)]
# *SEARCH* [2022-10-20 06:06:42] [005-250][100/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 2.183 (2.220)  Prec@1 18.75 (14.71) Prec@5 60.94 (61.51)]
# *SEARCH* [2022-10-20 06:06:51] [005-250][200/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 2.317 (2.214)  Prec@1 4.69 (15.07) Prec@5 56.25 (62.35)]
# *SEARCH* [2022-10-20 06:07:02] [005-250][300/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 2.306 (2.214)  Prec@1 10.94 (15.31) Prec@5 51.56 (62.40)]
# *SEARCH* [2022-10-20 06:07:11] [005-250][390/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 2.015 (2.216)  Prec@1 42.50 (15.16) Prec@5 72.50 (62.00)]
# [005-250] searching : loss=2.22, accuracy@1=15.16%, accuracy@5=62.00%, time-cost=257.7 s
# [005-250] evaluate  : loss=2.22, accuracy@1=15.00%, accuracy@5=62.56%
# [005-250] find-the-best : [Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|skip_connect~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|none~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|skip_connect~1|none~2|), Structure(4 nodes with |skip_connect~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |none~0|+|none~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|none~0|skip_connect~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|none~1|+|none~0|none~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|none~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|)], accuracy@1=26.37%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 005-250-th epoch : find the highest validation accuracy : 15.00%.
# Find tmp/checkpoint/seed-27924-best.pth exist, delete is at first before saving
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 006-250-th epoch] Time Left: [03:38:03], LR=0.024965906803127366
# *SEARCH* [2022-10-20 06:07:26] [006-250][000/391] Time 0.40 (0.40) Data 0.30 (0.30) Base [Loss 2.278 (2.278)  Prec@1 17.19 (17.19) Prec@5 60.94 (60.94)]
# *SEARCH* [2022-10-20 06:07:35] [006-250][100/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 2.157 (2.219)  Prec@1 14.06 (15.10) Prec@5 68.75 (61.71)]
# *SEARCH* [2022-10-20 06:07:45] [006-250][200/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 2.094 (2.215)  Prec@1 9.38 (14.75) Prec@5 73.44 (61.82)]
# *SEARCH* [2022-10-20 06:07:54] [006-250][300/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 2.097 (2.208)  Prec@1 17.19 (15.17) Prec@5 76.56 (62.56)]
# *SEARCH* [2022-10-20 06:08:03] [006-250][390/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 2.084 (2.211)  Prec@1 20.00 (15.21) Prec@5 70.00 (62.60)]
# [006-250] searching : loss=2.21, accuracy@1=15.21%, accuracy@5=62.60%, time-cost=294.9 s
# [006-250] evaluate  : loss=2.21, accuracy@1=14.80%, accuracy@5=63.13%
# [006-250] find-the-best : [Structure(4 nodes with |none~0|+|skip_connect~0|none~1|+|skip_connect~0|none~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|none~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|none~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|none~0|none~1|skip_connect~2|), Structure(4 nodes with |none~0|+|skip_connect~0|none~1|+|none~0|skip_connect~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|skip_connect~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|)], accuracy@1=22.27%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
#
# [Search the 007-250-th epoch] Time Left: [03:19:34], LR=0.024953603309718072
# *SEARCH* [2022-10-20 06:08:15] [007-250][000/391] Time 0.49 (0.49) Data 0.31 (0.31) Base [Loss 2.163 (2.163)  Prec@1 17.19 (17.19) Prec@5 65.62 (65.62)]
# *SEARCH* [2022-10-20 06:08:24] [007-250][100/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 2.296 (2.195)  Prec@1 9.38 (16.01) Prec@5 59.38 (63.68)]
# *SEARCH* [2022-10-20 06:08:32] [007-250][200/391] Time 0.09 (0.09) Data 0.00 (0.00) Base [Loss 2.316 (2.193)  Prec@1 10.94 (15.85) Prec@5 50.00 (64.05)]
# *SEARCH* [2022-10-20 06:08:41] [007-250][300/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 2.164 (2.192)  Prec@1 15.62 (15.88) Prec@5 67.19 (64.30)]
# *SEARCH* [2022-10-20 06:08:48] [007-250][390/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 2.322 (2.194)  Prec@1 7.50 (15.58) Prec@5 47.50 (64.30)]
# [007-250] searching : loss=2.19, accuracy@1=15.58%, accuracy@5=64.30%, time-cost=328.3 s
# [007-250] evaluate  : loss=2.20, accuracy@1=15.79%, accuracy@5=63.99%
# [007-250] find-the-best : [Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|none~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|none~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|none~1|none~2|)], accuracy@1=23.83%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 007-250-th epoch : find the highest validation accuracy : 15.79%.
# Find tmp/checkpoint/seed-27924-best.pth exist, delete is at first before saving
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 008-250-th epoch] Time Left: [03:13:01], LR=0.024939412203775605
# *SEARCH* [2022-10-20 06:09:03] [008-250][000/391] Time 0.56 (0.56) Data 0.31 (0.31) Base [Loss 2.007 (2.007)  Prec@1 32.81 (32.81) Prec@5 79.69 (79.69)]
# *SEARCH* [2022-10-20 06:09:16] [008-250][100/391] Time 0.12 (0.14) Data 0.00 (0.00) Base [Loss 2.062 (2.180)  Prec@1 18.75 (16.94) Prec@5 68.75 (66.94)]
# *SEARCH* [2022-10-20 06:09:30] [008-250][200/391] Time 0.20 (0.13) Data 0.00 (0.00) Base [Loss 2.132 (2.192)  Prec@1 17.19 (15.91) Prec@5 79.69 (65.07)]
# *SEARCH* [2022-10-20 06:09:43] [008-250][300/391] Time 0.12 (0.13) Data 0.00 (0.00) Base [Loss 2.114 (2.189)  Prec@1 17.19 (15.71) Prec@5 75.00 (65.05)]
# *SEARCH* [2022-10-20 06:09:51] [008-250][390/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 2.246 (2.192)  Prec@1 20.00 (15.62) Prec@5 55.00 (64.52)]
# [008-250] searching : loss=2.19, accuracy@1=15.62%, accuracy@5=64.52%, time-cost=376.7 s
# [008-250] evaluate  : loss=2.20, accuracy@1=15.39%, accuracy@5=63.80%
# [008-250] find-the-best : [Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|none~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|)], accuracy@1=23.05%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
#
# [Search the 009-250-th epoch] Time Left: [04:19:51], LR=0.0249233357262401
# *SEARCH* [2022-10-20 06:10:08] [009-250][000/391] Time 0.37 (0.37) Data 0.28 (0.28) Base [Loss 2.261 (2.261)  Prec@1 15.62 (15.62) Prec@5 62.50 (62.50)]
# *SEARCH* [2022-10-20 06:10:16] [009-250][100/391] Time 0.13 (0.09) Data 0.00 (0.00) Base [Loss 2.211 (2.195)  Prec@1 12.50 (14.85) Prec@5 71.88 (65.83)]
# *SEARCH* [2022-10-20 06:10:25] [009-250][200/391] Time 0.09 (0.09) Data 0.00 (0.00) Base [Loss 2.310 (2.191)  Prec@1 9.38 (15.30) Prec@5 46.88 (65.28)]
# *SEARCH* [2022-10-20 06:10:38] [009-250][300/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 2.331 (2.181)  Prec@1 4.69 (15.89) Prec@5 40.62 (65.99)]
# *SEARCH* [2022-10-20 06:10:46] [009-250][390/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 2.312 (2.181)  Prec@1 7.50 (15.84) Prec@5 50.00 (65.69)]
# [009-250] searching : loss=2.18, accuracy@1=15.84%, accuracy@5=65.69%, time-cost=415.8 s
# [009-250] evaluate  : loss=2.19, accuracy@1=15.94%, accuracy@5=64.38%
# [009-250] find-the-best : [Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|skip_connect~1|none~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|none~2|), Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|nor_conv_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|)], accuracy@1=23.63%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 009-250-th epoch : find the highest validation accuracy : 15.94%.
# Find tmp/checkpoint/seed-27924-best.pth exist, delete is at first before saving
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 010-250-th epoch] Time Left: [03:25:15], LR=0.024905376415773738
# *SEARCH* [2022-10-20 06:10:59] [010-250][000/391] Time 0.44 (0.44) Data 0.34 (0.34) Base [Loss 2.186 (2.186)  Prec@1 15.62 (15.62) Prec@5 75.00 (75.00)]
# *SEARCH* [2022-10-20 06:11:09] [010-250][100/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 2.048 (2.165)  Prec@1 17.19 (17.00) Prec@5 76.56 (67.73)]
# *SEARCH* [2022-10-20 06:11:18] [010-250][200/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 2.001 (2.171)  Prec@1 25.00 (16.79) Prec@5 81.25 (66.75)]
# *SEARCH* [2022-10-20 06:11:27] [010-250][300/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 2.172 (2.173)  Prec@1 17.19 (16.81) Prec@5 70.31 (66.38)]
# *SEARCH* [2022-10-20 06:11:37] [010-250][390/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 1.984 (2.172)  Prec@1 25.00 (16.66) Prec@5 72.50 (66.60)]
# [010-250] searching : loss=2.17, accuracy@1=16.66%, accuracy@5=66.60%, time-cost=454.5 s
# [010-250] evaluate  : loss=2.14, accuracy@1=17.35%, accuracy@5=69.83%
# [010-250] find-the-best : [Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|none~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|none~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|)], accuracy@1=26.37%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 010-250-th epoch : find the highest validation accuracy : 17.35%.
# Find tmp/checkpoint/seed-27924-best.pth exist, delete is at first before saving
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 011-250-th epoch] Time Left: [03:33:35], LR=0.024885537108359813
# *SEARCH* [2022-10-20 06:11:53] [011-250][000/391] Time 0.55 (0.55) Data 0.28 (0.28) Base [Loss 1.997 (1.997)  Prec@1 21.88 (21.88) Prec@5 82.81 (82.81)]
# *SEARCH* [2022-10-20 06:12:08] [011-250][100/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 2.300 (2.171)  Prec@1 15.62 (16.07) Prec@5 57.81 (66.09)]
# *SEARCH* [2022-10-20 06:12:22] [011-250][200/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 2.082 (2.164)  Prec@1 21.88 (17.11) Prec@5 76.56 (66.71)]
# *SEARCH* [2022-10-20 06:12:37] [011-250][300/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 2.134 (2.163)  Prec@1 15.62 (17.34) Prec@5 67.19 (66.72)]
# *SEARCH* [2022-10-20 06:12:50] [011-250][390/391] Time 0.21 (0.15) Data 0.00 (0.00) Base [Loss 2.216 (2.161)  Prec@1 27.50 (17.28) Prec@5 72.50 (66.84)]
# [011-250] searching : loss=2.16, accuracy@1=17.28%, accuracy@5=66.84%, time-cost=512.7 s
# [011-250] evaluate  : loss=2.16, accuracy@1=17.04%, accuracy@5=68.03%
# [011-250] find-the-best : [Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|none~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|)], accuracy@1=24.61%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
#
# [Search the 012-250-th epoch] Time Left: [04:45:29], LR=0.02486382093685497
# *SEARCH* [2022-10-20 06:13:05] [012-250][000/391] Time 0.40 (0.40) Data 0.30 (0.30) Base [Loss 2.334 (2.334)  Prec@1 7.81 (7.81) Prec@5 46.88 (46.88)]
# *SEARCH* [2022-10-20 06:13:18] [012-250][100/391] Time 0.14 (0.14) Data 0.00 (0.00) Base [Loss 2.332 (2.156)  Prec@1 7.81 (17.13) Prec@5 35.94 (66.58)]
# *SEARCH* [2022-10-20 06:13:33] [012-250][200/391] Time 0.14 (0.14) Data 0.00 (0.00) Base [Loss 2.109 (2.150)  Prec@1 14.06 (17.48) Prec@5 71.88 (67.46)]
# *SEARCH* [2022-10-20 06:13:47] [012-250][300/391] Time 0.12 (0.14) Data 0.00 (0.00) Base [Loss 2.293 (2.143)  Prec@1 12.50 (17.77) Prec@5 51.56 (68.16)]
# *SEARCH* [2022-10-20 06:13:55] [012-250][390/391] Time 0.07 (0.13) Data 0.00 (0.00) Base [Loss 2.311 (2.141)  Prec@1 10.00 (17.88) Prec@5 47.50 (68.40)]
# [012-250] searching : loss=2.14, accuracy@1=17.88%, accuracy@5=68.40%, time-cost=563.2 s
# [012-250] evaluate  : loss=2.21, accuracy@1=14.95%, accuracy@5=61.42%
# [012-250] find-the-best : [Structure(4 nodes with |none~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|skip_connect~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|none~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|none~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|)], accuracy@1=24.80%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
#
# [Search the 013-250-th epoch] Time Left: [04:18:56], LR=0.024840231330494417
# *SEARCH* [2022-10-20 06:14:10] [013-250][000/391] Time 0.55 (0.55) Data 0.31 (0.31) Base [Loss 2.029 (2.029)  Prec@1 18.75 (18.75) Prec@5 81.25 (81.25)]
# *SEARCH* [2022-10-20 06:14:22] [013-250][100/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 2.179 (2.135)  Prec@1 15.62 (17.73) Prec@5 68.75 (68.47)]
# *SEARCH* [2022-10-20 06:14:32] [013-250][200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 2.108 (2.130)  Prec@1 18.75 (17.93) Prec@5 76.56 (69.35)]
# *SEARCH* [2022-10-20 06:14:41] [013-250][300/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 2.033 (2.132)  Prec@1 18.75 (18.09) Prec@5 81.25 (69.14)]
# *SEARCH* [2022-10-20 06:14:50] [013-250][390/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 2.212 (2.133)  Prec@1 25.00 (17.95) Prec@5 65.00 (69.02)]
# [013-250] searching : loss=2.13, accuracy@1=17.95%, accuracy@5=69.02%, time-cost=603.1 s
# [013-250] evaluate  : loss=2.13, accuracy@1=18.21%, accuracy@5=68.42%
# [013-250] find-the-best : [Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|none~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|none~1|+|skip_connect~0|none~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|skip_connect~0|none~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|none~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|none~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|none~1|skip_connect~2|)], accuracy@1=27.54%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 013-250-th epoch : find the highest validation accuracy : 18.21%.
# Find tmp/checkpoint/seed-27924-best.pth exist, delete is at first before saving
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 014-250-th epoch] Time Left: [03:30:45], LR=0.024814772014350468
# *SEARCH* [2022-10-20 06:15:04] [014-250][000/391] Time 0.47 (0.47) Data 0.32 (0.32) Base [Loss 2.119 (2.119)  Prec@1 20.31 (20.31) Prec@5 73.44 (73.44)]
# *SEARCH* [2022-10-20 06:15:19] [014-250][100/391] Time 0.21 (0.15) Data 0.00 (0.00) Base [Loss 2.014 (2.128)  Prec@1 21.88 (18.64) Prec@5 82.81 (70.87)]
# *SEARCH* [2022-10-20 06:15:34] [014-250][200/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 2.304 (2.125)  Prec@1 14.06 (19.29) Prec@5 68.75 (70.45)]
# *SEARCH* [2022-10-20 06:15:49] [014-250][300/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 2.017 (2.125)  Prec@1 23.44 (19.23) Prec@5 78.12 (69.67)]
# *SEARCH* [2022-10-20 06:16:02] [014-250][390/391] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 2.299 (2.123)  Prec@1 10.00 (19.14) Prec@5 50.00 (69.94)]
# [014-250] searching : loss=2.12, accuracy@1=19.14%, accuracy@5=69.94%, time-cost=661.6 s
# [014-250] evaluate  : loss=2.07, accuracy@1=20.94%, accuracy@5=74.72%
# [014-250] find-the-best : [Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|none~1|skip_connect~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|skip_connect~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|skip_connect~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|), Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|none~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|none~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|nor_conv_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|none~2|)], accuracy@1=27.34%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
# <<<--->>> The 014-250-th epoch : find the highest validation accuracy : 20.94%.
# Find tmp/checkpoint/seed-27924-best.pth exist, delete is at first before saving
# copy the file from tmp/checkpoint/seed-27924-basic.pth into tmp/checkpoint/seed-27924-best.pth
#
# [Search the 015-250-th epoch] Time Left: [04:43:15], LR=0.024787447008744266
# *SEARCH* [2022-10-20 06:16:16] [015-250][000/391] Time 0.54 (0.54) Data 0.28 (0.28) Base [Loss 2.110 (2.110)  Prec@1 23.44 (23.44) Prec@5 71.88 (71.88)]
# *SEARCH* [2022-10-20 06:16:31] [015-250][100/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 2.319 (2.122)  Prec@1 9.38 (18.86) Prec@5 39.06 (68.97)]
# *SEARCH* [2022-10-20 06:16:42] [015-250][200/391] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 2.310 (2.137)  Prec@1 17.19 (18.07) Prec@5 48.44 (67.55)]
# *SEARCH* [2022-10-20 06:16:52] [015-250][300/391] Time 0.14 (0.12) Data 0.00 (0.00) Base [Loss 2.070 (2.123)  Prec@1 21.88 (18.83) Prec@5 76.56 (68.89)]
# ...
# save checkpoint into tmp/seed-27924-last-info.pth
#
# [Search the 019-250-th epoch] Time Left: [03:10:20], LR=0.02465958079497609
# *SEARCH* [2022-10-20 06:19:56] [019-250][000/391] Time 0.45 (0.45) Data 0.35 (0.35) Base [Loss 2.300 (2.300)  Prec@1 10.94 (10.94) Prec@5 56.25 (56.25)]
# *SEARCH* [2022-10-20 06:20:05] [019-250][100/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 2.113 (2.086)  Prec@1 12.50 (19.82) Prec@5 79.69 (71.32)]
# *SEARCH* [2022-10-20 06:20:15] [019-250][200/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 2.315 (2.096)  Prec@1 9.38 (19.54) Prec@5 37.50 (70.70)]
# *SEARCH* [2022-10-20 06:20:24] [019-250][300/391] Time 0.16 (0.10) Data 0.00 (0.00) Base [Loss 2.308 (2.095)  Prec@1 7.81 (19.46) Prec@5 45.31 (70.66)]
# *SEARCH* [2022-10-20 06:20:36] [019-250][390/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 2.036 (2.090)  Prec@1 25.00 (19.50) Prec@5 70.00 (71.08)]
# [019-250] searching : loss=2.09, accuracy@1=19.50%, accuracy@5=71.08%, time-cost=869.6 s
# [019-250] evaluate  : loss=2.11, accuracy@1=18.81%, accuracy@5=70.36%
# [019-250] find-the-best : [Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|none~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |none~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|none~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|skip_connect~2|), Structure(4 nodes with |none~0|+|none~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)], accuracy@1=29.49%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
#
# [Search the 020-250-th epoch] Time Left: [03:31:16], LR=0.024622997933543573
# *SEARCH* [2022-10-20 06:20:51] [020-250][000/391] Time 0.47 (0.47) Data 0.30 (0.30) Base [Loss 1.916 (1.916)  Prec@1 28.12 (28.12) Prec@5 82.81 (82.81)]
# *SEARCH* [2022-10-20 06:21:00] [020-250][100/391] Time 0.14 (0.09) Data 0.00 (0.00) Base [Loss 2.300 (2.091)  Prec@1 14.06 (18.98) Prec@5 42.19 (70.36)]
# *SEARCH* [2022-10-20 06:21:09] [020-250][200/391] Time 0.15 (0.09) Data 0.00 (0.00) Base [Loss 2.313 (2.088)  Prec@1 10.94 (19.52) Prec@5 50.00 (70.38)]
# *SEARCH* [2022-10-20 06:21:18] [020-250][300/391] Time 0.09 (0.09) Data 0.00 (0.00) Base [Loss 1.983 (2.087)  Prec@1 29.69 (19.66) Prec@5 82.81 (70.84)]
# *SEARCH* [2022-10-20 06:21:27] [020-250][390/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 2.093 (2.086)  Prec@1 17.50 (19.66) Prec@5 72.50 (70.90)]
# [020-250] searching : loss=2.09, accuracy@1=19.66%, accuracy@5=70.90%, time-cost=905.9 s
# [020-250] evaluate  : loss=2.12, accuracy@1=18.08%, accuracy@5=68.52%
# [020-250] find-the-best : [Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|none~0|none~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|skip_connect~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|skip_connect~0|none~1|+|none~0|avg_pool_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |none~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_3x3~2|)], accuracy@1=28.71%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
#
# [Search the 021-250-th epoch] Time Left: [03:15:31], LR=0.02458457966599929
# *SEARCH* [2022-10-20 06:21:42] [021-250][000/391] Time 0.39 (0.39) Data 0.28 (0.28) Base [Loss 2.308 (2.308)  Prec@1 6.25 (6.25) Prec@5 48.44 (48.44)]
# *SEARCH* [2022-10-20 06:21:55] [021-250][100/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 1.929 (2.082)  Prec@1 25.00 (19.28) Prec@5 81.25 (70.70)]
# *SEARCH* [2022-10-20 06:22:10] [021-250][200/391] Time 0.14 (0.14) Data 0.00 (0.00) Base [Loss 2.095 (2.082)  Prec@1 21.88 (19.39) Prec@5 81.25 (70.59)]
# *SEARCH* [2022-10-20 06:22:24] [021-250][300/391] Time 0.14 (0.14) Data 0.00 (0.00) Base [Loss 2.305 (2.086)  Prec@1 6.25 (19.37) Prec@5 50.00 (70.40)]
# *SEARCH* [2022-10-20 06:22:35] [021-250][390/391] Time 0.08 (0.14) Data 0.00 (0.00) Base [Loss 2.002 (2.086)  Prec@1 15.00 (19.48) Prec@5 77.50 (70.28)]
# [021-250] searching : loss=2.09, accuracy@1=19.48%, accuracy@5=70.28%, time-cost=958.8 s
# [021-250] evaluate  : loss=2.07, accuracy@1=20.10%, accuracy@5=71.72%
# [021-250] find-the-best : [Structure(4 nodes with |none~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|none~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|none~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|none~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|skip_connect~1|none~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|none~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|)], accuracy@1=30.08%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
#
# [Search the 022-250-th epoch] Time Left: [04:16:37], LR=0.02454433205903303
# *SEARCH* [2022-10-20 06:22:50] [022-250][000/391] Time 0.39 (0.39) Data 0.29 (0.29) Base [Loss 1.950 (1.950)  Prec@1 29.69 (29.69) Prec@5 79.69 (79.69)]
# *SEARCH* [2022-10-20 06:22:59] [022-250][100/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 2.054 (2.070)  Prec@1 23.44 (19.97) Prec@5 75.00 (71.92)]
# *SEARCH* [2022-10-20 06:23:09] [022-250][200/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 2.337 (2.072)  Prec@1 7.81 (19.94) Prec@5 43.75 (71.31)]
# *SEARCH* [2022-10-20 06:23:18] [022-250][300/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 1.911 (2.071)  Prec@1 28.12 (19.84) Prec@5 79.69 (71.35)]
# *SEARCH* [2022-10-20 06:23:27] [022-250][390/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 2.301 (2.072)  Prec@1 5.00 (19.62) Prec@5 57.50 (71.38)]
# [022-250] searching : loss=2.07, accuracy@1=19.62%, accuracy@5=71.38%, time-cost=996.3 s
# [022-250] evaluate  : loss=2.06, accuracy@1=20.56%, accuracy@5=72.63%
# [022-250] find-the-best : [Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|none~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|avg_pool_3x3~2|), Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|none~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|none~1|+|skip_connect~0|none~1|nor_conv_3x3~2|)], accuracy@1=29.30%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
#
# [Search the 023-250-th epoch] Time Left: [03:08:17], LR=0.02450226146820851
# *SEARCH* [2022-10-20 06:23:40] [023-250][000/391] Time 0.53 (0.53) Data 0.27 (0.27) Base [Loss 2.308 (2.308)  Prec@1 4.69 (4.69) Prec@5 37.50 (37.50)]
# *SEARCH* [2022-10-20 06:23:54] [023-250][100/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 1.894 (2.071)  Prec@1 28.12 (19.28) Prec@5 85.94 (69.99)]
# *SEARCH* [2022-10-20 06:24:09] [023-250][200/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 2.293 (2.082)  Prec@1 10.94 (19.12) Prec@5 59.38 (69.57)]
# *SEARCH* [2022-10-20 06:24:24] [023-250][300/391] Time 0.21 (0.15) Data 0.00 (0.00) Base [Loss 1.807 (2.073)  Prec@1 35.94 (19.54) Prec@5 90.62 (70.62)]
# *SEARCH* [2022-10-20 06:24:36] [023-250][390/391] Time 0.12 (0.14) Data 0.00 (0.00) Base [Loss 2.292 (2.078)  Prec@1 15.00 (19.65) Prec@5 55.00 (70.37)]
# [023-250] searching : loss=2.08, accuracy@1=19.65%, accuracy@5=70.37%, time-cost=1053.0 s
# [023-250] evaluate  : loss=2.07, accuracy@1=20.76%, accuracy@5=71.82%
# [023-250] find-the-best : [Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|avg_pool_3x3~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |none~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|), Structure(4 nodes with |none~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_1x1~1|+|none~0|skip_connect~1|none~2|), Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_1x1~0|nor_conv_1x1~1|nor_conv_1x1~2|)], accuracy@1=30.08%
# Find tmp/checkpoint/seed-27924-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/checkpoint/seed-27924-basic.pth
# Find tmp/seed-27924-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/seed-27924-last-info.pth
#
# [Search the 024-250-th epoch] Time Left: [04:27:47], LR=0.024458374536959718
# *SEARCH* [2022-10-20 06:24:51] [024-250][000/391] Time 0.43 (0.43) Data 0.35 (0.35) Base [Loss 2.313 (2.313)  Prec@1 12.50 (12.50) Prec@5 48.44 (48.44)]
# *SEARCH* [2022-10-20 06:24:59] [024-250][100/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 1.910 (2.063)  Prec@1 23.44 (20.53) Prec@5 81.25 (71.70)]
# *SEARCH* [2022-10-20 06:25:07] [024-250][200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 2.325 (2.070)  Prec@1 7.81 (20.72) Prec@5 46.88 (71.67)]
# *SEARCH* [2022-10-20 06:25:16] [024-250][300/391] Time 0.13 (0.08) Data 0.00 (0.00) Base [Loss 2.045 (2.062)  Prec@1 20.31 (20.89) Prec@5 73.44 (72.13)]
# *SEARCH* [2022-10-20 06:25:27] [024-250][390/391] Time 0.12 (0.09) Data 0.00 (0.00) Base [Loss 1.938 (2.060)  Prec@1 17.50 (20.74) Prec@5 82.50 (72.15)]
# [024-250] searching : loss=2.06, accuracy@1=20.74%, accuracy@5=72.15%, time-cost=1090.0 s
# [024-250] evaluate  : loss=2.06, accuracy@1=20.44%, accuracy@5=71.49%

# %%
torch.save(search_model.state_dict(), "./cell_wise_250ep_cosine.pth")

# %% [markdown]
# # Train a found model

# %%
print(best_arch)
import copy
best_arch_copy = copy.deepcopy(best_arch)
# Out:
# [Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|none~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|none~1|skip_connect~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|), Structure(4 nodes with |none~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|skip_connect~2|), Structure(4 nodes with |avg_pool_3x3~0|+|none~0|none~1|+|avg_pool_3x3~0|skip_connect~1|none~2|), Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|), Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_1x1~1|skip_connect~2|), Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|none~0|avg_pool_3x3~1|none~2|), Structure(4 nodes with |none~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_1x1~2|), Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|), Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|), Structure(4 nodes with |nor_conv_1x1~0|+|none~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)]

# %%
print(args)
args.save_dir = '../results/NB201/test'
# Out:
# Namespace(arch_nas_dataset=None, channel=16, config_path='../configs/RANDOM.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=100, rand_seed=16467, save_dir='../results/NB201/test', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
print(config)
# Out:
# Configure(scheduler='cos', eta_min=0.0, epochs=200, warmup=0, optim='SGD', LR=0.1, decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=256, class_num=10, xshape=(1, 3, 32, 32))

# %%
logger = prepare_logger(args)

cifar_train_config_path = "../configs/nas-benchmark/CIFAR.config"
###
train_data, valid_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(cifar_train_config_path, {"class_num": class_num, "xshape": xshape}, logger)
search_loader, _, valid_loader = get_nas_search_loaders(train_data,
                                                        valid_data,
                                                        xargs.dataset,
                                                        "../configs/nas-benchmark/",
                                                        (config.batch_size, config.batch_size),
                                                        xargs.workers)
logger.log("||||||| {:10s} ||||||| Search-Loader-Num={:}, Valid-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(search_loader), len(valid_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": True, # true for eval
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))

network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)

start_epoch, valid_accuracies, genotypes = 0, {"best": -1}, {}
# Out:
# Main Function with logger : Logger(dir=../results/NB201/test, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : None
# channel          : 16
# config_path      : ../configs/RANDOM.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 100
# rand_seed        : 16467
# save_dir         : ../results/NB201/test
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None
# Files already downloaded and verified
# Files already downloaded and verified
# ../configs/nas-benchmark/CIFAR.config
# Configure(scheduler='cos', eta_min=0.0, epochs=200, warmup=0, optim='SGD', LR=0.1, decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=256, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Search-Loader-Num=98, Valid-Loader-Num=98, batch size=256
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', eta_min=0.0, epochs=200, warmup=0, optim='SGD', LR=0.1, decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=256, class_num=10, xshape=(1, 3, 32, 32))
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.1
#     lr: 0.1
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=200, current::epoch=0, iter=0.00, type=cosine, T-max=200, eta-min=0.0)
# criterion   : CrossEntropyLoss()

# %%
from custom_search_cells import NAS201SearchCell as SearchCell

i = 0
for cell in network.module.cells:
    if isinstance(cell, SearchCell):
        cell.arch_cache = best_arch[i]
        i = i+1
print(i)
print(len(best_arch))
# Out:
# 15
# 15

# %%
def search_func_one_arch(xloader, network, criterion, scheduler, w_optimizer, epoch_str, print_freq, logger):
    data_time, batch_time = AverageMeter(), AverageMeter()
    base_losses, base_top1, base_top5 = AverageMeter(), AverageMeter(), AverageMeter()
    network.train()
    end = time.time()
    for step, (base_inputs, base_targets, arch_inputs, arch_targets) in enumerate(
        xloader
    ):
        scheduler.update(None, 1.0 * step / len(xloader))
        base_targets = base_targets.cuda(non_blocking=True)
        arch_targets = arch_targets.cuda(non_blocking=True)
        # measure data loading time
        data_time.update(time.time() - end)

        # update the weights
        ### sample a cell-wise randomized network
#         network.module.random_genotype_per_cell(True)
        ###
        w_optimizer.zero_grad()
        _, logits = network(base_inputs)
        base_loss = criterion(logits, base_targets)
        base_loss.backward()
        nn.utils.clip_grad_norm_(network.parameters(), 5)
        w_optimizer.step()
        # record
        base_prec1, base_prec5 = obtain_accuracy(
            logits.data, base_targets.data, topk=(1, 5)
        )
        base_losses.update(base_loss.item(), base_inputs.size(0))
        base_top1.update(base_prec1.item(), base_inputs.size(0))
        base_top5.update(base_prec5.item(), base_inputs.size(0))

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if step % print_freq == 0 or step + 1 == len(xloader):
            Sstr = (
                "*SEARCH* "
                + time_string()
                + " [{:}][{:03d}/{:03d}]".format(epoch_str, step, len(xloader))
            )
            Tstr = "Time {batch_time.val:.2f} ({batch_time.avg:.2f}) Data {data_time.val:.2f} ({data_time.avg:.2f})".format(
                batch_time=batch_time, data_time=data_time
            )
            Wstr = "Base [Loss {loss.val:.3f} ({loss.avg:.3f})  Prec@1 {top1.val:.2f} ({top1.avg:.2f}) Prec@5 {top5.val:.2f} ({top5.avg:.2f})]".format(
                loss=base_losses, top1=base_top1, top5=base_top5
            )
            logger.log(Sstr + " " + Tstr + " " + Wstr)
    return base_losses.avg, base_top1.avg, base_top5.avg

def valid_func_one_arch(xloader, network, criterion):
    data_time, batch_time = AverageMeter(), AverageMeter()
    arch_losses, arch_top1, arch_top5 = AverageMeter(), AverageMeter(), AverageMeter()
    network.eval()
    end = time.time()
    with torch.no_grad():
        for step, (arch_inputs, arch_targets) in enumerate(xloader):
            arch_targets = arch_targets.cuda(non_blocking=True)
            # measure data loading time
            data_time.update(time.time() - end)
            # prediction

#             network.module.random_genotype_per_cell(True)
            _, logits = network(arch_inputs)
            arch_loss = criterion(logits, arch_targets)
            # record
            arch_prec1, arch_prec5 = obtain_accuracy(
                logits.data, arch_targets.data, topk=(1, 5)
            )
            arch_losses.update(arch_loss.item(), arch_inputs.size(0))
            arch_top1.update(arch_prec1.item(), arch_inputs.size(0))
            arch_top5.update(arch_prec5.item(), arch_inputs.size(0))
            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()
    return arch_losses.avg, arch_top1.avg, arch_top5.avg

# %%
start_time, search_time, epoch_time, total_epoch = (
    time.time(),
    AverageMeter(),
    AverageMeter(),
    config.epochs + config.warmup,
)
for epoch in range(0, total_epoch):
    w_scheduler.update(epoch, 0.0)
    need_time = "Time Left: {:}".format(
        convert_secs2time(epoch_time.val * (total_epoch - epoch), True)
    )
    epoch_str = "{:03d}-{:03d}".format(epoch, total_epoch)
    logger.log(
        "\n[Search the {:}-th epoch] {:}, LR={:}".format(
            epoch_str, need_time, min(w_scheduler.get_lr())
        )
    )

    # selected_arch = search_find_best(valid_loader, network, criterion, xargs.select_num)
    search_w_loss, search_w_top1, search_w_top5 = search_func_one_arch(
        search_loader,
        network,
        criterion,
        w_scheduler,
        w_optimizer,
        epoch_str,
        xargs.print_freq,
        logger,
    )
    search_time.update(time.time() - start_time)
    logger.log(
        "[{:}] searching : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%, time-cost={:.1f} s".format(
            epoch_str, search_w_loss, search_w_top1, search_w_top5, search_time.sum
        )
    )
    valid_a_loss, valid_a_top1, valid_a_top5 = valid_func_one_arch(
        valid_loader, network, criterion
    )
    logger.log(
        "[{:}] evaluate  : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%".format(
            epoch_str, valid_a_loss, valid_a_top1, valid_a_top5
        )
    )
    
    # check the best accuracy
    valid_accuracies[epoch] = valid_a_top1
    if valid_a_top1 > valid_accuracies["best"]:
        valid_accuracies["best"] = valid_a_top1
        find_best = True
    else:
        find_best = False

    # save checkpoint
    save_path = save_checkpoint(
        {
            "epoch": epoch + 1,
            "args": deepcopy(xargs),
            "search_model": search_model.state_dict(),
            "w_optimizer": w_optimizer.state_dict(),
            "w_scheduler": w_scheduler.state_dict(),
            "genotypes": genotypes,
            "valid_accuracies": valid_accuracies,
        },
        model_base_path,
        logger,
    )
    last_info = save_checkpoint(
        {
            "epoch": epoch + 1,
            "args": deepcopy(args),
            "last_checkpoint": save_path,
        },
        logger.path("info"),
        logger,
    )
    if find_best:
        logger.log(
            "<<<--->>> The {:}-th epoch : find the highest validation accuracy : {:.2f}%.".format(
                epoch_str, valid_a_top1
            )
        )
        copy_checkpoint(model_base_path, model_best_path, logger)
    if api is not None:
        logger.log("{:}".format(api.query_by_arch(genotypes[epoch], "200")))
    # measure elapsed time
    epoch_time.update(time.time() - start_time)
    start_time = time.time()

logger.close()
# Out:
# [Search the 000-200-th epoch] Time Left: [00:00:00], LR=0.1
# *SEARCH* [2022-09-14 12:17:43] [000-200][000/098] Time 0.64 (0.64) Data 0.33 (0.33) Base [Loss 2.352 (2.352)  Prec@1 6.25 (6.25) Prec@5 50.78 (50.78)]
# *SEARCH* [2022-09-14 12:17:53] [000-200][097/098] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 1.697 (1.801)  Prec@1 35.71 (31.54) Prec@5 89.88 (84.53)]
# [000-200] searching : loss=1.80, accuracy@1=31.54%, accuracy@5=84.53%, time-cost=11.2 s
# [000-200] evaluate  : loss=2.09, accuracy@1=30.11%, accuracy@5=79.44%
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 000-200-th epoch : find the highest validation accuracy : 30.11%.
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 001-200-th epoch] Time Left: [01:08:23], LR=0.09999383162408304
# *SEARCH* [2022-09-14 12:18:03] [001-200][000/098] Time 0.62 (0.62) Data 0.46 (0.46) Base [Loss 1.684 (1.684)  Prec@1 36.33 (36.33) Prec@5 87.89 (87.89)]
# *SEARCH* [2022-09-14 12:18:18] [001-200][097/098] Time 0.14 (0.16) Data 0.00 (0.01) Base [Loss 1.391 (1.496)  Prec@1 45.83 (44.74) Prec@5 94.05 (91.70)]
# [001-200] searching : loss=1.50, accuracy@1=44.74%, accuracy@5=91.70%, time-cost=26.9 s
# [001-200] evaluate  : loss=1.59, accuracy@1=43.08%, accuracy@5=89.64%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 001-200-th epoch : find the highest validation accuracy : 43.08%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 002-200-th epoch] Time Left: [01:13:47], LR=0.09997532801828658
# *SEARCH* [2022-09-14 12:18:25] [002-200][000/098] Time 0.42 (0.42) Data 0.31 (0.31) Base [Loss 1.460 (1.460)  Prec@1 44.92 (44.92) Prec@5 94.53 (94.53)]
# *SEARCH* [2022-09-14 12:18:35] [002-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 1.269 (1.311)  Prec@1 56.55 (52.00) Prec@5 94.05 (94.04)]
# [002-200] searching : loss=1.31, accuracy@1=52.00%, accuracy@5=94.04%, time-cost=37.0 s
# [002-200] evaluate  : loss=1.55, accuracy@1=47.72%, accuracy@5=91.26%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 002-200-th epoch : find the highest validation accuracy : 47.72%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 003-200-th epoch] Time Left: [00:54:34], LR=0.09994449374809851
# *SEARCH* [2022-09-14 12:18:42] [003-200][000/098] Time 0.69 (0.69) Data 0.43 (0.43) Base [Loss 1.276 (1.276)  Prec@1 54.69 (54.69) Prec@5 92.58 (92.58)]
# *SEARCH* [2022-09-14 12:18:56] [003-200][097/098] Time 0.08 (0.15) Data 0.00 (0.00) Base [Loss 1.101 (1.192)  Prec@1 60.71 (56.79) Prec@5 97.02 (95.18)]
# [003-200] searching : loss=1.19, accuracy@1=56.79%, accuracy@5=95.18%, time-cost=52.0 s
# [003-200] evaluate  : loss=1.40, accuracy@1=49.55%, accuracy@5=93.96%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 003-200-th epoch : find the highest validation accuracy : 49.55%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 004-200-th epoch] Time Left: [01:20:08], LR=0.09990133642141358
# *SEARCH* [2022-09-14 12:19:07] [004-200][000/098] Time 0.58 (0.58) Data 0.48 (0.48) Base [Loss 1.088 (1.088)  Prec@1 61.33 (61.33) Prec@5 95.70 (95.70)]
# *SEARCH* [2022-09-14 12:19:20] [004-200][097/098] Time 0.13 (0.14) Data 0.00 (0.01) Base [Loss 1.235 (1.109)  Prec@1 57.74 (59.51) Prec@5 95.83 (96.09)]
# [004-200] searching : loss=1.11, accuracy@1=59.51%, accuracy@5=96.09%, time-cost=66.1 s
# [004-200] evaluate  : loss=1.47, accuracy@1=51.62%, accuracy@5=94.56%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 004-200-th epoch : find the highest validation accuracy : 51.62%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 005-200-th epoch] Time Left: [01:16:43], LR=0.0998458666866564
# *SEARCH* [2022-09-14 12:19:30] [005-200][000/098] Time 0.55 (0.55) Data 0.31 (0.31) Base [Loss 1.119 (1.119)  Prec@1 58.59 (58.59) Prec@5 95.31 (95.31)]
# *SEARCH* [2022-09-14 12:19:40] [005-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 1.195 (1.044)  Prec@1 55.36 (62.02) Prec@5 93.45 (96.53)]
# [005-200] searching : loss=1.04, accuracy@1=62.02%, accuracy@5=96.53%, time-cost=76.4 s
# [005-200] evaluate  : loss=1.32, accuracy@1=55.11%, accuracy@5=94.74%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 005-200-th epoch : find the highest validation accuracy : 55.11%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 006-200-th epoch] Time Left: [01:04:37], LR=0.099778098230154
# *SEARCH* [2022-09-14 12:19:50] [006-200][000/098] Time 0.54 (0.54) Data 0.44 (0.44) Base [Loss 1.063 (1.063)  Prec@1 64.45 (64.45) Prec@5 95.31 (95.31)]
# *SEARCH* [2022-09-14 12:20:00] [006-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 1.182 (0.987)  Prec@1 57.74 (64.79) Prec@5 97.62 (96.90)]
# [006-200] searching : loss=0.99, accuracy@1=64.79%, accuracy@5=96.90%, time-cost=86.4 s
# [006-200] evaluate  : loss=1.27, accuracy@1=55.43%, accuracy@5=95.14%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 006-200-th epoch : find the highest validation accuracy : 55.43%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 007-200-th epoch] Time Left: [00:53:20], LR=0.099698047772759
# *SEARCH* [2022-09-14 12:20:07] [007-200][000/098] Time 0.47 (0.47) Data 0.35 (0.35) Base [Loss 1.063 (1.063)  Prec@1 62.11 (62.11) Prec@5 96.09 (96.09)]
# *SEARCH* [2022-09-14 12:20:20] [007-200][097/098] Time 0.22 (0.14) Data 0.00 (0.00) Base [Loss 0.900 (0.952)  Prec@1 69.64 (66.00) Prec@5 94.05 (97.09)]
# [007-200] searching : loss=0.95, accuracy@1=66.00%, accuracy@5=97.09%, time-cost=100.6 s
# [007-200] evaluate  : loss=1.26, accuracy@1=57.24%, accuracy@5=95.80%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 007-200-th epoch : find the highest validation accuracy : 57.24%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 008-200-th epoch] Time Left: [01:16:23], LR=0.0996057350657239
# *SEARCH* [2022-09-14 12:20:31] [008-200][000/098] Time 0.47 (0.47) Data 0.36 (0.36) Base [Loss 0.916 (0.916)  Prec@1 64.06 (64.06) Prec@5 98.05 (98.05)]
# *SEARCH* [2022-09-14 12:20:43] [008-200][097/098] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.912 (0.901)  Prec@1 67.86 (67.56) Prec@5 98.81 (97.53)]
# [008-200] searching : loss=0.90, accuracy@1=67.56%, accuracy@5=97.53%, time-cost=113.2 s
# [008-200] evaluate  : loss=1.32, accuracy@1=57.55%, accuracy@5=96.00%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 008-200-th epoch : find the highest validation accuracy : 57.55%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 009-200-th epoch] Time Left: [01:10:49], LR=0.09950118288582788
# *SEARCH* [2022-09-14 12:20:53] [009-200][000/098] Time 0.57 (0.57) Data 0.36 (0.36) Base [Loss 0.937 (0.937)  Prec@1 64.84 (64.84) Prec@5 96.88 (96.88)]
# *SEARCH* [2022-09-14 12:21:02] [009-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.712 (0.879)  Prec@1 76.19 (68.57) Prec@5 96.43 (97.53)]
# [009-200] searching : loss=0.88, accuracy@1=68.57%, accuracy@5=97.53%, time-cost=123.3 s
# [009-200] evaluate  : loss=1.32, accuracy@1=57.96%, accuracy@5=94.87%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 009-200-th epoch : find the highest validation accuracy : 57.96%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 010-200-th epoch] Time Left: [00:58:32], LR=0.0993844170297569
# *SEARCH* [2022-09-14 12:21:11] [010-200][000/098] Time 0.49 (0.49) Data 0.37 (0.37) Base [Loss 0.969 (0.969)  Prec@1 61.72 (61.72) Prec@5 97.27 (97.27)]
# *SEARCH* [2022-09-14 12:21:21] [010-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.787 (0.852)  Prec@1 70.24 (69.43) Prec@5 99.40 (97.64)]
# [010-200] searching : loss=0.85, accuracy@1=69.43%, accuracy@5=97.64%, time-cost=133.3 s
# [010-200] evaluate  : loss=1.36, accuracy@1=56.15%, accuracy@5=94.80%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 011-200-th epoch] Time Left: [00:52:03], LR=0.0992554663077387
# *SEARCH* [2022-09-14 12:21:28] [011-200][000/098] Time 0.48 (0.48) Data 0.32 (0.32) Base [Loss 0.760 (0.760)  Prec@1 72.27 (72.27) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-09-14 12:21:42] [011-200][097/098] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.832 (0.815)  Prec@1 67.26 (71.16) Prec@5 97.62 (97.96)]
# [011-200] searching : loss=0.81, accuracy@1=71.16%, accuracy@5=97.96%, time-cost=148.5 s
# [011-200] evaluate  : loss=1.66, accuracy@1=52.87%, accuracy@5=91.50%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 012-200-th epoch] Time Left: [01:17:50], LR=0.09911436253643445
# *SEARCH* [2022-09-14 12:21:53] [012-200][000/098] Time 0.54 (0.54) Data 0.36 (0.36) Base [Loss 0.848 (0.848)  Prec@1 71.09 (71.09) Prec@5 97.66 (97.66)]
# *SEARCH* [2022-09-14 12:22:09] [012-200][097/098] Time 0.14 (0.17) Data 0.00 (0.00) Base [Loss 0.875 (0.791)  Prec@1 69.64 (72.17) Prec@5 98.21 (98.04)]
# [012-200] searching : loss=0.79, accuracy@1=72.17%, accuracy@5=98.04%, time-cost=165.0 s
# [012-200] evaluate  : loss=1.67, accuracy@1=50.18%, accuracy@5=94.22%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 013-200-th epoch] Time Left: [01:21:29], LR=0.09896114053108829
# *SEARCH* [2022-09-14 12:22:19] [013-200][000/098] Time 0.56 (0.56) Data 0.36 (0.36) Base [Loss 0.701 (0.701)  Prec@1 77.73 (77.73) Prec@5 98.05 (98.05)]
# *SEARCH* [2022-09-14 12:22:29] [013-200][097/098] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.749 (0.756)  Prec@1 73.81 (73.24) Prec@5 98.81 (98.37)]
# [013-200] searching : loss=0.76, accuracy@1=73.24%, accuracy@5=98.37%, time-cost=175.5 s
# [013-200] evaluate  : loss=1.40, accuracy@1=58.85%, accuracy@5=96.01%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 013-200-th epoch : find the highest validation accuracy : 58.85%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 014-200-th epoch] Time Left: [00:52:40], LR=0.09879583809693737
# *SEARCH* [2022-09-14 12:22:36] [014-200][000/098] Time 0.48 (0.48) Data 0.31 (0.31) Base [Loss 0.754 (0.754)  Prec@1 73.83 (73.83) Prec@5 98.05 (98.05)]
# *SEARCH* [2022-09-14 12:22:48] [014-200][097/098] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.732 (0.748)  Prec@1 76.79 (73.46) Prec@5 98.21 (98.30)]
# [014-200] searching : loss=0.75, accuracy@1=73.46%, accuracy@5=98.30%, time-cost=188.4 s
# [014-200] evaluate  : loss=1.64, accuracy@1=49.19%, accuracy@5=93.48%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 015-200-th epoch] Time Left: [00:59:54], LR=0.09861849601988383
# *SEARCH* [2022-09-14 12:22:55] [015-200][000/098] Time 0.46 (0.46) Data 0.35 (0.35) Base [Loss 0.747 (0.747)  Prec@1 71.88 (71.88) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-09-14 12:23:05] [015-200][097/098] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.739 (0.723)  Prec@1 74.40 (74.56) Prec@5 98.21 (98.53)]
# [015-200] searching : loss=0.72, accuracy@1=74.56%, accuracy@5=98.53%, time-cost=198.9 s
# [015-200] evaluate  : loss=0.95, accuracy@1=68.21%, accuracy@5=97.28%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 015-200-th epoch : find the highest validation accuracy : 68.21%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 016-200-th epoch] Time Left: [00:58:42], LR=0.09842915805643156
# *SEARCH* [2022-09-14 12:23:14] [016-200][000/098] Time 0.54 (0.54) Data 0.33 (0.33) Base [Loss 0.670 (0.670)  Prec@1 77.34 (77.34) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 12:23:24] [016-200][097/098] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.591 (0.691)  Prec@1 80.36 (76.08) Prec@5 97.62 (98.63)]
# [016-200] searching : loss=0.69, accuracy@1=76.08%, accuracy@5=98.63%, time-cost=209.3 s
# [016-200] evaluate  : loss=1.23, accuracy@1=62.19%, accuracy@5=96.34%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 017-200-th epoch] Time Left: [01:01:01], LR=0.09822787092288991
# *SEARCH* [2022-09-14 12:23:34] [017-200][000/098] Time 0.43 (0.43) Data 0.31 (0.31) Base [Loss 0.695 (0.695)  Prec@1 74.22 (74.22) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-09-14 12:23:44] [017-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.573 (0.683)  Prec@1 79.17 (75.81) Prec@5 99.40 (98.62)]
# [017-200] searching : loss=0.68, accuracy@1=75.81%, accuracy@5=98.62%, time-cost=219.3 s
# [017-200] evaluate  : loss=1.18, accuracy@1=62.45%, accuracy@5=97.14%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 018-200-th epoch] Time Left: [00:52:54], LR=0.09801468428384716
# *SEARCH* [2022-09-14 12:23:52] [018-200][000/098] Time 0.49 (0.49) Data 0.32 (0.32) Base [Loss 0.639 (0.639)  Prec@1 78.12 (78.12) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-09-14 12:24:06] [018-200][097/098] Time 0.21 (0.15) Data 0.00 (0.00) Base [Loss 0.678 (0.663)  Prec@1 77.98 (76.96) Prec@5 99.40 (98.70)]
# [018-200] searching : loss=0.66, accuracy@1=76.96%, accuracy@5=98.70%, time-cost=234.5 s
# [018-200] evaluate  : loss=1.06, accuracy@1=66.89%, accuracy@5=97.30%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 019-200-th epoch] Time Left: [01:14:48], LR=0.09778965073991651
# *SEARCH* [2022-09-14 12:24:17] [019-200][000/098] Time 0.46 (0.46) Data 0.36 (0.36) Base [Loss 0.638 (0.638)  Prec@1 78.52 (78.52) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-09-14 12:24:31] [019-200][097/098] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.724 (0.653)  Prec@1 75.00 (77.55) Prec@5 98.81 (98.69)]
# [019-200] searching : loss=0.65, accuracy@1=77.55%, accuracy@5=98.69%, time-cost=249.5 s
# [019-200] evaluate  : loss=0.92, accuracy@1=68.66%, accuracy@5=97.62%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 019-200-th epoch : find the highest validation accuracy : 68.66%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 020-200-th epoch] Time Left: [01:09:50], LR=0.09755282581475769
# *SEARCH* [2022-09-14 12:24:40] [020-200][000/098] Time 0.44 (0.44) Data 0.33 (0.33) Base [Loss 0.643 (0.643)  Prec@1 76.17 (76.17) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-09-14 12:24:55] [020-200][097/098] Time 0.14 (0.16) Data 0.00 (0.00) Base [Loss 0.579 (0.631)  Prec@1 78.57 (78.22) Prec@5 98.81 (98.88)]
# [020-200] searching : loss=0.63, accuracy@1=78.22%, accuracy@5=98.88%, time-cost=264.9 s
# [020-200] evaluate  : loss=0.87, accuracy@1=70.44%, accuracy@5=97.85%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 020-200-th epoch : find the highest validation accuracy : 70.44%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 021-200-th epoch] Time Left: [01:11:59], LR=0.09730426794137727
# *SEARCH* [2022-09-14 12:25:04] [021-200][000/098] Time 0.42 (0.42) Data 0.31 (0.31) Base [Loss 0.573 (0.573)  Prec@1 82.42 (82.42) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-09-14 12:25:16] [021-200][097/098] Time 0.15 (0.13) Data 0.00 (0.00) Base [Loss 0.793 (0.627)  Prec@1 73.21 (78.29) Prec@5 97.62 (98.86)]
# [021-200] searching : loss=0.63, accuracy@1=78.29%, accuracy@5=98.86%, time-cost=277.5 s
# [021-200] evaluate  : loss=0.82, accuracy@1=72.54%, accuracy@5=97.90%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 021-200-th epoch : find the highest validation accuracy : 72.54%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 022-200-th epoch] Time Left: [00:57:10], LR=0.09704403844771128
# *SEARCH* [2022-09-14 12:25:23] [022-200][000/098] Time 0.44 (0.44) Data 0.32 (0.32) Base [Loss 0.552 (0.552)  Prec@1 79.69 (79.69) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-09-14 12:25:33] [022-200][097/098] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.691 (0.616)  Prec@1 76.79 (78.45) Prec@5 98.81 (98.98)]
# [022-200] searching : loss=0.62, accuracy@1=78.45%, accuracy@5=98.98%, time-cost=288.1 s
# [022-200] evaluate  : loss=0.97, accuracy@1=68.01%, accuracy@5=97.67%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 023-200-th epoch] Time Left: [00:50:36], LR=0.09677220154149338
# *SEARCH* [2022-09-14 12:25:40] [023-200][000/098] Time 0.42 (0.42) Data 0.31 (0.31) Base [Loss 0.588 (0.588)  Prec@1 80.47 (80.47) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-09-14 12:25:50] [023-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.575 (0.602)  Prec@1 78.57 (79.05) Prec@5 99.40 (98.95)]
# [023-200] searching : loss=0.60, accuracy@1=79.05%, accuracy@5=98.95%, time-cost=298.1 s
# [023-200] evaluate  : loss=0.84, accuracy@1=73.08%, accuracy@5=97.68%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 023-200-th epoch : find the highest validation accuracy : 73.08%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 024-200-th epoch] Time Left: [00:57:47], LR=0.09648882429441258
# *SEARCH* [2022-09-14 12:26:00] [024-200][000/098] Time 0.45 (0.45) Data 0.34 (0.34) Base [Loss 0.644 (0.644)  Prec@1 75.00 (75.00) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-09-14 12:26:10] [024-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.537 (0.589)  Prec@1 82.74 (79.56) Prec@5 98.81 (98.97)]
# [024-200] searching : loss=0.59, accuracy@1=79.56%, accuracy@5=98.97%, time-cost=308.2 s
# [024-200] evaluate  : loss=1.08, accuracy@1=66.27%, accuracy@5=96.60%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 025-200-th epoch] Time Left: [00:48:12], LR=0.09619397662556434
# *SEARCH* [2022-09-14 12:26:17] [025-200][000/098] Time 0.53 (0.53) Data 0.42 (0.42) Base [Loss 0.627 (0.627)  Prec@1 78.91 (78.91) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-09-14 12:26:26] [025-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.503 (0.584)  Prec@1 83.93 (79.72) Prec@5 100.00 (99.06)]
# [025-200] searching : loss=0.58, accuracy@1=79.72%, accuracy@5=99.06%, time-cost=318.2 s
# [025-200] evaluate  : loss=1.11, accuracy@1=67.16%, accuracy@5=97.00%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 026-200-th epoch] Time Left: [00:48:29], LR=0.09588773128419906
# *SEARCH* [2022-09-14 12:26:33] [026-200][000/098] Time 0.47 (0.47) Data 0.31 (0.31) Base [Loss 0.545 (0.545)  Prec@1 78.91 (78.91) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-09-14 12:26:44] [026-200][097/098] Time 0.08 (0.11) Data 0.00 (0.00) Base [Loss 0.512 (0.570)  Prec@1 80.95 (80.34) Prec@5 99.40 (99.13)]
# [026-200] searching : loss=0.57, accuracy@1=80.34%, accuracy@5=99.13%, time-cost=329.5 s
# [026-200] evaluate  : loss=1.07, accuracy@1=66.61%, accuracy@5=96.75%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 027-200-th epoch] Time Left: [00:51:43], LR=0.09557016383177226
# *SEARCH* [2022-09-14 12:26:51] [027-200][000/098] Time 0.51 (0.51) Data 0.34 (0.34) Base [Loss 0.586 (0.586)  Prec@1 77.34 (77.34) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-09-14 12:27:02] [027-200][097/098] Time 0.08 (0.11) Data 0.00 (0.00) Base [Loss 0.651 (0.560)  Prec@1 76.79 (80.46) Prec@5 98.81 (99.16)]
# [027-200] searching : loss=0.56, accuracy@1=80.46%, accuracy@5=99.16%, time-cost=340.2 s
# [027-200] evaluate  : loss=1.18, accuracy@1=67.78%, accuracy@5=96.90%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 028-200-th epoch] Time Left: [00:49:34], LR=0.09524135262330098
# *SEARCH* [2022-09-14 12:27:09] [028-200][000/098] Time 0.53 (0.53) Data 0.33 (0.33) Base [Loss 0.372 (0.372)  Prec@1 87.50 (87.50) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 12:27:22] [028-200][097/098] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.612 (0.556)  Prec@1 77.98 (80.63) Prec@5 99.40 (99.04)]
# [028-200] searching : loss=0.56, accuracy@1=80.63%, accuracy@5=99.04%, time-cost=354.3 s
# [028-200] evaluate  : loss=0.90, accuracy@1=70.23%, accuracy@5=96.92%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 029-200-th epoch] Time Left: [01:03:36], LR=0.09490137878803079
# *SEARCH* [2022-09-14 12:27:31] [029-200][000/098] Time 0.48 (0.48) Data 0.35 (0.35) Base [Loss 0.516 (0.516)  Prec@1 81.25 (81.25) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-09-14 12:27:46] [029-200][097/098] Time 0.21 (0.15) Data 0.00 (0.00) Base [Loss 0.559 (0.555)  Prec@1 83.33 (80.68) Prec@5 99.40 (99.11)]
# [029-200] searching : loss=0.55, accuracy@1=80.68%, accuracy@5=99.11%, time-cost=369.5 s
# [029-200] evaluate  : loss=0.86, accuracy@1=72.33%, accuracy@5=98.09%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 030-200-th epoch] Time Left: [01:03:01], LR=0.09455032620941839
# *SEARCH* [2022-09-14 12:27:53] [030-200][000/098] Time 0.48 (0.48) Data 0.31 (0.31) Base [Loss 0.524 (0.524)  Prec@1 81.64 (81.64) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-09-14 12:28:09] [030-200][097/098] Time 0.14 (0.16) Data 0.00 (0.00) Base [Loss 0.506 (0.543)  Prec@1 82.14 (81.24) Prec@5 98.81 (99.03)]
# [030-200] searching : loss=0.54, accuracy@1=81.24%, accuracy@5=99.03%, time-cost=385.5 s
# [030-200] evaluate  : loss=1.11, accuracy@1=64.59%, accuracy@5=97.44%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 031-200-th epoch] Time Left: [01:12:20], LR=0.09418828150443469
# *SEARCH* [2022-09-14 12:28:19] [031-200][000/098] Time 0.43 (0.43) Data 0.32 (0.32) Base [Loss 0.518 (0.518)  Prec@1 82.42 (82.42) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 12:28:29] [031-200][097/098] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.477 (0.529)  Prec@1 85.12 (81.76) Prec@5 98.81 (99.16)]
# [031-200] searching : loss=0.53, accuracy@1=81.76%, accuracy@5=99.16%, time-cost=395.9 s
# [031-200] evaluate  : loss=0.94, accuracy@1=71.16%, accuracy@5=97.70%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 032-200-th epoch] Time Left: [00:47:22], LR=0.09381533400219318
# *SEARCH* [2022-09-14 12:28:36] [032-200][000/098] Time 0.52 (0.52) Data 0.30 (0.30) Base [Loss 0.463 (0.463)  Prec@1 81.25 (81.25) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 12:28:46] [032-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.689 (0.524)  Prec@1 78.57 (81.56) Prec@5 98.21 (99.21)]
# [032-200] searching : loss=0.52, accuracy@1=81.56%, accuracy@5=99.21%, time-cost=406.1 s
# [032-200] evaluate  : loss=1.54, accuracy@1=59.82%, accuracy@5=96.43%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 033-200-th epoch] Time Left: [00:55:10], LR=0.09343157572190958
# *SEARCH* [2022-09-14 12:28:56] [033-200][000/098] Time 0.54 (0.54) Data 0.43 (0.43) Base [Loss 0.486 (0.486)  Prec@1 83.59 (83.59) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-09-14 12:29:08] [033-200][097/098] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.603 (0.515)  Prec@1 77.98 (81.80) Prec@5 98.81 (99.31)]
# [033-200] searching : loss=0.51, accuracy@1=81.80%, accuracy@5=99.31%, time-cost=418.9 s
# [033-200] evaluate  : loss=0.84, accuracy@1=73.16%, accuracy@5=98.14%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 033-200-th epoch : find the highest validation accuracy : 73.16%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 034-200-th epoch] Time Left: [01:02:20], LR=0.09303710135019719
# *SEARCH* [2022-09-14 12:29:18] [034-200][000/098] Time 0.51 (0.51) Data 0.37 (0.37) Base [Loss 0.540 (0.540)  Prec@1 82.42 (82.42) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 12:29:28] [034-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.647 (0.509)  Prec@1 74.40 (82.19) Prec@5 99.40 (99.28)]
# [034-200] searching : loss=0.51, accuracy@1=82.19%, accuracy@5=99.28%, time-cost=429.0 s
# [034-200] evaluate  : loss=0.99, accuracy@1=70.01%, accuracy@5=97.50%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 035-200-th epoch] Time Left: [00:54:14], LR=0.09263200821770462
# *SEARCH* [2022-09-14 12:29:38] [035-200][000/098] Time 0.78 (0.78) Data 0.48 (0.48) Base [Loss 0.514 (0.514)  Prec@1 81.25 (81.25) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 12:29:49] [035-200][097/098] Time 0.08 (0.12) Data 0.00 (0.01) Base [Loss 0.415 (0.513)  Prec@1 87.50 (82.11) Prec@5 100.00 (99.20)]
# [035-200] searching : loss=0.51, accuracy@1=82.11%, accuracy@5=99.20%, time-cost=441.1 s
# [035-200] evaluate  : loss=1.12, accuracy@1=67.14%, accuracy@5=97.60%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 036-200-th epoch] Time Left: [00:59:20], LR=0.09221639627510075
# *SEARCH* [2022-09-14 12:30:00] [036-200][000/098] Time 0.57 (0.57) Data 0.46 (0.46) Base [Loss 0.534 (0.534)  Prec@1 79.69 (79.69) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-09-14 12:30:09] [036-200][097/098] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.472 (0.499)  Prec@1 84.52 (82.57) Prec@5 100.00 (99.27)]
# [036-200] searching : loss=0.50, accuracy@1=82.57%, accuracy@5=99.27%, time-cost=451.2 s
# [036-200] evaluate  : loss=0.70, accuracy@1=77.31%, accuracy@5=98.68%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 036-200-th epoch : find the highest validation accuracy : 77.31%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 037-200-th epoch] Time Left: [00:45:09], LR=0.09179036806841352
# *SEARCH* [2022-09-14 12:30:16] [037-200][000/098] Time 0.42 (0.42) Data 0.31 (0.31) Base [Loss 0.438 (0.438)  Prec@1 82.42 (82.42) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 12:30:26] [037-200][097/098] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 0.547 (0.501)  Prec@1 81.55 (82.58) Prec@5 99.40 (99.23)]
# [037-200] searching : loss=0.50, accuracy@1=82.58%, accuracy@5=99.23%, time-cost=461.6 s
# [037-200] evaluate  : loss=0.71, accuracy@1=76.19%, accuracy@5=98.44%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 038-200-th epoch] Time Left: [00:45:15], LR=0.0913540287137281
# *SEARCH* [2022-09-14 12:30:33] [038-200][000/098] Time 0.42 (0.42) Data 0.30 (0.30) Base [Loss 0.409 (0.409)  Prec@1 85.55 (85.55) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-09-14 12:30:49] [038-200][097/098] Time 0.14 (0.16) Data 0.00 (0.00) Base [Loss 0.414 (0.492)  Prec@1 86.90 (82.64) Prec@5 99.40 (99.28)]
# [038-200] searching : loss=0.49, accuracy@1=82.64%, accuracy@5=99.28%, time-cost=477.6 s
# [038-200] evaluate  : loss=0.68, accuracy@1=76.82%, accuracy@5=98.80%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 039-200-th epoch] Time Left: [01:09:09], LR=0.09090748587125118
# *SEARCH* [2022-09-14 12:30:59] [039-200][000/098] Time 0.51 (0.51) Data 0.31 (0.31) Base [Loss 0.538 (0.538)  Prec@1 82.03 (82.03) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-09-14 12:31:08] [039-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.340 (0.487)  Prec@1 89.88 (82.89) Prec@5 99.40 (99.31)]
# [039-200] searching : loss=0.49, accuracy@1=82.89%, accuracy@5=99.31%, time-cost=487.6 s
# [039-200] evaluate  : loss=1.00, accuracy@1=70.36%, accuracy@5=97.39%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 040-200-th epoch] Time Left: [00:44:01], LR=0.09045084971874738
# *SEARCH* [2022-09-14 12:31:15] [040-200][000/098] Time 0.48 (0.48) Data 0.32 (0.32) Base [Loss 0.421 (0.421)  Prec@1 85.94 (85.94) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-09-14 12:31:30] [040-200][097/098] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.465 (0.472)  Prec@1 80.95 (83.31) Prec@5 99.40 (99.39)]
# [040-200] searching : loss=0.47, accuracy@1=83.31%, accuracy@5=99.39%, time-cost=502.8 s
# [040-200] evaluate  : loss=0.73, accuracy@1=74.99%, accuracy@5=98.46%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 041-200-th epoch] Time Left: [01:06:12], LR=0.08998423292435453
# *SEARCH* [2022-09-14 12:31:40] [041-200][000/098] Time 0.63 (0.63) Data 0.47 (0.47) Base [Loss 0.493 (0.493)  Prec@1 82.81 (82.81) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-09-14 12:31:55] [041-200][097/098] Time 0.13 (0.16) Data 0.00 (0.01) Base [Loss 0.601 (0.479)  Prec@1 82.74 (83.18) Prec@5 98.21 (99.34)]
# [041-200] searching : loss=0.48, accuracy@1=83.18%, accuracy@5=99.34%, time-cost=518.3 s
# [041-200] evaluate  : loss=0.68, accuracy@1=77.39%, accuracy@5=98.62%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 041-200-th epoch : find the highest validation accuracy : 77.39%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 042-200-th epoch] Time Left: [00:58:01], LR=0.08950775061878452
# *SEARCH* [2022-09-14 12:32:02] [042-200][000/098] Time 0.61 (0.61) Data 0.32 (0.32) Base [Loss 0.427 (0.427)  Prec@1 85.94 (85.94) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-09-14 12:32:17] [042-200][097/098] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.518 (0.472)  Prec@1 81.55 (83.57) Prec@5 100.00 (99.36)]
# [042-200] searching : loss=0.47, accuracy@1=83.57%, accuracy@5=99.36%, time-cost=533.5 s
# [042-200] evaluate  : loss=1.16, accuracy@1=66.77%, accuracy@5=96.89%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 043-200-th epoch] Time Left: [00:56:49], LR=0.08902152036691649
# *SEARCH* [2022-09-14 12:32:24] [043-200][000/098] Time 0.42 (0.42) Data 0.31 (0.31) Base [Loss 0.473 (0.473)  Prec@1 85.94 (85.94) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-09-14 12:32:33] [043-200][097/098] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 0.459 (0.466)  Prec@1 86.31 (83.83) Prec@5 98.81 (99.36)]
# [043-200] searching : loss=0.47, accuracy@1=83.83%, accuracy@5=99.36%, time-cost=543.4 s
# [043-200] evaluate  : loss=1.07, accuracy@1=68.29%, accuracy@5=97.34%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 044-200-th epoch] Time Left: [00:50:53], LR=0.08852566213878947
# *SEARCH* [2022-09-14 12:32:44] [044-200][000/098] Time 0.47 (0.47) Data 0.36 (0.36) Base [Loss 0.567 (0.567)  Prec@1 80.47 (80.47) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-09-14 12:32:53] [044-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.392 (0.464)  Prec@1 86.90 (83.61) Prec@5 100.00 (99.37)]
# [044-200] searching : loss=0.46, accuracy@1=83.61%, accuracy@5=99.37%, time-cost=553.5 s
# [044-200] evaluate  : loss=0.82, accuracy@1=74.16%, accuracy@5=98.06%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 045-200-th epoch] Time Left: [00:42:44], LR=0.08802029828000156
# *SEARCH* [2022-09-14 12:33:00] [045-200][000/098] Time 0.52 (0.52) Data 0.35 (0.35) Base [Loss 0.445 (0.445)  Prec@1 82.81 (82.81) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 12:33:13] [045-200][097/098] Time 0.08 (0.14) Data 0.00 (0.00) Base [Loss 0.592 (0.458)  Prec@1 81.55 (84.05) Prec@5 100.00 (99.41)]
# [045-200] searching : loss=0.46, accuracy@1=84.05%, accuracy@5=99.41%, time-cost=567.1 s
# [045-200] evaluate  : loss=0.90, accuracy@1=72.55%, accuracy@5=97.45%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 046-200-th epoch] Time Left: [00:51:45], LR=0.08750555348152299
# *SEARCH* [2022-09-14 12:33:20] [046-200][000/098] Time 0.63 (0.63) Data 0.44 (0.44) Base [Loss 0.465 (0.465)  Prec@1 82.81 (82.81) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-09-14 12:33:30] [046-200][097/098] Time 0.08 (0.11) Data 0.00 (0.00) Base [Loss 0.477 (0.456)  Prec@1 84.52 (84.10) Prec@5 100.00 (99.44)]
# [046-200] searching : loss=0.46, accuracy@1=84.10%, accuracy@5=99.44%, time-cost=577.5 s
# [046-200] evaluate  : loss=1.11, accuracy@1=65.85%, accuracy@5=97.22%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 047-200-th epoch] Time Left: [00:48:05], LR=0.08698155474893049
# *SEARCH* [2022-09-14 12:33:39] [047-200][000/098] Time 0.63 (0.63) Data 0.46 (0.46) Base [Loss 0.447 (0.447)  Prec@1 83.98 (83.98) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 12:33:54] [047-200][097/098] Time 0.13 (0.16) Data 0.00 (0.01) Base [Loss 0.626 (0.455)  Prec@1 77.38 (84.14) Prec@5 100.00 (99.41)]
# [047-200] searching : loss=0.45, accuracy@1=84.14%, accuracy@5=99.41%, time-cost=592.9 s
# [047-200] evaluate  : loss=0.76, accuracy@1=76.63%, accuracy@5=97.66%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 048-200-th epoch] Time Left: [00:56:20], LR=0.08644843137107058
# *SEARCH* [2022-09-14 12:34:02] [048-200][000/098] Time 0.57 (0.57) Data 0.46 (0.46) Base [Loss 0.473 (0.473)  Prec@1 83.59 (83.59) Prec@5 99.61 (99.61)]
# ...
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 183-200-th epoch] Time Left: [00:06:10], LR=0.0017721290771101018
# *SEARCH* [2022-09-14 13:20:12] [183-200][000/098] Time 0.60 (0.60) Data 0.31 (0.31) Base [Loss 0.015 (0.015)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:20:27] [183-200][097/098] Time 0.13 (0.16) Data 0.00 (0.00) Base [Loss 0.011 (0.014)  Prec@1 100.00 (99.73) Prec@5 100.00 (100.00)]
# [183-200] searching : loss=0.01, accuracy@1=99.73%, accuracy@5=100.00%, time-cost=2304.8 s
# [183-200] evaluate  : loss=0.54, accuracy@1=87.58%, accuracy@5=99.32%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 184-200-th epoch] Time Left: [00:05:48], LR=0.0015708419435684518
# *SEARCH* [2022-09-14 13:20:34] [184-200][000/098] Time 0.44 (0.44) Data 0.31 (0.31) Base [Loss 0.016 (0.016)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:20:43] [184-200][097/098] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.018 (0.015)  Prec@1 100.00 (99.69) Prec@5 100.00 (100.00)]
# [184-200] searching : loss=0.02, accuracy@1=99.69%, accuracy@5=100.00%, time-cost=2314.9 s
# [184-200] evaluate  : loss=0.54, accuracy@1=87.56%, accuracy@5=99.26%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 185-200-th epoch] Time Left: [00:04:35], LR=0.0013815039801161723
# *SEARCH* [2022-09-14 13:20:52] [185-200][000/098] Time 0.58 (0.58) Data 0.47 (0.47) Base [Loss 0.012 (0.012)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:21:02] [185-200][097/098] Time 0.09 (0.11) Data 0.00 (0.01) Base [Loss 0.017 (0.015)  Prec@1 100.00 (99.71) Prec@5 100.00 (100.00)]
# [185-200] searching : loss=0.01, accuracy@1=99.71%, accuracy@5=100.00%, time-cost=2325.7 s
# [185-200] evaluate  : loss=0.53, accuracy@1=87.53%, accuracy@5=99.28%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 186-200-th epoch] Time Left: [00:04:01], LR=0.0012041619030626338
# *SEARCH* [2022-09-14 13:21:09] [186-200][000/098] Time 0.45 (0.45) Data 0.31 (0.31) Base [Loss 0.006 (0.006)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:21:21] [186-200][097/098] Time 0.15 (0.13) Data 0.00 (0.00) Base [Loss 0.017 (0.015)  Prec@1 100.00 (99.72) Prec@5 100.00 (100.00)]
# [186-200] searching : loss=0.01, accuracy@1=99.72%, accuracy@5=100.00%, time-cost=2338.4 s
# [186-200] evaluate  : loss=0.53, accuracy@1=87.71%, accuracy@5=99.31%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 187-200-th epoch] Time Left: [00:04:10], LR=0.001038859468911707
# *SEARCH* [2022-09-14 13:21:28] [187-200][000/098] Time 0.43 (0.43) Data 0.32 (0.32) Base [Loss 0.012 (0.012)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:21:39] [187-200][097/098] Time 0.17 (0.11) Data 0.00 (0.00) Base [Loss 0.010 (0.014)  Prec@1 99.40 (99.78) Prec@5 100.00 (100.00)]
# [187-200] searching : loss=0.01, accuracy@1=99.78%, accuracy@5=100.00%, time-cost=2349.2 s
# [187-200] evaluate  : loss=0.53, accuracy@1=87.63%, accuracy@5=99.30%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 188-200-th epoch] Time Left: [00:04:03], LR=0.000885637463565564
# *SEARCH* [2022-09-14 13:21:49] [188-200][000/098] Time 0.47 (0.47) Data 0.36 (0.36) Base [Loss 0.006 (0.006)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:21:59] [188-200][097/098] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.016 (0.014)  Prec@1 100.00 (99.78) Prec@5 100.00 (100.00)]
# [188-200] searching : loss=0.01, accuracy@1=99.78%, accuracy@5=100.00%, time-cost=2359.7 s
# [188-200] evaluate  : loss=0.54, accuracy@1=87.76%, accuracy@5=99.30%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 188-200-th epoch : find the highest validation accuracy : 87.76%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 189-200-th epoch] Time Left: [00:03:06], LR=0.0007445336922613067
# *SEARCH* [2022-09-14 13:22:06] [189-200][000/098] Time 0.54 (0.54) Data 0.31 (0.31) Base [Loss 0.028 (0.028)  Prec@1 99.22 (99.22) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:22:16] [189-200][097/098] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.018 (0.014)  Prec@1 100.00 (99.76) Prec@5 100.00 (100.00)]
# [189-200] searching : loss=0.01, accuracy@1=99.76%, accuracy@5=100.00%, time-cost=2370.2 s
# [189-200] evaluate  : loss=0.54, accuracy@1=87.71%, accuracy@5=99.30%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 190-200-th epoch] Time Left: [00:03:21], LR=0.0006155829702431171
# *SEARCH* [2022-09-14 13:22:26] [190-200][000/098] Time 0.58 (0.58) Data 0.47 (0.47) Base [Loss 0.013 (0.013)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:22:36] [190-200][097/098] Time 0.14 (0.10) Data 0.00 (0.01) Base [Loss 0.018 (0.013)  Prec@1 100.00 (99.74) Prec@5 100.00 (100.00)]
# [190-200] searching : loss=0.01, accuracy@1=99.74%, accuracy@5=100.00%, time-cost=2380.4 s
# [190-200] evaluate  : loss=0.54, accuracy@1=87.77%, accuracy@5=99.36%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
# <<<--->>> The 190-200-th epoch : find the highest validation accuracy : 87.77%.
# Find ../results/NB201/test/checkpoint/seed-16467-best.pth exist, delete is at first before saving
# copy the file from ../results/NB201/test/checkpoint/seed-16467-basic.pth into ../results/NB201/test/checkpoint/seed-16467-best.pth
#
# [Search the 191-200-th epoch] Time Left: [00:02:30], LR=0.0004988171141721232
# *SEARCH* [2022-09-14 13:22:43] [191-200][000/098] Time 0.64 (0.64) Data 0.47 (0.47) Base [Loss 0.010 (0.010)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:22:54] [191-200][097/098] Time 0.09 (0.12) Data 0.00 (0.01) Base [Loss 0.032 (0.014)  Prec@1 99.40 (99.77) Prec@5 100.00 (100.00)]
# [191-200] searching : loss=0.01, accuracy@1=99.77%, accuracy@5=100.00%, time-cost=2392.7 s
# [191-200] evaluate  : loss=0.54, accuracy@1=87.63%, accuracy@5=99.35%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 192-200-th epoch] Time Left: [00:02:32], LR=0.0003942649342761118
# *SEARCH* [2022-09-14 13:23:02] [192-200][000/098] Time 0.52 (0.52) Data 0.35 (0.35) Base [Loss 0.015 (0.015)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:23:14] [192-200][097/098] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.007 (0.013)  Prec@1 100.00 (99.78) Prec@5 100.00 (100.00)]
# [192-200] searching : loss=0.01, accuracy@1=99.78%, accuracy@5=100.00%, time-cost=2405.4 s
# [192-200] evaluate  : loss=0.53, accuracy@1=87.65%, accuracy@5=99.28%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 193-200-th epoch] Time Left: [00:02:14], LR=0.00030195222724102024
# *SEARCH* [2022-09-14 13:23:21] [193-200][000/098] Time 0.48 (0.48) Data 0.32 (0.32) Base [Loss 0.010 (0.010)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:23:36] [193-200][097/098] Time 0.14 (0.16) Data 0.00 (0.00) Base [Loss 0.018 (0.013)  Prec@1 98.81 (99.79) Prec@5 100.00 (100.00)]
# [193-200] searching : loss=0.01, accuracy@1=99.79%, accuracy@5=100.00%, time-cost=2420.9 s
# [193-200] evaluate  : loss=0.54, accuracy@1=87.74%, accuracy@5=99.37%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 194-200-th epoch] Time Left: [00:02:12], LR=0.0002219017698460002
# *SEARCH* [2022-09-14 13:23:43] [194-200][000/098] Time 0.42 (0.42) Data 0.31 (0.31) Base [Loss 0.009 (0.009)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:23:58] [194-200][097/098] Time 0.13 (0.16) Data 0.00 (0.00) Base [Loss 0.023 (0.014)  Prec@1 99.40 (99.74) Prec@5 100.00 (100.00)]
# [194-200] searching : loss=0.01, accuracy@1=99.74%, accuracy@5=100.00%, time-cost=2436.3 s
# [194-200] evaluate  : loss=0.53, accuracy@1=87.73%, accuracy@5=99.28%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 195-200-th epoch] Time Left: [00:01:49], LR=0.0001541333133436018
# *SEARCH* [2022-09-14 13:24:05] [195-200][000/098] Time 0.53 (0.53) Data 0.36 (0.36) Base [Loss 0.015 (0.015)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:24:20] [195-200][097/098] Time 0.13 (0.16) Data 0.00 (0.00) Base [Loss 0.008 (0.014)  Prec@1 100.00 (99.73) Prec@5 100.00 (100.00)]
# [195-200] searching : loss=0.01, accuracy@1=99.73%, accuracy@5=100.00%, time-cost=2451.8 s
# [195-200] evaluate  : loss=0.54, accuracy@1=87.68%, accuracy@5=99.28%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 196-200-th epoch] Time Left: [00:01:40], LR=9.866357858642206e-05
# *SEARCH* [2022-09-14 13:24:30] [196-200][000/098] Time 0.47 (0.47) Data 0.36 (0.36) Base [Loss 0.012 (0.012)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:24:40] [196-200][097/098] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.005 (0.013)  Prec@1 100.00 (99.76) Prec@5 100.00 (100.00)]
# [196-200] searching : loss=0.01, accuracy@1=99.76%, accuracy@5=100.00%, time-cost=2462.2 s
# [196-200] evaluate  : loss=0.53, accuracy@1=87.65%, accuracy@5=99.26%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 197-200-th epoch] Time Left: [00:00:55], LR=5.550625190150482e-05
# *SEARCH* [2022-09-14 13:24:49] [197-200][000/098] Time 0.48 (0.48) Data 0.31 (0.31) Base [Loss 0.012 (0.012)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:25:01] [197-200][097/098] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.019 (0.013)  Prec@1 99.40 (99.79) Prec@5 100.00 (100.00)]
# [197-200] searching : loss=0.01, accuracy@1=99.79%, accuracy@5=100.00%, time-cost=2475.3 s
# [197-200] evaluate  : loss=0.53, accuracy@1=87.75%, accuracy@5=99.35%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 198-200-th epoch] Time Left: [00:00:39], LR=2.467198171342e-05
# *SEARCH* [2022-09-14 13:25:08] [198-200][000/098] Time 0.45 (0.45) Data 0.34 (0.34) Base [Loss 0.009 (0.009)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:25:18] [198-200][097/098] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 0.031 (0.012)  Prec@1 98.81 (99.80) Prec@5 100.00 (100.00)]
# [198-200] searching : loss=0.01, accuracy@1=99.80%, accuracy@5=100.00%, time-cost=2485.8 s
# [198-200] evaluate  : loss=0.54, accuracy@1=87.66%, accuracy@5=99.30%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
#
# [Search the 199-200-th epoch] Time Left: [00:00:20], LR=6.168375916970615e-06
# *SEARCH* [2022-09-14 13:25:28] [199-200][000/098] Time 0.51 (0.51) Data 0.32 (0.32) Base [Loss 0.010 (0.010)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-09-14 13:25:39] [199-200][097/098] Time 0.15 (0.12) Data 0.00 (0.00) Base [Loss 0.009 (0.012)  Prec@1 100.00 (99.82) Prec@5 100.00 (100.00)]
# [199-200] searching : loss=0.01, accuracy@1=99.82%, accuracy@5=100.00%, time-cost=2497.2 s
# [199-200] evaluate  : loss=0.54, accuracy@1=87.69%, accuracy@5=99.32%
# Find ../results/NB201/test/checkpoint/seed-16467-basic.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/checkpoint/seed-16467-basic.pth
# Find ../results/NB201/test/seed-16467-last-info.pth exist, delete is at first before saving
# save checkpoint into ../results/NB201/test/seed-16467-last-info.pth
