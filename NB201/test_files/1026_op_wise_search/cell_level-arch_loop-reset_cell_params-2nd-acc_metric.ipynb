# %%
import os, sys, time, glob, random, argparse
import numpy as np
from copy import deepcopy
import torch
import torch.nn as nn

# XAutoDL 
from xautodl.config_utils import load_config, dict2config, configure2str
from xautodl.datasets import get_datasets, get_nas_search_loaders
from xautodl.procedures import (
    prepare_seed,
    prepare_logger,
    save_checkpoint,
    copy_checkpoint,
    get_optim_scheduler,
)
from xautodl.utils import get_model_infos, obtain_accuracy
from xautodl.log_utils import AverageMeter, time_string, convert_secs2time
from xautodl.models import get_search_spaces

from custom_models import get_cell_based_tiny_net
from custom_search_cells import NAS201SearchCell as SearchCell
from xautodl.models.cell_searchs.genotypes import Structure

# NB201
from nas_201_api import NASBench201API as API

import scipy.stats as stats
# Out:
# 2022-11-07 02:53:51.681924: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
parser = argparse.ArgumentParser("Random search for NAS.")
parser.add_argument("--data_path", type=str, default='../cifar.python', help="The path to dataset")
parser.add_argument("--dataset", type=str, default='cifar10',choices=["cifar10", "cifar100", "ImageNet16-120"], help="Choose between Cifar10/100 and ImageNet-16.")

# channels and number-of-cells
parser.add_argument("--search_space_name", type=str, default='nas-bench-201', help="The search space name.")
parser.add_argument("--config_path", type=str, default='./MY.config', help="The path to the configuration.")
parser.add_argument("--max_nodes", type=int, default=4, help="The maximum number of nodes.")
parser.add_argument("--channel", type=int, default=16, help="The number of channels.")
parser.add_argument("--num_cells", type=int, default=5, help="The number of cells in one stage.")
parser.add_argument("--select_num", type=int, default=100, help="The number of selected architectures to evaluate.")
parser.add_argument("--track_running_stats", type=int, default=0, choices=[0, 1], help="Whether use track_running_stats or not in the BN layer.")
# log
parser.add_argument("--workers", type=int, default=4, help="number of data loading workers")
parser.add_argument("--save_dir", type=str, default='./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric', help="Folder to save checkpoints and log.")
# parser.add_argument("--arch_nas_dataset", type=str, default='../NAS-Bench-201-v1_1-096897.pth', help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--arch_nas_dataset", type=str, default=None, help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--print_freq", type=int, default=200, help="print frequency (default: 200)")
parser.add_argument("--rand_seed", type=int, default=None, help="manual seed")
args = parser.parse_args(args=[])
if args.rand_seed is None or args.rand_seed < 0:
    args.rand_seed = random.randint(1, 100000)

    
print(args.rand_seed)
print(args)
xargs=args
# Out:
# 65819
# Namespace(arch_nas_dataset=None, channel=16, config_path='./MY.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=200, rand_seed=65819, save_dir='./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
assert torch.cuda.is_available(), "CUDA is not available."
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.set_num_threads(xargs.workers)
prepare_seed(xargs.rand_seed)
logger = prepare_logger(args)
# Out:
# Main Function with logger : Logger(dir=cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : None
# channel          : 16
# config_path      : ./MY.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 200
# rand_seed        : 65819
# save_dir         : ./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None

# %%
train_data, valid_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(xargs.config_path, {"class_num": class_num, "xshape": xshape}, logger)
search_loader, _, valid_loader = get_nas_search_loaders(train_data,
                                                        valid_data,
                                                        xargs.dataset,
                                                        "../configs/nas-benchmark/",
                                                        (config.batch_size, config.test_batch_size),
                                                        xargs.workers)
logger.log("||||||| {:10s} ||||||| Search-Loader-Num={:}, Valid-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(search_loader), len(valid_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": bool(xargs.track_running_stats),
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))
# if xargs.arch_nas_dataset is None:
api = None
# else:
#     api = API(xargs.arch_nas_dataset)
logger.log("{:} create API = {:} done".format(time_string(), api))

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)
network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

if last_info.exists():  # automatically resume from previous checkpoint
    logger.log(
        "=> loading checkpoint of the last-info '{:}' start".format(last_info)
    )
    last_info = torch.load(last_info)
    start_epoch = last_info["epoch"]
    checkpoint = torch.load(last_info["last_checkpoint"])
    genotypes = checkpoint["genotypes"]
    valid_accuracies = checkpoint["valid_accuracies"]
    search_model.load_state_dict(checkpoint["search_model"])
    w_scheduler.load_state_dict(checkpoint["w_scheduler"])
    w_optimizer.load_state_dict(checkpoint["w_optimizer"])
    logger.log(
        "=> loading checkpoint of the last-info '{:}' start with {:}-th epoch.".format(
            last_info, start_epoch
        )
    )
else:
    logger.log("=> do not find the last-info file : {:}".format(last_info))
    start_epoch, valid_accuracies, genotypes = 0, {"best": -1}, {}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ./MY.config
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=50, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Search-Loader-Num=391, Valid-Loader-Num=49, batch size=64
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=50, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.025
#     lr: 0.025
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=50, current::epoch=0, iter=0.00, type=cosine, T-max=50, eta-min=0.001)
# criterion   : CrossEntropyLoss()
# [2022-11-07 02:53:54] create API = None done
# => do not find the last-info file : cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/seed-65819-last-info.pth

# %%
def acc_confidence_robustness_metrics(network, inputs, targets):
    with torch.no_grad():
        # accuracy
        network.train()
        _, logits = network(inputs)
        val_top1, val_top5 = obtain_accuracy(logits.data, targets.data, topk=(1, 5))
        acc = val_top1
        
        return acc.item()
        
#         # confidence
#         prob = torch.nn.functional.softmax(logits, dim=1)
#         one_hot_idx = torch.nn.functional.one_hot(targets)
#         confidence = (prob[one_hot_idx==1].sum()) / inputs.size(0) * 100 # in percent
        
#         # sensitivity
#         _, noisy_logits = network(inputs + torch.randn_like(inputs)*0.1)
#         kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
#         sensitivity = kl_loss(torch.nn.functional.log_softmax(noisy_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
        
#         # robustness
#         original_weights = deepcopy(network.state_dict())
#         for m in network.modules():
#             if isinstance(m, SearchCell):
#                 for p in m.parameters():
#                     p.add_(torch.randn_like(p) * p.std()*0.3)
            
#         _, noisy_logits = network(inputs)
#         kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
#         robustness = -kl_loss(torch.nn.functional.log_softmax(noisy_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
#         network.load_state_dict(original_weights)
                
#         return acc.item(), confidence.item(), sensitivity.item(), robustness.item()
    
def step_sim_metric(network, criterion, inputs, targets):
#     inputs, targets = inputs[:64], targets[:64] # smaller batches
    original_dict = deepcopy(network.state_dict())
    optim_large_step = torch.optim.SGD(network.parameters(), lr=0.025)
    
    # single large step
    network.train()
    optim_large_step.zero_grad()
    _, logits = network(inputs)
    base_loss = criterion(logits, targets)
    base_loss.backward()
    optim_large_step.step()
    large_step_dict = deepcopy(network.state_dict())
    
    # multiple small steps
    network.load_state_dict(original_dict)
    optim_small_step = torch.optim.SGD(network.parameters(), lr=0.025/3)
    for i in range(3):
        optim_small_step.zero_grad()
        _, logits = network(inputs)
        base_loss = criterion(logits, targets)
        base_loss.backward()
        optim_small_step.step()
    small_step_dict = deepcopy(network.state_dict())
    scores = []
    for key in large_step_dict.keys():
        if ('weight' in key) and (original_dict[key].dim()==4):
            if (original_dict[key] != large_step_dict[key]).sum():
                large_step = large_step_dict[key] - original_dict[key]
                small_step = small_step_dict[key] - original_dict[key]
                co, ci, kh, kw = large_step.size()
                large_step = large_step.view(co, -1)
                small_step = small_step.view(co, -1)
                score = torch.nn.functional.cosine_similarity(large_step, small_step, dim=1)
                score = score.mean().item() * 100 # in percent
                scores.append(score)
    if len(scores)==0:
        step_sim = 100
        raise RuntimeError
    else:
        step_sim = np.mean(scores)
    
    # resume
    network.load_state_dict(original_dict)
            
    return step_sim

# %%
# start training
start_time, search_time, epoch_time, total_epoch = (
    time.time(),
    AverageMeter(),
    AverageMeter(),
    config.epochs + config.warmup,
)

################# initialize
cells = []
for m in network.modules():
    if isinstance(m, SearchCell):
        cells.append(m)
num_cells = len(cells)
print("total number of nodes:{}".format(num_cells*xargs.max_nodes))
        
op_names = deepcopy(cells[0].op_names)
op_names_wo_none = deepcopy(op_names)
if "none" in op_names_wo_none:
    op_names_wo_none.remove("none")

genotypes = []
for i in range(1, xargs.max_nodes):
    xlist = []
    for j in range(i):
        node_str = "{:}<-{:}".format(i, j)
        if i-j==1:
            op_name = "skip_connect"
        else:
            op_name = "none"
        xlist.append((op_name, j))
    genotypes.append(tuple(xlist))
init_arch = Structure(genotypes)

for c in cells:
    c.arch_cache = init_arch

### gen possible connections of a target node
possible_connections = {}
for target_node_idx in range(1,xargs.max_nodes):
    possible_connections[target_node_idx] = list()
    xlists = []
    for src_node in range(target_node_idx):
        node_str = "{:}<-{:}".format(target_node_idx, src_node)
        # select possible ops
#         if target_node_idx - src_node == 1:
#             op_names_tmp = op_names_wo_none
#         else:
#             op_names_tmp = op_names
        op_names_tmp = op_names
            
        if len(xlists) == 0: # initial iteration
            for op_name in op_names_tmp:
                xlists.append([(op_name, src_node)])
        else:
            new_xlists = []
            for op_name in op_names_tmp:
                for xlist in xlists:
                    new_xlist = deepcopy(xlist)
                    new_xlist.append((op_name, src_node))
                    new_xlists.append(new_xlist)
            xlists = new_xlists
    for xlist in xlists:
        selected_ops = []
        for l in xlist:
            selected_ops.append(l[0])
        if sum(np.array(selected_ops) == "none") == len(selected_ops):
            continue
        possible_connections[target_node_idx].append(tuple(xlist))
    print("target_node:{}".format(target_node_idx), len(possible_connections[target_node_idx]))
        
### train while generating random architectures by mutating connections of a target node

for arch_loop in range(5):
    for target_cell_idx in range(num_cells):
        target_cell = cells[target_cell_idx]
        print("\n\n Searching with a cell #{}".format(target_cell_idx))
        ####
#         for m in target_cell.modules():
#             if hasattr(m, 'reset_parameters'):
#                 m.reset_parameters()
        ####
        ## training
        for ep in range(2):
            ###
            genotypes = []
            for n in range(1, xargs.max_nodes):
                genotypes.append(random.choice(possible_connections[n]))
            arch = Structure(genotypes)
            target_cell.arch_cache = arch
#             arch = target_cell.random_genotype(True)
            ###
            data_time, batch_time = AverageMeter(), AverageMeter()
            base_losses, base_top1, base_top5 = AverageMeter(), AverageMeter(), AverageMeter()
            network.train()
            end = time.time()
            print_freq = 200
            for step, (base_inputs, base_targets, arch_inputs, arch_targets) in enumerate(search_loader):
                ######### forward/backward/optim
                base_targets = base_targets.cuda(non_blocking=True)
                arch_targets = arch_targets.cuda(non_blocking=True)
                # measure data loading time
                data_time.update(time.time() - end)
                w_optimizer.zero_grad()
                _, logits = network(base_inputs)
                base_loss = criterion(logits, base_targets)
                base_loss.backward()
                nn.utils.clip_grad_norm_(network.parameters(), 5)
                w_optimizer.step()

                ######### logging
                base_prec1, base_prec5 = obtain_accuracy(logits.data, base_targets.data, topk=(1, 5))
                base_losses.update(base_loss.item(), base_inputs.size(0))
                base_top1.update(base_prec1.item(), base_inputs.size(0))
                base_top5.update(base_prec5.item(), base_inputs.size(0))
                batch_time.update(time.time() - end)
                end = time.time()
                if step % print_freq == 0 or step + 1 == len(search_loader):
                    Sstr = ("*Train* "+ time_string()+" Ep:{:} [{:03d}/{:03d}]".format(ep, step, len(search_loader)))
                    Tstr = "Time {batch_time.val:.2f} ({batch_time.avg:.2f}) Data {data_time.val:.2f} ({data_time.avg:.2f})".format(batch_time=batch_time, data_time=data_time)
                    Wstr = "Base [Loss {loss.val:.3f} ({loss.avg:.3f})  Prec@1 {top1.val:.2f} ({top1.avg:.2f}) Prec@5 {top5.val:.2f} ({top5.avg:.2f})]".format(loss=base_losses, top1=base_top1, top5=base_top5)
                    logger.log(Sstr + " " + Tstr + " " + Wstr)

            logger.log("Ep:{:} ends : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%".format(ep, base_losses.avg, base_top1.avg, base_top5.avg))
        ## evaluation
        network.train()
        archs, metric_accs = [], []
        loader_iter = iter(valid_loader)
        for search_iter in range(200):
            ###### random gen
            genotypes = []
            for n in range(1, xargs.max_nodes):
                genotypes.append(random.choice(possible_connections[n]))
            arch = Structure(genotypes)
            target_cell.arch_cache = arch
#             arch = target_cell.random_genotype(True)
            ###### measure metrics
            try:
                inputs, targets = next(loader_iter)
            except:
                loader_iter = iter(valid_loader)
                inputs, targets = next(loader_iter)
            inputs, targets = inputs.cuda(non_blocking=True), targets.cuda(non_blocking=True)
            valid_acc = acc_confidence_robustness_metrics(network, inputs, targets)
            archs.append(arch)
            metric_accs.append(valid_acc)
        rank_accs = stats.rankdata(metric_accs)
        rank_agg = rank_accs
#         l = len(rank_accs)
#         rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l)+np.log(rank_step_sims/l)
#             rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_sensitivities/l)+np.log(rank_step_sims/l)
        best_idx = np.argmax(rank_agg)
        best_arch, best_acc = archs[best_idx], metric_accs[best_idx]
        logger.log("Found best op for target cell:{}".format(target_cell_idx))
        logger.log(": {:} with accuracy={:.2f}%".format(best_arch, best_acc))
        target_cell.arch_cache = best_arch
            
best_archs = []
for c in cells:
    best_archs.append(c.arch_cache)
    
torch.save({"model":search_model.state_dict(), "best_archs":best_archs}, os.path.join(xargs.save_dir, "output.pth"))

for m in search_model.modules():
    if isinstance(m, SearchCell):
        logger.log(m.arch_cache)

logger.close()
# Out:
# total number of nodes:60
# target_node:1 4
# target_node:2 24
# target_node:3 124
#
#
#  Searching with a cell #0
# *Train* [2022-11-07 02:53:58] Ep:0 [000/391] Time 2.60 (2.60) Data 0.21 (0.21) Base [Loss 2.294 (2.294)  Prec@1 10.94 (10.94) Prec@5 57.81 (57.81)]
# *Train* [2022-11-07 02:54:22] Ep:0 [200/391] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 1.594 (1.825)  Prec@1 39.06 (30.60) Prec@5 89.06 (84.26)]
# *Train* [2022-11-07 02:54:40] Ep:0 [390/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 1.753 (1.674)  Prec@1 35.00 (36.98) Prec@5 90.00 (87.82)]
# Ep:0 ends : loss=1.67, accuracy@1=36.98%, accuracy@5=87.82%
# *Train* [2022-11-07 02:54:41] Ep:1 [000/391] Time 0.30 (0.30) Data 0.21 (0.21) Base [Loss 2.792 (2.792)  Prec@1 10.94 (10.94) Prec@5 59.38 (59.38)]
# *Train* [2022-11-07 02:55:00] Ep:1 [200/391] Time 0.20 (0.10) Data 0.00 (0.00) Base [Loss 1.544 (1.549)  Prec@1 45.31 (42.45) Prec@5 89.06 (90.76)]
# *Train* [2022-11-07 02:55:25] Ep:1 [390/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 1.470 (1.445)  Prec@1 50.00 (46.88) Prec@5 90.00 (92.24)]
# Ep:1 ends : loss=1.44, accuracy@1=46.88%, accuracy@5=92.24%
# Found best op for target cell:0
# : Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|avg_pool_3x3~1|nor_conv_3x3~2|) with accuracy=50.78%
#
#
#  Searching with a cell #1
# *Train* [2022-11-07 02:55:42] Ep:0 [000/391] Time 0.32 (0.32) Data 0.24 (0.24) Base [Loss 2.603 (2.603)  Prec@1 18.75 (18.75) Prec@5 62.50 (62.50)]
# *Train* [2022-11-07 02:56:03] Ep:0 [200/391] Time 0.08 (0.11) Data 0.00 (0.00) Base [Loss 1.171 (1.323)  Prec@1 59.38 (52.42) Prec@5 92.19 (93.67)]
# *Train* [2022-11-07 02:56:24] Ep:0 [390/391] Time 0.20 (0.11) Data 0.00 (0.00) Base [Loss 1.116 (1.254)  Prec@1 60.00 (54.89) Prec@5 97.50 (94.54)]
# Ep:0 ends : loss=1.25, accuracy@1=54.89%, accuracy@5=94.54%
# *Train* [2022-11-07 02:56:25] Ep:1 [000/391] Time 0.35 (0.35) Data 0.21 (0.21) Base [Loss 1.744 (1.744)  Prec@1 39.06 (39.06) Prec@5 84.38 (84.38)]
# *Train* [2022-11-07 02:56:44] Ep:1 [200/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 1.004 (1.171)  Prec@1 60.94 (57.66) Prec@5 98.44 (95.43)]
# *Train* [2022-11-07 02:57:01] Ep:1 [390/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 1.334 (1.141)  Prec@1 52.50 (59.06) Prec@5 97.50 (95.60)]
# Ep:1 ends : loss=1.14, accuracy@1=59.06%, accuracy@5=95.60%
# Found best op for target cell:1
# : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_1x1~2|) with accuracy=59.77%
#
#
#  Searching with a cell #2
# *Train* [2022-11-07 02:57:18] Ep:0 [000/391] Time 0.34 (0.34) Data 0.24 (0.24) Base [Loss 1.539 (1.539)  Prec@1 43.75 (43.75) Prec@5 89.06 (89.06)]
# *Train* [2022-11-07 02:57:38] Ep:0 [200/391] Time 0.15 (0.10) Data 0.00 (0.00) Base [Loss 1.059 (1.104)  Prec@1 62.50 (60.42) Prec@5 96.88 (95.79)]
# *Train* [2022-11-07 02:57:58] Ep:0 [390/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 1.057 (1.075)  Prec@1 57.50 (61.40) Prec@5 95.00 (96.30)]
# Ep:0 ends : loss=1.07, accuracy@1=61.40%, accuracy@5=96.30%
# *Train* [2022-11-07 02:57:58] Ep:1 [000/391] Time 0.32 (0.32) Data 0.23 (0.23) Base [Loss 1.312 (1.312)  Prec@1 51.56 (51.56) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 02:58:24] Ep:1 [200/391] Time 0.22 (0.13) Data 0.00 (0.00) Base [Loss 0.796 (1.017)  Prec@1 71.88 (63.84) Prec@5 96.88 (96.59)]
# *Train* [2022-11-07 02:58:47] Ep:1 [390/391] Time 0.07 (0.13) Data 0.00 (0.00) Base [Loss 0.950 (0.997)  Prec@1 60.00 (64.83) Prec@5 100.00 (96.86)]
# Ep:1 ends : loss=1.00, accuracy@1=64.83%, accuracy@5=96.86%
# Found best op for target cell:2
# : Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|) with accuracy=64.45%
#
#
#  Searching with a cell #3
# *Train* [2022-11-07 02:59:04] Ep:0 [000/391] Time 0.40 (0.40) Data 0.23 (0.23) Base [Loss 3.446 (3.446)  Prec@1 14.06 (14.06) Prec@5 48.44 (48.44)]
# *Train* [2022-11-07 02:59:26] Ep:0 [200/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 0.845 (1.050)  Prec@1 70.31 (62.88) Prec@5 98.44 (96.43)]
# *Train* [2022-11-07 02:59:52] Ep:0 [390/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 1.060 (1.010)  Prec@1 57.50 (64.23) Prec@5 97.50 (96.73)]
# Ep:0 ends : loss=1.01, accuracy@1=64.23%, accuracy@5=96.73%
# *Train* [2022-11-07 02:59:53] Ep:1 [000/391] Time 0.55 (0.55) Data 0.30 (0.30) Base [Loss 1.160 (1.160)  Prec@1 65.62 (65.62) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 03:00:14] Ep:1 [200/391] Time 0.14 (0.11) Data 0.00 (0.00) Base [Loss 0.999 (0.976)  Prec@1 60.94 (65.14) Prec@5 98.44 (97.09)]
# *Train* [2022-11-07 03:00:33] Ep:1 [390/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.840 (0.950)  Prec@1 75.00 (66.18) Prec@5 97.50 (97.30)]
# Ep:1 ends : loss=0.95, accuracy@1=66.18%, accuracy@5=97.30%
# Found best op for target cell:3
# : Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|) with accuracy=67.77%
#
#
#  Searching with a cell #4
# *Train* [2022-11-07 03:00:50] Ep:0 [000/391] Time 0.32 (0.32) Data 0.23 (0.23) Base [Loss 3.472 (3.472)  Prec@1 9.38 (9.38) Prec@5 50.00 (50.00)]
# *Train* [2022-11-07 03:01:11] Ep:0 [200/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 1.003 (1.019)  Prec@1 64.06 (63.68) Prec@5 96.88 (96.40)]
# *Train* [2022-11-07 03:01:27] Ep:0 [390/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 1.121 (0.953)  Prec@1 67.50 (66.29) Prec@5 97.50 (96.98)]
# Ep:0 ends : loss=0.95, accuracy@1=66.29%, accuracy@5=96.98%
# *Train* [2022-11-07 03:01:27] Ep:1 [000/391] Time 0.32 (0.32) Data 0.22 (0.22) Base [Loss 1.199 (1.199)  Prec@1 60.94 (60.94) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 03:01:50] Ep:1 [200/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.665 (0.870)  Prec@1 82.81 (69.49) Prec@5 98.44 (97.57)]
# *Train* [2022-11-07 03:02:09] Ep:1 [390/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 0.957 (0.867)  Prec@1 72.50 (69.38) Prec@5 97.50 (97.68)]
# Ep:1 ends : loss=0.87, accuracy@1=69.38%, accuracy@5=97.68%
# Found best op for target cell:4
# : Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|nor_conv_1x1~0|nor_conv_1x1~1|none~2|) with accuracy=64.84%
#
#
#  Searching with a cell #5
# *Train* [2022-11-07 03:02:26] Ep:0 [000/391] Time 0.37 (0.37) Data 0.28 (0.28) Base [Loss 2.661 (2.661)  Prec@1 20.31 (20.31) Prec@5 64.06 (64.06)]
# *Train* [2022-11-07 03:02:43] Ep:0 [200/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 1.071 (0.973)  Prec@1 57.81 (66.00) Prec@5 98.44 (97.03)]
# *Train* [2022-11-07 03:03:06] Ep:0 [390/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 0.894 (0.919)  Prec@1 65.00 (67.80) Prec@5 100.00 (97.44)]
# Ep:0 ends : loss=0.92, accuracy@1=67.80%, accuracy@5=97.44%
# *Train* [2022-11-07 03:03:07] Ep:1 [000/391] Time 0.41 (0.41) Data 0.25 (0.25) Base [Loss 1.778 (1.778)  Prec@1 32.81 (32.81) Prec@5 89.06 (89.06)]
# *Train* [2022-11-07 03:03:30] Ep:1 [200/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.859 (0.875)  Prec@1 68.75 (69.36) Prec@5 100.00 (97.71)]
# *Train* [2022-11-07 03:03:52] Ep:1 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.781 (0.848)  Prec@1 72.50 (70.25) Prec@5 100.00 (97.90)]
# Ep:1 ends : loss=0.85, accuracy@1=70.25%, accuracy@5=97.90%
# Found best op for target cell:5
# : Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|avg_pool_3x3~0|skip_connect~1|none~2|) with accuracy=68.95%
#
#
#  Searching with a cell #6
# *Train* [2022-11-07 03:04:10] Ep:0 [000/391] Time 0.35 (0.35) Data 0.25 (0.25) Base [Loss 0.815 (0.815)  Prec@1 73.44 (73.44) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 03:04:28] Ep:0 [200/391] Time 0.12 (0.09) Data 0.00 (0.00) Base [Loss 1.163 (0.816)  Prec@1 60.94 (71.39) Prec@5 96.88 (97.93)]
# *Train* [2022-11-07 03:04:51] Ep:0 [390/391] Time 0.21 (0.11) Data 0.00 (0.00) Base [Loss 0.654 (0.805)  Prec@1 75.00 (71.81) Prec@5 100.00 (97.99)]
# Ep:0 ends : loss=0.81, accuracy@1=71.81%, accuracy@5=97.99%
# *Train* [2022-11-07 03:04:51] Ep:1 [000/391] Time 0.42 (0.42) Data 0.27 (0.27) Base [Loss 1.717 (1.717)  Prec@1 54.69 (54.69) Prec@5 84.38 (84.38)]
# *Train* [2022-11-07 03:05:09] Ep:1 [200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.885 (0.831)  Prec@1 71.88 (71.12) Prec@5 96.88 (97.71)]
# *Train* [2022-11-07 03:05:28] Ep:1 [390/391] Time 0.13 (0.09) Data 0.00 (0.00) Base [Loss 0.727 (0.808)  Prec@1 80.00 (71.86) Prec@5 92.50 (97.95)]
# Ep:1 ends : loss=0.81, accuracy@1=71.86%, accuracy@5=97.95%
# Found best op for target cell:6
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|skip_connect~0|none~1|none~2|) with accuracy=72.46%
#
#
#  Searching with a cell #7
# *Train* [2022-11-07 03:05:50] Ep:0 [000/391] Time 0.41 (0.41) Data 0.27 (0.27) Base [Loss 0.709 (0.709)  Prec@1 76.56 (76.56) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 03:06:12] Ep:0 [200/391] Time 0.20 (0.11) Data 0.00 (0.00) Base [Loss 0.752 (0.774)  Prec@1 68.75 (73.06) Prec@5 98.44 (98.25)]
# *Train* [2022-11-07 03:06:37] Ep:0 [390/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.502 (0.760)  Prec@1 82.50 (73.43) Prec@5 100.00 (98.28)]
# Ep:0 ends : loss=0.76, accuracy@1=73.43%, accuracy@5=98.28%
# *Train* [2022-11-07 03:06:38] Ep:1 [000/391] Time 0.39 (0.39) Data 0.25 (0.25) Base [Loss 0.937 (0.937)  Prec@1 65.62 (65.62) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:07:01] Ep:1 [200/391] Time 0.15 (0.12) Data 0.00 (0.00) Base [Loss 0.886 (0.736)  Prec@1 70.31 (74.05) Prec@5 95.31 (98.47)]
# *Train* [2022-11-07 03:07:20] Ep:1 [390/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.643 (0.734)  Prec@1 72.50 (74.11) Prec@5 100.00 (98.43)]
# Ep:1 ends : loss=0.73, accuracy@1=74.11%, accuracy@5=98.43%
# Found best op for target cell:7
# : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|none~2|) with accuracy=72.46%
#
#
#  Searching with a cell #8
# *Train* [2022-11-07 03:07:40] Ep:0 [000/391] Time 0.44 (0.44) Data 0.26 (0.26) Base [Loss 3.396 (3.396)  Prec@1 10.94 (10.94) Prec@5 46.88 (46.88)]
# *Train* [2022-11-07 03:08:04] Ep:0 [200/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.715 (0.896)  Prec@1 71.88 (68.71) Prec@5 98.44 (97.16)]
# *Train* [2022-11-07 03:08:28] Ep:0 [390/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.654 (0.829)  Prec@1 77.50 (71.16) Prec@5 97.50 (97.69)]
# Ep:0 ends : loss=0.83, accuracy@1=71.16%, accuracy@5=97.69%
# *Train* [2022-11-07 03:08:28] Ep:1 [000/391] Time 0.37 (0.37) Data 0.23 (0.23) Base [Loss 3.865 (3.865)  Prec@1 4.69 (4.69) Prec@5 37.50 (37.50)]
# *Train* [2022-11-07 03:08:47] Ep:1 [200/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.793 (0.857)  Prec@1 73.44 (70.31) Prec@5 98.44 (97.47)]
# *Train* [2022-11-07 03:09:07] Ep:1 [390/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 0.867 (0.801)  Prec@1 65.00 (72.04) Prec@5 97.50 (97.86)]
# Ep:1 ends : loss=0.80, accuracy@1=72.04%, accuracy@5=97.86%
# Found best op for target cell:8
# : Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_1x1~2|) with accuracy=69.14%
#
#
#  Searching with a cell #9
# *Train* [2022-11-07 03:09:24] Ep:0 [000/391] Time 0.37 (0.37) Data 0.27 (0.27) Base [Loss 0.950 (0.950)  Prec@1 68.75 (68.75) Prec@5 92.19 (92.19)]
# *Train* [2022-11-07 03:09:41] Ep:0 [200/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 1.038 (0.747)  Prec@1 64.06 (74.29) Prec@5 93.75 (98.20)]
# *Train* [2022-11-07 03:09:57] Ep:0 [390/391] Time 0.08 (0.08) Data 0.00 (0.00) Base [Loss 0.872 (0.741)  Prec@1 75.00 (74.37) Prec@5 92.50 (98.28)]
# Ep:0 ends : loss=0.74, accuracy@1=74.37%, accuracy@5=98.28%
# *Train* [2022-11-07 03:09:57] Ep:1 [000/391] Time 0.44 (0.44) Data 0.25 (0.25) Base [Loss 0.812 (0.812)  Prec@1 73.44 (73.44) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:10:19] Ep:1 [200/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.774 (0.719)  Prec@1 76.56 (75.10) Prec@5 98.44 (98.42)]
# *Train* [2022-11-07 03:10:41] Ep:1 [390/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.938 (0.723)  Prec@1 67.50 (74.86) Prec@5 97.50 (98.42)]
# Ep:1 ends : loss=0.72, accuracy@1=74.86%, accuracy@5=98.42%
# Found best op for target cell:9
# : Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|) with accuracy=73.44%
#
#
#  Searching with a cell #10
# *Train* [2022-11-07 03:11:01] Ep:0 [000/391] Time 0.32 (0.32) Data 0.23 (0.23) Base [Loss 2.350 (2.350)  Prec@1 17.19 (17.19) Prec@5 64.06 (64.06)]
# *Train* [2022-11-07 03:11:28] Ep:0 [200/391] Time 0.12 (0.14) Data 0.00 (0.00) Base [Loss 0.611 (0.780)  Prec@1 82.81 (72.97) Prec@5 98.44 (98.07)]
# *Train* [2022-11-07 03:11:51] Ep:0 [390/391] Time 0.21 (0.13) Data 0.00 (0.00) Base [Loss 0.976 (0.753)  Prec@1 70.00 (73.89) Prec@5 97.50 (98.19)]
# Ep:0 ends : loss=0.75, accuracy@1=73.89%, accuracy@5=98.19%
# *Train* [2022-11-07 03:11:52] Ep:1 [000/391] Time 0.35 (0.35) Data 0.23 (0.23) Base [Loss 0.631 (0.631)  Prec@1 82.81 (82.81) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:12:19] Ep:1 [200/391] Time 0.14 (0.14) Data 0.00 (0.00) Base [Loss 0.775 (0.701)  Prec@1 70.31 (75.23) Prec@5 98.44 (98.48)]
# *Train* [2022-11-07 03:12:44] Ep:1 [390/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.653 (0.691)  Prec@1 75.00 (75.94) Prec@5 97.50 (98.47)]
# Ep:1 ends : loss=0.69, accuracy@1=75.94%, accuracy@5=98.47%
# Found best op for target cell:10
# : Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_3x3~1|none~2|) with accuracy=74.02%
#
#
#  Searching with a cell #11
# *Train* [2022-11-07 03:13:05] Ep:0 [000/391] Time 0.43 (0.43) Data 0.28 (0.28) Base [Loss 1.184 (1.184)  Prec@1 62.50 (62.50) Prec@5 92.19 (92.19)]
# *Train* [2022-11-07 03:13:30] Ep:0 [200/391] Time 0.07 (0.13) Data 0.00 (0.00) Base [Loss 0.621 (0.714)  Prec@1 81.25 (75.31) Prec@5 98.44 (98.45)]
# *Train* [2022-11-07 03:13:45] Ep:0 [390/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.872 (0.701)  Prec@1 72.50 (75.54) Prec@5 100.00 (98.53)]
# Ep:0 ends : loss=0.70, accuracy@1=75.54%, accuracy@5=98.53%
# *Train* [2022-11-07 03:13:45] Ep:1 [000/391] Time 0.33 (0.33) Data 0.24 (0.24) Base [Loss 0.690 (0.690)  Prec@1 73.44 (73.44) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:14:04] Ep:1 [200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.473 (0.688)  Prec@1 85.94 (76.20) Prec@5 98.44 (98.59)]
# *Train* [2022-11-07 03:14:28] Ep:1 [390/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 1.045 (0.685)  Prec@1 62.50 (76.44) Prec@5 97.50 (98.64)]
# Ep:1 ends : loss=0.68, accuracy@1=76.44%, accuracy@5=98.64%
# Found best op for target cell:11
# : Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|avg_pool_3x3~2|) with accuracy=75.78%
#
#
#  Searching with a cell #12
# *Train* [2022-11-07 03:14:46] Ep:0 [000/391] Time 0.32 (0.32) Data 0.23 (0.23) Base [Loss 0.828 (0.828)  Prec@1 70.31 (70.31) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 03:15:05] Ep:0 [200/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.683 (0.676)  Prec@1 76.56 (76.16) Prec@5 100.00 (98.59)]
# *Train* [2022-11-07 03:15:22] Ep:0 [390/391] Time 0.12 (0.09) Data 0.00 (0.00) Base [Loss 0.649 (0.667)  Prec@1 77.50 (76.70) Prec@5 100.00 (98.59)]
# Ep:0 ends : loss=0.67, accuracy@1=76.70%, accuracy@5=98.59%
# *Train* [2022-11-07 03:15:23] Ep:1 [000/391] Time 0.36 (0.36) Data 0.26 (0.26) Base [Loss 2.427 (2.427)  Prec@1 18.75 (18.75) Prec@5 67.19 (67.19)]
# *Train* [2022-11-07 03:15:44] Ep:1 [200/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.540 (0.699)  Prec@1 81.25 (75.58) Prec@5 98.44 (98.39)]
# *Train* [2022-11-07 03:16:02] Ep:1 [390/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 1.196 (0.688)  Prec@1 62.50 (76.22) Prec@5 92.50 (98.49)]
# Ep:1 ends : loss=0.69, accuracy@1=76.22%, accuracy@5=98.49%
# Found best op for target cell:12
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|) with accuracy=75.78%
#
#
#  Searching with a cell #13
# *Train* [2022-11-07 03:16:20] Ep:0 [000/391] Time 0.42 (0.42) Data 0.27 (0.27) Base [Loss 2.540 (2.540)  Prec@1 17.19 (17.19) Prec@5 59.38 (59.38)]
# *Train* [2022-11-07 03:16:44] Ep:0 [200/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.585 (0.758)  Prec@1 81.25 (74.29) Prec@5 98.44 (97.88)]
# *Train* [2022-11-07 03:17:06] Ep:0 [390/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.852 (0.730)  Prec@1 72.50 (75.02) Prec@5 97.50 (98.22)]
# Ep:0 ends : loss=0.73, accuracy@1=75.02%, accuracy@5=98.22%
# *Train* [2022-11-07 03:17:06] Ep:1 [000/391] Time 0.36 (0.36) Data 0.25 (0.25) Base [Loss 2.892 (2.892)  Prec@1 3.12 (3.12) Prec@5 42.19 (42.19)]
# *Train* [2022-11-07 03:17:28] Ep:1 [200/391] Time 0.22 (0.11) Data 0.00 (0.00) Base [Loss 1.010 (0.692)  Prec@1 67.19 (76.17) Prec@5 98.44 (98.34)]
# *Train* [2022-11-07 03:17:49] Ep:1 [390/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.450 (0.673)  Prec@1 87.50 (76.81) Prec@5 97.50 (98.49)]
# Ep:1 ends : loss=0.67, accuracy@1=76.81%, accuracy@5=98.49%
# Found best op for target cell:13
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_1x1~2|) with accuracy=77.54%
#
#
#  Searching with a cell #14
# *Train* [2022-11-07 03:18:10] Ep:0 [000/391] Time 0.41 (0.41) Data 0.23 (0.23) Base [Loss 0.771 (0.771)  Prec@1 68.75 (68.75) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 03:18:30] Ep:0 [200/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.789 (0.630)  Prec@1 71.88 (78.09) Prec@5 100.00 (98.87)]
# *Train* [2022-11-07 03:18:55] Ep:0 [390/391] Time 0.14 (0.12) Data 0.00 (0.00) Base [Loss 0.483 (0.631)  Prec@1 77.50 (78.25) Prec@5 100.00 (98.82)]
# Ep:0 ends : loss=0.63, accuracy@1=78.25%, accuracy@5=98.82%
# *Train* [2022-11-07 03:18:56] Ep:1 [000/391] Time 0.42 (0.42) Data 0.26 (0.26) Base [Loss 0.641 (0.641)  Prec@1 73.44 (73.44) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:19:15] Ep:1 [200/391] Time 0.15 (0.10) Data 0.00 (0.00) Base [Loss 0.605 (0.625)  Prec@1 78.12 (78.20) Prec@5 100.00 (98.74)]
# *Train* [2022-11-07 03:19:32] Ep:1 [390/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.832 (0.624)  Prec@1 70.00 (78.52) Prec@5 97.50 (98.76)]
# Ep:1 ends : loss=0.62, accuracy@1=78.52%, accuracy@5=98.76%
# Found best op for target cell:14
# : Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|) with accuracy=77.34%
#
#
#  Searching with a cell #0
# *Train* [2022-11-07 03:19:54] Ep:0 [000/391] Time 0.33 (0.33) Data 0.23 (0.23) Base [Loss 3.991 (3.991)  Prec@1 12.50 (12.50) Prec@5 56.25 (56.25)]
# *Train* [2022-11-07 03:20:13] Ep:0 [200/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.525 (0.946)  Prec@1 84.38 (68.67) Prec@5 98.44 (96.63)]
# *Train* [2022-11-07 03:20:36] Ep:0 [390/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.705 (0.833)  Prec@1 77.50 (71.85) Prec@5 95.00 (97.52)]
# Ep:0 ends : loss=0.83, accuracy@1=71.85%, accuracy@5=97.52%
# *Train* [2022-11-07 03:20:36] Ep:1 [000/391] Time 0.35 (0.35) Data 0.27 (0.27) Base [Loss 3.561 (3.561)  Prec@1 18.75 (18.75) Prec@5 62.50 (62.50)]
# *Train* [2022-11-07 03:20:57] Ep:1 [200/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.888 (1.000)  Prec@1 60.94 (65.39) Prec@5 98.44 (96.56)]
# *Train* [2022-11-07 03:21:24] Ep:1 [390/391] Time 0.14 (0.12) Data 0.00 (0.00) Base [Loss 0.730 (0.928)  Prec@1 77.50 (67.84) Prec@5 100.00 (97.02)]
# Ep:1 ends : loss=0.93, accuracy@1=67.84%, accuracy@5=97.02%
# Found best op for target cell:0
# : Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|) with accuracy=66.21%
#
#
#  Searching with a cell #1
# *Train* [2022-11-07 03:21:42] Ep:0 [000/391] Time 0.33 (0.33) Data 0.24 (0.24) Base [Loss 3.650 (3.650)  Prec@1 10.94 (10.94) Prec@5 64.06 (64.06)]
# *Train* [2022-11-07 03:22:03] Ep:0 [200/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.961 (1.039)  Prec@1 64.06 (64.33) Prec@5 100.00 (95.97)]
# *Train* [2022-11-07 03:22:22] Ep:0 [390/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 1.067 (0.941)  Prec@1 65.00 (67.52) Prec@5 95.00 (96.80)]
# Ep:0 ends : loss=0.94, accuracy@1=67.52%, accuracy@5=96.80%
# *Train* [2022-11-07 03:22:23] Ep:1 [000/391] Time 0.41 (0.41) Data 0.26 (0.26) Base [Loss 2.126 (2.126)  Prec@1 43.75 (43.75) Prec@5 82.81 (82.81)]
# *Train* [2022-11-07 03:22:47] Ep:1 [200/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.959 (0.973)  Prec@1 67.19 (65.82) Prec@5 98.44 (96.88)]
# *Train* [2022-11-07 03:23:09] Ep:1 [390/391] Time 0.20 (0.12) Data 0.00 (0.00) Base [Loss 0.719 (0.924)  Prec@1 75.00 (67.64) Prec@5 97.50 (97.19)]
# Ep:1 ends : loss=0.92, accuracy@1=67.64%, accuracy@5=97.19%
# Found best op for target cell:1
# : Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|none~0|nor_conv_3x3~1|skip_connect~2|) with accuracy=68.75%
#
#
#  Searching with a cell #2
# *Train* [2022-11-07 03:23:27] Ep:0 [000/391] Time 0.39 (0.39) Data 0.30 (0.30) Base [Loss 2.060 (2.060)  Prec@1 32.81 (32.81) Prec@5 89.06 (89.06)]
# *Train* [2022-11-07 03:23:45] Ep:0 [200/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.817 (0.974)  Prec@1 65.62 (66.47) Prec@5 96.88 (96.95)]
# *Train* [2022-11-07 03:24:02] Ep:0 [390/391] Time 0.09 (0.09) Data 0.00 (0.00) Base [Loss 1.246 (0.935)  Prec@1 57.50 (67.66) Prec@5 100.00 (97.18)]
# Ep:0 ends : loss=0.93, accuracy@1=67.66%, accuracy@5=97.18%
# *Train* [2022-11-07 03:24:02] Ep:1 [000/391] Time 0.35 (0.35) Data 0.25 (0.25) Base [Loss 3.774 (3.774)  Prec@1 9.38 (9.38) Prec@5 48.44 (48.44)]
# *Train* [2022-11-07 03:24:25] Ep:1 [200/391] Time 0.14 (0.12) Data 0.00 (0.00) Base [Loss 0.958 (1.119)  Prec@1 60.94 (61.10) Prec@5 96.88 (95.05)]
# *Train* [2022-11-07 03:24:49] Ep:1 [390/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.934 (0.984)  Prec@1 70.00 (65.81) Prec@5 100.00 (96.30)]
# Ep:1 ends : loss=0.98, accuracy@1=65.81%, accuracy@5=96.30%
# Found best op for target cell:2
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|) with accuracy=65.62%
#
#
#  Searching with a cell #3
# *Train* [2022-11-07 03:25:08] Ep:0 [000/391] Time 0.39 (0.39) Data 0.30 (0.30) Base [Loss 1.304 (1.304)  Prec@1 51.56 (51.56) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 03:25:31] Ep:0 [200/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.706 (0.803)  Prec@1 76.56 (72.00) Prec@5 95.31 (97.85)]
# *Train* [2022-11-07 03:25:50] Ep:0 [390/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.987 (0.771)  Prec@1 65.00 (73.16) Prec@5 100.00 (98.05)]
# Ep:0 ends : loss=0.77, accuracy@1=73.16%, accuracy@5=98.05%
# *Train* [2022-11-07 03:25:51] Ep:1 [000/391] Time 0.41 (0.41) Data 0.25 (0.25) Base [Loss 0.489 (0.489)  Prec@1 79.69 (79.69) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 03:26:19] Ep:1 [200/391] Time 0.14 (0.14) Data 0.00 (0.00) Base [Loss 0.613 (0.719)  Prec@1 78.12 (75.31) Prec@5 98.44 (98.31)]
# *Train* [2022-11-07 03:26:45] Ep:1 [390/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.661 (0.709)  Prec@1 80.00 (75.50) Prec@5 95.00 (98.26)]
# Ep:1 ends : loss=0.71, accuracy@1=75.50%, accuracy@5=98.26%
# Found best op for target cell:3
# : Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|) with accuracy=71.68%
#
#
#  Searching with a cell #4
# *Train* [2022-11-07 03:27:04] Ep:0 [000/391] Time 0.52 (0.52) Data 0.25 (0.25) Base [Loss 1.999 (1.999)  Prec@1 37.50 (37.50) Prec@5 81.25 (81.25)]
# *Train* [2022-11-07 03:27:30] Ep:0 [200/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.671 (0.816)  Prec@1 85.94 (71.82) Prec@5 100.00 (97.75)]
# *Train* [2022-11-07 03:27:53] Ep:0 [390/391] Time 0.15 (0.13) Data 0.00 (0.00) Base [Loss 0.748 (0.785)  Prec@1 75.00 (73.18) Prec@5 97.50 (97.89)]
# Ep:0 ends : loss=0.78, accuracy@1=73.18%, accuracy@5=97.89%
# *Train* [2022-11-07 03:27:53] Ep:1 [000/391] Time 0.33 (0.33) Data 0.22 (0.22) Base [Loss 0.855 (0.855)  Prec@1 68.75 (68.75) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 03:28:13] Ep:1 [200/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.757 (0.718)  Prec@1 73.44 (75.07) Prec@5 98.44 (98.24)]
# *Train* [2022-11-07 03:28:32] Ep:1 [390/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.844 (0.721)  Prec@1 67.50 (74.92) Prec@5 97.50 (98.33)]
# Ep:1 ends : loss=0.72, accuracy@1=74.92%, accuracy@5=98.33%
# Found best op for target cell:4
# : Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|) with accuracy=71.68%
#
#
#  Searching with a cell #5
# *Train* [2022-11-07 03:28:50] Ep:0 [000/391] Time 0.35 (0.35) Data 0.25 (0.25) Base [Loss 1.104 (1.104)  Prec@1 65.62 (65.62) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 03:29:08] Ep:0 [200/391] Time 0.14 (0.09) Data 0.00 (0.00) Base [Loss 0.840 (0.749)  Prec@1 65.62 (73.93) Prec@5 98.44 (98.14)]
# *Train* [2022-11-07 03:29:29] Ep:0 [390/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.794 (0.731)  Prec@1 70.00 (74.59) Prec@5 95.00 (98.19)]
# Ep:0 ends : loss=0.73, accuracy@1=74.59%, accuracy@5=98.19%
# *Train* [2022-11-07 03:29:30] Ep:1 [000/391] Time 0.46 (0.46) Data 0.23 (0.23) Base [Loss 4.196 (4.196)  Prec@1 6.25 (6.25) Prec@5 51.56 (51.56)]
# *Train* [2022-11-07 03:29:56] Ep:1 [200/391] Time 0.07 (0.13) Data 0.00 (0.00) Base [Loss 0.676 (0.915)  Prec@1 76.56 (67.82) Prec@5 100.00 (96.98)]
# *Train* [2022-11-07 03:30:18] Ep:1 [390/391] Time 0.14 (0.12) Data 0.00 (0.00) Base [Loss 0.867 (0.825)  Prec@1 67.50 (71.28) Prec@5 97.50 (97.58)]
# Ep:1 ends : loss=0.83, accuracy@1=71.28%, accuracy@5=97.58%
# Found best op for target cell:5
# : Structure(4 nodes with |nor_conv_3x3~0|+|none~0|avg_pool_3x3~1|+|none~0|skip_connect~1|none~2|) with accuracy=67.77%
#
#
#  Searching with a cell #6
# *Train* [2022-11-07 03:30:36] Ep:0 [000/391] Time 0.41 (0.41) Data 0.24 (0.24) Base [Loss 3.065 (3.065)  Prec@1 12.50 (12.50) Prec@5 62.50 (62.50)]
# *Train* [2022-11-07 03:30:53] Ep:0 [200/391] Time 0.09 (0.09) Data 0.00 (0.00) Base [Loss 0.840 (0.825)  Prec@1 71.88 (71.38) Prec@5 100.00 (97.61)]
# *Train* [2022-11-07 03:31:18] Ep:0 [390/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.752 (0.778)  Prec@1 70.00 (72.97) Prec@5 100.00 (97.99)]
# Ep:0 ends : loss=0.78, accuracy@1=72.97%, accuracy@5=97.99%
# *Train* [2022-11-07 03:31:18] Ep:1 [000/391] Time 0.32 (0.32) Data 0.23 (0.23) Base [Loss 1.195 (1.195)  Prec@1 67.19 (67.19) Prec@5 90.62 (90.62)]
# *Train* [2022-11-07 03:31:41] Ep:1 [200/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.498 (0.736)  Prec@1 79.69 (74.67) Prec@5 98.44 (98.22)]
# *Train* [2022-11-07 03:32:04] Ep:1 [390/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.814 (0.725)  Prec@1 75.00 (75.04) Prec@5 97.50 (98.27)]
# Ep:1 ends : loss=0.72, accuracy@1=75.04%, accuracy@5=98.27%
# Found best op for target cell:6
# : Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|) with accuracy=70.51%
#
#
#  Searching with a cell #7
# *Train* [2022-11-07 03:32:24] Ep:0 [000/391] Time 0.43 (0.43) Data 0.25 (0.25) Base [Loss 1.007 (1.007)  Prec@1 70.31 (70.31) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 03:32:50] Ep:0 [200/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.550 (0.699)  Prec@1 79.69 (75.55) Prec@5 100.00 (98.59)]
# *Train* [2022-11-07 03:33:12] Ep:0 [390/391] Time 0.21 (0.12) Data 0.00 (0.00) Base [Loss 0.462 (0.686)  Prec@1 85.00 (75.98) Prec@5 100.00 (98.56)]
# Ep:0 ends : loss=0.69, accuracy@1=75.98%, accuracy@5=98.56%
# *Train* [2022-11-07 03:33:13] Ep:1 [000/391] Time 0.33 (0.33) Data 0.25 (0.25) Base [Loss 0.842 (0.842)  Prec@1 71.88 (71.88) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 03:33:30] Ep:1 [200/391] Time 0.09 (0.09) Data 0.00 (0.00) Base [Loss 0.617 (0.695)  Prec@1 78.12 (75.98) Prec@5 100.00 (98.51)]
# *Train* [2022-11-07 03:33:49] Ep:1 [390/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.482 (0.684)  Prec@1 82.50 (76.40) Prec@5 97.50 (98.55)]
# Ep:1 ends : loss=0.68, accuracy@1=76.40%, accuracy@5=98.55%
# Found best op for target cell:7
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|skip_connect~1|skip_connect~2|) with accuracy=72.85%
#
#
#  Searching with a cell #8
# *Train* [2022-11-07 03:34:10] Ep:0 [000/391] Time 0.36 (0.36) Data 0.26 (0.26) Base [Loss 0.786 (0.786)  Prec@1 76.56 (76.56) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:34:29] Ep:0 [200/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 0.643 (0.725)  Prec@1 73.44 (74.71) Prec@5 100.00 (98.42)]
# *Train* [2022-11-07 03:34:46] Ep:0 [390/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.716 (0.719)  Prec@1 67.50 (74.90) Prec@5 100.00 (98.36)]
# Ep:0 ends : loss=0.72, accuracy@1=74.90%, accuracy@5=98.36%
# *Train* [2022-11-07 03:34:46] Ep:1 [000/391] Time 0.39 (0.39) Data 0.23 (0.23) Base [Loss 4.358 (4.358)  Prec@1 7.81 (7.81) Prec@5 48.44 (48.44)]
# *Train* [2022-11-07 03:35:09] Ep:1 [200/391] Time 0.15 (0.11) Data 0.00 (0.00) Base [Loss 0.470 (0.798)  Prec@1 85.94 (73.03) Prec@5 100.00 (97.64)]
# *Train* [2022-11-07 03:35:32] Ep:1 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.770 (0.740)  Prec@1 75.00 (74.86) Prec@5 97.50 (98.10)]
# Ep:1 ends : loss=0.74, accuracy@1=74.86%, accuracy@5=98.10%
# Found best op for target cell:8
# : Structure(4 nodes with |avg_pool_3x3~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|none~2|) with accuracy=68.36%
#
#
#  Searching with a cell #9
# *Train* [2022-11-07 03:35:52] Ep:0 [000/391] Time 0.49 (0.49) Data 0.24 (0.24) Base [Loss 4.726 (4.726)  Prec@1 6.25 (6.25) Prec@5 40.62 (40.62)]
# *Train* [2022-11-07 03:36:12] Ep:0 [200/391] Time 0.11 (0.11) Data 0.00 (0.00) Base [Loss 0.642 (0.814)  Prec@1 76.56 (71.70) Prec@5 100.00 (97.73)]
# *Train* [2022-11-07 03:36:36] Ep:0 [390/391] Time 0.08 (0.11) Data 0.00 (0.00) Base [Loss 0.799 (0.755)  Prec@1 70.00 (73.90) Prec@5 97.50 (98.08)]
# Ep:0 ends : loss=0.76, accuracy@1=73.90%, accuracy@5=98.08%
# *Train* [2022-11-07 03:36:36] Ep:1 [000/391] Time 0.38 (0.38) Data 0.24 (0.24) Base [Loss 1.282 (1.282)  Prec@1 56.25 (56.25) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 03:37:01] Ep:1 [200/391] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.669 (0.680)  Prec@1 70.31 (76.32) Prec@5 98.44 (98.46)]
# *Train* [2022-11-07 03:37:22] Ep:1 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.900 (0.676)  Prec@1 70.00 (76.45) Prec@5 100.00 (98.44)]
# Ep:1 ends : loss=0.68, accuracy@1=76.45%, accuracy@5=98.44%
# Found best op for target cell:9
# : Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|none~1|avg_pool_3x3~2|) with accuracy=73.24%
#
#
#  Searching with a cell #10
# *Train* [2022-11-07 03:37:43] Ep:0 [000/391] Time 0.33 (0.33) Data 0.24 (0.24) Base [Loss 1.087 (1.087)  Prec@1 57.81 (57.81) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 03:38:03] Ep:0 [200/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.637 (0.654)  Prec@1 81.25 (77.49) Prec@5 96.88 (98.80)]
# *Train* [2022-11-07 03:38:25] Ep:0 [390/391] Time 0.08 (0.11) Data 0.00 (0.00) Base [Loss 0.889 (0.654)  Prec@1 67.50 (77.60) Prec@5 100.00 (98.67)]
# Ep:0 ends : loss=0.65, accuracy@1=77.60%, accuracy@5=98.67%
# *Train* [2022-11-07 03:38:25] Ep:1 [000/391] Time 0.35 (0.35) Data 0.24 (0.24) Base [Loss 3.801 (3.801)  Prec@1 12.50 (12.50) Prec@5 57.81 (57.81)]
# *Train* [2022-11-07 03:38:48] Ep:1 [200/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.523 (0.707)  Prec@1 82.81 (76.08) Prec@5 100.00 (98.20)]
# *Train* [2022-11-07 03:39:04] Ep:1 [390/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.685 (0.688)  Prec@1 82.50 (76.44) Prec@5 95.00 (98.34)]
# Ep:1 ends : loss=0.69, accuracy@1=76.44%, accuracy@5=98.34%
# Found best op for target cell:10
# : Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|) with accuracy=74.41%
#
#
#  Searching with a cell #11
# *Train* [2022-11-07 03:39:23] Ep:0 [000/391] Time 0.49 (0.49) Data 0.23 (0.23) Base [Loss 3.472 (3.472)  Prec@1 12.50 (12.50) Prec@5 43.75 (43.75)]
# *Train* [2022-11-07 03:39:45] Ep:0 [200/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.789 (0.691)  Prec@1 70.31 (76.45) Prec@5 100.00 (98.36)]
# *Train* [2022-11-07 03:40:06] Ep:0 [390/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 0.979 (0.672)  Prec@1 67.50 (77.21) Prec@5 95.00 (98.52)]
# Ep:0 ends : loss=0.67, accuracy@1=77.21%, accuracy@5=98.52%
# *Train* [2022-11-07 03:40:07] Ep:1 [000/391] Time 0.33 (0.33) Data 0.24 (0.24) Base [Loss 0.588 (0.588)  Prec@1 81.25 (81.25) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 03:40:32] Ep:1 [200/391] Time 0.10 (0.13) Data 0.00 (0.00) Base [Loss 0.603 (0.649)  Prec@1 82.81 (77.54) Prec@5 95.31 (98.64)]
# *Train* [2022-11-07 03:40:53] Ep:1 [390/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.936 (0.639)  Prec@1 70.00 (77.88) Prec@5 97.50 (98.70)]
# Ep:1 ends : loss=0.64, accuracy@1=77.88%, accuracy@5=98.70%
# Found best op for target cell:11
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|) with accuracy=75.78%
#
#
#  Searching with a cell #12
# *Train* [2022-11-07 03:41:13] Ep:0 [000/391] Time 0.33 (0.33) Data 0.23 (0.23) Base [Loss 3.047 (3.047)  Prec@1 18.75 (18.75) Prec@5 68.75 (68.75)]
# *Train* [2022-11-07 03:41:34] Ep:0 [200/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.765 (0.694)  Prec@1 70.31 (76.67) Prec@5 100.00 (98.44)]
# *Train* [2022-11-07 03:41:53] Ep:0 [390/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.603 (0.677)  Prec@1 80.00 (77.06) Prec@5 100.00 (98.42)]
# Ep:0 ends : loss=0.68, accuracy@1=77.06%, accuracy@5=98.42%
# *Train* [2022-11-07 03:41:53] Ep:1 [000/391] Time 0.41 (0.41) Data 0.25 (0.25) Base [Loss 0.600 (0.600)  Prec@1 79.69 (79.69) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 03:42:14] Ep:1 [200/391] Time 0.16 (0.11) Data 0.00 (0.00) Base [Loss 0.831 (0.601)  Prec@1 67.19 (79.32) Prec@5 98.44 (98.89)]
# *Train* [2022-11-07 03:42:40] Ep:1 [390/391] Time 0.22 (0.12) Data 0.00 (0.00) Base [Loss 0.563 (0.599)  Prec@1 87.50 (79.52) Prec@5 97.50 (98.76)]
# Ep:1 ends : loss=0.60, accuracy@1=79.52%, accuracy@5=98.76%
# Found best op for target cell:12
# : Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|none~2|) with accuracy=77.54%
#
#
#  Searching with a cell #13
# *Train* [2022-11-07 03:43:00] Ep:0 [000/391] Time 0.38 (0.38) Data 0.23 (0.23) Base [Loss 2.657 (2.657)  Prec@1 6.25 (6.25) Prec@5 57.81 (57.81)]
# *Train* [2022-11-07 03:43:20] Ep:0 [200/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.307 (0.648)  Prec@1 93.75 (78.28) Prec@5 100.00 (98.21)]
# *Train* [2022-11-07 03:43:41] Ep:0 [390/391] Time 0.14 (0.11) Data 0.00 (0.00) Base [Loss 0.289 (0.633)  Prec@1 92.50 (78.64) Prec@5 100.00 (98.54)]
# Ep:0 ends : loss=0.63, accuracy@1=78.64%, accuracy@5=98.54%
# *Train* [2022-11-07 03:43:41] Ep:1 [000/391] Time 0.34 (0.34) Data 0.23 (0.23) Base [Loss 0.683 (0.683)  Prec@1 73.44 (73.44) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 03:43:59] Ep:1 [200/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.498 (0.577)  Prec@1 82.81 (80.32) Prec@5 98.44 (99.18)]
# *Train* [2022-11-07 03:44:16] Ep:1 [390/391] Time 0.15 (0.09) Data 0.00 (0.00) Base [Loss 0.473 (0.581)  Prec@1 82.50 (80.13) Prec@5 97.50 (99.08)]
# Ep:1 ends : loss=0.58, accuracy@1=80.13%, accuracy@5=99.08%
# Found best op for target cell:13
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|nor_conv_1x1~2|) with accuracy=79.72%
#
#
#  Searching with a cell #14
# *Train* [2022-11-07 03:44:37] Ep:0 [000/391] Time 0.34 (0.34) Data 0.25 (0.25) Base [Loss 2.504 (2.504)  Prec@1 18.75 (18.75) Prec@5 56.25 (56.25)]
# *Train* [2022-11-07 03:45:02] Ep:0 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.630 (0.634)  Prec@1 73.44 (78.02) Prec@5 100.00 (98.50)]
# *Train* [2022-11-07 03:45:20] Ep:0 [390/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.750 (0.619)  Prec@1 75.00 (78.54) Prec@5 97.50 (98.67)]
# Ep:0 ends : loss=0.62, accuracy@1=78.54%, accuracy@5=98.67%
# *Train* [2022-11-07 03:45:21] Ep:1 [000/391] Time 0.50 (0.50) Data 0.24 (0.24) Base [Loss 2.185 (2.185)  Prec@1 14.06 (14.06) Prec@5 70.31 (70.31)]
# *Train* [2022-11-07 03:45:43] Ep:1 [200/391] Time 0.14 (0.11) Data 0.00 (0.00) Base [Loss 0.462 (0.622)  Prec@1 84.38 (78.68) Prec@5 100.00 (98.74)]
# *Train* [2022-11-07 03:46:05] Ep:1 [390/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.641 (0.616)  Prec@1 77.50 (78.95) Prec@5 100.00 (98.70)]
# Ep:1 ends : loss=0.62, accuracy@1=78.95%, accuracy@5=98.70%
# Found best op for target cell:14
# : Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|none~1|avg_pool_3x3~2|) with accuracy=74.80%
#
#
#  Searching with a cell #0
# *Train* [2022-11-07 03:46:24] Ep:0 [000/391] Time 0.37 (0.37) Data 0.22 (0.22) Base [Loss 2.227 (2.227)  Prec@1 37.50 (37.50) Prec@5 84.38 (84.38)]
# *Train* [2022-11-07 03:46:45] Ep:0 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.534 (0.653)  Prec@1 82.81 (77.60) Prec@5 100.00 (98.55)]
# *Train* [2022-11-07 03:47:10] Ep:0 [390/391] Time 0.14 (0.12) Data 0.00 (0.00) Base [Loss 0.716 (0.624)  Prec@1 75.00 (78.59) Prec@5 100.00 (98.64)]
# Ep:0 ends : loss=0.62, accuracy@1=78.59%, accuracy@5=98.64%
# *Train* [2022-11-07 03:47:11] Ep:1 [000/391] Time 0.33 (0.33) Data 0.23 (0.23) Base [Loss 4.192 (4.192)  Prec@1 10.94 (10.94) Prec@5 59.38 (59.38)]
# *Train* [2022-11-07 03:47:33] Ep:1 [200/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.697 (0.938)  Prec@1 79.69 (68.32) Prec@5 96.88 (96.83)]
# *Train* [2022-11-07 03:47:51] Ep:1 [390/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.794 (0.854)  Prec@1 77.50 (70.86) Prec@5 100.00 (97.44)]
# Ep:1 ends : loss=0.85, accuracy@1=70.86%, accuracy@5=97.44%
# Found best op for target cell:0
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|none~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|) with accuracy=68.75%
#
#
#  Searching with a cell #1
# *Train* [2022-11-07 03:48:11] Ep:0 [000/391] Time 0.52 (0.52) Data 0.25 (0.25) Base [Loss 1.988 (1.988)  Prec@1 32.81 (32.81) Prec@5 90.62 (90.62)]
# *Train* [2022-11-07 03:48:36] Ep:0 [200/391] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.622 (0.740)  Prec@1 79.69 (74.65) Prec@5 96.88 (98.16)]
# *Train* [2022-11-07 03:48:52] Ep:0 [390/391] Time 0.08 (0.11) Data 0.00 (0.00) Base [Loss 0.959 (0.691)  Prec@1 55.00 (76.26) Prec@5 100.00 (98.36)]
# Ep:0 ends : loss=0.69, accuracy@1=76.26%, accuracy@5=98.36%
# *Train* [2022-11-07 03:48:53] Ep:1 [000/391] Time 0.39 (0.39) Data 0.25 (0.25) Base [Loss 2.991 (2.991)  Prec@1 18.75 (18.75) Prec@5 70.31 (70.31)]
# *Train* [2022-11-07 03:49:12] Ep:1 [200/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.802 (0.771)  Prec@1 70.31 (73.48) Prec@5 96.88 (97.76)]
# *Train* [2022-11-07 03:49:30] Ep:1 [390/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.414 (0.702)  Prec@1 82.50 (75.75) Prec@5 100.00 (98.24)]
# Ep:1 ends : loss=0.70, accuracy@1=75.75%, accuracy@5=98.24%
# Found best op for target cell:1
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|none~1|none~2|) with accuracy=73.24%
#
#
#  Searching with a cell #2
# *Train* [2022-11-07 03:49:50] Ep:0 [000/391] Time 0.40 (0.40) Data 0.25 (0.25) Base [Loss 2.990 (2.990)  Prec@1 14.06 (14.06) Prec@5 62.50 (62.50)]
# *Train* [2022-11-07 03:50:16] Ep:0 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.517 (0.763)  Prec@1 84.38 (73.71) Prec@5 96.88 (97.65)]
# *Train* [2022-11-07 03:50:42] Ep:0 [390/391] Time 0.21 (0.14) Data 0.00 (0.00) Base [Loss 0.621 (0.687)  Prec@1 82.50 (76.11) Prec@5 97.50 (98.16)]
# Ep:0 ends : loss=0.69, accuracy@1=76.11%, accuracy@5=98.16%
# *Train* [2022-11-07 03:50:43] Ep:1 [000/391] Time 0.34 (0.34) Data 0.22 (0.22) Base [Loss 2.993 (2.993)  Prec@1 28.12 (28.12) Prec@5 67.19 (67.19)]
# *Train* [2022-11-07 03:51:02] Ep:1 [200/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.680 (0.734)  Prec@1 78.12 (74.91) Prec@5 100.00 (98.06)]
# *Train* [2022-11-07 03:51:28] Ep:1 [390/391] Time 0.21 (0.12) Data 0.00 (0.00) Base [Loss 0.724 (0.689)  Prec@1 72.50 (76.21) Prec@5 100.00 (98.34)]
# Ep:1 ends : loss=0.69, accuracy@1=76.21%, accuracy@5=98.34%
# Found best op for target cell:2
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|skip_connect~1|nor_conv_1x1~2|) with accuracy=66.27%
#
#
#  Searching with a cell #3
# *Train* [2022-11-07 03:51:50] Ep:0 [000/391] Time 0.36 (0.36) Data 0.27 (0.27) Base [Loss 3.672 (3.672)  Prec@1 9.38 (9.38) Prec@5 60.94 (60.94)]
# *Train* [2022-11-07 03:52:09] Ep:0 [200/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.683 (0.664)  Prec@1 71.88 (77.47) Prec@5 98.44 (98.30)]
# *Train* [2022-11-07 03:52:29] Ep:0 [390/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.548 (0.636)  Prec@1 80.00 (78.45) Prec@5 100.00 (98.51)]
# Ep:0 ends : loss=0.64, accuracy@1=78.45%, accuracy@5=98.51%
# *Train* [2022-11-07 03:52:30] Ep:1 [000/391] Time 0.38 (0.38) Data 0.28 (0.28) Base [Loss 1.067 (1.067)  Prec@1 65.62 (65.62) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:52:51] Ep:1 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.618 (0.622)  Prec@1 79.69 (78.71) Prec@5 98.44 (98.73)]
# *Train* [2022-11-07 03:53:16] Ep:1 [390/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.618 (0.599)  Prec@1 70.00 (79.51) Prec@5 100.00 (98.78)]
# Ep:1 ends : loss=0.60, accuracy@1=79.51%, accuracy@5=98.78%
# Found best op for target cell:3
# : Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|none~1|+|nor_conv_1x1~0|skip_connect~1|none~2|) with accuracy=75.20%
#
#
#  Searching with a cell #4
# *Train* [2022-11-07 03:53:34] Ep:0 [000/391] Time 0.31 (0.31) Data 0.23 (0.23) Base [Loss 3.633 (3.633)  Prec@1 14.06 (14.06) Prec@5 64.06 (64.06)]
# *Train* [2022-11-07 03:53:53] Ep:0 [200/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.781 (0.709)  Prec@1 75.00 (75.94) Prec@5 98.44 (97.98)]
# *Train* [2022-11-07 03:54:13] Ep:0 [390/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 1.033 (0.656)  Prec@1 70.00 (77.59) Prec@5 95.00 (98.36)]
# Ep:0 ends : loss=0.66, accuracy@1=77.59%, accuracy@5=98.36%
# *Train* [2022-11-07 03:54:13] Ep:1 [000/391] Time 0.37 (0.37) Data 0.27 (0.27) Base [Loss 0.836 (0.836)  Prec@1 73.44 (73.44) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:54:40] Ep:1 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.528 (0.579)  Prec@1 76.56 (79.73) Prec@5 98.44 (99.07)]
# *Train* [2022-11-07 03:55:00] Ep:1 [390/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.899 (0.577)  Prec@1 62.50 (79.86) Prec@5 100.00 (98.97)]
# Ep:1 ends : loss=0.58, accuracy@1=79.86%, accuracy@5=98.97%
# Found best op for target cell:4
# : Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|skip_connect~1|nor_conv_3x3~2|) with accuracy=68.95%
#
#
#  Searching with a cell #5
# *Train* [2022-11-07 03:55:18] Ep:0 [000/391] Time 0.35 (0.35) Data 0.26 (0.26) Base [Loss 3.776 (3.776)  Prec@1 10.94 (10.94) Prec@5 54.69 (54.69)]
# *Train* [2022-11-07 03:55:42] Ep:0 [200/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.654 (0.806)  Prec@1 76.56 (72.85) Prec@5 100.00 (97.70)]
# *Train* [2022-11-07 03:56:08] Ep:0 [390/391] Time 0.20 (0.13) Data 0.00 (0.00) Base [Loss 0.808 (0.720)  Prec@1 70.00 (75.74) Prec@5 100.00 (98.22)]
# Ep:0 ends : loss=0.72, accuracy@1=75.74%, accuracy@5=98.22%
# *Train* [2022-11-07 03:56:08] Ep:1 [000/391] Time 0.36 (0.36) Data 0.27 (0.27) Base [Loss 1.300 (1.300)  Prec@1 48.44 (48.44) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 03:56:28] Ep:1 [200/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.670 (0.732)  Prec@1 79.69 (74.62) Prec@5 98.44 (98.33)]
# *Train* [2022-11-07 03:56:49] Ep:1 [390/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 1.021 (0.697)  Prec@1 65.00 (75.38) Prec@5 100.00 (98.56)]
# Ep:1 ends : loss=0.70, accuracy@1=75.38%, accuracy@5=98.56%
# Found best op for target cell:5
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_1x1~1|nor_conv_3x3~2|) with accuracy=72.41%
#
#
#  Searching with a cell #6
# *Train* [2022-11-07 03:57:09] Ep:0 [000/391] Time 0.34 (0.34) Data 0.26 (0.26) Base [Loss 3.380 (3.380)  Prec@1 17.19 (17.19) Prec@5 70.31 (70.31)]
# *Train* [2022-11-07 03:57:29] Ep:0 [200/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.589 (0.692)  Prec@1 82.81 (76.29) Prec@5 98.44 (98.41)]
# *Train* [2022-11-07 03:57:48] Ep:0 [390/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 0.688 (0.663)  Prec@1 72.50 (77.28) Prec@5 100.00 (98.58)]
# Ep:0 ends : loss=0.66, accuracy@1=77.28%, accuracy@5=98.58%
# *Train* [2022-11-07 03:57:48] Ep:1 [000/391] Time 0.43 (0.43) Data 0.28 (0.28) Base [Loss 0.928 (0.928)  Prec@1 67.19 (67.19) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 03:58:10] Ep:1 [200/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 0.491 (0.614)  Prec@1 81.25 (78.69) Prec@5 100.00 (98.81)]
# *Train* [2022-11-07 03:58:33] Ep:1 [390/391] Time 0.10 (0.12) Data 0.00 (0.00) Base [Loss 0.570 (0.601)  Prec@1 82.50 (79.14) Prec@5 100.00 (98.87)]
# Ep:1 ends : loss=0.60, accuracy@1=79.14%, accuracy@5=98.87%
# Found best op for target cell:6
# : Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|skip_connect~0|none~1|avg_pool_3x3~2|) with accuracy=73.44%
#
#
#  Searching with a cell #7
# *Train* [2022-11-07 03:58:52] Ep:0 [000/391] Time 0.36 (0.36) Data 0.26 (0.26) Base [Loss 3.291 (3.291)  Prec@1 15.62 (15.62) Prec@5 65.62 (65.62)]
# *Train* [2022-11-07 03:59:14] Ep:0 [200/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.619 (0.682)  Prec@1 75.00 (76.34) Prec@5 100.00 (98.60)]
# *Train* [2022-11-07 03:59:36] Ep:0 [390/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.573 (0.644)  Prec@1 87.50 (77.76) Prec@5 97.50 (98.73)]
# Ep:0 ends : loss=0.64, accuracy@1=77.76%, accuracy@5=98.73%
# *Train* [2022-11-07 03:59:37] Ep:1 [000/391] Time 0.41 (0.41) Data 0.22 (0.22) Base [Loss 0.605 (0.605)  Prec@1 81.25 (81.25) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:59:58] Ep:1 [200/391] Time 0.08 (0.11) Data 0.00 (0.00) Base [Loss 0.612 (0.582)  Prec@1 84.38 (79.83) Prec@5 100.00 (98.87)]
# *Train* [2022-11-07 04:00:15] Ep:1 [390/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.644 (0.580)  Prec@1 82.50 (79.88) Prec@5 100.00 (98.93)]
# Ep:1 ends : loss=0.58, accuracy@1=79.88%, accuracy@5=98.93%
# Found best op for target cell:7
# : Structure(4 nodes with |skip_connect~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|) with accuracy=75.00%
#
#
#  Searching with a cell #8
# *Train* [2022-11-07 04:00:35] Ep:0 [000/391] Time 0.33 (0.33) Data 0.24 (0.24) Base [Loss 1.562 (1.562)  Prec@1 45.31 (45.31) Prec@5 89.06 (89.06)]
# *Train* [2022-11-07 04:00:58] Ep:0 [200/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 1.078 (0.960)  Prec@1 53.12 (66.40) Prec@5 96.88 (97.13)]
# *Train* [2022-11-07 04:01:21] Ep:0 [390/391] Time 0.21 (0.12) Data 0.00 (0.00) Base [Loss 0.646 (0.877)  Prec@1 75.00 (69.33) Prec@5 100.00 (97.57)]
# Ep:0 ends : loss=0.88, accuracy@1=69.33%, accuracy@5=97.57%
# *Train* [2022-11-07 04:01:21] Ep:1 [000/391] Time 0.32 (0.32) Data 0.23 (0.23) Base [Loss 3.052 (3.052)  Prec@1 25.00 (25.00) Prec@5 73.44 (73.44)]
# *Train* [2022-11-07 04:01:38] Ep:1 [200/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.716 (0.748)  Prec@1 73.44 (74.78) Prec@5 98.44 (98.14)]
# *Train* [2022-11-07 04:02:01] Ep:1 [390/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 0.465 (0.683)  Prec@1 85.00 (76.73) Prec@5 100.00 (98.44)]
# Ep:1 ends : loss=0.68, accuracy@1=76.73%, accuracy@5=98.44%
# Found best op for target cell:8
# : Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|none~1|none~2|) with accuracy=69.92%
#
#
#  Searching with a cell #9
# *Train* [2022-11-07 04:02:20] Ep:0 [000/391] Time 0.36 (0.36) Data 0.27 (0.27) Base [Loss 1.053 (1.053)  Prec@1 65.62 (65.62) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 04:02:48] Ep:0 [200/391] Time 0.12 (0.14) Data 0.00 (0.00) Base [Loss 0.616 (0.594)  Prec@1 81.25 (79.45) Prec@5 98.44 (98.94)]
# *Train* [2022-11-07 04:03:11] Ep:0 [390/391] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.528 (0.590)  Prec@1 80.00 (79.48) Prec@5 100.00 (98.91)]
# Ep:0 ends : loss=0.59, accuracy@1=79.48%, accuracy@5=98.91%
# *Train* [2022-11-07 04:03:12] Ep:1 [000/391] Time 0.36 (0.36) Data 0.26 (0.26) Base [Loss 0.987 (0.987)  Prec@1 65.62 (65.62) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 04:03:29] Ep:1 [200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.487 (0.593)  Prec@1 81.25 (79.52) Prec@5 100.00 (98.90)]
# ...
# *Train* [2022-11-07 04:46:54] Ep:0 [390/391] Time 0.21 (0.12) Data 0.00 (0.00) Base [Loss 0.538 (0.559)  Prec@1 77.50 (81.12) Prec@5 100.00 (98.80)]
# Ep:0 ends : loss=0.56, accuracy@1=81.12%, accuracy@5=98.80%
# *Train* [2022-11-07 04:46:54] Ep:1 [000/391] Time 0.34 (0.34) Data 0.24 (0.24) Base [Loss 1.716 (1.716)  Prec@1 43.75 (43.75) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 04:47:22] Ep:1 [200/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.548 (0.532)  Prec@1 81.25 (81.45) Prec@5 100.00 (99.13)]
# *Train* [2022-11-07 04:47:44] Ep:1 [390/391] Time 0.07 (0.13) Data 0.00 (0.00) Base [Loss 0.323 (0.520)  Prec@1 85.00 (81.88) Prec@5 100.00 (99.15)]
# Ep:1 ends : loss=0.52, accuracy@1=81.88%, accuracy@5=99.15%
# Found best op for target cell:3
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|) with accuracy=78.71%
#
#
#  Searching with a cell #4
# *Train* [2022-11-07 04:48:06] Ep:0 [000/391] Time 0.36 (0.36) Data 0.27 (0.27) Base [Loss 1.842 (1.842)  Prec@1 48.44 (48.44) Prec@5 84.38 (84.38)]
# *Train* [2022-11-07 04:48:24] Ep:0 [200/391] Time 0.09 (0.09) Data 0.00 (0.00) Base [Loss 0.578 (0.650)  Prec@1 79.69 (77.57) Prec@5 98.44 (98.59)]
# *Train* [2022-11-07 04:48:44] Ep:0 [390/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 1.046 (0.603)  Prec@1 65.00 (79.17) Prec@5 97.50 (98.78)]
# Ep:0 ends : loss=0.60, accuracy@1=79.17%, accuracy@5=98.78%
# *Train* [2022-11-07 04:48:45] Ep:1 [000/391] Time 0.35 (0.35) Data 0.23 (0.23) Base [Loss 1.254 (1.254)  Prec@1 62.50 (62.50) Prec@5 92.19 (92.19)]
# *Train* [2022-11-07 04:49:07] Ep:1 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.473 (0.548)  Prec@1 81.25 (81.16) Prec@5 100.00 (99.11)]
# *Train* [2022-11-07 04:49:25] Ep:1 [390/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.724 (0.535)  Prec@1 77.50 (81.72) Prec@5 95.00 (99.11)]
# Ep:1 ends : loss=0.54, accuracy@1=81.72%, accuracy@5=99.11%
# Found best op for target cell:4
# : Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|) with accuracy=74.22%
#
#
#  Searching with a cell #5
# *Train* [2022-11-07 04:49:45] Ep:0 [000/391] Time 0.32 (0.32) Data 0.23 (0.23) Base [Loss 1.610 (1.610)  Prec@1 50.00 (50.00) Prec@5 90.62 (90.62)]
# *Train* [2022-11-07 04:50:11] Ep:0 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.479 (0.627)  Prec@1 87.50 (78.37) Prec@5 98.44 (98.89)]
# *Train* [2022-11-07 04:50:32] Ep:0 [390/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.408 (0.591)  Prec@1 85.00 (79.58) Prec@5 100.00 (98.96)]
# Ep:0 ends : loss=0.59, accuracy@1=79.58%, accuracy@5=98.96%
# *Train* [2022-11-07 04:50:32] Ep:1 [000/391] Time 0.32 (0.32) Data 0.23 (0.23) Base [Loss 0.504 (0.504)  Prec@1 81.25 (81.25) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 04:51:01] Ep:1 [200/391] Time 0.12 (0.14) Data 0.00 (0.00) Base [Loss 0.497 (0.550)  Prec@1 87.50 (80.83) Prec@5 98.44 (99.07)]
# *Train* [2022-11-07 04:51:25] Ep:1 [390/391] Time 0.14 (0.14) Data 0.00 (0.00) Base [Loss 0.498 (0.541)  Prec@1 80.00 (81.17) Prec@5 97.50 (99.10)]
# Ep:1 ends : loss=0.54, accuracy@1=81.17%, accuracy@5=99.10%
# Found best op for target cell:5
# : Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|none~2|) with accuracy=78.71%
#
#
#  Searching with a cell #6
# *Train* [2022-11-07 04:51:48] Ep:0 [000/391] Time 0.40 (0.40) Data 0.26 (0.26) Base [Loss 0.785 (0.785)  Prec@1 71.88 (71.88) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 04:52:05] Ep:0 [200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.712 (0.548)  Prec@1 76.56 (80.88) Prec@5 98.44 (99.02)]
# *Train* [2022-11-07 04:52:23] Ep:0 [390/391] Time 0.16 (0.09) Data 0.00 (0.00) Base [Loss 0.714 (0.539)  Prec@1 77.50 (81.21) Prec@5 97.50 (99.08)]
# Ep:0 ends : loss=0.54, accuracy@1=81.21%, accuracy@5=99.08%
# *Train* [2022-11-07 04:52:24] Ep:1 [000/391] Time 0.31 (0.31) Data 0.22 (0.22) Base [Loss 0.895 (0.895)  Prec@1 68.75 (68.75) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 04:52:40] Ep:1 [200/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.306 (0.564)  Prec@1 90.62 (80.36) Prec@5 100.00 (98.97)]
# *Train* [2022-11-07 04:53:03] Ep:1 [390/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.646 (0.543)  Prec@1 77.50 (81.07) Prec@5 97.50 (99.07)]
# Ep:1 ends : loss=0.54, accuracy@1=81.07%, accuracy@5=99.07%
# Found best op for target cell:6
# : Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|skip_connect~2|) with accuracy=77.34%
#
#
#  Searching with a cell #7
# *Train* [2022-11-07 04:53:25] Ep:0 [000/391] Time 0.32 (0.32) Data 0.22 (0.22) Base [Loss 3.906 (3.906)  Prec@1 15.62 (15.62) Prec@5 57.81 (57.81)]
# *Train* [2022-11-07 04:53:43] Ep:0 [200/391] Time 0.14 (0.09) Data 0.00 (0.00) Base [Loss 0.572 (0.669)  Prec@1 78.12 (77.15) Prec@5 100.00 (98.44)]
# *Train* [2022-11-07 04:54:03] Ep:0 [390/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.467 (0.620)  Prec@1 80.00 (78.60) Prec@5 100.00 (98.68)]
# Ep:0 ends : loss=0.62, accuracy@1=78.60%, accuracy@5=98.68%
# *Train* [2022-11-07 04:54:03] Ep:1 [000/391] Time 0.35 (0.35) Data 0.26 (0.26) Base [Loss 0.556 (0.556)  Prec@1 82.81 (82.81) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 04:54:27] Ep:1 [200/391] Time 0.22 (0.12) Data 0.00 (0.00) Base [Loss 0.652 (0.514)  Prec@1 71.88 (82.11) Prec@5 98.44 (99.18)]
# *Train* [2022-11-07 04:54:53] Ep:1 [390/391] Time 0.12 (0.13) Data 0.00 (0.00) Base [Loss 0.887 (0.511)  Prec@1 67.50 (82.28) Prec@5 100.00 (99.17)]
# Ep:1 ends : loss=0.51, accuracy@1=82.28%, accuracy@5=99.17%
# Found best op for target cell:7
# : Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|) with accuracy=77.15%
#
#
#  Searching with a cell #8
# *Train* [2022-11-07 04:55:14] Ep:0 [000/391] Time 0.39 (0.39) Data 0.24 (0.24) Base [Loss 4.027 (4.027)  Prec@1 10.94 (10.94) Prec@5 45.31 (45.31)]
# *Train* [2022-11-07 04:55:33] Ep:0 [200/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.855 (0.761)  Prec@1 70.31 (73.98) Prec@5 98.44 (97.94)]
# *Train* [2022-11-07 04:55:56] Ep:0 [390/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.394 (0.685)  Prec@1 87.50 (76.27) Prec@5 100.00 (98.42)]
# Ep:0 ends : loss=0.69, accuracy@1=76.27%, accuracy@5=98.42%
# *Train* [2022-11-07 04:55:57] Ep:1 [000/391] Time 0.38 (0.38) Data 0.22 (0.22) Base [Loss 1.392 (1.392)  Prec@1 46.88 (46.88) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 04:56:17] Ep:1 [200/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.743 (0.620)  Prec@1 76.56 (78.46) Prec@5 96.88 (98.85)]
# *Train* [2022-11-07 04:56:45] Ep:1 [390/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.664 (0.601)  Prec@1 80.00 (79.33) Prec@5 97.50 (98.87)]
# Ep:1 ends : loss=0.60, accuracy@1=79.33%, accuracy@5=98.87%
# Found best op for target cell:8
# : Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|) with accuracy=74.61%
#
#
#  Searching with a cell #9
# *Train* [2022-11-07 04:57:05] Ep:0 [000/391] Time 0.34 (0.34) Data 0.23 (0.23) Base [Loss 0.894 (0.894)  Prec@1 65.62 (65.62) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 04:57:26] Ep:0 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.675 (0.570)  Prec@1 71.88 (79.84) Prec@5 100.00 (99.23)]
# *Train* [2022-11-07 04:57:46] Ep:0 [390/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.648 (0.560)  Prec@1 77.50 (80.36) Prec@5 100.00 (99.15)]
# Ep:0 ends : loss=0.56, accuracy@1=80.36%, accuracy@5=99.15%
# *Train* [2022-11-07 04:57:46] Ep:1 [000/391] Time 0.39 (0.39) Data 0.24 (0.24) Base [Loss 0.545 (0.545)  Prec@1 81.25 (81.25) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 04:58:09] Ep:1 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.454 (0.550)  Prec@1 84.38 (81.03) Prec@5 100.00 (99.14)]
# *Train* [2022-11-07 04:58:28] Ep:1 [390/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.438 (0.536)  Prec@1 87.50 (81.66) Prec@5 100.00 (99.12)]
# Ep:1 ends : loss=0.54, accuracy@1=81.66%, accuracy@5=99.12%
# Found best op for target cell:9
# : Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|) with accuracy=77.15%
#
#
#  Searching with a cell #10
# *Train* [2022-11-07 04:58:47] Ep:0 [000/391] Time 0.40 (0.40) Data 0.29 (0.29) Base [Loss 1.353 (1.353)  Prec@1 60.94 (60.94) Prec@5 92.19 (92.19)]
# *Train* [2022-11-07 04:59:09] Ep:0 [200/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.557 (0.573)  Prec@1 76.56 (80.64) Prec@5 100.00 (98.94)]
# *Train* [2022-11-07 04:59:29] Ep:0 [390/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.812 (0.562)  Prec@1 65.00 (80.83) Prec@5 97.50 (98.97)]
# Ep:0 ends : loss=0.56, accuracy@1=80.83%, accuracy@5=98.97%
# *Train* [2022-11-07 04:59:30] Ep:1 [000/391] Time 0.41 (0.41) Data 0.26 (0.26) Base [Loss 0.734 (0.734)  Prec@1 75.00 (75.00) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 04:59:55] Ep:1 [200/391] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.736 (0.588)  Prec@1 78.12 (79.59) Prec@5 98.44 (98.99)]
# *Train* [2022-11-07 05:00:19] Ep:1 [390/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.419 (0.574)  Prec@1 90.00 (80.07) Prec@5 97.50 (98.99)]
# Ep:1 ends : loss=0.57, accuracy@1=80.07%, accuracy@5=98.99%
# Found best op for target cell:10
# : Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|) with accuracy=76.76%
#
#
#  Searching with a cell #11
# *Train* [2022-11-07 05:00:41] Ep:0 [000/391] Time 0.53 (0.53) Data 0.26 (0.26) Base [Loss 1.059 (1.059)  Prec@1 59.38 (59.38) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 05:01:11] Ep:0 [200/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 0.472 (0.606)  Prec@1 84.38 (79.03) Prec@5 100.00 (98.76)]
# *Train* [2022-11-07 05:01:38] Ep:0 [390/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 0.721 (0.588)  Prec@1 80.00 (79.71) Prec@5 97.50 (98.93)]
# Ep:0 ends : loss=0.59, accuracy@1=79.71%, accuracy@5=98.93%
# *Train* [2022-11-07 05:01:39] Ep:1 [000/391] Time 0.38 (0.38) Data 0.28 (0.28) Base [Loss 0.605 (0.605)  Prec@1 76.56 (76.56) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 05:02:07] Ep:1 [200/391] Time 0.12 (0.14) Data 0.00 (0.00) Base [Loss 0.621 (0.536)  Prec@1 75.00 (81.77) Prec@5 100.00 (99.07)]
# *Train* [2022-11-07 05:02:27] Ep:1 [390/391] Time 0.22 (0.13) Data 0.00 (0.00) Base [Loss 0.616 (0.533)  Prec@1 72.50 (81.65) Prec@5 97.50 (99.07)]
# Ep:1 ends : loss=0.53, accuracy@1=81.65%, accuracy@5=99.07%
# Found best op for target cell:11
# : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|) with accuracy=76.95%
#
#
#  Searching with a cell #12
# *Train* [2022-11-07 05:02:47] Ep:0 [000/391] Time 0.34 (0.34) Data 0.23 (0.23) Base [Loss 0.512 (0.512)  Prec@1 81.25 (81.25) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 05:03:06] Ep:0 [200/391] Time 0.12 (0.09) Data 0.00 (0.00) Base [Loss 0.510 (0.534)  Prec@1 79.69 (81.53) Prec@5 98.44 (99.10)]
# *Train* [2022-11-07 05:03:31] Ep:0 [390/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.509 (0.531)  Prec@1 80.00 (81.63) Prec@5 100.00 (99.09)]
# Ep:0 ends : loss=0.53, accuracy@1=81.63%, accuracy@5=99.09%
# *Train* [2022-11-07 05:03:31] Ep:1 [000/391] Time 0.38 (0.38) Data 0.21 (0.21) Base [Loss 0.800 (0.800)  Prec@1 73.44 (73.44) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 05:03:56] Ep:1 [200/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.779 (0.566)  Prec@1 71.88 (80.61) Prec@5 100.00 (98.92)]
# *Train* [2022-11-07 05:04:17] Ep:1 [390/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.573 (0.548)  Prec@1 85.00 (81.05) Prec@5 97.50 (99.02)]
# Ep:1 ends : loss=0.55, accuracy@1=81.05%, accuracy@5=99.02%
# Found best op for target cell:12
# : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|) with accuracy=80.66%
#
#
#  Searching with a cell #13
# *Train* [2022-11-07 05:04:37] Ep:0 [000/391] Time 0.42 (0.42) Data 0.26 (0.26) Base [Loss 0.474 (0.474)  Prec@1 81.25 (81.25) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 05:05:04] Ep:0 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.672 (0.533)  Prec@1 78.12 (81.55) Prec@5 96.88 (99.16)]
# *Train* [2022-11-07 05:05:25] Ep:0 [390/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.519 (0.523)  Prec@1 82.50 (81.80) Prec@5 100.00 (99.18)]
# Ep:0 ends : loss=0.52, accuracy@1=81.80%, accuracy@5=99.18%
# *Train* [2022-11-07 05:05:26] Ep:1 [000/391] Time 0.41 (0.41) Data 0.25 (0.25) Base [Loss 0.675 (0.675)  Prec@1 79.69 (79.69) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 05:05:48] Ep:1 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.428 (0.504)  Prec@1 84.38 (82.73) Prec@5 100.00 (99.35)]
# *Train* [2022-11-07 05:06:14] Ep:1 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.614 (0.507)  Prec@1 77.50 (82.52) Prec@5 100.00 (99.27)]
# Ep:1 ends : loss=0.51, accuracy@1=82.52%, accuracy@5=99.27%
# Found best op for target cell:13
# : Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|none~0|skip_connect~1|skip_connect~2|) with accuracy=78.52%
#
#
#  Searching with a cell #14
# *Train* [2022-11-07 05:06:35] Ep:0 [000/391] Time 0.31 (0.31) Data 0.22 (0.22) Base [Loss 0.707 (0.707)  Prec@1 79.69 (79.69) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 05:06:59] Ep:0 [200/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.463 (0.548)  Prec@1 81.25 (81.38) Prec@5 98.44 (98.94)]
# *Train* [2022-11-07 05:07:18] Ep:0 [390/391] Time 0.17 (0.11) Data 0.00 (0.00) Base [Loss 0.469 (0.550)  Prec@1 87.50 (81.31) Prec@5 97.50 (99.05)]
# Ep:0 ends : loss=0.55, accuracy@1=81.31%, accuracy@5=99.05%
# *Train* [2022-11-07 05:07:19] Ep:1 [000/391] Time 0.36 (0.36) Data 0.27 (0.27) Base [Loss 0.781 (0.781)  Prec@1 76.56 (76.56) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 05:07:45] Ep:1 [200/391] Time 0.07 (0.13) Data 0.00 (0.00) Base [Loss 0.549 (0.492)  Prec@1 79.69 (83.11) Prec@5 98.44 (99.07)]
# *Train* [2022-11-07 05:08:08] Ep:1 [390/391] Time 0.12 (0.13) Data 0.00 (0.00) Base [Loss 0.575 (0.494)  Prec@1 75.00 (82.88) Prec@5 100.00 (99.20)]
# Ep:1 ends : loss=0.49, accuracy@1=82.88%, accuracy@5=99.20%
# Found best op for target cell:14
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|) with accuracy=79.10%
# Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|none~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|none~0|skip_connect~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)

# %%
# import matplotlib.pyplot as plt

# plt.scatter(rank_confidences,rank_accs)
# plt.show()

# plt.scatter(rank_sensitivities,rank_accs)
# plt.show()

# plt.scatter(rank_robustnesses,rank_accs)
# plt.show()

# plt.scatter(rank_step_sims,rank_accs)
# plt.show()

# %% [markdown]
# # Train a found model

# %%
trained_output = torch.load(os.path.join(xargs.save_dir, "output.pth"))
print(args)
args.save_dir = os.path.join(xargs.save_dir, "train")
print(args)
# Out:
# Namespace(arch_nas_dataset=None, channel=16, config_path='./MY.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=200, rand_seed=65819, save_dir='./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)
# Namespace(arch_nas_dataset=None, channel=16, config_path='./MY.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=200, rand_seed=65819, save_dir='./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
print(config)
# Out:
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=50, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))

# %%
logger = prepare_logger(args)

# cifar_train_config_path = "./MY.config"
cifar_train_config_path = "../configs/nas-benchmark/CIFAR.config"
###
train_data, test_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(cifar_train_config_path, {"class_num": class_num, "xshape": xshape}, logger)

train_loader = torch.utils.data.DataLoader(
            train_data,
            batch_size=config.batch_size,
            shuffle=True,
            num_workers=xargs.workers,
            pin_memory=True,)

test_loader = torch.utils.data.DataLoader(
            test_data,
            batch_size=config.batch_size,
            shuffle=True,
            num_workers=xargs.workers,
            pin_memory=True,)

# search_loader, _, valid_loader = get_nas_search_loaders(train_data,
#                                                         valid_data,
#                                                         xargs.dataset,
#                                                         "../configs/nas-benchmark/",
#                                                         (config.batch_size, config.batch_size),
#                                                         xargs.workers)
logger.log("||||||| {:10s} ||||||| Train-Loader-Num={:}, Test-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(train_loader), len(test_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": True, # true for eval
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

### load
# trained_output = torch.load(os.path.join(xargs.save_dir, "output.pth"))
# search_model.load_state_dict(trained_output['model'], strict=False)
best_archs = trained_output['best_archs']
i=0
for m in search_model.modules():
    if isinstance(m, SearchCell):
        m.arch_cache = best_archs[i]
        i += 1
for m in network.modules():
    if isinstance(m, SearchCell):
        print(m.arch_cache)
###

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))

network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)

start_epoch, valid_accuracies, genotypes = 0, {"best": -1}, {}
# Out:
# Main Function with logger : Logger(dir=cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : None
# channel          : 16
# config_path      : ./MY.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 200
# rand_seed        : 65819
# save_dir         : ./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None
# Files already downloaded and verified
# Files already downloaded and verified
# ../configs/nas-benchmark/CIFAR.config
# Configure(scheduler='cos', eta_min=0.0, epochs=200, warmup=0, optim='SGD', LR=0.1, decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=256, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Train-Loader-Num=196, Test-Loader-Num=40, batch size=256
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', eta_min=0.0, epochs=200, warmup=0, optim='SGD', LR=0.1, decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=256, class_num=10, xshape=(1, 3, 32, 32))
# Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|none~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|none~0|skip_connect~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.1
#     lr: 0.1
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=200, current::epoch=0, iter=0.00, type=cosine, T-max=200, eta-min=0.0)
# criterion   : CrossEntropyLoss()

# %%
# def search_func_one_arch(xloader, network, criterion, scheduler, w_optimizer, epoch_str, print_freq, logger):
#     data_time, batch_time = AverageMeter(), AverageMeter()
#     base_losses, base_top1, base_top5 = AverageMeter(), AverageMeter(), AverageMeter()
#     network.train()
#     end = time.time()
#     for step, (base_inputs, base_targets, arch_inputs, arch_targets) in enumerate(
#         xloader
#     ):
#         scheduler.update(None, 1.0 * step / len(xloader))
#         base_targets = base_targets.cuda(non_blocking=True)
#         arch_targets = arch_targets.cuda(non_blocking=True)
#         # measure data loading time
#         data_time.update(time.time() - end)

#         w_optimizer.zero_grad()
#         _, logits = network(base_inputs)
#         base_loss = criterion(logits, base_targets)
#         base_loss.backward()
#         nn.utils.clip_grad_norm_(network.parameters(), 5)
#         w_optimizer.step()
#         # record
#         base_prec1, base_prec5 = obtain_accuracy(
#             logits.data, base_targets.data, topk=(1, 5)
#         )
#         base_losses.update(base_loss.item(), base_inputs.size(0))
#         base_top1.update(base_prec1.item(), base_inputs.size(0))
#         base_top5.update(base_prec5.item(), base_inputs.size(0))

#         # measure elapsed time
#         batch_time.update(time.time() - end)
#         end = time.time()

#         if step % print_freq == 0 or step + 1 == len(xloader):
#             Sstr = (
#                 "*SEARCH* "
#                 + time_string()
#                 + " [{:}][{:03d}/{:03d}]".format(epoch_str, step, len(xloader))
#             )
#             Tstr = "Time {batch_time.val:.2f} ({batch_time.avg:.2f}) Data {data_time.val:.2f} ({data_time.avg:.2f})".format(
#                 batch_time=batch_time, data_time=data_time
#             )
#             Wstr = "Base [Loss {loss.val:.3f} ({loss.avg:.3f})  Prec@1 {top1.val:.2f} ({top1.avg:.2f}) Prec@5 {top5.val:.2f} ({top5.avg:.2f})]".format(
#                 loss=base_losses, top1=base_top1, top5=base_top5
#             )
#             logger.log(Sstr + " " + Tstr + " " + Wstr)
#     return base_losses.avg, base_top1.avg, base_top5.avg

def train_func_one_arch(xloader, network, criterion, scheduler, w_optimizer, epoch_str, print_freq, logger):
    data_time, batch_time = AverageMeter(), AverageMeter()
    base_losses, base_top1, base_top5 = AverageMeter(), AverageMeter(), AverageMeter()
    network.train()
    end = time.time()
    for step, (base_inputs, base_targets) in enumerate(
        xloader
    ):
        scheduler.update(None, 1.0 * step / len(xloader))
        base_targets = base_targets.cuda(non_blocking=True)
        # measure data loading time
        data_time.update(time.time() - end)

        w_optimizer.zero_grad()
        _, logits = network(base_inputs)
        base_loss = criterion(logits, base_targets)
        base_loss.backward()
        nn.utils.clip_grad_norm_(network.parameters(), 5)
        w_optimizer.step()
        # record
        base_prec1, base_prec5 = obtain_accuracy(
            logits.data, base_targets.data, topk=(1, 5)
        )
        base_losses.update(base_loss.item(), base_inputs.size(0))
        base_top1.update(base_prec1.item(), base_inputs.size(0))
        base_top5.update(base_prec5.item(), base_inputs.size(0))

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if step % print_freq == 0 or step + 1 == len(xloader):
            Sstr = (
                "*SEARCH* "
                + time_string()
                + " [{:}][{:03d}/{:03d}]".format(epoch_str, step, len(xloader))
            )
            Tstr = "Time {batch_time.val:.2f} ({batch_time.avg:.2f}) Data {data_time.val:.2f} ({data_time.avg:.2f})".format(
                batch_time=batch_time, data_time=data_time
            )
            Wstr = "Base [Loss {loss.val:.3f} ({loss.avg:.3f})  Prec@1 {top1.val:.2f} ({top1.avg:.2f}) Prec@5 {top5.val:.2f} ({top5.avg:.2f})]".format(
                loss=base_losses, top1=base_top1, top5=base_top5
            )
            logger.log(Sstr + " " + Tstr + " " + Wstr)
    return base_losses.avg, base_top1.avg, base_top5.avg

def valid_func_one_arch(xloader, network, criterion):
    data_time, batch_time = AverageMeter(), AverageMeter()
    arch_losses, arch_top1, arch_top5 = AverageMeter(), AverageMeter(), AverageMeter()
    network.eval()
    end = time.time()
    with torch.no_grad():
        for step, (arch_inputs, arch_targets) in enumerate(xloader):
            arch_targets = arch_targets.cuda(non_blocking=True)
            # measure data loading time
            data_time.update(time.time() - end)
            # prediction

#             network.module.random_genotype_per_cell(True)
            _, logits = network(arch_inputs)
            arch_loss = criterion(logits, arch_targets)
            # record
            arch_prec1, arch_prec5 = obtain_accuracy(
                logits.data, arch_targets.data, topk=(1, 5)
            )
            arch_losses.update(arch_loss.item(), arch_inputs.size(0))
            arch_top1.update(arch_prec1.item(), arch_inputs.size(0))
            arch_top5.update(arch_prec5.item(), arch_inputs.size(0))
            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()
    return arch_losses.avg, arch_top1.avg, arch_top5.avg

# %%
start_time, search_time, epoch_time, total_epoch = (
    time.time(),
    AverageMeter(),
    AverageMeter(),
    config.epochs + config.warmup,
)
for epoch in range(0, total_epoch):
    w_scheduler.update(epoch, 0.0)
    need_time = "Time Left: {:}".format(
        convert_secs2time(epoch_time.val * (total_epoch - epoch), True)
    )
    epoch_str = "{:03d}-{:03d}".format(epoch, total_epoch)
    logger.log(
        "\n[Search the {:}-th epoch] {:}, LR={:}".format(
            epoch_str, need_time, min(w_scheduler.get_lr())
        )
    )

    # selected_arch = search_find_best(valid_loader, network, criterion, xargs.select_num)
    search_w_loss, search_w_top1, search_w_top5 = train_func_one_arch(
        train_loader,
        network,
        criterion,
        w_scheduler,
        w_optimizer,
        epoch_str,
        xargs.print_freq,
        logger,
    )
    search_time.update(time.time() - start_time)
    logger.log(
        "[{:}] searching : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%, time-cost={:.1f} s".format(
            epoch_str, search_w_loss, search_w_top1, search_w_top5, search_time.sum
        )
    )
    valid_a_loss, valid_a_top1, valid_a_top5 = valid_func_one_arch(
        test_loader, network, criterion
    )
    logger.log(
        "[{:}] evaluate  : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%".format(
            epoch_str, valid_a_loss, valid_a_top1, valid_a_top5
        )
    )
    
    # check the best accuracy
    valid_accuracies[epoch] = valid_a_top1
    if valid_a_top1 > valid_accuracies["best"]:
        valid_accuracies["best"] = valid_a_top1
        find_best = True
    else:
        find_best = False

    # save checkpoint
    save_path = save_checkpoint(
        {
            "epoch": epoch + 1,
            "args": deepcopy(xargs),
            "search_model": search_model.state_dict(),
            "w_optimizer": w_optimizer.state_dict(),
            "w_scheduler": w_scheduler.state_dict(),
            "genotypes": genotypes,
            "valid_accuracies": valid_accuracies,
        },
        model_base_path,
        logger,
    )
    last_info = save_checkpoint(
        {
            "epoch": epoch + 1,
            "args": deepcopy(args),
            "last_checkpoint": save_path,
        },
        logger.path("info"),
        logger,
    )
    if find_best:
        logger.log(
            "<<<--->>> The {:}-th epoch : find the highest validation accuracy : {:.2f}%.".format(
                epoch_str, valid_a_top1
            )
        )
        copy_checkpoint(model_base_path, model_best_path, logger)
    if api is not None:
        logger.log("{:}".format(api.query_by_arch(genotypes[epoch], "200")))
    # measure elapsed time
    epoch_time.update(time.time() - start_time)
    start_time = time.time()

logger.close()
# Out:
# [Search the 000-200-th epoch] Time Left: [00:00:00], LR=0.1
# *SEARCH* [2022-11-07 05:08:29] [000-200][000/196] Time 0.38 (0.38) Data 0.26 (0.26) Base [Loss 2.321 (2.321)  Prec@1 9.77 (9.77) Prec@5 55.47 (55.47)]
# *SEARCH* [2022-11-07 05:08:54] [000-200][195/196] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 1.375 (1.673)  Prec@1 51.25 (37.69) Prec@5 93.75 (87.40)]
# [000-200] searching : loss=1.67, accuracy@1=37.69%, accuracy@5=87.40%, time-cost=24.7 s
# [000-200] evaluate  : loss=4.32, accuracy@1=17.97%, accuracy@5=73.91%
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 000-200-th epoch : find the highest validation accuracy : 17.97%.
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 001-200-th epoch] Time Left: [01:35:36], LR=0.09999383162408304
# *SEARCH* [2022-11-07 05:08:58] [001-200][000/196] Time 0.41 (0.41) Data 0.30 (0.30) Base [Loss 1.536 (1.536)  Prec@1 49.22 (49.22) Prec@5 89.84 (89.84)]
# *SEARCH* [2022-11-07 05:09:21] [001-200][195/196] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 1.145 (1.194)  Prec@1 63.75 (56.85) Prec@5 98.75 (95.12)]
# [001-200] searching : loss=1.19, accuracy@1=56.85%, accuracy@5=95.12%, time-cost=48.1 s
# [001-200] evaluate  : loss=1.66, accuracy@1=46.81%, accuracy@5=93.06%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 001-200-th epoch : find the highest validation accuracy : 46.81%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 002-200-th epoch] Time Left: [01:31:17], LR=0.09997532801828658
# *SEARCH* [2022-11-07 05:09:26] [002-200][000/196] Time 0.46 (0.46) Data 0.28 (0.28) Base [Loss 0.949 (0.949)  Prec@1 65.62 (65.62) Prec@5 97.66 (97.66)]
# *SEARCH* [2022-11-07 05:09:52] [002-200][195/196] Time 0.16 (0.13) Data 0.00 (0.00) Base [Loss 0.980 (0.968)  Prec@1 63.75 (65.11) Prec@5 96.25 (96.98)]
# [002-200] searching : loss=0.97, accuracy@1=65.11%, accuracy@5=96.98%, time-cost=74.1 s
# [002-200] evaluate  : loss=1.12, accuracy@1=61.19%, accuracy@5=96.62%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 002-200-th epoch : find the highest validation accuracy : 61.19%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 003-200-th epoch] Time Left: [01:37:32], LR=0.09994449374809851
# *SEARCH* [2022-11-07 05:09:56] [003-200][000/196] Time 0.37 (0.37) Data 0.26 (0.26) Base [Loss 0.939 (0.939)  Prec@1 67.58 (67.58) Prec@5 97.27 (97.27)]
# *SEARCH* [2022-11-07 05:10:26] [003-200][195/196] Time 0.08 (0.15) Data 0.00 (0.00) Base [Loss 0.966 (0.856)  Prec@1 63.75 (69.62) Prec@5 97.50 (97.73)]
# [003-200] searching : loss=0.86, accuracy@1=69.62%, accuracy@5=97.73%, time-cost=104.6 s
# [003-200] evaluate  : loss=1.43, accuracy@1=52.30%, accuracy@5=95.81%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 004-200-th epoch] Time Left: [01:53:44], LR=0.09990133642141358
# *SEARCH* [2022-11-07 05:10:31] [004-200][000/196] Time 0.45 (0.45) Data 0.30 (0.30) Base [Loss 0.904 (0.904)  Prec@1 70.70 (70.70) Prec@5 98.05 (98.05)]
# *SEARCH* [2022-11-07 05:10:55] [004-200][195/196] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.899 (0.769)  Prec@1 72.50 (72.97) Prec@5 97.50 (98.19)]
# [004-200] searching : loss=0.77, accuracy@1=72.97%, accuracy@5=98.19%, time-cost=129.2 s
# [004-200] evaluate  : loss=1.13, accuracy@1=64.03%, accuracy@5=96.61%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 004-200-th epoch : find the highest validation accuracy : 64.03%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 005-200-th epoch] Time Left: [01:33:51], LR=0.0998458666866564
# *SEARCH* [2022-11-07 05:10:59] [005-200][000/196] Time 0.42 (0.42) Data 0.30 (0.30) Base [Loss 0.904 (0.904)  Prec@1 71.48 (71.48) Prec@5 95.70 (95.70)]
# *SEARCH* [2022-11-07 05:11:31] [005-200][195/196] Time 0.09 (0.16) Data 0.00 (0.00) Base [Loss 0.746 (0.715)  Prec@1 72.50 (75.02) Prec@5 100.00 (98.49)]
# [005-200] searching : loss=0.72, accuracy@1=75.02%, accuracy@5=98.49%, time-cost=161.1 s
# [005-200] evaluate  : loss=1.43, accuracy@1=56.22%, accuracy@5=97.01%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 006-200-th epoch] Time Left: [01:55:44], LR=0.099778098230154
# *SEARCH* [2022-11-07 05:11:35] [006-200][000/196] Time 0.38 (0.38) Data 0.24 (0.24) Base [Loss 0.736 (0.736)  Prec@1 75.39 (75.39) Prec@5 98.05 (98.05)]
# *SEARCH* [2022-11-07 05:12:00] [006-200][195/196] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.633 (0.673)  Prec@1 76.25 (76.52) Prec@5 98.75 (98.64)]
# [006-200] searching : loss=0.67, accuracy@1=76.52%, accuracy@5=98.64%, time-cost=186.1 s
# [006-200] evaluate  : loss=1.36, accuracy@1=58.98%, accuracy@5=96.82%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 007-200-th epoch] Time Left: [01:30:11], LR=0.099698047772759
# *SEARCH* [2022-11-07 05:12:03] [007-200][000/196] Time 0.45 (0.45) Data 0.26 (0.26) Base [Loss 0.704 (0.704)  Prec@1 76.95 (76.95) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 05:12:31] [007-200][195/196] Time 0.16 (0.14) Data 0.00 (0.00) Base [Loss 0.601 (0.638)  Prec@1 73.75 (77.95) Prec@5 100.00 (98.82)]
# [007-200] searching : loss=0.64, accuracy@1=77.95%, accuracy@5=98.82%, time-cost=214.6 s
# [007-200] evaluate  : loss=0.89, accuracy@1=70.68%, accuracy@5=97.76%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 007-200-th epoch : find the highest validation accuracy : 70.68%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 008-200-th epoch] Time Left: [01:40:34], LR=0.0996057350657239
# *SEARCH* [2022-11-07 05:12:35] [008-200][000/196] Time 0.41 (0.41) Data 0.31 (0.31) Base [Loss 0.630 (0.630)  Prec@1 80.08 (80.08) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 05:13:01] [008-200][195/196] Time 0.10 (0.14) Data 0.00 (0.00) Base [Loss 0.658 (0.610)  Prec@1 77.50 (79.01) Prec@5 98.75 (98.80)]
# [008-200] searching : loss=0.61, accuracy@1=79.01%, accuracy@5=98.80%, time-cost=241.6 s
# [008-200] evaluate  : loss=0.88, accuracy@1=70.96%, accuracy@5=97.35%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 008-200-th epoch : find the highest validation accuracy : 70.96%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 009-200-th epoch] Time Left: [01:38:45], LR=0.09950118288582788
# *SEARCH* [2022-11-07 05:13:06] [009-200][000/196] Time 0.47 (0.47) Data 0.30 (0.30) Base [Loss 0.706 (0.706)  Prec@1 75.00 (75.00) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 05:13:32] [009-200][195/196] Time 0.09 (0.14) Data 0.00 (0.00) Base [Loss 0.688 (0.594)  Prec@1 81.25 (79.25) Prec@5 98.75 (98.95)]
# [009-200] searching : loss=0.59, accuracy@1=79.25%, accuracy@5=98.95%, time-cost=268.3 s
# [009-200] evaluate  : loss=0.94, accuracy@1=69.74%, accuracy@5=95.76%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 010-200-th epoch] Time Left: [01:36:29], LR=0.0993844170297569
# *SEARCH* [2022-11-07 05:13:36] [010-200][000/196] Time 0.42 (0.42) Data 0.29 (0.29) Base [Loss 0.656 (0.656)  Prec@1 76.56 (76.56) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 05:14:03] [010-200][195/196] Time 0.15 (0.14) Data 0.00 (0.00) Base [Loss 0.576 (0.570)  Prec@1 80.00 (80.24) Prec@5 95.00 (98.99)]
# [010-200] searching : loss=0.57, accuracy@1=80.24%, accuracy@5=98.99%, time-cost=295.7 s
# [010-200] evaluate  : loss=0.92, accuracy@1=70.22%, accuracy@5=97.81%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 011-200-th epoch] Time Left: [01:35:41], LR=0.0992554663077387
# *SEARCH* [2022-11-07 05:14:07] [011-200][000/196] Time 0.44 (0.44) Data 0.26 (0.26) Base [Loss 0.502 (0.502)  Prec@1 83.20 (83.20) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 05:14:30] [011-200][195/196] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.787 (0.557)  Prec@1 72.50 (80.70) Prec@5 97.50 (99.07)]
# [011-200] searching : loss=0.56, accuracy@1=80.70%, accuracy@5=99.07%, time-cost=320.0 s
# [011-200] evaluate  : loss=0.95, accuracy@1=68.05%, accuracy@5=97.44%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 012-200-th epoch] Time Left: [01:28:54], LR=0.09911436253643445
# *SEARCH* [2022-11-07 05:14:35] [012-200][000/196] Time 0.39 (0.39) Data 0.27 (0.27) Base [Loss 0.496 (0.496)  Prec@1 82.81 (82.81) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 05:14:58] [012-200][195/196] Time 0.10 (0.12) Data 0.00 (0.00) Base [Loss 0.596 (0.546)  Prec@1 80.00 (81.26) Prec@5 98.75 (99.05)]
# [012-200] searching : loss=0.55, accuracy@1=81.26%, accuracy@5=99.05%, time-cost=344.0 s
# [012-200] evaluate  : loss=1.82, accuracy@1=59.10%, accuracy@5=90.76%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 013-200-th epoch] Time Left: [01:24:09], LR=0.09896114053108829
# *SEARCH* [2022-11-07 05:15:02] [013-200][000/196] Time 0.37 (0.37) Data 0.25 (0.25) Base [Loss 0.495 (0.495)  Prec@1 82.03 (82.03) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 05:15:27] [013-200][195/196] Time 0.07 (0.13) Data 0.00 (0.00) Base [Loss 0.718 (0.537)  Prec@1 73.75 (81.49) Prec@5 97.50 (99.14)]
# [013-200] searching : loss=0.54, accuracy@1=81.49%, accuracy@5=99.14%, time-cost=369.5 s
# [013-200] evaluate  : loss=1.10, accuracy@1=66.07%, accuracy@5=96.55%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 014-200-th epoch] Time Left: [01:28:17], LR=0.09879583809693737
# *SEARCH* [2022-11-07 05:15:30] [014-200][000/196] Time 0.36 (0.36) Data 0.26 (0.26) Base [Loss 0.506 (0.506)  Prec@1 83.59 (83.59) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 05:15:56] [014-200][195/196] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.400 (0.529)  Prec@1 87.50 (81.77) Prec@5 98.75 (99.05)]
# [014-200] searching : loss=0.53, accuracy@1=81.77%, accuracy@5=99.05%, time-cost=395.2 s
# [014-200] evaluate  : loss=1.03, accuracy@1=67.20%, accuracy@5=97.51%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 015-200-th epoch] Time Left: [01:28:34], LR=0.09861849601988383
# *SEARCH* [2022-11-07 05:15:59] [015-200][000/196] Time 0.40 (0.40) Data 0.30 (0.30) Base [Loss 0.670 (0.670)  Prec@1 78.12 (78.12) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-11-07 05:16:27] [015-200][195/196] Time 0.09 (0.14) Data 0.00 (0.00) Base [Loss 0.680 (0.512)  Prec@1 78.75 (82.19) Prec@5 96.25 (99.17)]
# [015-200] searching : loss=0.51, accuracy@1=82.19%, accuracy@5=99.17%, time-cost=423.5 s
# [015-200] evaluate  : loss=1.19, accuracy@1=64.86%, accuracy@5=97.79%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 016-200-th epoch] Time Left: [01:40:03], LR=0.09842915805643156
# *SEARCH* [2022-11-07 05:16:32] [016-200][000/196] Time 0.37 (0.37) Data 0.24 (0.24) Base [Loss 0.642 (0.642)  Prec@1 78.12 (78.12) Prec@5 97.66 (97.66)]
# *SEARCH* [2022-11-07 05:16:55] [016-200][195/196] Time 0.15 (0.12) Data 0.00 (0.00) Base [Loss 0.440 (0.513)  Prec@1 83.75 (82.35) Prec@5 100.00 (99.21)]
# [016-200] searching : loss=0.51, accuracy@1=82.35%, accuracy@5=99.21%, time-cost=447.1 s
# [016-200] evaluate  : loss=0.82, accuracy@1=72.60%, accuracy@5=97.84%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 016-200-th epoch : find the highest validation accuracy : 72.60%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 017-200-th epoch] Time Left: [01:21:19], LR=0.09822787092288991
# *SEARCH* [2022-11-07 05:16:58] [017-200][000/196] Time 0.36 (0.36) Data 0.25 (0.25) Base [Loss 0.529 (0.529)  Prec@1 80.86 (80.86) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 05:17:21] [017-200][195/196] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.549 (0.498)  Prec@1 83.75 (82.78) Prec@5 100.00 (99.34)]
# [017-200] searching : loss=0.50, accuracy@1=82.78%, accuracy@5=99.34%, time-cost=469.6 s
# [017-200] evaluate  : loss=0.94, accuracy@1=70.18%, accuracy@5=97.55%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 018-200-th epoch] Time Left: [01:20:36], LR=0.09801468428384716
# *SEARCH* [2022-11-07 05:17:25] [018-200][000/196] Time 0.43 (0.43) Data 0.31 (0.31) Base [Loss 0.457 (0.457)  Prec@1 83.98 (83.98) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 05:17:48] [018-200][195/196] Time 0.16 (0.12) Data 0.00 (0.00) Base [Loss 0.655 (0.492)  Prec@1 76.25 (82.97) Prec@5 97.50 (99.24)]
# [018-200] searching : loss=0.49, accuracy@1=82.97%, accuracy@5=99.24%, time-cost=493.4 s
# [018-200] evaluate  : loss=0.85, accuracy@1=73.84%, accuracy@5=97.76%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 018-200-th epoch : find the highest validation accuracy : 73.84%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 019-200-th epoch] Time Left: [01:20:59], LR=0.09778965073991651
# *SEARCH* [2022-11-07 05:17:52] [019-200][000/196] Time 0.42 (0.42) Data 0.32 (0.32) Base [Loss 0.549 (0.549)  Prec@1 80.86 (80.86) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-11-07 05:18:19] [019-200][195/196] Time 0.08 (0.14) Data 0.00 (0.00) Base [Loss 0.620 (0.484)  Prec@1 78.75 (83.30) Prec@5 100.00 (99.28)]
# [019-200] searching : loss=0.48, accuracy@1=83.30%, accuracy@5=99.28%, time-cost=520.8 s
# [019-200] evaluate  : loss=0.95, accuracy@1=68.06%, accuracy@5=97.43%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 020-200-th epoch] Time Left: [01:31:45], LR=0.09755282581475769
# *SEARCH* [2022-11-07 05:18:22] [020-200][000/196] Time 0.45 (0.45) Data 0.24 (0.24) Base [Loss 0.438 (0.438)  Prec@1 83.59 (83.59) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 05:18:51] [020-200][195/196] Time 0.15 (0.15) Data 0.00 (0.00) Base [Loss 0.382 (0.484)  Prec@1 86.25 (83.22) Prec@5 100.00 (99.27)]
# [020-200] searching : loss=0.48, accuracy@1=83.22%, accuracy@5=99.27%, time-cost=549.4 s
# [020-200] evaluate  : loss=1.02, accuracy@1=67.28%, accuracy@5=97.41%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 021-200-th epoch] Time Left: [01:37:39], LR=0.09730426794137727
# *SEARCH* [2022-11-07 05:18:55] [021-200][000/196] Time 0.48 (0.48) Data 0.34 (0.34) Base [Loss 0.541 (0.541)  Prec@1 82.03 (82.03) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 05:19:21] [021-200][195/196] Time 0.10 (0.14) Data 0.00 (0.00) Base [Loss 0.574 (0.473)  Prec@1 80.00 (83.81) Prec@5 98.75 (99.29)]
# [021-200] searching : loss=0.47, accuracy@1=83.81%, accuracy@5=99.29%, time-cost=576.0 s
# [021-200] evaluate  : loss=1.19, accuracy@1=65.79%, accuracy@5=97.68%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 022-200-th epoch] Time Left: [01:28:05], LR=0.09704403844771128
# *SEARCH* [2022-11-07 05:19:25] [022-200][000/196] Time 0.43 (0.43) Data 0.31 (0.31) Base [Loss 0.527 (0.527)  Prec@1 82.42 (82.42) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-11-07 05:19:52] [022-200][195/196] Time 0.23 (0.14) Data 0.00 (0.00) Base [Loss 0.457 (0.474)  Prec@1 83.75 (83.78) Prec@5 100.00 (99.33)]
# [022-200] searching : loss=0.47, accuracy@1=83.78%, accuracy@5=99.33%, time-cost=603.3 s
# [022-200] evaluate  : loss=1.20, accuracy@1=64.12%, accuracy@5=97.62%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 023-200-th epoch] Time Left: [01:30:00], LR=0.09677220154149338
# *SEARCH* [2022-11-07 05:19:55] [023-200][000/196] Time 0.43 (0.43) Data 0.32 (0.32) Base [Loss 0.475 (0.475)  Prec@1 83.20 (83.20) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 05:20:21] [023-200][195/196] Time 0.10 (0.13) Data 0.00 (0.00) Base [Loss 0.286 (0.462)  Prec@1 88.75 (84.20) Prec@5 100.00 (99.37)]
# [023-200] searching : loss=0.46, accuracy@1=84.20%, accuracy@5=99.37%, time-cost=629.6 s
# [023-200] evaluate  : loss=1.08, accuracy@1=67.66%, accuracy@5=98.17%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 024-200-th epoch] Time Left: [01:30:10], LR=0.09648882429441258
# *SEARCH* [2022-11-07 05:20:26] [024-200][000/196] Time 0.56 (0.56) Data 0.34 (0.34) Base [Loss 0.520 (0.520)  Prec@1 85.55 (85.55) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 05:20:54] [024-200][195/196] Time 0.10 (0.14) Data 0.00 (0.00) Base [Loss 0.587 (0.461)  Prec@1 82.50 (84.09) Prec@5 97.50 (99.38)]
# [024-200] searching : loss=0.46, accuracy@1=84.09%, accuracy@5=99.38%, time-cost=657.5 s
# [024-200] evaluate  : loss=1.15, accuracy@1=67.02%, accuracy@5=95.64%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 025-200-th epoch] Time Left: [01:30:52], LR=0.09619397662556434
# *SEARCH* [2022-11-07 05:20:57] [025-200][000/196] Time 0.36 (0.36) Data 0.26 (0.26) Base [Loss 0.393 (0.393)  Prec@1 85.94 (85.94) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 05:21:25] [025-200][195/196] Time 0.14 (0.14) Data 0.00 (0.00) Base [Loss 0.513 (0.455)  Prec@1 77.50 (84.39) Prec@5 100.00 (99.39)]
# [025-200] searching : loss=0.46, accuracy@1=84.39%, accuracy@5=99.39%, time-cost=685.9 s
# [025-200] evaluate  : loss=1.43, accuracy@1=60.47%, accuracy@5=94.87%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 026-200-th epoch] Time Left: [01:32:36], LR=0.09588773128419906
# *SEARCH* [2022-11-07 05:21:29] [026-200][000/196] Time 0.41 (0.41) Data 0.29 (0.29) Base [Loss 0.489 (0.489)  Prec@1 82.81 (82.81) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-11-07 05:21:58] [026-200][195/196] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.334 (0.455)  Prec@1 85.00 (84.48) Prec@5 100.00 (99.37)]
# [026-200] searching : loss=0.46, accuracy@1=84.48%, accuracy@5=99.37%, time-cost=714.7 s
# [026-200] evaluate  : loss=0.81, accuracy@1=74.84%, accuracy@5=98.06%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 026-200-th epoch : find the highest validation accuracy : 74.84%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 027-200-th epoch] Time Left: [01:35:29], LR=0.09557016383177226
# *SEARCH* [2022-11-07 05:22:02] [027-200][000/196] Time 0.40 (0.40) Data 0.28 (0.28) Base [Loss 0.434 (0.434)  Prec@1 83.98 (83.98) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 05:22:30] [027-200][195/196] Time 0.10 (0.14) Data 0.00 (0.00) Base [Loss 0.402 (0.445)  Prec@1 87.50 (84.77) Prec@5 98.75 (99.41)]
# [027-200] searching : loss=0.45, accuracy@1=84.77%, accuracy@5=99.41%, time-cost=743.1 s
# [027-200] evaluate  : loss=0.98, accuracy@1=69.72%, accuracy@5=97.80%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 028-200-th epoch] Time Left: [01:32:56], LR=0.09524135262330098
# *SEARCH* [2022-11-07 05:22:35] [028-200][000/196] Time 0.44 (0.44) Data 0.26 (0.26) Base [Loss 0.475 (0.475)  Prec@1 84.38 (84.38) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 05:23:04] [028-200][195/196] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.595 (0.444)  Prec@1 80.00 (84.71) Prec@5 98.75 (99.39)]
# [028-200] searching : loss=0.44, accuracy@1=84.71%, accuracy@5=99.39%, time-cost=773.3 s
# [028-200] evaluate  : loss=0.86, accuracy@1=71.42%, accuracy@5=98.23%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 029-200-th epoch] Time Left: [01:38:09], LR=0.09490137878803079
# *SEARCH* [2022-11-07 05:23:09] [029-200][000/196] Time 0.42 (0.42) Data 0.31 (0.31) Base [Loss 0.401 (0.401)  Prec@1 86.33 (86.33) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 05:23:38] [029-200][195/196] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.466 (0.435)  Prec@1 83.75 (84.91) Prec@5 97.50 (99.41)]
# [029-200] searching : loss=0.43, accuracy@1=84.91%, accuracy@5=99.41%, time-cost=802.3 s
# [029-200] evaluate  : loss=0.87, accuracy@1=71.06%, accuracy@5=97.02%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 030-200-th epoch] Time Left: [01:31:05], LR=0.09455032620941839
# *SEARCH* [2022-11-07 05:23:41] [030-200][000/196] Time 0.46 (0.46) Data 0.27 (0.27) Base [Loss 0.365 (0.365)  Prec@1 87.50 (87.50) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 05:24:08] [030-200][195/196] Time 0.15 (0.14) Data 0.00 (0.00) Base [Loss 0.428 (0.440)  Prec@1 87.50 (84.88) Prec@5 100.00 (99.44)]
# [030-200] searching : loss=0.44, accuracy@1=84.88%, accuracy@5=99.44%, time-cost=829.5 s
# [030-200] evaluate  : loss=0.94, accuracy@1=71.13%, accuracy@5=97.61%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 031-200-th epoch] Time Left: [01:29:20], LR=0.09418828150443469
# *SEARCH* [2022-11-07 05:24:13] [031-200][000/196] Time 0.48 (0.48) Data 0.34 (0.34) Base [Loss 0.471 (0.471)  Prec@1 84.38 (84.38) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 05:24:40] [031-200][195/196] Time 0.11 (0.14) Data 0.00 (0.00) Base [Loss 0.581 (0.432)  Prec@1 81.25 (85.08) Prec@5 100.00 (99.40)]
# [031-200] searching : loss=0.43, accuracy@1=85.08%, accuracy@5=99.40%, time-cost=856.6 s
# [031-200] evaluate  : loss=0.86, accuracy@1=71.72%, accuracy@5=98.49%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 032-200-th epoch] Time Left: [01:27:52], LR=0.09381533400219318
# *SEARCH* [2022-11-07 05:24:45] [032-200][000/196] Time 0.54 (0.54) Data 0.30 (0.30) Base [Loss 0.447 (0.447)  Prec@1 84.38 (84.38) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 05:25:13] [032-200][195/196] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 0.419 (0.430)  Prec@1 91.25 (85.12) Prec@5 98.75 (99.42)]
# [032-200] searching : loss=0.43, accuracy@1=85.12%, accuracy@5=99.42%, time-cost=886.1 s
# [032-200] evaluate  : loss=1.43, accuracy@1=63.16%, accuracy@5=96.81%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 033-200-th epoch] Time Left: [01:30:46], LR=0.09343157572190958
# *SEARCH* [2022-11-07 05:25:17] [033-200][000/196] Time 0.47 (0.47) Data 0.25 (0.25) Base [Loss 0.469 (0.469)  Prec@1 83.98 (83.98) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 05:25:45] [033-200][195/196] Time 0.09 (0.15) Data 0.00 (0.00) Base [Loss 0.423 (0.427)  Prec@1 85.00 (85.21) Prec@5 100.00 (99.43)]
# [033-200] searching : loss=0.43, accuracy@1=85.21%, accuracy@5=99.43%, time-cost=914.8 s
# [033-200] evaluate  : loss=0.74, accuracy@1=75.30%, accuracy@5=98.43%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 033-200-th epoch : find the highest validation accuracy : 75.30%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 034-200-th epoch] Time Left: [01:31:46], LR=0.09303710135019719
# *SEARCH* [2022-11-07 05:25:50] [034-200][000/196] Time 0.44 (0.44) Data 0.29 (0.29) Base [Loss 0.338 (0.338)  Prec@1 90.23 (90.23) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 05:26:21] [034-200][195/196] Time 0.10 (0.16) Data 0.00 (0.00) Base [Loss 0.514 (0.422)  Prec@1 75.00 (85.36) Prec@5 100.00 (99.42)]
# [034-200] searching : loss=0.42, accuracy@1=85.36%, accuracy@5=99.42%, time-cost=946.3 s
# [034-200] evaluate  : loss=1.81, accuracy@1=52.18%, accuracy@5=93.69%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 035-200-th epoch] Time Left: [01:35:50], LR=0.09263200821770462
# *SEARCH* [2022-11-07 05:26:25] [035-200][000/196] Time 0.46 (0.46) Data 0.28 (0.28) Base [Loss 0.507 (0.507)  Prec@1 80.86 (80.86) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 05:26:56] [035-200][195/196] Time 0.23 (0.16) Data 0.00 (0.00) Base [Loss 0.331 (0.422)  Prec@1 87.50 (85.42) Prec@5 100.00 (99.44)]
# [035-200] searching : loss=0.42, accuracy@1=85.42%, accuracy@5=99.44%, time-cost=978.0 s
# [035-200] evaluate  : loss=0.79, accuracy@1=74.88%, accuracy@5=98.88%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 036-200-th epoch] Time Left: [01:35:45], LR=0.09221639627510075
# *SEARCH* [2022-11-07 05:27:00] [036-200][000/196] Time 0.43 (0.43) Data 0.31 (0.31) Base [Loss 0.501 (0.501)  Prec@1 84.77 (84.77) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 05:27:28] [036-200][195/196] Time 0.09 (0.14) Data 0.00 (0.00) Base [Loss 0.562 (0.418)  Prec@1 77.50 (85.43) Prec@5 97.50 (99.46)]
# [036-200] searching : loss=0.42, accuracy@1=85.43%, accuracy@5=99.46%, time-cost=1006.1 s
# [036-200] evaluate  : loss=0.67, accuracy@1=77.86%, accuracy@5=98.65%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
# <<<--->>> The 036-200-th epoch : find the highest validation accuracy : 77.86%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-best.pth
#
# [Search the 037-200-th epoch] Time Left: [01:25:33], LR=0.09179036806841352
# *SEARCH* [2022-11-07 05:27:32] [037-200][000/196] Time 0.55 (0.55) Data 0.29 (0.29) Base [Loss 0.330 (0.330)  Prec@1 89.45 (89.45) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 05:28:01] [037-200][195/196] Time 0.09 (0.15) Data 0.00 (0.00) Base [Loss 0.532 (0.419)  Prec@1 81.25 (85.60) Prec@5 97.50 (99.45)]
# [037-200] searching : loss=0.42, accuracy@1=85.60%, accuracy@5=99.45%, time-cost=1036.0 s
# [037-200] evaluate  : loss=0.88, accuracy@1=71.68%, accuracy@5=98.71%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 038-200-th epoch] Time Left: [01:32:56], LR=0.0913540287137281
# *SEARCH* [2022-11-07 05:28:06] [038-200][000/196] Time 0.46 (0.46) Data 0.34 (0.34) Base [Loss 0.418 (0.418)  Prec@1 84.38 (84.38) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 05:28:37] [038-200][195/196] Time 0.15 (0.16) Data 0.00 (0.00) Base [Loss 0.382 (0.409)  Prec@1 83.75 (85.90) Prec@5 98.75 (99.47)]
# [038-200] searching : loss=0.41, accuracy@1=85.90%, accuracy@5=99.47%, time-cost=1067.0 s
# [038-200] evaluate  : loss=0.71, accuracy@1=76.86%, accuracy@5=98.61%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 039-200-th epoch] Time Left: [01:31:53], LR=0.09090748587125118
# ...
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 186-200-th epoch] Time Left: [00:07:32], LR=0.0012041619030626338
# *SEARCH* [2022-11-07 06:52:47] [186-200][000/196] Time 0.51 (0.51) Data 0.33 (0.33) Base [Loss 0.016 (0.016)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:53:17] [186-200][195/196] Time 0.15 (0.15) Data 0.00 (0.00) Base [Loss 0.023 (0.019)  Prec@1 100.00 (99.54) Prec@5 100.00 (100.00)]
# [186-200] searching : loss=0.02, accuracy@1=99.54%, accuracy@5=100.00%, time-cost=5575.0 s
# [186-200] evaluate  : loss=0.33, accuracy@1=91.61%, accuracy@5=99.71%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 187-200-th epoch] Time Left: [00:07:31], LR=0.001038859468911707
# *SEARCH* [2022-11-07 06:53:22] [187-200][000/196] Time 0.45 (0.45) Data 0.30 (0.30) Base [Loss 0.033 (0.033)  Prec@1 99.22 (99.22) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:53:50] [187-200][195/196] Time 0.09 (0.15) Data 0.00 (0.00) Base [Loss 0.039 (0.020)  Prec@1 98.75 (99.50) Prec@5 100.00 (100.00)]
# [187-200] searching : loss=0.02, accuracy@1=99.50%, accuracy@5=100.00%, time-cost=5604.1 s
# [187-200] evaluate  : loss=0.33, accuracy@1=91.54%, accuracy@5=99.66%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 188-200-th epoch] Time Left: [00:06:32], LR=0.000885637463565564
# *SEARCH* [2022-11-07 06:53:54] [188-200][000/196] Time 0.36 (0.36) Data 0.25 (0.25) Base [Loss 0.011 (0.011)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:54:25] [188-200][195/196] Time 0.15 (0.16) Data 0.00 (0.00) Base [Loss 0.023 (0.018)  Prec@1 100.00 (99.62) Prec@5 100.00 (100.00)]
# [188-200] searching : loss=0.02, accuracy@1=99.62%, accuracy@5=100.00%, time-cost=5635.3 s
# [188-200] evaluate  : loss=0.33, accuracy@1=91.54%, accuracy@5=99.72%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 189-200-th epoch] Time Left: [00:06:18], LR=0.0007445336922613067
# *SEARCH* [2022-11-07 06:54:29] [189-200][000/196] Time 0.45 (0.45) Data 0.26 (0.26) Base [Loss 0.014 (0.014)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:54:57] [189-200][195/196] Time 0.10 (0.14) Data 0.00 (0.00) Base [Loss 0.044 (0.017)  Prec@1 97.50 (99.62) Prec@5 100.00 (100.00)]
# [189-200] searching : loss=0.02, accuracy@1=99.62%, accuracy@5=100.00%, time-cost=5663.8 s
# [189-200] evaluate  : loss=0.33, accuracy@1=91.62%, accuracy@5=99.76%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 190-200-th epoch] Time Left: [00:05:17], LR=0.0006155829702431171
# *SEARCH* [2022-11-07 06:55:01] [190-200][000/196] Time 0.51 (0.51) Data 0.28 (0.28) Base [Loss 0.010 (0.010)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:55:32] [190-200][195/196] Time 0.14 (0.16) Data 0.00 (0.00) Base [Loss 0.024 (0.018)  Prec@1 98.75 (99.60) Prec@5 100.00 (100.00)]
# [190-200] searching : loss=0.02, accuracy@1=99.60%, accuracy@5=100.00%, time-cost=5695.6 s
# [190-200] evaluate  : loss=0.33, accuracy@1=91.62%, accuracy@5=99.73%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 191-200-th epoch] Time Left: [00:05:27], LR=0.0004988171141721232
# *SEARCH* [2022-11-07 06:55:37] [191-200][000/196] Time 0.51 (0.51) Data 0.25 (0.25) Base [Loss 0.008 (0.008)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:56:05] [191-200][195/196] Time 0.11 (0.14) Data 0.00 (0.00) Base [Loss 0.014 (0.017)  Prec@1 100.00 (99.58) Prec@5 100.00 (100.00)]
# [191-200] searching : loss=0.02, accuracy@1=99.58%, accuracy@5=100.00%, time-cost=5723.7 s
# [191-200] evaluate  : loss=0.34, accuracy@1=91.51%, accuracy@5=99.72%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 192-200-th epoch] Time Left: [00:04:21], LR=0.0003942649342761118
# *SEARCH* [2022-11-07 06:56:10] [192-200][000/196] Time 0.44 (0.44) Data 0.29 (0.29) Base [Loss 0.019 (0.019)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:56:40] [192-200][195/196] Time 0.12 (0.15) Data 0.00 (0.00) Base [Loss 0.047 (0.017)  Prec@1 98.75 (99.61) Prec@5 100.00 (100.00)]
# [192-200] searching : loss=0.02, accuracy@1=99.61%, accuracy@5=100.00%, time-cost=5754.1 s
# [192-200] evaluate  : loss=0.34, accuracy@1=91.49%, accuracy@5=99.73%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 193-200-th epoch] Time Left: [00:04:04], LR=0.00030195222724102024
# *SEARCH* [2022-11-07 06:56:45] [193-200][000/196] Time 0.50 (0.50) Data 0.34 (0.34) Base [Loss 0.010 (0.010)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:57:13] [193-200][195/196] Time 0.19 (0.15) Data 0.00 (0.00) Base [Loss 0.133 (0.017)  Prec@1 96.25 (99.62) Prec@5 100.00 (100.00)]
# [193-200] searching : loss=0.02, accuracy@1=99.62%, accuracy@5=100.00%, time-cost=5782.7 s
# [193-200] evaluate  : loss=0.34, accuracy@1=91.44%, accuracy@5=99.66%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 194-200-th epoch] Time Left: [00:03:12], LR=0.0002219017698460002
# *SEARCH* [2022-11-07 06:57:17] [194-200][000/196] Time 0.38 (0.38) Data 0.26 (0.26) Base [Loss 0.023 (0.023)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:57:48] [194-200][195/196] Time 0.17 (0.16) Data 0.00 (0.00) Base [Loss 0.030 (0.017)  Prec@1 98.75 (99.63) Prec@5 100.00 (100.00)]
# [194-200] searching : loss=0.02, accuracy@1=99.63%, accuracy@5=100.00%, time-cost=5814.5 s
# [194-200] evaluate  : loss=0.33, accuracy@1=91.52%, accuracy@5=99.71%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 195-200-th epoch] Time Left: [00:02:56], LR=0.0001541333133436018
# *SEARCH* [2022-11-07 06:57:52] [195-200][000/196] Time 0.49 (0.49) Data 0.29 (0.29) Base [Loss 0.014 (0.014)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:58:23] [195-200][195/196] Time 0.15 (0.16) Data 0.00 (0.00) Base [Loss 0.035 (0.017)  Prec@1 98.75 (99.62) Prec@5 100.00 (100.00)]
# [195-200] searching : loss=0.02, accuracy@1=99.62%, accuracy@5=100.00%, time-cost=5845.5 s
# [195-200] evaluate  : loss=0.33, accuracy@1=91.52%, accuracy@5=99.72%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 196-200-th epoch] Time Left: [00:02:19], LR=9.866357858642206e-05
# *SEARCH* [2022-11-07 06:58:27] [196-200][000/196] Time 0.52 (0.52) Data 0.34 (0.34) Base [Loss 0.023 (0.023)  Prec@1 98.83 (98.83) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:58:57] [196-200][195/196] Time 0.09 (0.15) Data 0.00 (0.00) Base [Loss 0.048 (0.016)  Prec@1 97.50 (99.68) Prec@5 100.00 (100.00)]
# [196-200] searching : loss=0.02, accuracy@1=99.68%, accuracy@5=100.00%, time-cost=5875.9 s
# [196-200] evaluate  : loss=0.33, accuracy@1=91.61%, accuracy@5=99.76%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 197-200-th epoch] Time Left: [00:01:41], LR=5.550625190150482e-05
# *SEARCH* [2022-11-07 06:59:01] [197-200][000/196] Time 0.43 (0.43) Data 0.32 (0.32) Base [Loss 0.013 (0.013)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 06:59:30] [197-200][195/196] Time 0.18 (0.15) Data 0.00 (0.00) Base [Loss 0.040 (0.016)  Prec@1 98.75 (99.68) Prec@5 100.00 (100.00)]
# [197-200] searching : loss=0.02, accuracy@1=99.68%, accuracy@5=100.00%, time-cost=5905.3 s
# [197-200] evaluate  : loss=0.34, accuracy@1=91.54%, accuracy@5=99.69%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 198-200-th epoch] Time Left: [00:01:06], LR=2.467198171342e-05
# *SEARCH* [2022-11-07 06:59:34] [198-200][000/196] Time 0.50 (0.50) Data 0.28 (0.28) Base [Loss 0.022 (0.022)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 07:00:04] [198-200][195/196] Time 0.08 (0.16) Data 0.00 (0.00) Base [Loss 0.014 (0.016)  Prec@1 100.00 (99.66) Prec@5 100.00 (100.00)]
# [198-200] searching : loss=0.02, accuracy@1=99.66%, accuracy@5=100.00%, time-cost=5935.8 s
# [198-200] evaluate  : loss=0.33, accuracy@1=91.57%, accuracy@5=99.73%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth
#
# [Search the 199-200-th epoch] Time Left: [00:00:34], LR=6.168375916970615e-06
# *SEARCH* [2022-11-07 07:00:08] [199-200][000/196] Time 0.54 (0.54) Data 0.31 (0.31) Base [Loss 0.015 (0.015)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 07:00:39] [199-200][195/196] Time 0.09 (0.16) Data 0.00 (0.00) Base [Loss 0.031 (0.016)  Prec@1 98.75 (99.67) Prec@5 100.00 (100.00)]
# [199-200] searching : loss=0.02, accuracy@1=99.67%, accuracy@5=100.00%, time-cost=5967.5 s
# [199-200] evaluate  : loss=0.33, accuracy@1=91.68%, accuracy@5=99.73%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/checkpoint/seed-65819-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200-acc_metric/train/seed-65819-last-info.pth

# %%
best_archs
# Out:
# [Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|),
#  Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|),
#  Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|skip_connect~0|avg_pool_3x3~1|nor_conv_3x3~2|),
#  Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|),
#  Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|),
#  Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_1x1~0|skip_connect~1|none~2|),
#  Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|skip_connect~1|skip_connect~2|),
#  Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|),
#  Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|skip_connect~0|nor_conv_1x1~1|nor_conv_1x1~2|),
#  Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_1x1~1|avg_pool_3x3~2|),
#  Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|),
#  Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_1x1~0|avg_pool_3x3~1|avg_pool_3x3~2|),
#  Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_3x3~0|avg_pool_3x3~1|nor_conv_1x1~2|),
#  Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|none~0|skip_connect~1|skip_connect~2|),
#  Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|avg_pool_3x3~2|)]
