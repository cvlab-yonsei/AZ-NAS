# %%
import os, sys, time, glob, random, argparse
import numpy as np
from copy import deepcopy
import torch
import torch.nn as nn

# XAutoDL 
from xautodl.config_utils import load_config, dict2config, configure2str
from xautodl.datasets import get_datasets, get_nas_search_loaders
from xautodl.procedures import (
    prepare_seed,
    prepare_logger,
    save_checkpoint,
    copy_checkpoint,
    get_optim_scheduler,
)
from xautodl.utils import get_model_infos, obtain_accuracy
from xautodl.log_utils import AverageMeter, time_string, convert_secs2time
from xautodl.models import get_search_spaces

from custom_models import get_cell_based_tiny_net
from custom_search_cells import NAS201SearchCell as SearchCell
from xautodl.models.cell_searchs.genotypes import Structure

# NB201
from nas_201_api import NASBench201API as API

import scipy.stats as stats
# Out:
# 2022-11-07 02:53:54.098392: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
parser = argparse.ArgumentParser("Random search for NAS.")
parser.add_argument("--data_path", type=str, default='../cifar.python', help="The path to dataset")
parser.add_argument("--dataset", type=str, default='cifar10',choices=["cifar10", "cifar100", "ImageNet16-120"], help="Choose between Cifar10/100 and ImageNet-16.")

# channels and number-of-cells
parser.add_argument("--search_space_name", type=str, default='nas-bench-201', help="The search space name.")
parser.add_argument("--config_path", type=str, default='./MY.config', help="The path to the configuration.")
parser.add_argument("--max_nodes", type=int, default=4, help="The maximum number of nodes.")
parser.add_argument("--channel", type=int, default=16, help="The number of channels.")
parser.add_argument("--num_cells", type=int, default=5, help="The number of cells in one stage.")
parser.add_argument("--select_num", type=int, default=100, help="The number of selected architectures to evaluate.")
parser.add_argument("--track_running_stats", type=int, default=0, choices=[0, 1], help="Whether use track_running_stats or not in the BN layer.")
# log
parser.add_argument("--workers", type=int, default=4, help="number of data loading workers")
parser.add_argument("--save_dir", type=str, default='./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200', help="Folder to save checkpoints and log.")
# parser.add_argument("--arch_nas_dataset", type=str, default='../NAS-Bench-201-v1_1-096897.pth', help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--arch_nas_dataset", type=str, default=None, help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--print_freq", type=int, default=200, help="print frequency (default: 200)")
parser.add_argument("--rand_seed", type=int, default=None, help="manual seed")
args = parser.parse_args(args=[])
if args.rand_seed is None or args.rand_seed < 0:
    args.rand_seed = random.randint(1, 100000)

    
print(args.rand_seed)
print(args)
xargs=args
# Out:
# 74964
# Namespace(arch_nas_dataset=None, channel=16, config_path='./MY.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=200, rand_seed=74964, save_dir='./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
assert torch.cuda.is_available(), "CUDA is not available."
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.set_num_threads(xargs.workers)
prepare_seed(xargs.rand_seed)
logger = prepare_logger(args)
# Out:
# Main Function with logger : Logger(dir=cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : None
# channel          : 16
# config_path      : ./MY.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 200
# rand_seed        : 74964
# save_dir         : ./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None

# %%
train_data, valid_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(xargs.config_path, {"class_num": class_num, "xshape": xshape}, logger)
search_loader, _, valid_loader = get_nas_search_loaders(train_data,
                                                        valid_data,
                                                        xargs.dataset,
                                                        "../configs/nas-benchmark/",
                                                        (config.batch_size, config.test_batch_size),
                                                        xargs.workers)
logger.log("||||||| {:10s} ||||||| Search-Loader-Num={:}, Valid-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(search_loader), len(valid_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": bool(xargs.track_running_stats),
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))
# if xargs.arch_nas_dataset is None:
api = None
# else:
#     api = API(xargs.arch_nas_dataset)
logger.log("{:} create API = {:} done".format(time_string(), api))

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)
network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

if last_info.exists():  # automatically resume from previous checkpoint
    logger.log(
        "=> loading checkpoint of the last-info '{:}' start".format(last_info)
    )
    last_info = torch.load(last_info)
    start_epoch = last_info["epoch"]
    checkpoint = torch.load(last_info["last_checkpoint"])
    genotypes = checkpoint["genotypes"]
    valid_accuracies = checkpoint["valid_accuracies"]
    search_model.load_state_dict(checkpoint["search_model"])
    w_scheduler.load_state_dict(checkpoint["w_scheduler"])
    w_optimizer.load_state_dict(checkpoint["w_optimizer"])
    logger.log(
        "=> loading checkpoint of the last-info '{:}' start with {:}-th epoch.".format(
            last_info, start_epoch
        )
    )
else:
    logger.log("=> do not find the last-info file : {:}".format(last_info))
    start_epoch, valid_accuracies, genotypes = 0, {"best": -1}, {}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ./MY.config
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=50, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Search-Loader-Num=391, Valid-Loader-Num=49, batch size=64
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=50, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.025
#     lr: 0.025
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=50, current::epoch=0, iter=0.00, type=cosine, T-max=50, eta-min=0.001)
# criterion   : CrossEntropyLoss()
# [2022-11-07 02:53:56] create API = None done
# => do not find the last-info file : cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/seed-74964-last-info.pth

# %%
def acc_confidence_robustness_metrics(network, inputs, targets):
    with torch.no_grad():
        # accuracy
        network.train()
        _, logits = network(inputs)
        val_top1, val_top5 = obtain_accuracy(logits.data, targets.data, topk=(1, 5))
        acc = val_top1
        
        # confidence
        prob = torch.nn.functional.softmax(logits, dim=1)
        one_hot_idx = torch.nn.functional.one_hot(targets)
        confidence = (prob[one_hot_idx==1].sum()) / inputs.size(0) * 100 # in percent
        
        # sensitivity
        _, noisy_logits = network(inputs + torch.randn_like(inputs)*0.1)
        kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
        sensitivity = kl_loss(torch.nn.functional.log_softmax(noisy_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
        
        # robustness
        original_weights = deepcopy(network.state_dict())
        for m in network.modules():
            if isinstance(m, SearchCell):
                for p in m.parameters():
                    p.add_(torch.randn_like(p) * p.std()*0.3)
            
        _, noisy_logits = network(inputs)
        kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
        robustness = -kl_loss(torch.nn.functional.log_softmax(noisy_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
        network.load_state_dict(original_weights)
                
        return acc.item(), confidence.item(), sensitivity.item(), robustness.item()
    
def step_sim_metric(network, criterion, inputs, targets):
#     inputs, targets = inputs[:64], targets[:64] # smaller batches
    original_dict = deepcopy(network.state_dict())
    optim_large_step = torch.optim.SGD(network.parameters(), lr=0.025)
    
    # single large step
    network.train()
    optim_large_step.zero_grad()
    _, logits = network(inputs)
    base_loss = criterion(logits, targets)
    base_loss.backward()
    optim_large_step.step()
    large_step_dict = deepcopy(network.state_dict())
    
    # multiple small steps
    network.load_state_dict(original_dict)
    optim_small_step = torch.optim.SGD(network.parameters(), lr=0.025/3)
    for i in range(3):
        optim_small_step.zero_grad()
        _, logits = network(inputs)
        base_loss = criterion(logits, targets)
        base_loss.backward()
        optim_small_step.step()
    small_step_dict = deepcopy(network.state_dict())
    scores = []
    for key in large_step_dict.keys():
        if ('weight' in key) and (original_dict[key].dim()==4):
            if (original_dict[key] != large_step_dict[key]).sum():
                large_step = large_step_dict[key] - original_dict[key]
                small_step = small_step_dict[key] - original_dict[key]
                co, ci, kh, kw = large_step.size()
                large_step = large_step.view(co, -1)
                small_step = small_step.view(co, -1)
                score = torch.nn.functional.cosine_similarity(large_step, small_step, dim=1)
                score = score.mean().item() * 100 # in percent
                scores.append(score)
    if len(scores)==0:
        step_sim = 100
        raise RuntimeError
    else:
        step_sim = np.mean(scores)
    
    # resume
    network.load_state_dict(original_dict)
            
    return step_sim

# %%
# start training
start_time, search_time, epoch_time, total_epoch = (
    time.time(),
    AverageMeter(),
    AverageMeter(),
    config.epochs + config.warmup,
)

################# initialize
cells = []
for m in network.modules():
    if isinstance(m, SearchCell):
        cells.append(m)
num_cells = len(cells)
print("total number of nodes:{}".format(num_cells*xargs.max_nodes))
        
op_names = deepcopy(cells[0].op_names)
op_names_wo_none = deepcopy(op_names)
if "none" in op_names_wo_none:
    op_names_wo_none.remove("none")

genotypes = []
for i in range(1, xargs.max_nodes):
    xlist = []
    for j in range(i):
        node_str = "{:}<-{:}".format(i, j)
        if i-j==1:
            op_name = "skip_connect"
        else:
            op_name = "none"
        xlist.append((op_name, j))
    genotypes.append(tuple(xlist))
init_arch = Structure(genotypes)

for c in cells:
    c.arch_cache = init_arch

### gen possible connections of a target node
possible_connections = {}
for target_node_idx in range(1,xargs.max_nodes):
    possible_connections[target_node_idx] = list()
    xlists = []
    for src_node in range(target_node_idx):
        node_str = "{:}<-{:}".format(target_node_idx, src_node)
        # select possible ops
#         if target_node_idx - src_node == 1:
#             op_names_tmp = op_names_wo_none
#         else:
#             op_names_tmp = op_names
        op_names_tmp = op_names
            
        if len(xlists) == 0: # initial iteration
            for op_name in op_names_tmp:
                xlists.append([(op_name, src_node)])
        else:
            new_xlists = []
            for op_name in op_names_tmp:
                for xlist in xlists:
                    new_xlist = deepcopy(xlist)
                    new_xlist.append((op_name, src_node))
                    new_xlists.append(new_xlist)
            xlists = new_xlists
    for xlist in xlists:
        selected_ops = []
        for l in xlist:
            selected_ops.append(l[0])
        if sum(np.array(selected_ops) == "none") == len(selected_ops):
            continue
        possible_connections[target_node_idx].append(tuple(xlist))
    print("target_node:{}".format(target_node_idx), len(possible_connections[target_node_idx]))
        
### train while generating random architectures by mutating connections of a target node

for arch_loop in range(5):
    for target_cell_idx in range(num_cells):
        target_cell = cells[target_cell_idx]
        print("\n\n Searching with a cell #{}".format(target_cell_idx))
        ####
#         for m in target_cell.modules():
#             if hasattr(m, 'reset_parameters'):
#                 m.reset_parameters()
        ####
        ## training
        for ep in range(2):
            ###
            genotypes = []
            for n in range(1, xargs.max_nodes):
                genotypes.append(random.choice(possible_connections[n]))
            arch = Structure(genotypes)
            target_cell.arch_cache = arch
#             arch = target_cell.random_genotype(True)
            ###
            data_time, batch_time = AverageMeter(), AverageMeter()
            base_losses, base_top1, base_top5 = AverageMeter(), AverageMeter(), AverageMeter()
            network.train()
            end = time.time()
            print_freq = 200
            for step, (base_inputs, base_targets, arch_inputs, arch_targets) in enumerate(search_loader):
                ######### forward/backward/optim
                base_targets = base_targets.cuda(non_blocking=True)
                arch_targets = arch_targets.cuda(non_blocking=True)
                # measure data loading time
                data_time.update(time.time() - end)
                w_optimizer.zero_grad()
                _, logits = network(base_inputs)
                base_loss = criterion(logits, base_targets)
                base_loss.backward()
                nn.utils.clip_grad_norm_(network.parameters(), 5)
                w_optimizer.step()

                ######### logging
                base_prec1, base_prec5 = obtain_accuracy(logits.data, base_targets.data, topk=(1, 5))
                base_losses.update(base_loss.item(), base_inputs.size(0))
                base_top1.update(base_prec1.item(), base_inputs.size(0))
                base_top5.update(base_prec5.item(), base_inputs.size(0))
                batch_time.update(time.time() - end)
                end = time.time()
                if step % print_freq == 0 or step + 1 == len(search_loader):
                    Sstr = ("*Train* "+ time_string()+" Ep:{:} [{:03d}/{:03d}]".format(ep, step, len(search_loader)))
                    Tstr = "Time {batch_time.val:.2f} ({batch_time.avg:.2f}) Data {data_time.val:.2f} ({data_time.avg:.2f})".format(batch_time=batch_time, data_time=data_time)
                    Wstr = "Base [Loss {loss.val:.3f} ({loss.avg:.3f})  Prec@1 {top1.val:.2f} ({top1.avg:.2f}) Prec@5 {top5.val:.2f} ({top5.avg:.2f})]".format(loss=base_losses, top1=base_top1, top5=base_top5)
                    logger.log(Sstr + " " + Tstr + " " + Wstr)

            logger.log("Ep:{:} ends : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%".format(ep, base_losses.avg, base_top1.avg, base_top5.avg))
        ## evaluation
        network.train()
        archs, metric_accs, metric_confidences, metric_sensitivities, metric_robustnesses, metric_step_sims = [], [], [], [], [], []
        loader_iter = iter(valid_loader)
        for search_iter in range(200):
            ###### random gen
            genotypes = []
            for n in range(1, xargs.max_nodes):
                genotypes.append(random.choice(possible_connections[n]))
            arch = Structure(genotypes)
            target_cell.arch_cache = arch
#             arch = target_cell.random_genotype(True)
            ###### measure metrics
            try:
                inputs, targets = next(loader_iter)
            except:
                loader_iter = iter(valid_loader)
                inputs, targets = next(loader_iter)
            inputs, targets = inputs.cuda(non_blocking=True), targets.cuda(non_blocking=True)
            valid_acc, confidence, sensitivity, robustness = acc_confidence_robustness_metrics(network, inputs, targets)
            step_sim = step_sim_metric(network, criterion, inputs, targets)
            archs.append(arch)
            metric_accs.append(valid_acc)
            metric_confidences.append(confidence)
            metric_sensitivities.append(sensitivity)
            metric_robustnesses.append(robustness)
            metric_step_sims.append(step_sim)
        rank_accs, rank_confidences, rank_sensitivities, rank_robustnesses, rank_step_sims = stats.rankdata(metric_accs), stats.rankdata(metric_confidences), stats.rankdata(metric_sensitivities), stats.rankdata(metric_robustnesses), stats.rankdata(metric_step_sims)
        l = len(rank_accs)
        rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l)+np.log(rank_step_sims/l)
#             rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_sensitivities/l)+np.log(rank_step_sims/l)
        best_idx = np.argmax(rank_agg)
        best_arch, best_acc, best_conf, best_sensitivity, best_robust, best_step_sim = archs[best_idx], metric_accs[best_idx], metric_confidences[best_idx], metric_sensitivities[best_idx], metric_robustnesses[best_idx], metric_step_sims[best_idx]
        logger.log("Found best op for target cell:{}".format(target_cell_idx))
        logger.log(": {:} with accuracy={:.2f}%, confidence={:.3f}%, sensitivity={:.3f}, robustness={:.3f}, step_sim={:.3f}".format(best_arch, best_acc, best_conf, best_sensitivity, best_robust, best_step_sim))
        target_cell.arch_cache = best_arch
            
best_archs = []
for c in cells:
    best_archs.append(c.arch_cache)
    
torch.save({"model":search_model.state_dict(), "best_archs":best_archs}, os.path.join(xargs.save_dir, "output.pth"))

for m in search_model.modules():
    if isinstance(m, SearchCell):
        logger.log(m.arch_cache)

logger.close()
# Out:
# total number of nodes:60
# target_node:1 4
# target_node:2 24
# target_node:3 124
#
#
#  Searching with a cell #0
# *Train* [2022-11-07 02:54:00] Ep:0 [000/391] Time 2.97 (2.97) Data 0.15 (0.15) Base [Loss 2.290 (2.290)  Prec@1 12.50 (12.50) Prec@5 57.81 (57.81)]
# *Train* [2022-11-07 02:54:21] Ep:0 [200/391] Time 0.18 (0.12) Data 0.00 (0.00) Base [Loss 1.706 (1.804)  Prec@1 32.81 (31.61) Prec@5 84.38 (84.59)]
# *Train* [2022-11-07 02:54:43] Ep:0 [390/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 1.340 (1.671)  Prec@1 47.50 (37.48) Prec@5 97.50 (87.84)]
# Ep:0 ends : loss=1.67, accuracy@1=37.48%, accuracy@5=87.84%
# *Train* [2022-11-07 02:54:43] Ep:1 [000/391] Time 0.29 (0.29) Data 0.21 (0.21) Base [Loss 2.659 (2.659)  Prec@1 14.06 (14.06) Prec@5 67.19 (67.19)]
# *Train* [2022-11-07 02:55:06] Ep:1 [200/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 1.562 (1.481)  Prec@1 40.62 (45.13) Prec@5 89.06 (92.06)]
# *Train* [2022-11-07 02:55:29] Ep:1 [390/391] Time 0.20 (0.12) Data 0.00 (0.00) Base [Loss 1.349 (1.409)  Prec@1 52.50 (47.88) Prec@5 92.50 (92.92)]
# Ep:1 ends : loss=1.41, accuracy@1=47.88%, accuracy@5=92.92%
# Found best op for target cell:0
# : Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|none~0|nor_conv_3x3~1|none~2|) with accuracy=54.69%, confidence=40.131%, sensitivity=0.006, robustness=-0.010, step_sim=99.890
#
#
#  Searching with a cell #1
# *Train* [2022-11-07 02:58:15] Ep:0 [000/391] Time 0.26 (0.26) Data 0.17 (0.17) Base [Loss 1.902 (1.902)  Prec@1 26.56 (26.56) Prec@5 87.50 (87.50)]
# *Train* [2022-11-07 02:58:33] Ep:0 [200/391] Time 0.13 (0.09) Data 0.00 (0.00) Base [Loss 1.393 (1.341)  Prec@1 40.62 (51.34) Prec@5 93.75 (93.57)]
# *Train* [2022-11-07 02:58:57] Ep:0 [390/391] Time 0.22 (0.11) Data 0.00 (0.00) Base [Loss 1.010 (1.279)  Prec@1 55.00 (53.76) Prec@5 97.50 (94.20)]
# Ep:0 ends : loss=1.28, accuracy@1=53.76%, accuracy@5=94.20%
# *Train* [2022-11-07 02:58:57] Ep:1 [000/391] Time 0.33 (0.33) Data 0.18 (0.18) Base [Loss 3.545 (3.545)  Prec@1 7.81 (7.81) Prec@5 48.44 (48.44)]
# *Train* [2022-11-07 02:59:19] Ep:1 [200/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 1.310 (1.279)  Prec@1 45.31 (54.28) Prec@5 95.31 (94.15)]
# *Train* [2022-11-07 02:59:36] Ep:1 [390/391] Time 0.20 (0.10) Data 0.00 (0.00) Base [Loss 0.997 (1.223)  Prec@1 65.00 (56.42) Prec@5 95.00 (94.81)]
# Ep:1 ends : loss=1.22, accuracy@1=56.42%, accuracy@5=94.81%
# Found best op for target cell:1
# : Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|nor_conv_3x3~1|none~2|) with accuracy=59.57%, confidence=44.432%, sensitivity=0.021, robustness=-0.012, step_sim=99.885
#
#
#  Searching with a cell #2
# *Train* [2022-11-07 03:02:39] Ep:0 [000/391] Time 0.30 (0.30) Data 0.20 (0.20) Base [Loss 2.740 (2.740)  Prec@1 15.62 (15.62) Prec@5 67.19 (67.19)]
# *Train* [2022-11-07 03:03:03] Ep:0 [200/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 1.136 (1.178)  Prec@1 64.06 (58.49) Prec@5 96.88 (95.06)]
# *Train* [2022-11-07 03:03:23] Ep:0 [390/391] Time 0.15 (0.11) Data 0.00 (0.00) Base [Loss 1.414 (1.131)  Prec@1 50.00 (59.70) Prec@5 90.00 (95.67)]
# Ep:0 ends : loss=1.13, accuracy@1=59.70%, accuracy@5=95.67%
# *Train* [2022-11-07 03:03:23] Ep:1 [000/391] Time 0.33 (0.33) Data 0.18 (0.18) Base [Loss 1.441 (1.441)  Prec@1 56.25 (56.25) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 03:03:50] Ep:1 [200/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.992 (1.074)  Prec@1 64.06 (61.74) Prec@5 96.88 (96.31)]
# *Train* [2022-11-07 03:04:16] Ep:1 [390/391] Time 0.21 (0.14) Data 0.00 (0.00) Base [Loss 1.221 (1.058)  Prec@1 60.00 (62.35) Prec@5 100.00 (96.36)]
# Ep:1 ends : loss=1.06, accuracy@1=62.35%, accuracy@5=96.36%
# Found best op for target cell:2
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|skip_connect~0|none~1|none~2|) with accuracy=60.74%, confidence=45.565%, sensitivity=0.081, robustness=-0.013, step_sim=99.938
#
#
#  Searching with a cell #3
# *Train* [2022-11-07 03:07:10] Ep:0 [000/391] Time 0.29 (0.29) Data 0.19 (0.19) Base [Loss 1.682 (1.682)  Prec@1 40.62 (40.62) Prec@5 87.50 (87.50)]
# *Train* [2022-11-07 03:07:32] Ep:0 [200/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 1.150 (1.035)  Prec@1 56.25 (63.45) Prec@5 96.88 (96.22)]
# *Train* [2022-11-07 03:07:48] Ep:0 [390/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.952 (1.008)  Prec@1 60.00 (64.19) Prec@5 95.00 (96.67)]
# Ep:0 ends : loss=1.01, accuracy@1=64.19%, accuracy@5=96.67%
# *Train* [2022-11-07 03:07:49] Ep:1 [000/391] Time 0.28 (0.28) Data 0.20 (0.20) Base [Loss 1.529 (1.529)  Prec@1 50.00 (50.00) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 03:08:08] Ep:1 [200/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 1.058 (0.997)  Prec@1 64.06 (64.39) Prec@5 95.31 (96.70)]
# *Train* [2022-11-07 03:08:24] Ep:1 [390/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 1.281 (0.978)  Prec@1 45.00 (65.24) Prec@5 95.00 (96.96)]
# Ep:1 ends : loss=0.98, accuracy@1=65.24%, accuracy@5=96.96%
# Found best op for target cell:3
# : Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|none~2|) with accuracy=62.03%, confidence=49.195%, sensitivity=0.053, robustness=-0.025, step_sim=99.933
#
#
#  Searching with a cell #4
# *Train* [2022-11-07 03:11:38] Ep:0 [000/391] Time 0.26 (0.26) Data 0.18 (0.18) Base [Loss 1.056 (1.056)  Prec@1 62.50 (62.50) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 03:12:03] Ep:0 [200/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 1.153 (0.978)  Prec@1 59.38 (65.59) Prec@5 95.31 (96.81)]
# *Train* [2022-11-07 03:12:22] Ep:0 [390/391] Time 0.20 (0.11) Data 0.00 (0.00) Base [Loss 1.101 (0.953)  Prec@1 55.00 (66.38) Prec@5 90.00 (97.02)]
# Ep:0 ends : loss=0.95, accuracy@1=66.38%, accuracy@5=97.02%
# *Train* [2022-11-07 03:12:23] Ep:1 [000/391] Time 0.31 (0.31) Data 0.22 (0.22) Base [Loss 2.837 (2.837)  Prec@1 18.75 (18.75) Prec@5 64.06 (64.06)]
# *Train* [2022-11-07 03:12:44] Ep:1 [200/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.975 (0.982)  Prec@1 59.38 (65.28) Prec@5 98.44 (96.88)]
# *Train* [2022-11-07 03:13:05] Ep:1 [390/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 1.013 (0.942)  Prec@1 60.00 (66.57) Prec@5 100.00 (97.12)]
# Ep:1 ends : loss=0.94, accuracy@1=66.57%, accuracy@5=97.12%
# Found best op for target cell:4
# : Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|none~2|) with accuracy=63.87%, confidence=51.554%, sensitivity=0.061, robustness=-0.029, step_sim=99.888
#
#
#  Searching with a cell #5
# *Train* [2022-11-07 03:16:17] Ep:0 [000/391] Time 0.36 (0.36) Data 0.20 (0.20) Base [Loss 1.761 (1.761)  Prec@1 32.81 (32.81) Prec@5 90.62 (90.62)]
# *Train* [2022-11-07 03:16:37] Ep:0 [200/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.959 (0.947)  Prec@1 62.50 (66.50) Prec@5 95.31 (97.19)]
# *Train* [2022-11-07 03:17:02] Ep:0 [390/391] Time 0.15 (0.12) Data 0.00 (0.00) Base [Loss 0.888 (0.923)  Prec@1 72.50 (67.24) Prec@5 100.00 (97.24)]
# Ep:0 ends : loss=0.92, accuracy@1=67.24%, accuracy@5=97.24%
# *Train* [2022-11-07 03:17:03] Ep:1 [000/391] Time 0.26 (0.26) Data 0.18 (0.18) Base [Loss 0.702 (0.702)  Prec@1 78.12 (78.12) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 03:17:24] Ep:1 [200/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 0.739 (0.876)  Prec@1 81.25 (69.12) Prec@5 98.44 (97.57)]
# *Train* [2022-11-07 03:17:40] Ep:1 [390/391] Time 0.13 (0.09) Data 0.00 (0.00) Base [Loss 0.686 (0.863)  Prec@1 77.50 (69.58) Prec@5 100.00 (97.74)]
# Ep:1 ends : loss=0.86, accuracy@1=69.58%, accuracy@5=97.74%
# Found best op for target cell:5
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|avg_pool_3x3~1|none~2|) with accuracy=65.23%, confidence=54.751%, sensitivity=0.085, robustness=-0.031, step_sim=99.912
#
#
#  Searching with a cell #6
# *Train* [2022-11-07 03:20:50] Ep:0 [000/391] Time 0.31 (0.31) Data 0.22 (0.22) Base [Loss 1.271 (1.271)  Prec@1 56.25 (56.25) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 03:21:08] Ep:0 [200/391] Time 0.13 (0.09) Data 0.00 (0.00) Base [Loss 0.665 (0.885)  Prec@1 78.12 (68.84) Prec@5 98.44 (97.50)]
# *Train* [2022-11-07 03:21:33] Ep:0 [390/391] Time 0.22 (0.11) Data 0.00 (0.00) Base [Loss 0.844 (0.867)  Prec@1 72.50 (69.38) Prec@5 95.00 (97.74)]
# Ep:0 ends : loss=0.87, accuracy@1=69.38%, accuracy@5=97.74%
# *Train* [2022-11-07 03:21:33] Ep:1 [000/391] Time 0.33 (0.33) Data 0.23 (0.23) Base [Loss 1.127 (1.127)  Prec@1 59.38 (59.38) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:22:01] Ep:1 [200/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.809 (0.836)  Prec@1 64.06 (70.73) Prec@5 98.44 (97.81)]
# *Train* [2022-11-07 03:22:23] Ep:1 [390/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.618 (0.824)  Prec@1 82.50 (70.96) Prec@5 100.00 (97.86)]
# Ep:1 ends : loss=0.82, accuracy@1=70.96%, accuracy@5=97.86%
# Found best op for target cell:6
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|avg_pool_3x3~1|nor_conv_3x3~2|) with accuracy=63.67%, confidence=52.204%, sensitivity=0.098, robustness=-0.029, step_sim=99.672
#
#
#  Searching with a cell #7
# *Train* [2022-11-07 03:25:38] Ep:0 [000/391] Time 0.28 (0.28) Data 0.18 (0.18) Base [Loss 1.210 (1.210)  Prec@1 54.69 (54.69) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 03:25:59] Ep:0 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.746 (0.831)  Prec@1 71.88 (70.67) Prec@5 100.00 (97.85)]
# *Train* [2022-11-07 03:26:21] Ep:0 [390/391] Time 0.20 (0.11) Data 0.00 (0.00) Base [Loss 0.797 (0.821)  Prec@1 75.00 (71.14) Prec@5 92.50 (97.89)]
# Ep:0 ends : loss=0.82, accuracy@1=71.14%, accuracy@5=97.89%
# *Train* [2022-11-07 03:26:22] Ep:1 [000/391] Time 0.31 (0.31) Data 0.22 (0.22) Base [Loss 3.841 (3.841)  Prec@1 10.94 (10.94) Prec@5 53.12 (53.12)]
# *Train* [2022-11-07 03:26:46] Ep:1 [200/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 1.004 (0.924)  Prec@1 73.44 (67.91) Prec@5 100.00 (97.01)]
# *Train* [2022-11-07 03:27:10] Ep:1 [390/391] Time 0.20 (0.12) Data 0.00 (0.00) Base [Loss 0.601 (0.867)  Prec@1 80.00 (69.80) Prec@5 100.00 (97.47)]
# Ep:1 ends : loss=0.87, accuracy@1=69.80%, accuracy@5=97.47%
# Found best op for target cell:7
# : Structure(4 nodes with |skip_connect~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|) with accuracy=70.12%, confidence=57.229%, sensitivity=0.073, robustness=-0.035, step_sim=99.959
#
#
#  Searching with a cell #8
# *Train* [2022-11-07 03:30:28] Ep:0 [000/391] Time 0.30 (0.30) Data 0.20 (0.20) Base [Loss 1.267 (1.267)  Prec@1 62.50 (62.50) Prec@5 92.19 (92.19)]
# *Train* [2022-11-07 03:30:49] Ep:0 [200/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 0.797 (0.832)  Prec@1 71.88 (70.75) Prec@5 98.44 (97.85)]
# *Train* [2022-11-07 03:31:08] Ep:0 [390/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 0.737 (0.819)  Prec@1 77.50 (71.43) Prec@5 97.50 (97.94)]
# Ep:0 ends : loss=0.82, accuracy@1=71.43%, accuracy@5=97.94%
# *Train* [2022-11-07 03:31:08] Ep:1 [000/391] Time 0.33 (0.33) Data 0.18 (0.18) Base [Loss 0.956 (0.956)  Prec@1 64.06 (64.06) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:31:31] Ep:1 [200/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.591 (0.827)  Prec@1 82.81 (70.61) Prec@5 100.00 (98.05)]
# *Train* [2022-11-07 03:31:50] Ep:1 [390/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.996 (0.801)  Prec@1 70.00 (71.78) Prec@5 97.50 (98.11)]
# Ep:1 ends : loss=0.80, accuracy@1=71.78%, accuracy@5=98.11%
# Found best op for target cell:8
# : Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_3x3~2|) with accuracy=70.90%, confidence=58.720%, sensitivity=0.088, robustness=-0.035, step_sim=99.928
#
#
#  Searching with a cell #9
# *Train* [2022-11-07 03:35:14] Ep:0 [000/391] Time 0.28 (0.28) Data 0.20 (0.20) Base [Loss 0.744 (0.744)  Prec@1 76.56 (76.56) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 03:35:33] Ep:0 [200/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.700 (0.778)  Prec@1 75.00 (72.57) Prec@5 98.44 (98.01)]
# *Train* [2022-11-07 03:35:52] Ep:0 [390/391] Time 0.22 (0.10) Data 0.00 (0.00) Base [Loss 1.010 (0.778)  Prec@1 67.50 (72.78) Prec@5 97.50 (98.09)]
# Ep:0 ends : loss=0.78, accuracy@1=72.78%, accuracy@5=98.09%
# *Train* [2022-11-07 03:35:52] Ep:1 [000/391] Time 0.29 (0.29) Data 0.20 (0.20) Base [Loss 3.142 (3.142)  Prec@1 9.38 (9.38) Prec@5 56.25 (56.25)]
# *Train* [2022-11-07 03:36:15] Ep:1 [200/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.670 (0.872)  Prec@1 81.25 (69.80) Prec@5 100.00 (97.48)]
# *Train* [2022-11-07 03:36:33] Ep:1 [390/391] Time 0.15 (0.11) Data 0.00 (0.00) Base [Loss 0.590 (0.832)  Prec@1 85.00 (71.22) Prec@5 100.00 (97.75)]
# Ep:1 ends : loss=0.83, accuracy@1=71.22%, accuracy@5=97.75%
# Found best op for target cell:9
# : Structure(4 nodes with |nor_conv_1x1~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|) with accuracy=69.73%, confidence=57.217%, sensitivity=0.099, robustness=-0.036, step_sim=99.937
#
#
#  Searching with a cell #10
# *Train* [2022-11-07 03:40:06] Ep:0 [000/391] Time 0.36 (0.36) Data 0.22 (0.22) Base [Loss 0.680 (0.680)  Prec@1 79.69 (79.69) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 03:40:28] Ep:0 [200/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.773 (0.778)  Prec@1 68.75 (72.69) Prec@5 100.00 (98.05)]
# *Train* [2022-11-07 03:40:50] Ep:0 [390/391] Time 0.22 (0.12) Data 0.00 (0.00) Base [Loss 0.741 (0.770)  Prec@1 75.00 (73.03) Prec@5 97.50 (98.06)]
# Ep:0 ends : loss=0.77, accuracy@1=73.03%, accuracy@5=98.06%
# *Train* [2022-11-07 03:40:51] Ep:1 [000/391] Time 0.35 (0.35) Data 0.25 (0.25) Base [Loss 3.190 (3.190)  Prec@1 4.69 (4.69) Prec@5 43.75 (43.75)]
# *Train* [2022-11-07 03:41:08] Ep:1 [200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.532 (0.788)  Prec@1 79.69 (72.26) Prec@5 98.44 (97.78)]
# *Train* [2022-11-07 03:41:29] Ep:1 [390/391] Time 0.15 (0.10) Data 0.00 (0.00) Base [Loss 0.755 (0.770)  Prec@1 72.50 (73.23) Prec@5 100.00 (97.96)]
# Ep:1 ends : loss=0.77, accuracy@1=73.23%, accuracy@5=97.96%
# Found best op for target cell:10
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_3x3~1|+|avg_pool_3x3~0|none~1|none~2|) with accuracy=69.34%, confidence=57.846%, sensitivity=0.075, robustness=-0.043, step_sim=99.956
#
#
#  Searching with a cell #11
# *Train* [2022-11-07 03:44:41] Ep:0 [000/391] Time 0.29 (0.29) Data 0.20 (0.20) Base [Loss 2.955 (2.955)  Prec@1 9.38 (9.38) Prec@5 39.06 (39.06)]
# *Train* [2022-11-07 03:45:00] Ep:0 [200/391] Time 0.14 (0.09) Data 0.00 (0.00) Base [Loss 0.758 (0.843)  Prec@1 76.56 (71.19) Prec@5 95.31 (97.52)]
# *Train* [2022-11-07 03:45:20] Ep:0 [390/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.726 (0.811)  Prec@1 72.50 (72.20) Prec@5 97.50 (97.84)]
# Ep:0 ends : loss=0.81, accuracy@1=72.20%, accuracy@5=97.84%
# *Train* [2022-11-07 03:45:20] Ep:1 [000/391] Time 0.33 (0.33) Data 0.18 (0.18) Base [Loss 0.702 (0.702)  Prec@1 76.56 (76.56) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:45:43] Ep:1 [200/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.635 (0.711)  Prec@1 75.00 (75.30) Prec@5 98.44 (98.59)]
# *Train* [2022-11-07 03:46:02] Ep:1 [390/391] Time 0.14 (0.11) Data 0.00 (0.00) Base [Loss 1.057 (0.714)  Prec@1 60.00 (75.35) Prec@5 95.00 (98.40)]
# Ep:1 ends : loss=0.71, accuracy@1=75.35%, accuracy@5=98.40%
# Found best op for target cell:11
# : Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|) with accuracy=72.66%, confidence=60.831%, sensitivity=0.112, robustness=-0.040, step_sim=99.901
#
#
#  Searching with a cell #12
# *Train* [2022-11-07 03:49:26] Ep:0 [000/391] Time 0.39 (0.39) Data 0.23 (0.23) Base [Loss 0.796 (0.796)  Prec@1 75.00 (75.00) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 03:49:50] Ep:0 [200/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.705 (0.701)  Prec@1 73.44 (76.05) Prec@5 96.88 (98.55)]
# *Train* [2022-11-07 03:50:09] Ep:0 [390/391] Time 0.16 (0.11) Data 0.00 (0.00) Base [Loss 0.486 (0.704)  Prec@1 85.00 (75.79) Prec@5 100.00 (98.52)]
# Ep:0 ends : loss=0.70, accuracy@1=75.79%, accuracy@5=98.52%
# *Train* [2022-11-07 03:50:10] Ep:1 [000/391] Time 0.28 (0.28) Data 0.18 (0.18) Base [Loss 0.492 (0.492)  Prec@1 81.25 (81.25) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 03:50:31] Ep:1 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.692 (0.731)  Prec@1 79.69 (74.57) Prec@5 96.88 (98.44)]
# *Train* [2022-11-07 03:50:54] Ep:1 [390/391] Time 0.20 (0.11) Data 0.00 (0.00) Base [Loss 0.802 (0.712)  Prec@1 75.00 (75.20) Prec@5 100.00 (98.47)]
# Ep:1 ends : loss=0.71, accuracy@1=75.20%, accuracy@5=98.47%
# Found best op for target cell:12
# : Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_3x3~0|skip_connect~1|skip_connect~2|) with accuracy=77.34%, confidence=64.294%, sensitivity=0.092, robustness=-0.042, step_sim=99.973
#
#
#  Searching with a cell #13
# *Train* [2022-11-07 03:54:27] Ep:0 [000/391] Time 0.32 (0.32) Data 0.18 (0.18) Base [Loss 2.433 (2.433)  Prec@1 7.81 (7.81) Prec@5 67.19 (67.19)]
# *Train* [2022-11-07 03:54:54] Ep:0 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.540 (0.751)  Prec@1 85.94 (74.35) Prec@5 100.00 (98.17)]
# *Train* [2022-11-07 03:55:17] Ep:0 [390/391] Time 0.12 (0.13) Data 0.00 (0.00) Base [Loss 0.929 (0.730)  Prec@1 67.50 (75.04) Prec@5 97.50 (98.33)]
# Ep:0 ends : loss=0.73, accuracy@1=75.04%, accuracy@5=98.33%
# *Train* [2022-11-07 03:55:18] Ep:1 [000/391] Time 0.38 (0.38) Data 0.21 (0.21) Base [Loss 0.690 (0.690)  Prec@1 75.00 (75.00) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 03:55:44] Ep:1 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.784 (0.659)  Prec@1 68.75 (76.95) Prec@5 98.44 (98.61)]
# *Train* [2022-11-07 03:56:08] Ep:1 [390/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.861 (0.667)  Prec@1 77.50 (76.78) Prec@5 95.00 (98.54)]
# Ep:1 ends : loss=0.67, accuracy@1=76.78%, accuracy@5=98.54%
# Found best op for target cell:13
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|skip_connect~1|skip_connect~2|) with accuracy=76.95%, confidence=65.024%, sensitivity=0.092, robustness=-0.048, step_sim=99.964
#
#
#  Searching with a cell #14
# *Train* [2022-11-07 03:59:28] Ep:0 [000/391] Time 0.34 (0.34) Data 0.19 (0.19) Base [Loss 2.497 (2.497)  Prec@1 12.50 (12.50) Prec@5 70.31 (70.31)]
# *Train* [2022-11-07 03:59:52] Ep:0 [200/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.779 (0.733)  Prec@1 71.88 (74.44) Prec@5 98.44 (98.10)]
# *Train* [2022-11-07 04:00:17] Ep:0 [390/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.775 (0.718)  Prec@1 72.50 (75.04) Prec@5 95.00 (98.20)]
# Ep:0 ends : loss=0.72, accuracy@1=75.04%, accuracy@5=98.20%
# *Train* [2022-11-07 04:00:17] Ep:1 [000/391] Time 0.33 (0.33) Data 0.18 (0.18) Base [Loss 0.474 (0.474)  Prec@1 82.81 (82.81) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 04:00:41] Ep:1 [200/391] Time 0.15 (0.12) Data 0.00 (0.00) Base [Loss 0.907 (0.653)  Prec@1 67.19 (77.60) Prec@5 96.88 (98.45)]
# *Train* [2022-11-07 04:01:01] Ep:1 [390/391] Time 0.14 (0.11) Data 0.00 (0.00) Base [Loss 0.964 (0.660)  Prec@1 65.00 (77.40) Prec@5 92.50 (98.44)]
# Ep:1 ends : loss=0.66, accuracy@1=77.40%, accuracy@5=98.44%
# Found best op for target cell:14
# : Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|avg_pool_3x3~0|none~1|nor_conv_1x1~2|) with accuracy=75.98%, confidence=64.764%, sensitivity=0.114, robustness=-0.047, step_sim=99.959
#
#
#  Searching with a cell #0
# *Train* [2022-11-07 04:04:33] Ep:0 [000/391] Time 0.30 (0.30) Data 0.21 (0.21) Base [Loss 2.349 (2.349)  Prec@1 18.75 (18.75) Prec@5 84.38 (84.38)]
# *Train* [2022-11-07 04:04:52] Ep:0 [200/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.730 (0.798)  Prec@1 75.00 (72.42) Prec@5 98.44 (97.69)]
# *Train* [2022-11-07 04:05:13] Ep:0 [390/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.791 (0.751)  Prec@1 67.50 (73.95) Prec@5 97.50 (97.97)]
# Ep:0 ends : loss=0.75, accuracy@1=73.95%, accuracy@5=97.97%
# *Train* [2022-11-07 04:05:14] Ep:1 [000/391] Time 0.30 (0.30) Data 0.21 (0.21) Base [Loss 1.342 (1.342)  Prec@1 54.69 (54.69) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 04:05:34] Ep:1 [200/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.624 (0.716)  Prec@1 79.69 (74.98) Prec@5 98.44 (98.37)]
# *Train* [2022-11-07 04:05:56] Ep:1 [390/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 0.698 (0.697)  Prec@1 77.50 (75.73) Prec@5 97.50 (98.51)]
# Ep:1 ends : loss=0.70, accuracy@1=75.73%, accuracy@5=98.51%
# Found best op for target cell:0
# : Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|skip_connect~0|nor_conv_3x3~1|none~2|) with accuracy=68.36%, confidence=60.828%, sensitivity=0.111, robustness=-0.072, step_sim=99.940
#
#
#  Searching with a cell #1
# *Train* [2022-11-07 04:09:24] Ep:0 [000/391] Time 0.36 (0.36) Data 0.19 (0.19) Base [Loss 3.005 (3.005)  Prec@1 23.44 (23.44) Prec@5 68.75 (68.75)]
# *Train* [2022-11-07 04:09:50] Ep:0 [200/391] Time 0.07 (0.13) Data 0.00 (0.00) Base [Loss 0.825 (1.014)  Prec@1 71.88 (65.59) Prec@5 96.88 (96.07)]
# *Train* [2022-11-07 04:10:11] Ep:0 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.648 (0.908)  Prec@1 82.50 (68.78) Prec@5 100.00 (96.95)]
# Ep:0 ends : loss=0.91, accuracy@1=68.78%, accuracy@5=96.95%
# *Train* [2022-11-07 04:10:11] Ep:1 [000/391] Time 0.27 (0.27) Data 0.18 (0.18) Base [Loss 1.686 (1.686)  Prec@1 56.25 (56.25) Prec@5 87.50 (87.50)]
# *Train* [2022-11-07 04:10:36] Ep:1 [200/391] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.892 (0.782)  Prec@1 68.75 (73.17) Prec@5 98.44 (97.96)]
# *Train* [2022-11-07 04:10:59] Ep:1 [390/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.739 (0.754)  Prec@1 70.00 (73.95) Prec@5 97.50 (98.12)]
# Ep:1 ends : loss=0.75, accuracy@1=73.95%, accuracy@5=98.12%
# Found best op for target cell:1
# : Structure(4 nodes with |nor_conv_1x1~0|+|none~0|skip_connect~1|+|skip_connect~0|nor_conv_1x1~1|avg_pool_3x3~2|) with accuracy=66.41%, confidence=58.790%, sensitivity=0.155, robustness=-0.076, step_sim=99.916
#
#
#  Searching with a cell #2
# *Train* [2022-11-07 04:14:12] Ep:0 [000/391] Time 0.33 (0.33) Data 0.18 (0.18) Base [Loss 3.307 (3.307)  Prec@1 15.62 (15.62) Prec@5 65.62 (65.62)]
# *Train* [2022-11-07 04:14:31] Ep:0 [200/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.778 (0.831)  Prec@1 70.31 (71.89) Prec@5 100.00 (97.33)]
# *Train* [2022-11-07 04:14:49] Ep:0 [390/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 1.076 (0.781)  Prec@1 65.00 (73.38) Prec@5 97.50 (97.70)]
# Ep:0 ends : loss=0.78, accuracy@1=73.38%, accuracy@5=97.70%
# *Train* [2022-11-07 04:14:49] Ep:1 [000/391] Time 0.27 (0.27) Data 0.18 (0.18) Base [Loss 1.278 (1.278)  Prec@1 56.25 (56.25) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 04:15:15] Ep:1 [200/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.582 (0.725)  Prec@1 82.81 (74.63) Prec@5 98.44 (98.52)]
# *Train* [2022-11-07 04:15:35] Ep:1 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.380 (0.704)  Prec@1 85.00 (75.50) Prec@5 97.50 (98.45)]
# Ep:1 ends : loss=0.70, accuracy@1=75.50%, accuracy@5=98.45%
# Found best op for target cell:2
# : Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|nor_conv_1x1~0|none~1|none~2|) with accuracy=69.14%, confidence=58.654%, sensitivity=0.178, robustness=-0.096, step_sim=99.857
#
#
#  Searching with a cell #3
# *Train* [2022-11-07 04:19:08] Ep:0 [000/391] Time 0.33 (0.33) Data 0.19 (0.19) Base [Loss 1.761 (1.761)  Prec@1 46.88 (46.88) Prec@5 90.62 (90.62)]
# *Train* [2022-11-07 04:19:34] Ep:0 [200/391] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.841 (0.737)  Prec@1 71.88 (74.20) Prec@5 98.44 (98.30)]
# *Train* [2022-11-07 04:19:52] Ep:0 [390/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.557 (0.724)  Prec@1 82.50 (74.82) Prec@5 97.50 (98.32)]
# Ep:0 ends : loss=0.72, accuracy@1=74.82%, accuracy@5=98.32%
# *Train* [2022-11-07 04:19:52] Ep:1 [000/391] Time 0.34 (0.34) Data 0.23 (0.23) Base [Loss 1.964 (1.964)  Prec@1 42.19 (42.19) Prec@5 89.06 (89.06)]
# *Train* [2022-11-07 04:20:13] Ep:1 [200/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.792 (0.736)  Prec@1 76.56 (74.41) Prec@5 96.88 (98.24)]
# *Train* [2022-11-07 04:20:35] Ep:1 [390/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.749 (0.714)  Prec@1 70.00 (75.11) Prec@5 97.50 (98.33)]
# Ep:1 ends : loss=0.71, accuracy@1=75.11%, accuracy@5=98.33%
# Found best op for target cell:3
# : Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|skip_connect~0|nor_conv_1x1~1|none~2|) with accuracy=71.88%, confidence=62.539%, sensitivity=0.130, robustness=-0.066, step_sim=99.934
#
#
#  Searching with a cell #4
# *Train* [2022-11-07 04:23:55] Ep:0 [000/391] Time 0.29 (0.29) Data 0.18 (0.18) Base [Loss 1.484 (1.484)  Prec@1 51.56 (51.56) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 04:24:16] Ep:0 [200/391] Time 0.21 (0.10) Data 0.00 (0.00) Base [Loss 0.957 (0.790)  Prec@1 70.31 (72.90) Prec@5 96.88 (97.92)]
# *Train* [2022-11-07 04:24:40] Ep:0 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.532 (0.753)  Prec@1 87.50 (74.00) Prec@5 95.00 (98.11)]
# Ep:0 ends : loss=0.75, accuracy@1=74.00%, accuracy@5=98.11%
# *Train* [2022-11-07 04:24:41] Ep:1 [000/391] Time 0.27 (0.27) Data 0.18 (0.18) Base [Loss 1.768 (1.768)  Prec@1 48.44 (48.44) Prec@5 85.94 (85.94)]
# *Train* [2022-11-07 04:25:04] Ep:1 [200/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.580 (0.716)  Prec@1 78.12 (75.01) Prec@5 98.44 (98.23)]
# *Train* [2022-11-07 04:25:25] Ep:1 [390/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.732 (0.710)  Prec@1 70.00 (75.24) Prec@5 100.00 (98.26)]
# Ep:1 ends : loss=0.71, accuracy@1=75.24%, accuracy@5=98.26%
# Found best op for target cell:4
# : Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|none~1|+|skip_connect~0|none~1|none~2|) with accuracy=65.43%, confidence=56.045%, sensitivity=0.173, robustness=-0.105, step_sim=99.852
#
#
#  Searching with a cell #5
# *Train* [2022-11-07 04:28:50] Ep:0 [000/391] Time 0.28 (0.28) Data 0.18 (0.18) Base [Loss 2.863 (2.863)  Prec@1 17.19 (17.19) Prec@5 71.88 (71.88)]
# *Train* [2022-11-07 04:29:12] Ep:0 [200/391] Time 0.08 (0.11) Data 0.00 (0.00) Base [Loss 0.632 (0.812)  Prec@1 82.81 (71.77) Prec@5 96.88 (97.82)]
# *Train* [2022-11-07 04:29:31] Ep:0 [390/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.677 (0.751)  Prec@1 77.50 (74.04) Prec@5 100.00 (98.14)]
# Ep:0 ends : loss=0.75, accuracy@1=74.04%, accuracy@5=98.14%
# *Train* [2022-11-07 04:29:31] Ep:1 [000/391] Time 0.44 (0.44) Data 0.17 (0.17) Base [Loss 3.174 (3.174)  Prec@1 15.62 (15.62) Prec@5 59.38 (59.38)]
# *Train* [2022-11-07 04:29:51] Ep:1 [200/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.614 (0.745)  Prec@1 78.12 (74.47) Prec@5 100.00 (97.99)]
# *Train* [2022-11-07 04:30:14] Ep:1 [390/391] Time 0.08 (0.11) Data 0.00 (0.00) Base [Loss 1.100 (0.724)  Prec@1 65.00 (74.99) Prec@5 97.50 (98.30)]
# Ep:1 ends : loss=0.72, accuracy@1=74.99%, accuracy@5=98.30%
# Found best op for target cell:5
# : Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|none~1|none~2|) with accuracy=69.14%, confidence=58.855%, sensitivity=0.233, robustness=-0.114, step_sim=99.201
#
#
#  Searching with a cell #6
# *Train* [2022-11-07 04:33:28] Ep:0 [000/391] Time 0.29 (0.29) Data 0.18 (0.18) Base [Loss 2.567 (2.567)  Prec@1 28.12 (28.12) Prec@5 79.69 (79.69)]
# *Train* [2022-11-07 04:33:54] Ep:0 [200/391] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.668 (0.746)  Prec@1 78.12 (74.39) Prec@5 96.88 (98.13)]
# *Train* [2022-11-07 04:34:18] Ep:0 [390/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.593 (0.707)  Prec@1 80.00 (75.78) Prec@5 100.00 (98.36)]
# Ep:0 ends : loss=0.71, accuracy@1=75.78%, accuracy@5=98.36%
# *Train* [2022-11-07 04:34:19] Ep:1 [000/391] Time 0.33 (0.33) Data 0.23 (0.23) Base [Loss 0.942 (0.942)  Prec@1 68.75 (68.75) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 04:34:40] Ep:1 [200/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.661 (0.682)  Prec@1 79.69 (76.57) Prec@5 100.00 (98.45)]
# *Train* [2022-11-07 04:35:06] Ep:1 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.760 (0.672)  Prec@1 77.50 (76.84) Prec@5 95.00 (98.52)]
# Ep:1 ends : loss=0.67, accuracy@1=76.84%, accuracy@5=98.52%
# Found best op for target cell:6
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|skip_connect~1|none~2|) with accuracy=72.07%, confidence=63.358%, sensitivity=0.178, robustness=-0.080, step_sim=99.902
#
#
#  Searching with a cell #7
# *Train* [2022-11-07 04:38:25] Ep:0 [000/391] Time 0.28 (0.28) Data 0.17 (0.17) Base [Loss 1.207 (1.207)  Prec@1 62.50 (62.50) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 04:38:46] Ep:0 [200/391] Time 0.14 (0.11) Data 0.00 (0.00) Base [Loss 0.649 (0.680)  Prec@1 76.56 (76.28) Prec@5 100.00 (98.62)]
# *Train* [2022-11-07 04:39:06] Ep:0 [390/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.538 (0.660)  Prec@1 80.00 (76.98) Prec@5 97.50 (98.68)]
# Ep:0 ends : loss=0.66, accuracy@1=76.98%, accuracy@5=98.68%
# *Train* [2022-11-07 04:39:06] Ep:1 [000/391] Time 0.35 (0.35) Data 0.19 (0.19) Base [Loss 1.709 (1.709)  Prec@1 53.12 (53.12) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 04:39:30] Ep:1 [200/391] Time 0.14 (0.12) Data 0.00 (0.00) Base [Loss 0.863 (0.707)  Prec@1 73.44 (75.49) Prec@5 98.44 (98.42)]
# *Train* [2022-11-07 04:39:51] Ep:1 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.643 (0.679)  Prec@1 77.50 (76.28) Prec@5 100.00 (98.58)]
# Ep:1 ends : loss=0.68, accuracy@1=76.28%, accuracy@5=98.58%
# Found best op for target cell:7
# : Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|) with accuracy=70.70%, confidence=62.369%, sensitivity=0.172, robustness=-0.094, step_sim=99.931
#
#
#  Searching with a cell #8
# *Train* [2022-11-07 04:43:12] Ep:0 [000/391] Time 0.33 (0.33) Data 0.24 (0.24) Base [Loss 1.211 (1.211)  Prec@1 62.50 (62.50) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 04:43:38] Ep:0 [200/391] Time 0.10 (0.13) Data 0.00 (0.00) Base [Loss 0.504 (0.670)  Prec@1 84.38 (76.95) Prec@5 98.44 (98.56)]
# *Train* [2022-11-07 04:44:01] Ep:0 [390/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.679 (0.650)  Prec@1 77.50 (77.42) Prec@5 97.50 (98.72)]
# Ep:0 ends : loss=0.65, accuracy@1=77.42%, accuracy@5=98.72%
# *Train* [2022-11-07 04:44:01] Ep:1 [000/391] Time 0.29 (0.29) Data 0.20 (0.20) Base [Loss 2.078 (2.078)  Prec@1 39.06 (39.06) Prec@5 82.81 (82.81)]
# *Train* [2022-11-07 04:44:26] Ep:1 [200/391] Time 0.14 (0.12) Data 0.00 (0.00) Base [Loss 0.542 (0.657)  Prec@1 81.25 (76.87) Prec@5 100.00 (98.56)]
# *Train* [2022-11-07 04:44:46] Ep:1 [390/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.650 (0.636)  Prec@1 80.00 (77.71) Prec@5 95.00 (98.64)]
# Ep:1 ends : loss=0.64, accuracy@1=77.71%, accuracy@5=98.64%
# Found best op for target cell:8
# : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|avg_pool_3x3~1|avg_pool_3x3~2|) with accuracy=74.61%, confidence=65.969%, sensitivity=0.154, robustness=-0.074, step_sim=99.940
#
#
#  Searching with a cell #9
# *Train* [2022-11-07 04:48:29] Ep:0 [000/391] Time 0.29 (0.29) Data 0.19 (0.19) Base [Loss 1.020 (1.020)  Prec@1 64.06 (64.06) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 04:48:51] Ep:0 [200/391] Time 0.14 (0.11) Data 0.00 (0.00) Base [Loss 0.739 (0.644)  Prec@1 71.88 (77.86) Prec@5 98.44 (98.71)]
# *Train* [2022-11-07 04:49:16] Ep:0 [390/391] Time 0.14 (0.12) Data 0.00 (0.00) Base [Loss 0.737 (0.634)  Prec@1 75.00 (78.16) Prec@5 97.50 (98.80)]
# Ep:0 ends : loss=0.63, accuracy@1=78.16%, accuracy@5=98.80%
# *Train* [2022-11-07 04:49:16] Ep:1 [000/391] Time 0.49 (0.49) Data 0.20 (0.20) Base [Loss 4.702 (4.702)  Prec@1 9.38 (9.38) Prec@5 31.25 (31.25)]
# *Train* [2022-11-07 04:49:40] Ep:1 [200/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.645 (0.799)  Prec@1 78.12 (72.95) Prec@5 98.44 (97.75)]
# *Train* [2022-11-07 04:49:58] Ep:1 [390/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 0.837 (0.725)  Prec@1 67.50 (75.11) Prec@5 100.00 (98.16)]
# Ep:1 ends : loss=0.72, accuracy@1=75.11%, accuracy@5=98.16%
# Found best op for target cell:9
# : Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|none~1|+|skip_connect~0|skip_connect~1|none~2|) with accuracy=75.78%, confidence=65.393%, sensitivity=0.109, robustness=-0.049, step_sim=99.967
#
#
#  Searching with a cell #10
# *Train* [2022-11-07 04:53:50] Ep:0 [000/391] Time 0.30 (0.30) Data 0.21 (0.21) Base [Loss 3.568 (3.568)  Prec@1 6.25 (6.25) Prec@5 40.62 (40.62)]
# *Train* [2022-11-07 04:54:13] Ep:0 [200/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.577 (0.692)  Prec@1 78.12 (76.38) Prec@5 100.00 (98.22)]
# *Train* [2022-11-07 04:54:33] Ep:0 [390/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.506 (0.669)  Prec@1 82.50 (76.85) Prec@5 100.00 (98.44)]
# Ep:0 ends : loss=0.67, accuracy@1=76.85%, accuracy@5=98.44%
# *Train* [2022-11-07 04:54:34] Ep:1 [000/391] Time 0.32 (0.32) Data 0.18 (0.18) Base [Loss 0.644 (0.644)  Prec@1 82.81 (82.81) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 04:54:55] Ep:1 [200/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.460 (0.582)  Prec@1 85.94 (79.86) Prec@5 100.00 (98.96)]
# *Train* [2022-11-07 04:55:19] Ep:1 [390/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.366 (0.586)  Prec@1 85.00 (79.84) Prec@5 97.50 (98.89)]
# Ep:1 ends : loss=0.59, accuracy@1=79.84%, accuracy@5=98.89%
# Found best op for target cell:10
# : Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|skip_connect~2|) with accuracy=77.15%, confidence=69.768%, sensitivity=0.139, robustness=-0.065, step_sim=99.937
#
#
#  Searching with a cell #11
# *Train* [2022-11-07 04:58:54] Ep:0 [000/391] Time 0.28 (0.28) Data 0.18 (0.18) Base [Loss 0.620 (0.620)  Prec@1 73.44 (73.44) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 04:59:17] Ep:0 [200/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.488 (0.595)  Prec@1 82.81 (79.59) Prec@5 100.00 (98.82)]
# *Train* [2022-11-07 04:59:41] Ep:0 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.683 (0.596)  Prec@1 72.50 (79.61) Prec@5 100.00 (98.83)]
# Ep:0 ends : loss=0.60, accuracy@1=79.61%, accuracy@5=98.83%
# *Train* [2022-11-07 04:59:42] Ep:1 [000/391] Time 0.40 (0.40) Data 0.21 (0.21) Base [Loss 0.818 (0.818)  Prec@1 67.19 (67.19) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 05:00:03] Ep:1 [200/391] Time 0.15 (0.11) Data 0.00 (0.00) Base [Loss 0.802 (0.630)  Prec@1 70.31 (78.46) Prec@5 95.31 (98.86)]
# *Train* [2022-11-07 05:00:25] Ep:1 [390/391] Time 0.20 (0.11) Data 0.00 (0.00) Base [Loss 0.497 (0.624)  Prec@1 85.00 (78.77) Prec@5 100.00 (98.78)]
# Ep:1 ends : loss=0.62, accuracy@1=78.77%, accuracy@5=98.78%
# Found best op for target cell:11
# : Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|avg_pool_3x3~2|) with accuracy=79.49%, confidence=72.178%, sensitivity=0.120, robustness=-0.056, step_sim=99.961
#
#
#  Searching with a cell #12
# *Train* [2022-11-07 05:03:40] Ep:0 [000/391] Time 0.32 (0.32) Data 0.18 (0.18) Base [Loss 3.008 (3.008)  Prec@1 6.25 (6.25) Prec@5 39.06 (39.06)]
# *Train* [2022-11-07 05:03:57] Ep:0 [200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.711 (0.653)  Prec@1 78.12 (77.88) Prec@5 96.88 (98.17)]
# *Train* [2022-11-07 05:04:14] Ep:0 [390/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.544 (0.635)  Prec@1 87.50 (78.38) Prec@5 95.00 (98.48)]
# Ep:0 ends : loss=0.63, accuracy@1=78.38%, accuracy@5=98.48%
# *Train* [2022-11-07 05:04:14] Ep:1 [000/391] Time 0.32 (0.32) Data 0.18 (0.18) Base [Loss 0.495 (0.495)  Prec@1 82.81 (82.81) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 05:04:36] Ep:1 [200/391] Time 0.14 (0.11) Data 0.00 (0.00) Base [Loss 0.438 (0.569)  Prec@1 79.69 (80.26) Prec@5 100.00 (99.09)]
# *Train* [2022-11-07 05:04:59] Ep:1 [390/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.284 (0.572)  Prec@1 92.50 (80.11) Prec@5 100.00 (99.02)]
# Ep:1 ends : loss=0.57, accuracy@1=80.11%, accuracy@5=99.02%
# Found best op for target cell:12
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|skip_connect~0|avg_pool_3x3~1|avg_pool_3x3~2|) with accuracy=79.69%, confidence=70.843%, sensitivity=0.106, robustness=-0.043, step_sim=99.964
#
#
#  Searching with a cell #13
# *Train* [2022-11-07 05:08:28] Ep:0 [000/391] Time 0.35 (0.35) Data 0.19 (0.19) Base [Loss 1.030 (1.030)  Prec@1 70.31 (70.31) Prec@5 93.75 (93.75)]
# *Train* [2022-11-07 05:08:51] Ep:0 [200/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.480 (0.608)  Prec@1 79.69 (79.71) Prec@5 98.44 (98.78)]
# *Train* [2022-11-07 05:09:11] Ep:0 [390/391] Time 0.12 (0.11) Data 0.00 (0.00) Base [Loss 0.672 (0.613)  Prec@1 75.00 (79.17) Prec@5 97.50 (98.76)]
# Ep:0 ends : loss=0.61, accuracy@1=79.17%, accuracy@5=98.76%
# *Train* [2022-11-07 05:09:11] Ep:1 [000/391] Time 0.37 (0.37) Data 0.23 (0.23) Base [Loss 1.061 (1.061)  Prec@1 67.19 (67.19) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 05:09:34] Ep:1 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.564 (0.600)  Prec@1 78.12 (79.56) Prec@5 100.00 (98.84)]
# *Train* [2022-11-07 05:09:56] Ep:1 [390/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.676 (0.593)  Prec@1 70.00 (79.69) Prec@5 97.50 (98.86)]
# Ep:1 ends : loss=0.59, accuracy@1=79.69%, accuracy@5=98.86%
# Found best op for target cell:13
# : Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|avg_pool_3x3~0|skip_connect~1|avg_pool_3x3~2|) with accuracy=80.47%, confidence=70.425%, sensitivity=0.114, robustness=-0.048, step_sim=99.971
#
#
#  Searching with a cell #14
# *Train* [2022-11-07 05:13:28] Ep:0 [000/391] Time 0.28 (0.28) Data 0.19 (0.19) Base [Loss 0.404 (0.404)  Prec@1 85.94 (85.94) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 05:13:49] Ep:0 [200/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.648 (0.540)  Prec@1 82.81 (81.44) Prec@5 96.88 (99.25)]
# *Train* [2022-11-07 05:14:13] Ep:0 [390/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 0.367 (0.545)  Prec@1 85.00 (81.15) Prec@5 100.00 (99.16)]
# Ep:0 ends : loss=0.54, accuracy@1=81.15%, accuracy@5=99.16%
# *Train* [2022-11-07 05:14:13] Ep:1 [000/391] Time 0.31 (0.31) Data 0.21 (0.21) Base [Loss 0.470 (0.470)  Prec@1 84.38 (84.38) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 05:14:33] Ep:1 [200/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 0.293 (0.541)  Prec@1 89.06 (81.32) Prec@5 100.00 (99.09)]
# *Train* [2022-11-07 05:14:57] Ep:1 [390/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.496 (0.537)  Prec@1 85.00 (81.54) Prec@5 100.00 (99.06)]
# Ep:1 ends : loss=0.54, accuracy@1=81.54%, accuracy@5=99.06%
# Found best op for target cell:14
# : Structure(4 nodes with |skip_connect~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|skip_connect~1|skip_connect~2|) with accuracy=77.83%, confidence=70.670%, sensitivity=0.126, robustness=-0.050, step_sim=99.953
#
#
#  Searching with a cell #0
# *Train* [2022-11-07 05:18:58] Ep:0 [000/391] Time 0.35 (0.35) Data 0.24 (0.24) Base [Loss 2.182 (2.182)  Prec@1 40.62 (40.62) Prec@5 82.81 (82.81)]
# *Train* [2022-11-07 05:19:20] Ep:0 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.811 (0.649)  Prec@1 67.19 (77.69) Prec@5 98.44 (98.59)]
# *Train* [2022-11-07 05:19:46] Ep:0 [390/391] Time 0.21 (0.12) Data 0.00 (0.00) Base [Loss 0.543 (0.607)  Prec@1 80.00 (79.06) Prec@5 100.00 (98.78)]
# Ep:0 ends : loss=0.61, accuracy@1=79.06%, accuracy@5=98.78%
# *Train* [2022-11-07 05:19:46] Ep:1 [000/391] Time 0.32 (0.32) Data 0.22 (0.22) Base [Loss 2.114 (2.114)  Prec@1 37.50 (37.50) Prec@5 92.19 (92.19)]
# *Train* [2022-11-07 05:20:10] Ep:1 [200/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.559 (0.665)  Prec@1 85.94 (77.25) Prec@5 96.88 (98.64)]
# *Train* [2022-11-07 05:20:32] Ep:1 [390/391] Time 0.22 (0.12) Data 0.00 (0.00) Base [Loss 0.748 (0.632)  Prec@1 77.50 (78.32) Prec@5 97.50 (98.75)]
# Ep:1 ends : loss=0.63, accuracy@1=78.32%, accuracy@5=98.75%
# Found best op for target cell:0
# : Structure(4 nodes with |skip_connect~0|+|none~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|none~2|) with accuracy=79.49%, confidence=70.076%, sensitivity=0.138, robustness=-0.074, step_sim=99.938
#
#
#  Searching with a cell #1
# *Train* [2022-11-07 05:24:32] Ep:0 [000/391] Time 0.31 (0.31) Data 0.21 (0.21) Base [Loss 0.963 (0.963)  Prec@1 65.62 (65.62) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 05:24:55] Ep:0 [200/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.696 (0.591)  Prec@1 71.88 (79.50) Prec@5 100.00 (98.90)]
# *Train* [2022-11-07 05:25:18] Ep:0 [390/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.967 (0.584)  Prec@1 67.50 (79.80) Prec@5 97.50 (98.94)]
# Ep:0 ends : loss=0.58, accuracy@1=79.80%, accuracy@5=98.94%
# *Train* [2022-11-07 05:25:18] Ep:1 [000/391] Time 0.29 (0.29) Data 0.20 (0.20) Base [Loss 0.951 (0.951)  Prec@1 67.19 (67.19) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 05:25:43] Ep:1 [200/391] Time 0.12 (0.13) Data 0.00 (0.00) Base [Loss 0.508 (0.596)  Prec@1 76.56 (79.25) Prec@5 100.00 (99.04)]
# *Train* [2022-11-07 05:26:07] Ep:1 [390/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.552 (0.572)  Prec@1 75.00 (80.21) Prec@5 97.50 (99.00)]
# Ep:1 ends : loss=0.57, accuracy@1=80.21%, accuracy@5=99.00%
# Found best op for target cell:1
# : Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|avg_pool_3x3~0|nor_conv_1x1~1|nor_conv_1x1~2|) with accuracy=76.76%, confidence=68.367%, sensitivity=0.164, robustness=-0.110, step_sim=99.909
#
#
#  Searching with a cell #2
# *Train* [2022-11-07 05:30:22] Ep:0 [000/391] Time 0.26 (0.26) Data 0.17 (0.17) Base [Loss 1.986 (1.986)  Prec@1 48.44 (48.44) Prec@5 87.50 (87.50)]
# *Train* [2022-11-07 05:30:47] Ep:0 [200/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.403 (0.646)  Prec@1 89.06 (77.74) Prec@5 98.44 (98.74)]
# *Train* [2022-11-07 05:31:07] Ep:0 [390/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.789 (0.607)  Prec@1 77.50 (79.02) Prec@5 92.50 (98.78)]
# Ep:0 ends : loss=0.61, accuracy@1=79.02%, accuracy@5=98.78%
# *Train* [2022-11-07 05:31:07] Ep:1 [000/391] Time 0.29 (0.29) Data 0.18 (0.18) Base [Loss 1.882 (1.882)  Prec@1 42.19 (42.19) Prec@5 90.62 (90.62)]
# *Train* [2022-11-07 05:31:31] Ep:1 [200/391] Time 0.11 (0.12) Data 0.00 (0.00) Base [Loss 0.589 (0.595)  Prec@1 78.12 (79.21) Prec@5 100.00 (98.88)]
# *Train* [2022-11-07 05:31:52] Ep:1 [390/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.380 (0.579)  Prec@1 82.50 (79.82) Prec@5 100.00 (98.94)]
# Ep:1 ends : loss=0.58, accuracy@1=79.82%, accuracy@5=98.94%
# Found best op for target cell:2
# : Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|avg_pool_3x3~1|+|nor_conv_1x1~0|none~1|none~2|) with accuracy=75.39%, confidence=67.021%, sensitivity=0.220, robustness=-0.072, step_sim=99.881
#
#
#  Searching with a cell #3
# *Train* [2022-11-07 05:36:13] Ep:0 [000/391] Time 0.28 (0.28) Data 0.17 (0.17) Base [Loss 1.910 (1.910)  Prec@1 53.12 (53.12) Prec@5 90.62 (90.62)]
# *Train* [2022-11-07 05:36:35] Ep:0 [200/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.799 (0.645)  Prec@1 78.12 (77.77) Prec@5 98.44 (98.65)]
# *Train* [2022-11-07 05:36:57] Ep:0 [390/391] Time 0.10 (0.11) Data 0.00 (0.00) Base [Loss 0.303 (0.615)  Prec@1 85.00 (78.81) Prec@5 100.00 (98.82)]
# Ep:0 ends : loss=0.61, accuracy@1=78.81%, accuracy@5=98.82%
# *Train* [2022-11-07 05:36:58] Ep:1 [000/391] Time 0.37 (0.37) Data 0.20 (0.20) Base [Loss 3.111 (3.111)  Prec@1 20.31 (20.31) Prec@5 73.44 (73.44)]
# *Train* [2022-11-07 05:37:24] Ep:1 [200/391] Time 0.15 (0.13) Data 0.00 (0.00) Base [Loss 0.724 (0.663)  Prec@1 75.00 (77.33) Prec@5 100.00 (98.58)]
# *Train* [2022-11-07 05:37:49] Ep:1 [390/391] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.477 (0.635)  Prec@1 80.00 (78.26) Prec@5 100.00 (98.70)]
# Ep:1 ends : loss=0.63, accuracy@1=78.26%, accuracy@5=98.70%
# Found best op for target cell:3
# : Structure(4 nodes with |avg_pool_3x3~0|+|none~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|none~2|) with accuracy=71.68%, confidence=62.964%, sensitivity=0.243, robustness=-0.079, step_sim=99.830
#
#
#  Searching with a cell #4
# *Train* [2022-11-07 05:42:14] Ep:0 [000/391] Time 0.31 (0.31) Data 0.20 (0.20) Base [Loss 1.267 (1.267)  Prec@1 50.00 (50.00) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 05:42:40] Ep:0 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.518 (0.625)  Prec@1 81.25 (78.30) Prec@5 96.88 (98.67)]
# *Train* [2022-11-07 05:43:04] Ep:0 [390/391] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.570 (0.607)  Prec@1 87.50 (78.78) Prec@5 95.00 (98.74)]
# Ep:0 ends : loss=0.61, accuracy@1=78.78%, accuracy@5=98.74%
# *Train* [2022-11-07 05:43:04] Ep:1 [000/391] Time 0.31 (0.31) Data 0.20 (0.20) Base [Loss 0.896 (0.896)  Prec@1 78.12 (78.12) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 05:43:27] Ep:1 [200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.534 (0.586)  Prec@1 79.69 (79.59) Prec@5 98.44 (98.95)]
# *Train* [2022-11-07 05:43:49] Ep:1 [390/391] Time 0.16 (0.11) Data 0.00 (0.00) Base [Loss 0.886 (0.582)  Prec@1 72.50 (79.86) Prec@5 95.00 (98.94)]
# Ep:1 ends : loss=0.58, accuracy@1=79.86%, accuracy@5=98.94%
# Found best op for target cell:4
# : Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|none~1|+|nor_conv_3x3~0|skip_connect~1|none~2|) with accuracy=68.75%, confidence=60.955%, sensitivity=0.157, robustness=-0.067, step_sim=99.867
#
#
#  Searching with a cell #5
# *Train* [2022-11-07 05:48:02] Ep:0 [000/391] Time 0.37 (0.37) Data 0.20 (0.20) Base [Loss 2.440 (2.440)  Prec@1 37.50 (37.50) Prec@5 78.12 (78.12)]
# *Train* [2022-11-07 05:48:29] Ep:0 [200/391] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.572 (0.731)  Prec@1 78.12 (75.05) Prec@5 98.44 (98.11)]
# *Train* [2022-11-07 05:48:54] Ep:0 [390/391] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.747 (0.679)  Prec@1 75.00 (76.70) Prec@5 97.50 (98.43)]
# Ep:0 ends : loss=0.68, accuracy@1=76.70%, accuracy@5=98.43%
# *Train* [2022-11-07 05:48:54] Ep:1 [000/391] Time 0.33 (0.33) Data 0.21 (0.21) Base [Loss 2.188 (2.188)  Prec@1 31.25 (31.25) Prec@5 81.25 (81.25)]
# *Train* [2022-11-07 05:49:20] Ep:1 [200/391] Time 0.11 (0.13) Data 0.00 (0.00) Base [Loss 0.599 (0.620)  Prec@1 75.00 (78.34) Prec@5 100.00 (98.83)]
# *Train* [2022-11-07 05:49:43] Ep:1 [390/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.886 (0.598)  Prec@1 72.50 (79.40) Prec@5 97.50 (98.88)]
# Ep:1 ends : loss=0.60, accuracy@1=79.40%, accuracy@5=98.88%
# Found best op for target cell:5
# : Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|none~0|nor_conv_1x1~1|avg_pool_3x3~2|) with accuracy=70.51%, confidence=60.786%, sensitivity=0.168, robustness=-0.060, step_sim=99.948
#
#
#  Searching with a cell #6
# *Train* [2022-11-07 05:54:04] Ep:0 [000/391] Time 0.32 (0.32) Data 0.24 (0.24) Base [Loss 4.176 (4.176)  Prec@1 6.25 (6.25) Prec@5 48.44 (48.44)]
# *Train* [2022-11-07 05:54:27] Ep:0 [200/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.563 (0.778)  Prec@1 78.12 (73.60) Prec@5 98.44 (97.79)]
# *Train* [2022-11-07 05:54:52] Ep:0 [390/391] Time 0.07 (0.12) Data 0.00 (0.00) Base [Loss 0.557 (0.701)  Prec@1 82.50 (75.75) Prec@5 100.00 (98.25)]
# Ep:0 ends : loss=0.70, accuracy@1=75.75%, accuracy@5=98.25%
# *Train* [2022-11-07 05:54:52] Ep:1 [000/391] Time 0.27 (0.27) Data 0.18 (0.18) Base [Loss 4.499 (4.499)  Prec@1 3.12 (3.12) Prec@5 43.75 (43.75)]
# *Train* [2022-11-07 05:55:17] Ep:1 [200/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.523 (0.749)  Prec@1 87.50 (74.49) Prec@5 98.44 (98.03)]
# *Train* [2022-11-07 05:55:41] Ep:1 [390/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.642 (0.689)  Prec@1 75.00 (76.20) Prec@5 100.00 (98.42)]
# Ep:1 ends : loss=0.69, accuracy@1=76.20%, accuracy@5=98.42%
# Found best op for target cell:6
# : Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|none~0|skip_connect~1|nor_conv_3x3~2|) with accuracy=70.12%, confidence=60.301%, sensitivity=0.175, robustness=-0.061, step_sim=99.941
#
#
#  Searching with a cell #7
# *Train* [2022-11-07 05:59:46] Ep:0 [000/391] Time 0.29 (0.29) Data 0.19 (0.19) Base [Loss 1.207 (1.207)  Prec@1 56.25 (56.25) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 06:00:14] Ep:0 [200/391] Time 0.23 (0.14) Data 0.00 (0.00) Base [Loss 0.492 (0.664)  Prec@1 82.81 (76.59) Prec@5 96.88 (98.61)]
# *Train* [2022-11-07 06:00:37] Ep:0 [390/391] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.557 (0.656)  Prec@1 82.50 (76.96) Prec@5 97.50 (98.62)]
# Ep:0 ends : loss=0.66, accuracy@1=76.96%, accuracy@5=98.62%
# ...
# Found best op for target cell:3
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|none~2|) with accuracy=72.66%, confidence=64.682%, sensitivity=0.212, robustness=-0.074, step_sim=99.924
#
#
#  Searching with a cell #4
# *Train* [2022-11-07 08:39:15] Ep:0 [000/391] Time 0.36 (0.36) Data 0.21 (0.21) Base [Loss 3.036 (3.036)  Prec@1 29.69 (29.69) Prec@5 73.44 (73.44)]
# *Train* [2022-11-07 08:39:41] Ep:0 [200/391] Time 0.10 (0.13) Data 0.00 (0.00) Base [Loss 0.403 (0.540)  Prec@1 84.38 (81.63) Prec@5 100.00 (99.02)]
# *Train* [2022-11-07 08:40:07] Ep:0 [390/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.252 (0.514)  Prec@1 92.50 (82.28) Prec@5 100.00 (99.18)]
# Ep:0 ends : loss=0.51, accuracy@1=82.28%, accuracy@5=99.18%
# *Train* [2022-11-07 08:40:07] Ep:1 [000/391] Time 0.35 (0.35) Data 0.18 (0.18) Base [Loss 1.061 (1.061)  Prec@1 64.06 (64.06) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 08:40:31] Ep:1 [200/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.329 (0.556)  Prec@1 89.06 (81.18) Prec@5 100.00 (98.90)]
# *Train* [2022-11-07 08:40:54] Ep:1 [390/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.300 (0.523)  Prec@1 85.00 (81.99) Prec@5 100.00 (99.02)]
# Ep:1 ends : loss=0.52, accuracy@1=81.99%, accuracy@5=99.02%
# Found best op for target cell:4
# : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_1x1~1|none~2|) with accuracy=78.12%, confidence=71.532%, sensitivity=0.214, robustness=-0.041, step_sim=99.923
#
#
#  Searching with a cell #5
# *Train* [2022-11-07 08:45:25] Ep:0 [000/391] Time 0.36 (0.36) Data 0.21 (0.21) Base [Loss 2.265 (2.265)  Prec@1 42.19 (42.19) Prec@5 81.25 (81.25)]
# *Train* [2022-11-07 08:45:51] Ep:0 [200/391] Time 0.15 (0.13) Data 0.00 (0.00) Base [Loss 0.476 (0.741)  Prec@1 84.38 (74.72) Prec@5 98.44 (98.19)]
# *Train* [2022-11-07 08:46:16] Ep:0 [390/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.592 (0.664)  Prec@1 82.50 (77.11) Prec@5 100.00 (98.51)]
# Ep:0 ends : loss=0.66, accuracy@1=77.11%, accuracy@5=98.51%
# *Train* [2022-11-07 08:46:17] Ep:1 [000/391] Time 0.34 (0.34) Data 0.22 (0.22) Base [Loss 0.960 (0.960)  Prec@1 65.62 (65.62) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 08:46:41] Ep:1 [200/391] Time 0.16 (0.12) Data 0.00 (0.00) Base [Loss 0.429 (0.549)  Prec@1 84.38 (81.09) Prec@5 100.00 (99.06)]
# *Train* [2022-11-07 08:47:07] Ep:1 [390/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.799 (0.527)  Prec@1 75.00 (81.82) Prec@5 100.00 (99.14)]
# Ep:1 ends : loss=0.53, accuracy@1=81.82%, accuracy@5=99.14%
# Found best op for target cell:5
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|) with accuracy=75.39%, confidence=65.527%, sensitivity=0.180, robustness=-0.070, step_sim=99.877
#
#
#  Searching with a cell #6
# *Train* [2022-11-07 08:51:33] Ep:0 [000/391] Time 0.36 (0.36) Data 0.19 (0.19) Base [Loss 0.642 (0.642)  Prec@1 76.56 (76.56) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 08:51:59] Ep:0 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.717 (0.540)  Prec@1 78.12 (81.34) Prec@5 95.31 (99.11)]
# *Train* [2022-11-07 08:52:21] Ep:0 [390/391] Time 0.10 (0.12) Data 0.00 (0.00) Base [Loss 0.414 (0.520)  Prec@1 85.00 (81.84) Prec@5 100.00 (99.13)]
# Ep:0 ends : loss=0.52, accuracy@1=81.84%, accuracy@5=99.13%
# *Train* [2022-11-07 08:52:21] Ep:1 [000/391] Time 0.45 (0.45) Data 0.24 (0.24) Base [Loss 0.998 (0.998)  Prec@1 70.31 (70.31) Prec@5 95.31 (95.31)]
# *Train* [2022-11-07 08:52:50] Ep:1 [200/391] Time 0.15 (0.15) Data 0.00 (0.00) Base [Loss 0.458 (0.587)  Prec@1 87.50 (79.80) Prec@5 98.44 (98.95)]
# *Train* [2022-11-07 08:53:15] Ep:1 [390/391] Time 0.11 (0.14) Data 0.00 (0.00) Base [Loss 0.728 (0.558)  Prec@1 82.50 (80.79) Prec@5 100.00 (99.00)]
# Ep:1 ends : loss=0.56, accuracy@1=80.79%, accuracy@5=99.00%
# Found best op for target cell:6
# : Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|skip_connect~2|) with accuracy=73.24%, confidence=65.147%, sensitivity=0.155, robustness=-0.057, step_sim=99.907
#
#
#  Searching with a cell #7
# *Train* [2022-11-07 08:57:47] Ep:0 [000/391] Time 0.29 (0.29) Data 0.19 (0.19) Base [Loss 4.475 (4.475)  Prec@1 6.25 (6.25) Prec@5 42.19 (42.19)]
# *Train* [2022-11-07 08:58:13] Ep:0 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.653 (0.650)  Prec@1 68.75 (77.78) Prec@5 100.00 (98.46)]
# *Train* [2022-11-07 08:58:37] Ep:0 [390/391] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.418 (0.605)  Prec@1 85.00 (79.21) Prec@5 100.00 (98.75)]
# Ep:0 ends : loss=0.61, accuracy@1=79.21%, accuracy@5=98.75%
# *Train* [2022-11-07 08:58:38] Ep:1 [000/391] Time 0.30 (0.30) Data 0.18 (0.18) Base [Loss 0.460 (0.460)  Prec@1 85.94 (85.94) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 08:59:02] Ep:1 [200/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.371 (0.528)  Prec@1 85.94 (82.09) Prec@5 100.00 (99.28)]
# *Train* [2022-11-07 08:59:28] Ep:1 [390/391] Time 0.22 (0.13) Data 0.00 (0.00) Base [Loss 0.552 (0.519)  Prec@1 72.50 (82.10) Prec@5 100.00 (99.26)]
# Ep:1 ends : loss=0.52, accuracy@1=82.10%, accuracy@5=99.26%
# Found best op for target cell:7
# : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|none~0|avg_pool_3x3~1|skip_connect~2|) with accuracy=78.71%, confidence=70.447%, sensitivity=0.120, robustness=-0.045, step_sim=99.942
#
#
#  Searching with a cell #8
# *Train* [2022-11-07 09:04:11] Ep:0 [000/391] Time 0.32 (0.32) Data 0.23 (0.23) Base [Loss 1.159 (1.159)  Prec@1 56.25 (56.25) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 09:04:37] Ep:0 [200/391] Time 0.15 (0.13) Data 0.00 (0.00) Base [Loss 0.632 (0.628)  Prec@1 76.56 (78.29) Prec@5 100.00 (98.82)]
# *Train* [2022-11-07 09:05:03] Ep:0 [390/391] Time 0.10 (0.13) Data 0.00 (0.00) Base [Loss 0.564 (0.585)  Prec@1 75.00 (79.85) Prec@5 100.00 (98.98)]
# Ep:0 ends : loss=0.59, accuracy@1=79.85%, accuracy@5=98.98%
# *Train* [2022-11-07 09:05:03] Ep:1 [000/391] Time 0.43 (0.43) Data 0.21 (0.21) Base [Loss 0.489 (0.489)  Prec@1 81.25 (81.25) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 09:05:25] Ep:1 [200/391] Time 0.21 (0.11) Data 0.00 (0.00) Base [Loss 0.540 (0.544)  Prec@1 84.38 (80.81) Prec@5 98.44 (99.16)]
# *Train* [2022-11-07 09:05:48] Ep:1 [390/391] Time 0.14 (0.12) Data 0.00 (0.00) Base [Loss 0.696 (0.545)  Prec@1 75.00 (81.01) Prec@5 97.50 (99.09)]
# Ep:1 ends : loss=0.54, accuracy@1=81.01%, accuracy@5=99.09%
# Found best op for target cell:8
# : Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|skip_connect~2|) with accuracy=75.20%, confidence=64.991%, sensitivity=0.159, robustness=-0.027, step_sim=99.938
#
#
#  Searching with a cell #9
# *Train* [2022-11-07 09:10:21] Ep:0 [000/391] Time 0.29 (0.29) Data 0.19 (0.19) Base [Loss 0.757 (0.757)  Prec@1 82.81 (82.81) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 09:10:44] Ep:0 [200/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.609 (0.538)  Prec@1 78.12 (81.18) Prec@5 100.00 (99.25)]
# *Train* [2022-11-07 09:11:09] Ep:0 [390/391] Time 0.15 (0.12) Data 0.00 (0.00) Base [Loss 0.400 (0.532)  Prec@1 90.00 (81.56) Prec@5 100.00 (99.22)]
# Ep:0 ends : loss=0.53, accuracy@1=81.56%, accuracy@5=99.22%
# *Train* [2022-11-07 09:11:10] Ep:1 [000/391] Time 0.39 (0.39) Data 0.23 (0.23) Base [Loss 0.560 (0.560)  Prec@1 85.94 (85.94) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 09:11:36] Ep:1 [200/391] Time 0.23 (0.13) Data 0.00 (0.00) Base [Loss 0.436 (0.526)  Prec@1 87.50 (81.85) Prec@5 98.44 (99.18)]
# *Train* [2022-11-07 09:11:59] Ep:1 [390/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.546 (0.527)  Prec@1 82.50 (81.97) Prec@5 100.00 (99.09)]
# Ep:1 ends : loss=0.53, accuracy@1=81.97%, accuracy@5=99.09%
# Found best op for target cell:9
# : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|none~2|) with accuracy=76.76%, confidence=69.868%, sensitivity=0.181, robustness=-0.065, step_sim=99.841
#
#
#  Searching with a cell #10
# *Train* [2022-11-07 09:16:23] Ep:0 [000/391] Time 0.35 (0.35) Data 0.23 (0.23) Base [Loss 0.755 (0.755)  Prec@1 78.12 (78.12) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 09:16:48] Ep:0 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.431 (0.573)  Prec@1 84.38 (80.60) Prec@5 98.44 (98.99)]
# *Train* [2022-11-07 09:17:11] Ep:0 [390/391] Time 0.10 (0.12) Data 0.00 (0.00) Base [Loss 0.493 (0.561)  Prec@1 87.50 (80.77) Prec@5 97.50 (98.99)]
# Ep:0 ends : loss=0.56, accuracy@1=80.77%, accuracy@5=98.99%
# *Train* [2022-11-07 09:17:11] Ep:1 [000/391] Time 0.34 (0.34) Data 0.19 (0.19) Base [Loss 0.999 (0.999)  Prec@1 68.75 (68.75) Prec@5 96.88 (96.88)]
# *Train* [2022-11-07 09:17:36] Ep:1 [200/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.336 (0.527)  Prec@1 85.94 (81.66) Prec@5 100.00 (99.21)]
# *Train* [2022-11-07 09:18:00] Ep:1 [390/391] Time 0.16 (0.13) Data 0.00 (0.00) Base [Loss 0.646 (0.514)  Prec@1 77.50 (82.16) Prec@5 97.50 (99.18)]
# Ep:1 ends : loss=0.51, accuracy@1=82.16%, accuracy@5=99.18%
# Found best op for target cell:10
# : Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|) with accuracy=77.34%, confidence=71.567%, sensitivity=0.150, robustness=-0.045, step_sim=99.872
#
#
#  Searching with a cell #11
# *Train* [2022-11-07 09:22:27] Ep:0 [000/391] Time 0.33 (0.33) Data 0.21 (0.21) Base [Loss 0.583 (0.583)  Prec@1 73.44 (73.44) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 09:22:51] Ep:0 [200/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.528 (0.569)  Prec@1 79.69 (80.25) Prec@5 95.31 (98.98)]
# *Train* [2022-11-07 09:23:17] Ep:0 [390/391] Time 0.22 (0.13) Data 0.00 (0.00) Base [Loss 0.506 (0.555)  Prec@1 85.00 (80.84) Prec@5 97.50 (98.94)]
# Ep:0 ends : loss=0.55, accuracy@1=80.84%, accuracy@5=98.94%
# *Train* [2022-11-07 09:23:17] Ep:1 [000/391] Time 0.35 (0.35) Data 0.24 (0.24) Base [Loss 0.636 (0.636)  Prec@1 76.56 (76.56) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 09:23:42] Ep:1 [200/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.545 (0.526)  Prec@1 79.69 (82.00) Prec@5 100.00 (99.17)]
# *Train* [2022-11-07 09:24:07] Ep:1 [390/391] Time 0.22 (0.13) Data 0.00 (0.00) Base [Loss 0.619 (0.518)  Prec@1 77.50 (82.18) Prec@5 100.00 (99.13)]
# Ep:1 ends : loss=0.52, accuracy@1=82.18%, accuracy@5=99.13%
# Found best op for target cell:11
# : Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|none~2|) with accuracy=77.93%, confidence=69.936%, sensitivity=0.140, robustness=-0.055, step_sim=99.909
#
#
#  Searching with a cell #12
# *Train* [2022-11-07 09:28:34] Ep:0 [000/391] Time 0.34 (0.34) Data 0.18 (0.18) Base [Loss 0.452 (0.452)  Prec@1 82.81 (82.81) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 09:28:58] Ep:0 [200/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 0.541 (0.540)  Prec@1 84.38 (81.41) Prec@5 100.00 (99.16)]
# *Train* [2022-11-07 09:29:22] Ep:0 [390/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.333 (0.523)  Prec@1 92.50 (82.00) Prec@5 97.50 (99.20)]
# Ep:0 ends : loss=0.52, accuracy@1=82.00%, accuracy@5=99.20%
# *Train* [2022-11-07 09:29:22] Ep:1 [000/391] Time 0.32 (0.32) Data 0.21 (0.21) Base [Loss 0.315 (0.315)  Prec@1 90.62 (90.62) Prec@5 98.44 (98.44)]
# *Train* [2022-11-07 09:29:48] Ep:1 [200/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.480 (0.510)  Prec@1 79.69 (82.10) Prec@5 100.00 (99.18)]
# *Train* [2022-11-07 09:30:12] Ep:1 [390/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.299 (0.507)  Prec@1 87.50 (82.37) Prec@5 100.00 (99.20)]
# Ep:1 ends : loss=0.51, accuracy@1=82.37%, accuracy@5=99.20%
# Found best op for target cell:12
# : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|none~1|skip_connect~2|) with accuracy=78.91%, confidence=69.430%, sensitivity=0.188, robustness=-0.049, step_sim=99.917
#
#
#  Searching with a cell #13
# *Train* [2022-11-07 09:34:29] Ep:0 [000/391] Time 0.30 (0.30) Data 0.21 (0.21) Base [Loss 0.357 (0.357)  Prec@1 89.06 (89.06) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 09:34:55] Ep:0 [200/391] Time 0.15 (0.13) Data 0.00 (0.00) Base [Loss 0.625 (0.484)  Prec@1 79.69 (83.75) Prec@5 98.44 (99.34)]
# *Train* [2022-11-07 09:35:20] Ep:0 [390/391] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.414 (0.492)  Prec@1 87.50 (83.32) Prec@5 100.00 (99.21)]
# Ep:0 ends : loss=0.49, accuracy@1=83.32%, accuracy@5=99.21%
# *Train* [2022-11-07 09:35:20] Ep:1 [000/391] Time 0.30 (0.30) Data 0.21 (0.21) Base [Loss 0.504 (0.504)  Prec@1 78.12 (78.12) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 09:35:46] Ep:1 [200/391] Time 0.18 (0.13) Data 0.00 (0.00) Base [Loss 0.504 (0.484)  Prec@1 82.81 (83.48) Prec@5 100.00 (99.21)]
# *Train* [2022-11-07 09:36:11] Ep:1 [390/391] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.373 (0.480)  Prec@1 85.00 (83.55) Prec@5 100.00 (99.23)]
# Ep:1 ends : loss=0.48, accuracy@1=83.55%, accuracy@5=99.23%
# Found best op for target cell:13
# : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|) with accuracy=79.88%, confidence=71.954%, sensitivity=0.151, robustness=-0.057, step_sim=99.903
#
#
#  Searching with a cell #14
# *Train* [2022-11-07 09:40:28] Ep:0 [000/391] Time 0.38 (0.38) Data 0.23 (0.23) Base [Loss 3.321 (3.321)  Prec@1 25.00 (25.00) Prec@5 60.94 (60.94)]
# *Train* [2022-11-07 09:40:53] Ep:0 [200/391] Time 0.17 (0.13) Data 0.00 (0.00) Base [Loss 0.595 (0.545)  Prec@1 78.12 (81.46) Prec@5 100.00 (98.90)]
# *Train* [2022-11-07 09:41:15] Ep:0 [390/391] Time 0.22 (0.12) Data 0.00 (0.00) Base [Loss 0.690 (0.534)  Prec@1 80.00 (81.82) Prec@5 100.00 (98.96)]
# Ep:0 ends : loss=0.53, accuracy@1=81.82%, accuracy@5=98.96%
# *Train* [2022-11-07 09:41:16] Ep:1 [000/391] Time 0.33 (0.33) Data 0.18 (0.18) Base [Loss 0.480 (0.480)  Prec@1 81.25 (81.25) Prec@5 100.00 (100.00)]
# *Train* [2022-11-07 09:41:42] Ep:1 [200/391] Time 0.15 (0.13) Data 0.00 (0.00) Base [Loss 0.327 (0.526)  Prec@1 84.38 (82.18) Prec@5 100.00 (99.06)]
# *Train* [2022-11-07 09:42:07] Ep:1 [390/391] Time 0.14 (0.13) Data 0.00 (0.00) Base [Loss 0.513 (0.512)  Prec@1 80.00 (82.43) Prec@5 100.00 (99.12)]
# Ep:1 ends : loss=0.51, accuracy@1=82.43%, accuracy@5=99.12%
# Found best op for target cell:14
# : Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|) with accuracy=80.47%, confidence=72.569%, sensitivity=0.138, robustness=-0.050, step_sim=99.946
# Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|skip_connect~1|none~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|none~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|none~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|none~0|avg_pool_3x3~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|none~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|)
# Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|none~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)

# %%
import matplotlib.pyplot as plt

plt.scatter(rank_confidences,rank_accs)
plt.show()

plt.scatter(rank_sensitivities,rank_accs)
plt.show()

plt.scatter(rank_robustnesses,rank_accs)
plt.show()

plt.scatter(rank_step_sims,rank_accs)
plt.show()

# %% [markdown]
# # Train a found model

# %%
trained_output = torch.load(os.path.join(xargs.save_dir, "output.pth"))
print(args)
args.save_dir = os.path.join(xargs.save_dir, "train")
print(args)
# Out:
# Namespace(arch_nas_dataset=None, channel=16, config_path='./MY.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=200, rand_seed=74964, save_dir='./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)
# Namespace(arch_nas_dataset=None, channel=16, config_path='./MY.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=200, rand_seed=74964, save_dir='./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
print(config)
# Out:
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=50, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))

# %%
logger = prepare_logger(args)

# cifar_train_config_path = "./MY.config"
cifar_train_config_path = "../configs/nas-benchmark/CIFAR.config"
###
train_data, test_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(cifar_train_config_path, {"class_num": class_num, "xshape": xshape}, logger)

train_loader = torch.utils.data.DataLoader(
            train_data,
            batch_size=config.batch_size,
            shuffle=True,
            num_workers=xargs.workers,
            pin_memory=True,)

test_loader = torch.utils.data.DataLoader(
            test_data,
            batch_size=config.batch_size,
            shuffle=True,
            num_workers=xargs.workers,
            pin_memory=True,)

# search_loader, _, valid_loader = get_nas_search_loaders(train_data,
#                                                         valid_data,
#                                                         xargs.dataset,
#                                                         "../configs/nas-benchmark/",
#                                                         (config.batch_size, config.batch_size),
#                                                         xargs.workers)
logger.log("||||||| {:10s} ||||||| Train-Loader-Num={:}, Test-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(train_loader), len(test_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": True, # true for eval
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

### load
# trained_output = torch.load(os.path.join(xargs.save_dir, "output.pth"))
# search_model.load_state_dict(trained_output['model'], strict=False)
best_archs = trained_output['best_archs']
i=0
for m in search_model.modules():
    if isinstance(m, SearchCell):
        m.arch_cache = best_archs[i]
        i += 1
for m in network.modules():
    if isinstance(m, SearchCell):
        print(m.arch_cache)
###

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))

network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)

start_epoch, valid_accuracies, genotypes = 0, {"best": -1}, {}
# Out:
# Main Function with logger : Logger(dir=cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : None
# channel          : 16
# config_path      : ./MY.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 200
# rand_seed        : 74964
# save_dir         : ./cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None
# Files already downloaded and verified
# Files already downloaded and verified
# ../configs/nas-benchmark/CIFAR.config
# Configure(scheduler='cos', eta_min=0.0, epochs=200, warmup=0, optim='SGD', LR=0.1, decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=256, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Train-Loader-Num=196, Test-Loader-Num=40, batch size=256
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', eta_min=0.0, epochs=200, warmup=0, optim='SGD', LR=0.1, decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=256, class_num=10, xshape=(1, 3, 32, 32))
# Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|skip_connect~1|none~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|none~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|none~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_1x1~1|none~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|none~0|avg_pool_3x3~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|none~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|)
# Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|none~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|none~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.1
#     lr: 0.1
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=200, current::epoch=0, iter=0.00, type=cosine, T-max=200, eta-min=0.0)
# criterion   : CrossEntropyLoss()

# %%
# def search_func_one_arch(xloader, network, criterion, scheduler, w_optimizer, epoch_str, print_freq, logger):
#     data_time, batch_time = AverageMeter(), AverageMeter()
#     base_losses, base_top1, base_top5 = AverageMeter(), AverageMeter(), AverageMeter()
#     network.train()
#     end = time.time()
#     for step, (base_inputs, base_targets, arch_inputs, arch_targets) in enumerate(
#         xloader
#     ):
#         scheduler.update(None, 1.0 * step / len(xloader))
#         base_targets = base_targets.cuda(non_blocking=True)
#         arch_targets = arch_targets.cuda(non_blocking=True)
#         # measure data loading time
#         data_time.update(time.time() - end)

#         w_optimizer.zero_grad()
#         _, logits = network(base_inputs)
#         base_loss = criterion(logits, base_targets)
#         base_loss.backward()
#         nn.utils.clip_grad_norm_(network.parameters(), 5)
#         w_optimizer.step()
#         # record
#         base_prec1, base_prec5 = obtain_accuracy(
#             logits.data, base_targets.data, topk=(1, 5)
#         )
#         base_losses.update(base_loss.item(), base_inputs.size(0))
#         base_top1.update(base_prec1.item(), base_inputs.size(0))
#         base_top5.update(base_prec5.item(), base_inputs.size(0))

#         # measure elapsed time
#         batch_time.update(time.time() - end)
#         end = time.time()

#         if step % print_freq == 0 or step + 1 == len(xloader):
#             Sstr = (
#                 "*SEARCH* "
#                 + time_string()
#                 + " [{:}][{:03d}/{:03d}]".format(epoch_str, step, len(xloader))
#             )
#             Tstr = "Time {batch_time.val:.2f} ({batch_time.avg:.2f}) Data {data_time.val:.2f} ({data_time.avg:.2f})".format(
#                 batch_time=batch_time, data_time=data_time
#             )
#             Wstr = "Base [Loss {loss.val:.3f} ({loss.avg:.3f})  Prec@1 {top1.val:.2f} ({top1.avg:.2f}) Prec@5 {top5.val:.2f} ({top5.avg:.2f})]".format(
#                 loss=base_losses, top1=base_top1, top5=base_top5
#             )
#             logger.log(Sstr + " " + Tstr + " " + Wstr)
#     return base_losses.avg, base_top1.avg, base_top5.avg

def train_func_one_arch(xloader, network, criterion, scheduler, w_optimizer, epoch_str, print_freq, logger):
    data_time, batch_time = AverageMeter(), AverageMeter()
    base_losses, base_top1, base_top5 = AverageMeter(), AverageMeter(), AverageMeter()
    network.train()
    end = time.time()
    for step, (base_inputs, base_targets) in enumerate(
        xloader
    ):
        scheduler.update(None, 1.0 * step / len(xloader))
        base_targets = base_targets.cuda(non_blocking=True)
        # measure data loading time
        data_time.update(time.time() - end)

        w_optimizer.zero_grad()
        _, logits = network(base_inputs)
        base_loss = criterion(logits, base_targets)
        base_loss.backward()
        nn.utils.clip_grad_norm_(network.parameters(), 5)
        w_optimizer.step()
        # record
        base_prec1, base_prec5 = obtain_accuracy(
            logits.data, base_targets.data, topk=(1, 5)
        )
        base_losses.update(base_loss.item(), base_inputs.size(0))
        base_top1.update(base_prec1.item(), base_inputs.size(0))
        base_top5.update(base_prec5.item(), base_inputs.size(0))

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if step % print_freq == 0 or step + 1 == len(xloader):
            Sstr = (
                "*SEARCH* "
                + time_string()
                + " [{:}][{:03d}/{:03d}]".format(epoch_str, step, len(xloader))
            )
            Tstr = "Time {batch_time.val:.2f} ({batch_time.avg:.2f}) Data {data_time.val:.2f} ({data_time.avg:.2f})".format(
                batch_time=batch_time, data_time=data_time
            )
            Wstr = "Base [Loss {loss.val:.3f} ({loss.avg:.3f})  Prec@1 {top1.val:.2f} ({top1.avg:.2f}) Prec@5 {top5.val:.2f} ({top5.avg:.2f})]".format(
                loss=base_losses, top1=base_top1, top5=base_top5
            )
            logger.log(Sstr + " " + Tstr + " " + Wstr)
    return base_losses.avg, base_top1.avg, base_top5.avg

def valid_func_one_arch(xloader, network, criterion):
    data_time, batch_time = AverageMeter(), AverageMeter()
    arch_losses, arch_top1, arch_top5 = AverageMeter(), AverageMeter(), AverageMeter()
    network.eval()
    end = time.time()
    with torch.no_grad():
        for step, (arch_inputs, arch_targets) in enumerate(xloader):
            arch_targets = arch_targets.cuda(non_blocking=True)
            # measure data loading time
            data_time.update(time.time() - end)
            # prediction

#             network.module.random_genotype_per_cell(True)
            _, logits = network(arch_inputs)
            arch_loss = criterion(logits, arch_targets)
            # record
            arch_prec1, arch_prec5 = obtain_accuracy(
                logits.data, arch_targets.data, topk=(1, 5)
            )
            arch_losses.update(arch_loss.item(), arch_inputs.size(0))
            arch_top1.update(arch_prec1.item(), arch_inputs.size(0))
            arch_top5.update(arch_prec5.item(), arch_inputs.size(0))
            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()
    return arch_losses.avg, arch_top1.avg, arch_top5.avg

# %%
start_time, search_time, epoch_time, total_epoch = (
    time.time(),
    AverageMeter(),
    AverageMeter(),
    config.epochs + config.warmup,
)
for epoch in range(0, total_epoch):
    w_scheduler.update(epoch, 0.0)
    need_time = "Time Left: {:}".format(
        convert_secs2time(epoch_time.val * (total_epoch - epoch), True)
    )
    epoch_str = "{:03d}-{:03d}".format(epoch, total_epoch)
    logger.log(
        "\n[Search the {:}-th epoch] {:}, LR={:}".format(
            epoch_str, need_time, min(w_scheduler.get_lr())
        )
    )

    # selected_arch = search_find_best(valid_loader, network, criterion, xargs.select_num)
    search_w_loss, search_w_top1, search_w_top5 = train_func_one_arch(
        train_loader,
        network,
        criterion,
        w_scheduler,
        w_optimizer,
        epoch_str,
        xargs.print_freq,
        logger,
    )
    search_time.update(time.time() - start_time)
    logger.log(
        "[{:}] searching : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%, time-cost={:.1f} s".format(
            epoch_str, search_w_loss, search_w_top1, search_w_top5, search_time.sum
        )
    )
    valid_a_loss, valid_a_top1, valid_a_top5 = valid_func_one_arch(
        test_loader, network, criterion
    )
    logger.log(
        "[{:}] evaluate  : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%".format(
            epoch_str, valid_a_loss, valid_a_top1, valid_a_top5
        )
    )
    
    # check the best accuracy
    valid_accuracies[epoch] = valid_a_top1
    if valid_a_top1 > valid_accuracies["best"]:
        valid_accuracies["best"] = valid_a_top1
        find_best = True
    else:
        find_best = False

    # save checkpoint
    save_path = save_checkpoint(
        {
            "epoch": epoch + 1,
            "args": deepcopy(xargs),
            "search_model": search_model.state_dict(),
            "w_optimizer": w_optimizer.state_dict(),
            "w_scheduler": w_scheduler.state_dict(),
            "genotypes": genotypes,
            "valid_accuracies": valid_accuracies,
        },
        model_base_path,
        logger,
    )
    last_info = save_checkpoint(
        {
            "epoch": epoch + 1,
            "args": deepcopy(args),
            "last_checkpoint": save_path,
        },
        logger.path("info"),
        logger,
    )
    if find_best:
        logger.log(
            "<<<--->>> The {:}-th epoch : find the highest validation accuracy : {:.2f}%.".format(
                epoch_str, valid_a_top1
            )
        )
        copy_checkpoint(model_base_path, model_best_path, logger)
    if api is not None:
        logger.log("{:}".format(api.query_by_arch(genotypes[epoch], "200")))
    # measure elapsed time
    epoch_time.update(time.time() - start_time)
    start_time = time.time()

logger.close()
# Out:
# [Search the 000-200-th epoch] Time Left: [00:00:00], LR=0.1
# *SEARCH* [2022-11-07 09:46:36] [000-200][000/196] Time 0.47 (0.47) Data 0.24 (0.24) Base [Loss 2.366 (2.366)  Prec@1 9.38 (9.38) Prec@5 46.48 (46.48)]
# *SEARCH* [2022-11-07 09:47:06] [000-200][195/196] Time 0.15 (0.16) Data 0.00 (0.00) Base [Loss 1.419 (1.592)  Prec@1 46.25 (40.49) Prec@5 91.25 (88.63)]
# [000-200] searching : loss=1.59, accuracy@1=40.49%, accuracy@5=88.63%, time-cost=30.5 s
# [000-200] evaluate  : loss=1.51, accuracy@1=44.67%, accuracy@5=92.40%
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 000-200-th epoch : find the highest validation accuracy : 44.67%.
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 001-200-th epoch] Time Left: [01:51:56], LR=0.09999383162408304
# *SEARCH* [2022-11-07 09:47:10] [001-200][000/196] Time 0.35 (0.35) Data 0.21 (0.21) Base [Loss 1.198 (1.198)  Prec@1 56.64 (56.64) Prec@5 96.88 (96.88)]
# *SEARCH* [2022-11-07 09:47:38] [001-200][195/196] Time 0.08 (0.15) Data 0.00 (0.00) Base [Loss 1.042 (1.113)  Prec@1 66.25 (59.98) Prec@5 95.00 (96.00)]
# [001-200] searching : loss=1.11, accuracy@1=59.98%, accuracy@5=96.00%, time-cost=59.2 s
# [001-200] evaluate  : loss=1.53, accuracy@1=52.39%, accuracy@5=92.99%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 001-200-th epoch : find the highest validation accuracy : 52.39%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 002-200-th epoch] Time Left: [01:46:56], LR=0.09997532801828658
# *SEARCH* [2022-11-07 09:47:43] [002-200][000/196] Time 0.41 (0.41) Data 0.28 (0.28) Base [Loss 1.092 (1.092)  Prec@1 62.89 (62.89) Prec@5 95.70 (95.70)]
# *SEARCH* [2022-11-07 09:48:11] [002-200][195/196] Time 0.26 (0.14) Data 0.00 (0.00) Base [Loss 0.722 (0.953)  Prec@1 70.00 (65.80) Prec@5 98.75 (97.17)]
# [002-200] searching : loss=0.95, accuracy@1=65.80%, accuracy@5=97.17%, time-cost=87.6 s
# [002-200] evaluate  : loss=1.68, accuracy@1=49.37%, accuracy@5=92.44%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 003-200-th epoch] Time Left: [01:47:29], LR=0.09994449374809851
# *SEARCH* [2022-11-07 09:48:15] [003-200][000/196] Time 0.47 (0.47) Data 0.21 (0.21) Base [Loss 0.928 (0.928)  Prec@1 66.02 (66.02) Prec@5 97.66 (97.66)]
# *SEARCH* [2022-11-07 09:48:44] [003-200][195/196] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 0.872 (0.863)  Prec@1 71.25 (69.33) Prec@5 96.25 (97.77)]
# [003-200] searching : loss=0.86, accuracy@1=69.33%, accuracy@5=97.77%, time-cost=116.7 s
# [003-200] evaluate  : loss=1.49, accuracy@1=54.75%, accuracy@5=95.41%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 003-200-th epoch : find the highest validation accuracy : 54.75%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 004-200-th epoch] Time Left: [01:45:57], LR=0.09990133642141358
# *SEARCH* [2022-11-07 09:48:48] [004-200][000/196] Time 0.41 (0.41) Data 0.28 (0.28) Base [Loss 0.731 (0.731)  Prec@1 75.78 (75.78) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 09:49:16] [004-200][195/196] Time 0.08 (0.14) Data 0.00 (0.00) Base [Loss 0.604 (0.793)  Prec@1 77.50 (72.07) Prec@5 100.00 (98.09)]
# [004-200] searching : loss=0.79, accuracy@1=72.07%, accuracy@5=98.09%, time-cost=145.1 s
# [004-200] evaluate  : loss=1.18, accuracy@1=62.79%, accuracy@5=97.46%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 004-200-th epoch : find the highest validation accuracy : 62.79%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 005-200-th epoch] Time Left: [01:43:02], LR=0.0998458666866564
# *SEARCH* [2022-11-07 09:49:19] [005-200][000/196] Time 0.38 (0.38) Data 0.26 (0.26) Base [Loss 0.812 (0.812)  Prec@1 71.48 (71.48) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-11-07 09:49:46] [005-200][195/196] Time 0.10 (0.14) Data 0.00 (0.00) Base [Loss 0.743 (0.735)  Prec@1 63.75 (74.17) Prec@5 98.75 (98.39)]
# [005-200] searching : loss=0.74, accuracy@1=74.17%, accuracy@5=98.39%, time-cost=172.6 s
# [005-200] evaluate  : loss=1.26, accuracy@1=61.34%, accuracy@5=96.12%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 006-200-th epoch] Time Left: [01:39:27], LR=0.099778098230154
# *SEARCH* [2022-11-07 09:49:50] [006-200][000/196] Time 0.44 (0.44) Data 0.28 (0.28) Base [Loss 0.674 (0.674)  Prec@1 74.61 (74.61) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 09:50:19] [006-200][195/196] Time 0.08 (0.15) Data 0.00 (0.00) Base [Loss 0.689 (0.691)  Prec@1 80.00 (75.99) Prec@5 96.25 (98.59)]
# [006-200] searching : loss=0.69, accuracy@1=75.99%, accuracy@5=98.59%, time-cost=201.4 s
# [006-200] evaluate  : loss=1.32, accuracy@1=58.17%, accuracy@5=96.47%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 007-200-th epoch] Time Left: [01:45:50], LR=0.099698047772759
# *SEARCH* [2022-11-07 09:50:23] [007-200][000/196] Time 0.48 (0.48) Data 0.32 (0.32) Base [Loss 0.762 (0.762)  Prec@1 71.48 (71.48) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 09:50:54] [007-200][195/196] Time 0.10 (0.16) Data 0.00 (0.00) Base [Loss 0.680 (0.659)  Prec@1 80.00 (77.01) Prec@5 100.00 (98.80)]
# [007-200] searching : loss=0.66, accuracy@1=77.01%, accuracy@5=98.80%, time-cost=232.4 s
# [007-200] evaluate  : loss=1.12, accuracy@1=66.62%, accuracy@5=96.59%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 007-200-th epoch : find the highest validation accuracy : 66.62%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 008-200-th epoch] Time Left: [01:52:32], LR=0.0996057350657239
# *SEARCH* [2022-11-07 09:50:58] [008-200][000/196] Time 0.43 (0.43) Data 0.26 (0.26) Base [Loss 0.584 (0.584)  Prec@1 80.47 (80.47) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 09:51:28] [008-200][195/196] Time 0.15 (0.15) Data 0.00 (0.00) Base [Loss 0.908 (0.636)  Prec@1 73.75 (77.90) Prec@5 96.25 (98.82)]
# [008-200] searching : loss=0.64, accuracy@1=77.90%, accuracy@5=98.82%, time-cost=262.2 s
# [008-200] evaluate  : loss=0.88, accuracy@1=70.31%, accuracy@5=98.30%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 008-200-th epoch : find the highest validation accuracy : 70.31%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 009-200-th epoch] Time Left: [01:47:56], LR=0.09950118288582788
# *SEARCH* [2022-11-07 09:51:32] [009-200][000/196] Time 0.36 (0.36) Data 0.23 (0.23) Base [Loss 0.618 (0.618)  Prec@1 79.30 (79.30) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-11-07 09:52:00] [009-200][195/196] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 0.540 (0.612)  Prec@1 85.00 (78.80) Prec@5 98.75 (98.88)]
# [009-200] searching : loss=0.61, accuracy@1=78.80%, accuracy@5=98.88%, time-cost=290.8 s
# [009-200] evaluate  : loss=1.09, accuracy@1=66.00%, accuracy@5=97.16%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 010-200-th epoch] Time Left: [01:44:01], LR=0.0993844170297569
# *SEARCH* [2022-11-07 09:52:05] [010-200][000/196] Time 0.43 (0.43) Data 0.27 (0.27) Base [Loss 0.566 (0.566)  Prec@1 78.91 (78.91) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 09:52:34] [010-200][195/196] Time 0.26 (0.15) Data 0.00 (0.00) Base [Loss 0.641 (0.594)  Prec@1 72.50 (79.46) Prec@5 100.00 (98.90)]
# [010-200] searching : loss=0.59, accuracy@1=79.46%, accuracy@5=98.90%, time-cost=320.3 s
# [010-200] evaluate  : loss=0.78, accuracy@1=74.18%, accuracy@5=98.13%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 010-200-th epoch : find the highest validation accuracy : 74.18%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 011-200-th epoch] Time Left: [01:44:26], LR=0.0992554663077387
# *SEARCH* [2022-11-07 09:52:38] [011-200][000/196] Time 0.38 (0.38) Data 0.24 (0.24) Base [Loss 0.542 (0.542)  Prec@1 81.25 (81.25) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 09:53:07] [011-200][195/196] Time 0.10 (0.15) Data 0.00 (0.00) Base [Loss 0.711 (0.578)  Prec@1 77.50 (80.07) Prec@5 97.50 (98.98)]
# [011-200] searching : loss=0.58, accuracy@1=80.07%, accuracy@5=98.98%, time-cost=349.2 s
# [011-200] evaluate  : loss=1.15, accuracy@1=64.28%, accuracy@5=95.17%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 012-200-th epoch] Time Left: [01:44:38], LR=0.09911436253643445
# *SEARCH* [2022-11-07 09:53:12] [012-200][000/196] Time 0.40 (0.40) Data 0.27 (0.27) Base [Loss 0.627 (0.627)  Prec@1 78.91 (78.91) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-11-07 09:53:40] [012-200][195/196] Time 0.08 (0.15) Data 0.00 (0.00) Base [Loss 0.592 (0.561)  Prec@1 80.00 (80.51) Prec@5 100.00 (99.08)]
# [012-200] searching : loss=0.56, accuracy@1=80.51%, accuracy@5=99.08%, time-cost=377.8 s
# [012-200] evaluate  : loss=1.08, accuracy@1=67.14%, accuracy@5=97.93%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 013-200-th epoch] Time Left: [01:40:22], LR=0.09896114053108829
# *SEARCH* [2022-11-07 09:53:44] [013-200][000/196] Time 0.40 (0.40) Data 0.27 (0.27) Base [Loss 0.563 (0.563)  Prec@1 78.91 (78.91) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 09:54:11] [013-200][195/196] Time 0.11 (0.14) Data 0.00 (0.00) Base [Loss 0.518 (0.548)  Prec@1 82.50 (81.06) Prec@5 100.00 (99.13)]
# [013-200] searching : loss=0.55, accuracy@1=81.06%, accuracy@5=99.13%, time-cost=405.9 s
# [013-200] evaluate  : loss=1.02, accuracy@1=66.80%, accuracy@5=98.24%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 014-200-th epoch] Time Left: [01:38:01], LR=0.09879583809693737
# *SEARCH* [2022-11-07 09:54:15] [014-200][000/196] Time 0.32 (0.32) Data 0.21 (0.21) Base [Loss 0.521 (0.521)  Prec@1 80.08 (80.08) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 09:54:45] [014-200][195/196] Time 0.15 (0.15) Data 0.00 (0.00) Base [Loss 0.679 (0.545)  Prec@1 75.00 (81.22) Prec@5 96.25 (99.02)]
# [014-200] searching : loss=0.54, accuracy@1=81.22%, accuracy@5=99.02%, time-cost=435.9 s
# [014-200] evaluate  : loss=1.30, accuracy@1=61.24%, accuracy@5=98.46%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 015-200-th epoch] Time Left: [01:44:46], LR=0.09861849601988383
# *SEARCH* [2022-11-07 09:54:50] [015-200][000/196] Time 0.55 (0.55) Data 0.22 (0.22) Base [Loss 0.559 (0.559)  Prec@1 81.64 (81.64) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 09:55:18] [015-200][195/196] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.744 (0.529)  Prec@1 77.50 (81.57) Prec@5 98.75 (99.23)]
# [015-200] searching : loss=0.53, accuracy@1=81.57%, accuracy@5=99.23%, time-cost=464.9 s
# [015-200] evaluate  : loss=0.69, accuracy@1=76.71%, accuracy@5=98.65%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 015-200-th epoch : find the highest validation accuracy : 76.71%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 016-200-th epoch] Time Left: [01:39:34], LR=0.09842915805643156
# *SEARCH* [2022-11-07 09:55:22] [016-200][000/196] Time 0.46 (0.46) Data 0.24 (0.24) Base [Loss 0.463 (0.463)  Prec@1 85.16 (85.16) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 09:55:52] [016-200][195/196] Time 0.12 (0.16) Data 0.00 (0.00) Base [Loss 0.538 (0.523)  Prec@1 77.50 (81.94) Prec@5 100.00 (99.15)]
# [016-200] searching : loss=0.52, accuracy@1=81.94%, accuracy@5=99.15%, time-cost=495.7 s
# [016-200] evaluate  : loss=1.08, accuracy@1=68.03%, accuracy@5=97.76%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 017-200-th epoch] Time Left: [01:44:25], LR=0.09822787092288991
# *SEARCH* [2022-11-07 09:55:56] [017-200][000/196] Time 0.43 (0.43) Data 0.31 (0.31) Base [Loss 0.565 (0.565)  Prec@1 79.69 (79.69) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 09:56:23] [017-200][195/196] Time 0.07 (0.14) Data 0.00 (0.00) Base [Loss 0.616 (0.512)  Prec@1 76.25 (82.38) Prec@5 97.50 (99.28)]
# [017-200] searching : loss=0.51, accuracy@1=82.38%, accuracy@5=99.28%, time-cost=522.9 s
# [017-200] evaluate  : loss=1.60, accuracy@1=58.32%, accuracy@5=94.04%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 018-200-th epoch] Time Left: [01:34:08], LR=0.09801468428384716
# *SEARCH* [2022-11-07 09:56:27] [018-200][000/196] Time 0.35 (0.35) Data 0.23 (0.23) Base [Loss 0.430 (0.430)  Prec@1 85.16 (85.16) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 09:56:55] [018-200][195/196] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 0.591 (0.510)  Prec@1 77.50 (82.39) Prec@5 100.00 (99.19)]
# [018-200] searching : loss=0.51, accuracy@1=82.39%, accuracy@5=99.19%, time-cost=551.7 s
# [018-200] evaluate  : loss=0.98, accuracy@1=70.02%, accuracy@5=98.08%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 019-200-th epoch] Time Left: [01:40:11], LR=0.09778965073991651
# *SEARCH* [2022-11-07 09:57:00] [019-200][000/196] Time 0.51 (0.51) Data 0.24 (0.24) Base [Loss 0.433 (0.433)  Prec@1 84.77 (84.77) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 09:57:30] [019-200][195/196] Time 0.16 (0.15) Data 0.00 (0.00) Base [Loss 0.418 (0.501)  Prec@1 90.00 (82.92) Prec@5 98.75 (99.23)]
# [019-200] searching : loss=0.50, accuracy@1=82.92%, accuracy@5=99.23%, time-cost=581.4 s
# [019-200] evaluate  : loss=1.15, accuracy@1=67.59%, accuracy@5=97.23%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 020-200-th epoch] Time Left: [01:38:58], LR=0.09755282581475769
# *SEARCH* [2022-11-07 09:57:33] [020-200][000/196] Time 0.37 (0.37) Data 0.23 (0.23) Base [Loss 0.464 (0.464)  Prec@1 82.42 (82.42) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 09:58:03] [020-200][195/196] Time 0.11 (0.15) Data 0.00 (0.00) Base [Loss 0.663 (0.490)  Prec@1 73.75 (83.12) Prec@5 97.50 (99.24)]
# [020-200] searching : loss=0.49, accuracy@1=83.12%, accuracy@5=99.24%, time-cost=611.2 s
# [020-200] evaluate  : loss=0.73, accuracy@1=75.43%, accuracy@5=98.38%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 021-200-th epoch] Time Left: [01:40:50], LR=0.09730426794137727
# *SEARCH* [2022-11-07 09:58:07] [021-200][000/196] Time 0.44 (0.44) Data 0.30 (0.30) Base [Loss 0.496 (0.496)  Prec@1 85.16 (85.16) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 09:58:35] [021-200][195/196] Time 0.15 (0.14) Data 0.00 (0.00) Base [Loss 0.434 (0.488)  Prec@1 87.50 (83.18) Prec@5 100.00 (99.27)]
# [021-200] searching : loss=0.49, accuracy@1=83.18%, accuracy@5=99.27%, time-cost=639.6 s
# [021-200] evaluate  : loss=0.95, accuracy@1=70.60%, accuracy@5=98.21%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 022-200-th epoch] Time Left: [01:37:23], LR=0.09704403844771128
# *SEARCH* [2022-11-07 09:58:40] [022-200][000/196] Time 0.41 (0.41) Data 0.22 (0.22) Base [Loss 0.474 (0.474)  Prec@1 83.98 (83.98) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 09:59:10] [022-200][195/196] Time 0.10 (0.16) Data 0.00 (0.00) Base [Loss 0.743 (0.484)  Prec@1 72.50 (83.38) Prec@5 98.75 (99.29)]
# [022-200] searching : loss=0.48, accuracy@1=83.38%, accuracy@5=99.29%, time-cost=670.6 s
# [022-200] evaluate  : loss=1.35, accuracy@1=66.03%, accuracy@5=97.54%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 023-200-th epoch] Time Left: [01:42:43], LR=0.09677220154149338
# *SEARCH* [2022-11-07 09:59:15] [023-200][000/196] Time 0.40 (0.40) Data 0.24 (0.24) Base [Loss 0.449 (0.449)  Prec@1 86.72 (86.72) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-11-07 09:59:44] [023-200][195/196] Time 0.18 (0.15) Data 0.00 (0.00) Base [Loss 0.449 (0.477)  Prec@1 87.50 (83.71) Prec@5 100.00 (99.30)]
# [023-200] searching : loss=0.48, accuracy@1=83.71%, accuracy@5=99.30%, time-cost=700.6 s
# [023-200] evaluate  : loss=0.72, accuracy@1=75.96%, accuracy@5=98.47%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 024-200-th epoch] Time Left: [01:39:37], LR=0.09648882429441258
# *SEARCH* [2022-11-07 09:59:49] [024-200][000/196] Time 0.53 (0.53) Data 0.28 (0.28) Base [Loss 0.675 (0.675)  Prec@1 73.05 (73.05) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-11-07 10:00:18] [024-200][195/196] Time 0.15 (0.15) Data 0.00 (0.00) Base [Loss 0.565 (0.472)  Prec@1 80.00 (83.76) Prec@5 97.50 (99.32)]
# [024-200] searching : loss=0.47, accuracy@1=83.76%, accuracy@5=99.32%, time-cost=730.7 s
# [024-200] evaluate  : loss=1.15, accuracy@1=66.54%, accuracy@5=97.54%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 025-200-th epoch] Time Left: [01:39:39], LR=0.09619397662556434
# *SEARCH* [2022-11-07 10:00:23] [025-200][000/196] Time 0.32 (0.32) Data 0.22 (0.22) Base [Loss 0.464 (0.464)  Prec@1 81.25 (81.25) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 10:00:49] [025-200][195/196] Time 0.07 (0.14) Data 0.00 (0.00) Base [Loss 0.547 (0.472)  Prec@1 81.25 (83.68) Prec@5 100.00 (99.30)]
# [025-200] searching : loss=0.47, accuracy@1=83.68%, accuracy@5=99.30%, time-cost=757.7 s
# [025-200] evaluate  : loss=1.29, accuracy@1=63.58%, accuracy@5=97.57%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 026-200-th epoch] Time Left: [01:30:38], LR=0.09588773128419906
# *SEARCH* [2022-11-07 10:00:54] [026-200][000/196] Time 0.45 (0.45) Data 0.26 (0.26) Base [Loss 0.546 (0.546)  Prec@1 80.08 (80.08) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 10:01:22] [026-200][195/196] Time 0.10 (0.14) Data 0.00 (0.00) Base [Loss 0.563 (0.466)  Prec@1 78.75 (83.98) Prec@5 97.50 (99.34)]
# [026-200] searching : loss=0.47, accuracy@1=83.98%, accuracy@5=99.34%, time-cost=786.1 s
# [026-200] evaluate  : loss=0.89, accuracy@1=70.99%, accuracy@5=98.06%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 027-200-th epoch] Time Left: [01:33:17], LR=0.09557016383177226
# *SEARCH* [2022-11-07 10:01:27] [027-200][000/196] Time 0.50 (0.50) Data 0.25 (0.25) Base [Loss 0.427 (0.427)  Prec@1 83.20 (83.20) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 10:01:55] [027-200][195/196] Time 0.09 (0.15) Data 0.00 (0.00) Base [Loss 0.754 (0.463)  Prec@1 78.75 (83.97) Prec@5 98.75 (99.33)]
# [027-200] searching : loss=0.46, accuracy@1=83.97%, accuracy@5=99.33%, time-cost=815.6 s
# [027-200] evaluate  : loss=1.34, accuracy@1=63.87%, accuracy@5=96.67%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 028-200-th epoch] Time Left: [01:35:59], LR=0.09524135262330098
# *SEARCH* [2022-11-07 10:02:00] [028-200][000/196] Time 0.40 (0.40) Data 0.25 (0.25) Base [Loss 0.409 (0.409)  Prec@1 86.72 (86.72) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 10:02:28] [028-200][195/196] Time 0.11 (0.15) Data 0.00 (0.00) Base [Loss 0.331 (0.459)  Prec@1 86.25 (84.30) Prec@5 100.00 (99.37)]
# [028-200] searching : loss=0.46, accuracy@1=84.30%, accuracy@5=99.37%, time-cost=844.4 s
# [028-200] evaluate  : loss=0.86, accuracy@1=73.02%, accuracy@5=98.13%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 029-200-th epoch] Time Left: [01:32:25], LR=0.09490137878803079
# *SEARCH* [2022-11-07 10:02:32] [029-200][000/196] Time 0.39 (0.39) Data 0.24 (0.24) Base [Loss 0.574 (0.574)  Prec@1 81.64 (81.64) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 10:03:00] [029-200][195/196] Time 0.11 (0.14) Data 0.00 (0.00) Base [Loss 0.641 (0.454)  Prec@1 80.00 (84.32) Prec@5 98.75 (99.41)]
# [029-200] searching : loss=0.45, accuracy@1=84.32%, accuracy@5=99.41%, time-cost=872.5 s
# [029-200] evaluate  : loss=1.07, accuracy@1=71.32%, accuracy@5=96.94%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 030-200-th epoch] Time Left: [01:30:18], LR=0.09455032620941839
# *SEARCH* [2022-11-07 10:03:04] [030-200][000/196] Time 0.43 (0.43) Data 0.25 (0.25) Base [Loss 0.449 (0.449)  Prec@1 84.77 (84.77) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-11-07 10:03:34] [030-200][195/196] Time 0.09 (0.15) Data 0.00 (0.00) Base [Loss 0.417 (0.454)  Prec@1 83.75 (84.41) Prec@5 100.00 (99.34)]
# [030-200] searching : loss=0.45, accuracy@1=84.41%, accuracy@5=99.34%, time-cost=902.2 s
# [030-200] evaluate  : loss=1.26, accuracy@1=67.40%, accuracy@5=95.95%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 031-200-th epoch] Time Left: [01:33:47], LR=0.09418828150443469
# *SEARCH* [2022-11-07 10:03:38] [031-200][000/196] Time 0.46 (0.46) Data 0.26 (0.26) Base [Loss 0.451 (0.451)  Prec@1 84.38 (84.38) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 10:04:04] [031-200][195/196] Time 0.08 (0.14) Data 0.00 (0.00) Base [Loss 0.375 (0.448)  Prec@1 86.25 (84.61) Prec@5 100.00 (99.40)]
# [031-200] searching : loss=0.45, accuracy@1=84.61%, accuracy@5=99.40%, time-cost=929.3 s
# [031-200] evaluate  : loss=0.72, accuracy@1=76.72%, accuracy@5=98.91%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 031-200-th epoch : find the highest validation accuracy : 76.72%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 032-200-th epoch] Time Left: [01:27:05], LR=0.09381533400219318
# *SEARCH* [2022-11-07 10:04:09] [032-200][000/196] Time 0.40 (0.40) Data 0.25 (0.25) Base [Loss 0.410 (0.410)  Prec@1 84.77 (84.77) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 10:04:38] [032-200][195/196] Time 0.25 (0.15) Data 0.00 (0.00) Base [Loss 0.463 (0.444)  Prec@1 86.25 (84.61) Prec@5 100.00 (99.37)]
# [032-200] searching : loss=0.44, accuracy@1=84.61%, accuracy@5=99.37%, time-cost=959.3 s
# [032-200] evaluate  : loss=1.12, accuracy@1=66.47%, accuracy@5=98.17%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 033-200-th epoch] Time Left: [01:34:49], LR=0.09343157572190958
# *SEARCH* [2022-11-07 10:04:43] [033-200][000/196] Time 0.49 (0.49) Data 0.26 (0.26) Base [Loss 0.408 (0.408)  Prec@1 85.94 (85.94) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 10:05:12] [033-200][195/196] Time 0.15 (0.15) Data 0.00 (0.00) Base [Loss 0.484 (0.442)  Prec@1 83.75 (84.69) Prec@5 100.00 (99.40)]
# [033-200] searching : loss=0.44, accuracy@1=84.69%, accuracy@5=99.40%, time-cost=989.0 s
# [033-200] evaluate  : loss=0.75, accuracy@1=76.10%, accuracy@5=98.81%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 034-200-th epoch] Time Left: [01:32:16], LR=0.09303710135019719
# *SEARCH* [2022-11-07 10:05:16] [034-200][000/196] Time 0.46 (0.46) Data 0.31 (0.31) Base [Loss 0.400 (0.400)  Prec@1 85.94 (85.94) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 10:05:46] [034-200][195/196] Time 0.08 (0.16) Data 0.00 (0.00) Base [Loss 0.379 (0.434)  Prec@1 88.75 (85.02) Prec@5 100.00 (99.46)]
# [034-200] searching : loss=0.43, accuracy@1=85.02%, accuracy@5=99.46%, time-cost=1019.7 s
# [034-200] evaluate  : loss=0.62, accuracy@1=79.71%, accuracy@5=98.66%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 034-200-th epoch : find the highest validation accuracy : 79.71%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 035-200-th epoch] Time Left: [01:36:36], LR=0.09263200821770462
# *SEARCH* [2022-11-07 10:05:51] [035-200][000/196] Time 0.37 (0.37) Data 0.22 (0.22) Base [Loss 0.430 (0.430)  Prec@1 82.81 (82.81) Prec@5 99.61 (99.61)]
# *SEARCH* [2022-11-07 10:06:21] [035-200][195/196] Time 0.11 (0.15) Data 0.00 (0.00) Base [Loss 0.419 (0.439)  Prec@1 86.25 (84.81) Prec@5 100.00 (99.36)]
# [035-200] searching : loss=0.44, accuracy@1=84.81%, accuracy@5=99.36%, time-cost=1049.9 s
# [035-200] evaluate  : loss=0.76, accuracy@1=74.61%, accuracy@5=98.64%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 036-200-th epoch] Time Left: [01:32:50], LR=0.09221639627510075
# *SEARCH* [2022-11-07 10:06:25] [036-200][000/196] Time 0.46 (0.46) Data 0.23 (0.23) Base [Loss 0.378 (0.378)  Prec@1 85.94 (85.94) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 10:06:55] [036-200][195/196] Time 0.10 (0.15) Data 0.00 (0.00) Base [Loss 0.601 (0.437)  Prec@1 82.50 (84.88) Prec@5 98.75 (99.40)]
# [036-200] searching : loss=0.44, accuracy@1=84.88%, accuracy@5=99.40%, time-cost=1080.1 s
# [036-200] evaluate  : loss=0.69, accuracy@1=76.37%, accuracy@5=98.85%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 037-200-th epoch] Time Left: [01:30:58], LR=0.09179036806841352
# *SEARCH* [2022-11-07 10:06:59] [037-200][000/196] Time 0.44 (0.44) Data 0.30 (0.30) Base [Loss 0.449 (0.449)  Prec@1 86.33 (86.33) Prec@5 98.83 (98.83)]
# *SEARCH* [2022-11-07 10:07:28] [037-200][195/196] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 0.425 (0.424)  Prec@1 87.50 (85.38) Prec@5 100.00 (99.45)]
# [037-200] searching : loss=0.42, accuracy@1=85.38%, accuracy@5=99.45%, time-cost=1110.1 s
# [037-200] evaluate  : loss=0.63, accuracy@1=79.65%, accuracy@5=98.99%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 038-200-th epoch] Time Left: [01:29:56], LR=0.0913540287137281
# *SEARCH* [2022-11-07 10:07:32] [038-200][000/196] Time 0.45 (0.45) Data 0.23 (0.23) Base [Loss 0.433 (0.433)  Prec@1 80.47 (80.47) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 10:07:59] [038-200][195/196] Time 0.09 (0.14) Data 0.00 (0.00) Base [Loss 0.414 (0.424)  Prec@1 87.50 (85.42) Prec@5 100.00 (99.43)]
# [038-200] searching : loss=0.42, accuracy@1=85.42%, accuracy@5=99.43%, time-cost=1137.5 s
# [038-200] evaluate  : loss=0.64, accuracy@1=78.45%, accuracy@5=98.81%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 039-200-th epoch] Time Left: [01:26:00], LR=0.09090748587125118
# *SEARCH* [2022-11-07 10:08:04] [039-200][000/196] Time 0.42 (0.42) Data 0.24 (0.24) Base [Loss 0.372 (0.372)  Prec@1 88.28 (88.28) Prec@5 99.22 (99.22)]
# *SEARCH* [2022-11-07 10:08:33] [039-200][195/196] Time 0.17 (0.15) Data 0.00 (0.00) Base [Loss 0.395 (0.425)  Prec@1 85.00 (85.28) Prec@5 100.00 (99.46)]
# [039-200] searching : loss=0.43, accuracy@1=85.28%, accuracy@5=99.46%, time-cost=1166.7 s
# [039-200] evaluate  : loss=0.72, accuracy@1=77.30%, accuracy@5=98.72%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 040-200-th epoch] Time Left: [01:26:27], LR=0.09045084971874738
# *SEARCH* [2022-11-07 10:08:37] [040-200][000/196] Time 0.44 (0.44) Data 0.28 (0.28) Base [Loss 0.453 (0.453)  Prec@1 84.38 (84.38) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 10:09:05] [040-200][195/196] Time 0.10 (0.15) Data 0.00 (0.00) Base [Loss 0.337 (0.420)  Prec@1 86.25 (85.63) Prec@5 100.00 (99.45)]
# [040-200] searching : loss=0.42, accuracy@1=85.63%, accuracy@5=99.45%, time-cost=1195.3 s
# [040-200] evaluate  : loss=0.63, accuracy@1=79.97%, accuracy@5=98.75%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 040-200-th epoch : find the highest validation accuracy : 79.97%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# ...
# [185-200] evaluate  : loss=0.34, accuracy@1=91.32%, accuracy@5=99.72%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
# <<<--->>> The 185-200-th epoch : find the highest validation accuracy : 91.32%.
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth exist, delete is at first before saving
# copy the file from cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-best.pth
#
# [Search the 186-200-th epoch] Time Left: [00:05:11], LR=0.0012041619030626338
# *SEARCH* [2022-11-07 11:20:18] [186-200][000/196] Time 0.37 (0.37) Data 0.28 (0.28) Base [Loss 0.037 (0.037)  Prec@1 98.44 (98.44) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:20:36] [186-200][195/196] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.086 (0.037)  Prec@1 97.50 (98.96) Prec@5 100.00 (100.00)]
# [186-200] searching : loss=0.04, accuracy@1=98.96%, accuracy@5=100.00%, time-cost=4955.9 s
# [186-200] evaluate  : loss=0.34, accuracy@1=91.12%, accuracy@5=99.71%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 187-200-th epoch] Time Left: [00:04:49], LR=0.001038859468911707
# *SEARCH* [2022-11-07 11:20:41] [187-200][000/196] Time 0.31 (0.31) Data 0.21 (0.21) Base [Loss 0.040 (0.040)  Prec@1 98.44 (98.44) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:21:04] [187-200][195/196] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.076 (0.035)  Prec@1 96.25 (99.03) Prec@5 100.00 (100.00)]
# [187-200] searching : loss=0.03, accuracy@1=99.03%, accuracy@5=100.00%, time-cost=4979.3 s
# [187-200] evaluate  : loss=0.35, accuracy@1=91.05%, accuracy@5=99.71%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 188-200-th epoch] Time Left: [00:05:30], LR=0.000885637463565564
# *SEARCH* [2022-11-07 11:21:08] [188-200][000/196] Time 0.45 (0.45) Data 0.29 (0.29) Base [Loss 0.026 (0.026)  Prec@1 98.83 (98.83) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:21:33] [188-200][195/196] Time 0.22 (0.13) Data 0.00 (0.00) Base [Loss 0.035 (0.034)  Prec@1 98.75 (99.06) Prec@5 100.00 (100.00)]
# [188-200] searching : loss=0.03, accuracy@1=99.06%, accuracy@5=100.00%, time-cost=5004.2 s
# [188-200] evaluate  : loss=0.35, accuracy@1=91.10%, accuracy@5=99.71%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 189-200-th epoch] Time Left: [00:05:03], LR=0.0007445336922613067
# *SEARCH* [2022-11-07 11:21:36] [189-200][000/196] Time 0.39 (0.39) Data 0.30 (0.30) Base [Loss 0.027 (0.027)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:21:53] [189-200][195/196] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.021 (0.032)  Prec@1 100.00 (99.15) Prec@5 100.00 (100.00)]
# [189-200] searching : loss=0.03, accuracy@1=99.15%, accuracy@5=100.00%, time-cost=5022.4 s
# [189-200] evaluate  : loss=0.35, accuracy@1=91.07%, accuracy@5=99.74%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 190-200-th epoch] Time Left: [00:03:28], LR=0.0006155829702431171
# *SEARCH* [2022-11-07 11:21:57] [190-200][000/196] Time 0.55 (0.55) Data 0.26 (0.26) Base [Loss 0.045 (0.045)  Prec@1 98.83 (98.83) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:22:16] [190-200][195/196] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.070 (0.033)  Prec@1 98.75 (99.13) Prec@5 100.00 (100.00)]
# [190-200] searching : loss=0.03, accuracy@1=99.13%, accuracy@5=100.00%, time-cost=5041.8 s
# [190-200] evaluate  : loss=0.34, accuracy@1=91.05%, accuracy@5=99.69%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 191-200-th epoch] Time Left: [00:03:20], LR=0.0004988171141721232
# *SEARCH* [2022-11-07 11:22:19] [191-200][000/196] Time 0.30 (0.30) Data 0.20 (0.20) Base [Loss 0.020 (0.020)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:22:36] [191-200][195/196] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.051 (0.032)  Prec@1 100.00 (99.15) Prec@5 100.00 (100.00)]
# [191-200] searching : loss=0.03, accuracy@1=99.15%, accuracy@5=100.00%, time-cost=5059.9 s
# [191-200] evaluate  : loss=0.35, accuracy@1=91.07%, accuracy@5=99.72%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 192-200-th epoch] Time Left: [00:02:57], LR=0.0003942649342761118
# *SEARCH* [2022-11-07 11:22:41] [192-200][000/196] Time 0.35 (0.35) Data 0.24 (0.24) Base [Loss 0.031 (0.031)  Prec@1 98.83 (98.83) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:22:59] [192-200][195/196] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.059 (0.030)  Prec@1 97.50 (99.23) Prec@5 100.00 (100.00)]
# [192-200] searching : loss=0.03, accuracy@1=99.23%, accuracy@5=100.00%, time-cost=5078.1 s
# [192-200] evaluate  : loss=0.35, accuracy@1=91.20%, accuracy@5=99.72%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 193-200-th epoch] Time Left: [00:02:35], LR=0.00030195222724102024
# *SEARCH* [2022-11-07 11:23:03] [193-200][000/196] Time 0.34 (0.34) Data 0.22 (0.22) Base [Loss 0.018 (0.018)  Prec@1 99.22 (99.22) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:23:23] [193-200][195/196] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 0.044 (0.030)  Prec@1 98.75 (99.22) Prec@5 100.00 (100.00)]
# [193-200] searching : loss=0.03, accuracy@1=99.22%, accuracy@5=100.00%, time-cost=5098.4 s
# [193-200] evaluate  : loss=0.34, accuracy@1=91.09%, accuracy@5=99.73%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 194-200-th epoch] Time Left: [00:02:18], LR=0.0002219017698460002
# *SEARCH* [2022-11-07 11:23:26] [194-200][000/196] Time 0.37 (0.37) Data 0.20 (0.20) Base [Loss 0.037 (0.037)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:23:47] [194-200][195/196] Time 0.14 (0.11) Data 0.00 (0.00) Base [Loss 0.027 (0.030)  Prec@1 98.75 (99.26) Prec@5 100.00 (100.00)]
# [194-200] searching : loss=0.03, accuracy@1=99.26%, accuracy@5=100.00%, time-cost=5119.8 s
# [194-200] evaluate  : loss=0.34, accuracy@1=91.13%, accuracy@5=99.72%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 195-200-th epoch] Time Left: [00:02:01], LR=0.0001541333133436018
# *SEARCH* [2022-11-07 11:23:50] [195-200][000/196] Time 0.33 (0.33) Data 0.22 (0.22) Base [Loss 0.030 (0.030)  Prec@1 98.83 (98.83) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:24:09] [195-200][195/196] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.030 (0.029)  Prec@1 100.00 (99.27) Prec@5 100.00 (100.00)]
# [195-200] searching : loss=0.03, accuracy@1=99.27%, accuracy@5=100.00%, time-cost=5138.8 s
# [195-200] evaluate  : loss=0.34, accuracy@1=91.07%, accuracy@5=99.74%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 196-200-th epoch] Time Left: [00:01:32], LR=9.866357858642206e-05
# *SEARCH* [2022-11-07 11:24:14] [196-200][000/196] Time 0.37 (0.37) Data 0.26 (0.26) Base [Loss 0.013 (0.013)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:24:31] [196-200][195/196] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.098 (0.030)  Prec@1 96.25 (99.23) Prec@5 100.00 (100.00)]
# [196-200] searching : loss=0.03, accuracy@1=99.23%, accuracy@5=100.00%, time-cost=5157.0 s
# [196-200] evaluate  : loss=0.35, accuracy@1=90.95%, accuracy@5=99.73%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 197-200-th epoch] Time Left: [00:01:06], LR=5.550625190150482e-05
# *SEARCH* [2022-11-07 11:24:36] [197-200][000/196] Time 0.51 (0.51) Data 0.31 (0.31) Base [Loss 0.025 (0.025)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:24:54] [197-200][195/196] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.067 (0.030)  Prec@1 96.25 (99.20) Prec@5 100.00 (100.00)]
# [197-200] searching : loss=0.03, accuracy@1=99.20%, accuracy@5=100.00%, time-cost=5175.3 s
# [197-200] evaluate  : loss=0.35, accuracy@1=91.08%, accuracy@5=99.74%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 198-200-th epoch] Time Left: [00:00:44], LR=2.467198171342e-05
# *SEARCH* [2022-11-07 11:24:58] [198-200][000/196] Time 0.37 (0.37) Data 0.26 (0.26) Base [Loss 0.024 (0.024)  Prec@1 99.22 (99.22) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:25:16] [198-200][195/196] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.076 (0.029)  Prec@1 97.50 (99.23) Prec@5 100.00 (100.00)]
# [198-200] searching : loss=0.03, accuracy@1=99.23%, accuracy@5=100.00%, time-cost=5193.5 s
# [198-200] evaluate  : loss=0.34, accuracy@1=91.02%, accuracy@5=99.72%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth
#
# [Search the 199-200-th epoch] Time Left: [00:00:22], LR=6.168375916970615e-06
# *SEARCH* [2022-11-07 11:25:20] [199-200][000/196] Time 0.35 (0.35) Data 0.25 (0.25) Base [Loss 0.018 (0.018)  Prec@1 99.61 (99.61) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-11-07 11:25:38] [199-200][195/196] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.075 (0.029)  Prec@1 97.50 (99.25) Prec@5 100.00 (100.00)]
# [199-200] searching : loss=0.03, accuracy@1=99.25%, accuracy@5=100.00%, time-cost=5211.7 s
# [199-200] evaluate  : loss=0.35, accuracy@1=91.02%, accuracy@5=99.72%
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/checkpoint/seed-74964-basic.pth
# Find cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth exist, delete is at first before saving
# save checkpoint into cell_level-arch_loop-no_reset_cell_params-loop5_ep2_sample200/train/seed-74964-last-info.pth

# %%
best_archs
# Out:
# [Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|none~1|+|nor_conv_3x3~0|skip_connect~1|none~2|),
#  Structure(4 nodes with |avg_pool_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|none~2|),
#  Structure(4 nodes with |nor_conv_1x1~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_3x3~0|skip_connect~1|nor_conv_3x3~2|),
#  Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|none~2|),
#  Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|nor_conv_1x1~1|none~2|),
#  Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|avg_pool_3x3~1|+|none~0|nor_conv_3x3~1|nor_conv_3x3~2|),
#  Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|avg_pool_3x3~0|none~1|skip_connect~2|),
#  Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|none~0|avg_pool_3x3~1|skip_connect~2|),
#  Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|none~1|skip_connect~2|),
#  Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|skip_connect~0|skip_connect~1|none~2|),
#  Structure(4 nodes with |avg_pool_3x3~0|+|nor_conv_1x1~0|none~1|+|avg_pool_3x3~0|nor_conv_3x3~1|none~2|),
#  Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|nor_conv_1x1~0|skip_connect~1|none~2|),
#  Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|avg_pool_3x3~0|none~1|skip_connect~2|),
#  Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|none~1|+|avg_pool_3x3~0|skip_connect~1|nor_conv_1x1~2|),
#  Structure(4 nodes with |avg_pool_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)]
