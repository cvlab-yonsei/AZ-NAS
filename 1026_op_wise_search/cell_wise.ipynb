# %%
import os, sys, time, glob, random, argparse
import numpy as np
from copy import deepcopy
import torch
import torch.nn as nn

# XAutoDL 
from xautodl.config_utils import load_config, dict2config, configure2str
from xautodl.datasets import get_datasets, get_nas_search_loaders
from xautodl.procedures import (
    prepare_seed,
    prepare_logger,
    save_checkpoint,
    copy_checkpoint,
    get_optim_scheduler,
)
from xautodl.utils import get_model_infos, obtain_accuracy
from xautodl.log_utils import AverageMeter, time_string, convert_secs2time
from xautodl.models import get_search_spaces

from custom_models import get_cell_based_tiny_net
from custom_search_cells import NAS201SearchCell as SearchCell
from xautodl.models.cell_searchs.genotypes import Structure

# NB201
from nas_201_api import NASBench201API as API

import scipy.stats as stats
# Out:
# 2022-10-27 08:23:54.407410: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
parser = argparse.ArgumentParser("Random search for NAS.")
parser.add_argument("--data_path", type=str, default='../cifar.python', help="The path to dataset")
parser.add_argument("--dataset", type=str, default='cifar10',choices=["cifar10", "cifar100", "ImageNet16-120"], help="Choose between Cifar10/100 and ImageNet-16.")

# channels and number-of-cells
parser.add_argument("--search_space_name", type=str, default='nas-bench-201', help="The search space name.")
parser.add_argument("--config_path", type=str, default='../configs/nas-benchmark/algos/RANDOM.config', help="The path to the configuration.")
parser.add_argument("--max_nodes", type=int, default=4, help="The maximum number of nodes.")
parser.add_argument("--channel", type=int, default=16, help="The number of channels.")
parser.add_argument("--num_cells", type=int, default=5, help="The number of cells in one stage.")
parser.add_argument("--select_num", type=int, default=100, help="The number of selected architectures to evaluate.")
parser.add_argument("--track_running_stats", type=int, default=0, choices=[0, 1], help="Whether use track_running_stats or not in the BN layer.")
# log
parser.add_argument("--workers", type=int, default=4, help="number of data loading workers")
parser.add_argument("--save_dir", type=str, default='./tmp', help="Folder to save checkpoints and log.")
# parser.add_argument("--arch_nas_dataset", type=str, default='../NAS-Bench-201-v1_1-096897.pth', help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--arch_nas_dataset", type=str, default=None, help="The path to load the architecture dataset (tiny-nas-benchmark).")
parser.add_argument("--print_freq", type=int, default=100, help="print frequency (default: 200)")
parser.add_argument("--rand_seed", type=int, default=None, help="manual seed")
args = parser.parse_args(args=[])
if args.rand_seed is None or args.rand_seed < 0:
    args.rand_seed = random.randint(1, 100000)

    
print(args.rand_seed)
print(args)
xargs=args
# Out:
# 67474
# Namespace(arch_nas_dataset=None, channel=16, config_path='../configs/nas-benchmark/algos/RANDOM.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=100, rand_seed=67474, save_dir='./tmp', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
assert torch.cuda.is_available(), "CUDA is not available."
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.set_num_threads(xargs.workers)
prepare_seed(xargs.rand_seed)
logger = prepare_logger(args)
# Out:
# Main Function with logger : Logger(dir=tmp, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : None
# channel          : 16
# config_path      : ../configs/nas-benchmark/algos/RANDOM.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 100
# rand_seed        : 67474
# save_dir         : ./tmp
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None

# %%
train_data, valid_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(xargs.config_path, {"class_num": class_num, "xshape": xshape}, logger)
search_loader, _, valid_loader = get_nas_search_loaders(train_data,
                                                        valid_data,
                                                        xargs.dataset,
                                                        "../configs/nas-benchmark/",
                                                        (config.batch_size, config.test_batch_size),
                                                        xargs.workers)
logger.log("||||||| {:10s} ||||||| Search-Loader-Num={:}, Valid-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(search_loader), len(valid_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": bool(xargs.track_running_stats),
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))
# if xargs.arch_nas_dataset is None:
api = None
# else:
#     api = API(xargs.arch_nas_dataset)
logger.log("{:} create API = {:} done".format(time_string(), api))

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)
network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

if last_info.exists():  # automatically resume from previous checkpoint
    logger.log(
        "=> loading checkpoint of the last-info '{:}' start".format(last_info)
    )
    last_info = torch.load(last_info)
    start_epoch = last_info["epoch"]
    checkpoint = torch.load(last_info["last_checkpoint"])
    genotypes = checkpoint["genotypes"]
    valid_accuracies = checkpoint["valid_accuracies"]
    search_model.load_state_dict(checkpoint["search_model"])
    w_scheduler.load_state_dict(checkpoint["w_scheduler"])
    w_optimizer.load_state_dict(checkpoint["w_optimizer"])
    logger.log(
        "=> loading checkpoint of the last-info '{:}' start with {:}-th epoch.".format(
            last_info, start_epoch
        )
    )
else:
    logger.log("=> do not find the last-info file : {:}".format(last_info))
    start_epoch, valid_accuracies, genotypes = 0, {"best": -1}, {}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ../configs/nas-benchmark/algos/RANDOM.config
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Search-Loader-Num=391, Valid-Loader-Num=49, batch size=64
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.025
#     lr: 0.025
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=250, current::epoch=0, iter=0.00, type=cosine, T-max=250, eta-min=0.001)
# criterion   : CrossEntropyLoss()
# [2022-10-27 08:32:22] create API = None done
# => do not find the last-info file : tmp/seed-67474-last-info.pth

# %%
def acc_confidence_robustness_metrics(network, inputs, targets):
    with torch.no_grad():
        # accuracy
        network.train()
        _, logits = network(inputs)
        val_top1, val_top5 = obtain_accuracy(logits.data, targets.data, topk=(1, 5))
        acc = val_top1
        
        # confidence
        prob = torch.nn.functional.softmax(logits, dim=1)
        one_hot_idx = torch.nn.functional.one_hot(targets)
        confidence = (prob[one_hot_idx==1].sum()) / inputs.size(0) * 100 # in percent
        
        # sensitivity
        _, noisy_logits = network(inputs + torch.randn_like(inputs)*0.1)
        kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
        sensitivity = kl_loss(torch.nn.functional.log_softmax(noisy_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
        
        # robustness
        original_weights = deepcopy(network.state_dict())
        for m in network.modules():
            if isinstance(m, SearchCell):
                for p in m.parameters():
                    p.add_(torch.randn_like(p) * p.std()*0.3)
            
        _, noisy_logits = network(inputs)
        kl_loss = torch.nn.KLDivLoss(reduction="batchmean")
        robustness = -kl_loss(torch.nn.functional.log_softmax(noisy_logits, dim=1), torch.nn.functional.softmax(logits, dim=1))
        network.load_state_dict(original_weights)
                
        return acc.item(), confidence.item(), sensitivity.item(), robustness.item()
    
def step_sim_metric(network, criterion, inputs, targets):
    original_dict = deepcopy(network.state_dict())
    optim_large_step = torch.optim.SGD(network.parameters(), lr=0.025)
    
    # single large step
    network.train()
    optim_large_step.zero_grad()
    _, logits = network(inputs)
    base_loss = criterion(logits, targets)
    base_loss.backward()
    optim_large_step.step()
    large_step_dict = deepcopy(network.state_dict())
    
    # multiple small steps
    network.load_state_dict(original_dict)
    optim_small_step = torch.optim.SGD(network.parameters(), lr=0.025/3)
    for i in range(3):
        optim_small_step.zero_grad()
        _, logits = network(inputs)
        base_loss = criterion(logits, targets)
        base_loss.backward()
        optim_small_step.step()
    small_step_dict = deepcopy(network.state_dict())
    scores = []
    for key in large_step_dict.keys():
        if ('weight' in key) and (original_dict[key].dim()==4):
            if (original_dict[key] != large_step_dict[key]).sum():
                large_step = large_step_dict[key] - original_dict[key]
                small_step = small_step_dict[key] - original_dict[key]
                co, ci, kh, kw = large_step.size()
                large_step = large_step.view(co, -1)
                small_step = small_step.view(co, -1)
                score = torch.nn.functional.cosine_similarity(large_step, small_step, dim=1)
                score = score.mean().item() * 100 # in percent
                scores.append(score)
    if len(scores)==0:
        step_sim = 0
    else:
        step_sim = np.mean(scores)
    
    # resume
    network.load_state_dict(original_dict)
            
    return step_sim

# %%
# start training
start_time, search_time, epoch_time, total_epoch = (
    time.time(),
    AverageMeter(),
    AverageMeter(),
    config.epochs + config.warmup,
)

################# initialize
cells = []
for m in network.modules():
    if isinstance(m, SearchCell):
        cells.append(m)
num_cells = len(cells)
print("total number of nodes:{}".format(num_cells*xargs.max_nodes))
        
op_names = deepcopy(cells[0].op_names)
op_names_wo_none = deepcopy(op_names)
if "none" in op_names_wo_none:
    op_names_wo_none.remove("none")

genotypes = []
for i in range(1, xargs.max_nodes):
    xlist = []
    for j in range(i):
        node_str = "{:}<-{:}".format(i, j)
        if i-j==1:
            op_name = "skip_connect"
        else:
            op_name = "none"
        xlist.append((op_name, j))
    genotypes.append(tuple(xlist))
init_arch = Structure(genotypes)

for c in cells:
    c.arch_cache = init_arch

### gen possible connections of a target node
possible_connections = {}
for target_node_idx in range(1,xargs.max_nodes):
    possible_connections[target_node_idx] = list()
    xlists = []
    for src_node in range(target_node_idx):
        node_str = "{:}<-{:}".format(target_node_idx, src_node)
        # select possible ops
        if target_node_idx - src_node == 1:
            op_names_tmp = op_names_wo_none
        else:
            op_names_tmp = op_names
            
        if len(xlists) == 0: # initial iteration
            for op_name in op_names_tmp:
                xlists.append([(op_name, src_node)])
        else:
            new_xlists = []
            for op_name in op_names_tmp:
                for xlist in xlists:
                    new_xlist = deepcopy(xlist)
                    new_xlist.append((op_name, src_node))
                    new_xlists.append(new_xlist)
            xlists = new_xlists
    print("target_node:{}".format(target_node_idx), len(xlists))
    for xlist in xlists:
        possible_connections[target_node_idx].append(tuple(xlist))
        
### train while generating random architectures by mutating connections of a target node
for target_cell_idx in range(num_cells):
    target_cell = cells[target_cell_idx]
    print("\n\n Searching with a new cell #{}".format(target_cell_idx))
    for target_node_idx in range(1,xargs.max_nodes):
        current_genotypes,_ = target_cell.arch_cache.tolist(None)
        print("\nCurrent target cell:{} / current target node:{}".format(target_cell_idx, target_node_idx))
        ## training
        for ep in range(3):
            data_time, batch_time = AverageMeter(), AverageMeter()
            base_losses, base_top1, base_top5 = AverageMeter(), AverageMeter(), AverageMeter()
            network.train()
            end = time.time()
            print_freq = 200
            for step, (base_inputs, base_targets, arch_inputs, arch_targets) in enumerate(search_loader):
                ######### random generation
                genotypes = deepcopy(current_genotypes)
                connection = random.choice(possible_connections[target_node_idx])
                genotypes[target_node_idx-1] = connection
                arch = Structure(genotypes)
                target_cell.arch_cache = arch
                
                ######### forward/backward/optim
                base_targets = base_targets.cuda(non_blocking=True)
                arch_targets = arch_targets.cuda(non_blocking=True)
                # measure data loading time
                data_time.update(time.time() - end)
                w_optimizer.zero_grad()
                _, logits = network(base_inputs)
                base_loss = criterion(logits, base_targets)
                base_loss.backward()
                nn.utils.clip_grad_norm_(network.parameters(), 5)
                w_optimizer.step()
                
                ######### logging
                base_prec1, base_prec5 = obtain_accuracy(logits.data, base_targets.data, topk=(1, 5))
                base_losses.update(base_loss.item(), base_inputs.size(0))
                base_top1.update(base_prec1.item(), base_inputs.size(0))
                base_top5.update(base_prec5.item(), base_inputs.size(0))
                batch_time.update(time.time() - end)
                end = time.time()
                if step % print_freq == 0 or step + 1 == len(search_loader):
                    Sstr = ("*Train* "+ time_string()+" Ep:{:} [{:03d}/{:03d}]".format(ep, step, len(search_loader)))
                    Tstr = "Time {batch_time.val:.2f} ({batch_time.avg:.2f}) Data {data_time.val:.2f} ({data_time.avg:.2f})".format(batch_time=batch_time, data_time=data_time)
                    Wstr = "Base [Loss {loss.val:.3f} ({loss.avg:.3f})  Prec@1 {top1.val:.2f} ({top1.avg:.2f}) Prec@5 {top5.val:.2f} ({top5.avg:.2f})]".format(loss=base_losses, top1=base_top1, top5=base_top5)
                    logger.log(Sstr + " " + Tstr + " " + Wstr)
                    
            logger.log("Ep:{:} ends : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%".format(ep, base_losses.avg, base_top1.avg, base_top5.avg))
        ## evaluation
        network.train()
        archs, metric_accs, metric_confidences, metric_sensitivities, metric_robustnesses, metric_step_sims = [], [], [], [], [], []
        loader_iter = iter(valid_loader)
        for connection in possible_connections[target_node_idx]:
            ###### traverse over possible archs
            genotypes = deepcopy(current_genotypes)
            genotypes[target_node_idx-1] = connection
            arch = Structure(genotypes)
            target_cell.arch_cache = arch
            ###### measure metrics
            try:
                inputs, targets = next(loader_iter)
            except:
                loader_iter = iter(valid_loader)
                inputs, targets = next(loader_iter)
            inputs, targets = inputs.cuda(non_blocking=True), targets.cuda(non_blocking=True)
            valid_acc, confidence, sensitivity, robustness = acc_confidence_robustness_metrics(network, inputs, targets)
            step_sim = step_sim_metric(network, criterion, inputs, targets)
            archs.append(arch)
            metric_accs.append(valid_acc)
            metric_confidences.append(confidence)
            metric_sensitivities.append(sensitivity)
            metric_robustnesses.append(robustness)
            metric_step_sims.append(step_sim)
        rank_accs, rank_confidences, rank_sensitivities, rank_robustnesses, rank_step_sims = stats.rankdata(metric_accs), stats.rankdata(metric_confidences), stats.rankdata(metric_sensitivities), stats.rankdata(metric_robustnesses), stats.rankdata(metric_step_sims)
        l = len(rank_accs)
        rank_agg = np.log(rank_accs/l)+np.log(rank_confidences/l)+np.log(rank_sensitivities/l)+np.log(rank_robustnesses/l)+np.log(rank_step_sims/l)
        best_idx = np.argmax(rank_agg)
        best_arch, best_acc, best_conf, best_sensitivity, best_robust, best_step_sim = archs[best_idx], metric_accs[best_idx], metric_confidences[best_idx], metric_sensitivities[best_idx], metric_robustnesses[best_idx], metric_step_sims[best_idx]
        logger.log("Found best op for target cell:{} / target node:{}".format(target_cell_idx, target_node_idx))
        logger.log(": {:} with accuracy={:.2f}%, confidence={:.3f}%, sensitivity={:.3f}, robustness={:.3f}, step_sim={:.3f}".format(best_arch, best_acc, best_conf, best_sensitivity, best_robust, best_step_sim))
        target_cell.arch_cache = best_arch
            
best_archs = []
for c in cells:
    best_archs.append(c.arch_cache)
    
torch.save({"model":search_model.state_dict(), "best_archs":best_archs}, "./output.pth")

logger.close()
# Out:
# total number of nodes:60
# target_node:1 4
# target_node:2 20
# target_node:3 100
# current target cell:0 / current target node:1
# *Train* [2022-10-27 08:32:22]current target cell:0 / current target node:1 Ep:0 [000/391] Time 0.25 (0.25) Data 0.15 (0.15) Base [Loss 2.359 (2.359)  Prec@1 6.25 (6.25) Prec@5 46.88 (46.88)]
# *Train* [2022-10-27 08:32:42]current target cell:0 / current target node:1 Ep:0 [200/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 1.640 (1.945)  Prec@1 34.38 (26.96) Prec@5 87.50 (80.25)]
# *Train* [2022-10-27 08:33:05]current target cell:0 / current target node:1 Ep:0 [390/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 1.818 (1.825)  Prec@1 37.50 (31.54) Prec@5 85.00 (84.06)]
# current target cell:0 / current target node:1 // Ep:0 searching : loss=1.82, accuracy@1=31.54%, accuracy@5=84.06%
# *Train* [2022-10-27 08:33:05]current target cell:0 / current target node:1 Ep:1 [000/391] Time 0.32 (0.32) Data 0.17 (0.17) Base [Loss 1.480 (1.480)  Prec@1 48.44 (48.44) Prec@5 92.19 (92.19)]
# *Train* [2022-10-27 08:33:26]current target cell:0 / current target node:1 Ep:1 [200/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 1.495 (1.575)  Prec@1 45.31 (42.23) Prec@5 98.44 (90.63)]
# *Train* [2022-10-27 08:33:45]current target cell:0 / current target node:1 Ep:1 [390/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 1.387 (1.527)  Prec@1 55.00 (44.05) Prec@5 95.00 (91.24)]
# current target cell:0 / current target node:1 // Ep:1 searching : loss=1.53, accuracy@1=44.05%, accuracy@5=91.24%
# *Train* [2022-10-27 08:33:46]current target cell:0 / current target node:1 Ep:2 [000/391] Time 0.27 (0.27) Data 0.18 (0.18) Base [Loss 1.345 (1.345)  Prec@1 45.31 (45.31) Prec@5 93.75 (93.75)]
# *Train* [2022-10-27 08:34:02]current target cell:0 / current target node:1 Ep:2 [200/391] Time 0.08 (0.08) Data 0.00 (0.00) Base [Loss 1.164 (1.390)  Prec@1 59.38 (49.92) Prec@5 95.31 (93.10)]
# *Train* [2022-10-27 08:34:18]current target cell:0 / current target node:1 Ep:2 [390/391] Time 0.07 (0.08) Data 0.00 (0.00) Base [Loss 1.483 (1.354)  Prec@1 45.00 (51.24) Prec@5 90.00 (93.57)]
# current target cell:0 / current target node:1 // Ep:2 searching : loss=1.35, accuracy@1=51.24%, accuracy@5=93.57%
# Best one : Structure(4 nodes with |nor_conv_3x3~0|+|none~0|skip_connect~1|+|none~0|none~1|skip_connect~2|) with accuracy=53.91%, confidence=38.789%, sensitivity=0.006, robustness=-0.004, step_sim=99.964
# current target cell:0 / current target node:2
# *Train* [2022-10-27 08:34:22]current target cell:0 / current target node:2 Ep:0 [000/391] Time 0.25 (0.25) Data 0.16 (0.16) Base [Loss 1.715 (1.715)  Prec@1 37.50 (37.50) Prec@5 95.31 (95.31)]
# *Train* [2022-10-27 08:34:39]current target cell:0 / current target node:2 Ep:0 [200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 1.086 (1.332)  Prec@1 53.12 (51.68) Prec@5 96.88 (93.82)]
# *Train* [2022-10-27 08:34:55]current target cell:0 / current target node:2 Ep:0 [390/391] Time 0.06 (0.09) Data 0.00 (0.00) Base [Loss 1.297 (1.280)  Prec@1 47.50 (53.70) Prec@5 100.00 (94.36)]
# current target cell:0 / current target node:2 // Ep:0 searching : loss=1.28, accuracy@1=53.70%, accuracy@5=94.36%
# *Train* [2022-10-27 08:34:55]current target cell:0 / current target node:2 Ep:1 [000/391] Time 0.29 (0.29) Data 0.16 (0.16) Base [Loss 1.266 (1.266)  Prec@1 53.12 (53.12) Prec@5 95.31 (95.31)]
# *Train* [2022-10-27 08:35:22]current target cell:0 / current target node:2 Ep:1 [200/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 1.098 (1.180)  Prec@1 57.81 (57.45) Prec@5 95.31 (95.32)]
# *Train* [2022-10-27 08:35:41]current target cell:0 / current target node:2 Ep:1 [390/391] Time 0.12 (0.12) Data 0.00 (0.00) Base [Loss 1.145 (1.156)  Prec@1 67.50 (58.62) Prec@5 97.50 (95.60)]
# current target cell:0 / current target node:2 // Ep:1 searching : loss=1.16, accuracy@1=58.62%, accuracy@5=95.60%
# *Train* [2022-10-27 08:35:42]current target cell:0 / current target node:2 Ep:2 [000/391] Time 0.33 (0.33) Data 0.19 (0.19) Base [Loss 1.167 (1.167)  Prec@1 60.94 (60.94) Prec@5 92.19 (92.19)]
# *Train* [2022-10-27 08:36:07]current target cell:0 / current target node:2 Ep:2 [200/391] Time 0.12 (0.13) Data 0.00 (0.00) Base [Loss 0.973 (1.100)  Prec@1 67.19 (60.98) Prec@5 96.88 (95.93)]
# *Train* [2022-10-27 08:36:31]current target cell:0 / current target node:2 Ep:2 [390/391] Time 0.12 (0.13) Data 0.00 (0.00) Base [Loss 1.274 (1.085)  Prec@1 45.00 (61.30) Prec@5 95.00 (96.17)]
# current target cell:0 / current target node:2 // Ep:2 searching : loss=1.09, accuracy@1=61.30%, accuracy@5=96.17%
# Best one : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|none~0|none~1|skip_connect~2|) with accuracy=62.11%, confidence=48.406%, sensitivity=0.014, robustness=-0.002, step_sim=99.964
# current target cell:0 / current target node:3
# *Train* [2022-10-27 08:36:45]current target cell:0 / current target node:3 Ep:0 [000/391] Time 0.24 (0.24) Data 0.16 (0.16) Base [Loss 1.024 (1.024)  Prec@1 64.06 (64.06) Prec@5 98.44 (98.44)]
# *Train* [2022-10-27 08:37:05]current target cell:0 / current target node:3 Ep:0 [200/391] Time 0.12 (0.10) Data 0.00 (0.00) Base [Loss 0.997 (1.103)  Prec@1 67.19 (60.93) Prec@5 93.75 (96.04)]
# *Train* [2022-10-27 08:37:28]current target cell:0 / current target node:3 Ep:0 [390/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 1.015 (1.072)  Prec@1 65.00 (62.20) Prec@5 97.50 (96.32)]
# current target cell:0 / current target node:3 // Ep:0 searching : loss=1.07, accuracy@1=62.20%, accuracy@5=96.32%
# *Train* [2022-10-27 08:37:29]current target cell:0 / current target node:3 Ep:1 [000/391] Time 0.24 (0.24) Data 0.16 (0.16) Base [Loss 1.068 (1.068)  Prec@1 67.19 (67.19) Prec@5 98.44 (98.44)]
# *Train* [2022-10-27 08:37:51]current target cell:0 / current target node:3 Ep:1 [200/391] Time 0.11 (0.11) Data 0.00 (0.00) Base [Loss 0.876 (0.999)  Prec@1 62.50 (64.69) Prec@5 96.88 (96.95)]
# *Train* [2022-10-27 08:38:13]current target cell:0 / current target node:3 Ep:1 [390/391] Time 0.06 (0.11) Data 0.00 (0.00) Base [Loss 1.154 (1.000)  Prec@1 57.50 (64.83) Prec@5 100.00 (96.87)]
# current target cell:0 / current target node:3 // Ep:1 searching : loss=1.00, accuracy@1=64.83%, accuracy@5=96.87%
# *Train* [2022-10-27 08:38:13]current target cell:0 / current target node:3 Ep:2 [000/391] Time 0.32 (0.32) Data 0.15 (0.15) Base [Loss 1.000 (1.000)  Prec@1 67.19 (67.19) Prec@5 100.00 (100.00)]
# *Train* [2022-10-27 08:38:28]current target cell:0 / current target node:3 Ep:2 [200/391] Time 0.07 (0.07) Data 0.00 (0.00) Base [Loss 0.866 (0.958)  Prec@1 68.75 (66.39) Prec@5 100.00 (97.26)]
# *Train* [2022-10-27 08:38:46]current target cell:0 / current target node:3 Ep:2 [390/391] Time 0.13 (0.08) Data 0.00 (0.00) Base [Loss 1.075 (0.957)  Prec@1 57.50 (66.18) Prec@5 92.50 (97.10)]
# current target cell:0 / current target node:3 // Ep:2 searching : loss=0.96, accuracy@1=66.18%, accuracy@5=97.10%
# Best one : Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|) with accuracy=66.21%, confidence=53.509%, sensitivity=0.049, robustness=-0.005, step_sim=99.956
# current target cell:1 / current target node:1
# *Train* [2022-10-27 08:40:04]current target cell:1 / current target node:1 Ep:0 [000/391] Time 0.32 (0.32) Data 0.18 (0.18) Base [Loss 1.038 (1.038)  Prec@1 64.06 (64.06) Prec@5 98.44 (98.44)]
# *Train* [2022-10-27 08:40:32]current target cell:1 / current target node:1 Ep:0 [200/391] Time 0.12 (0.14) Data 0.00 (0.00) Base [Loss 0.924 (1.020)  Prec@1 79.69 (64.59) Prec@5 95.31 (96.19)]
# *Train* [2022-10-27 08:40:54]current target cell:1 / current target node:1 Ep:0 [390/391] Time 0.06 (0.13) Data 0.00 (0.00) Base [Loss 1.154 (0.976)  Prec@1 57.50 (65.84) Prec@5 95.00 (96.76)]
# current target cell:1 / current target node:1 // Ep:0 searching : loss=0.98, accuracy@1=65.84%, accuracy@5=96.76%
# *Train* [2022-10-27 08:40:54]current target cell:1 / current target node:1 Ep:1 [000/391] Time 0.26 (0.26) Data 0.18 (0.18) Base [Loss 0.584 (0.584)  Prec@1 82.81 (82.81) Prec@5 100.00 (100.00)]
# *Train* [2022-10-27 08:41:20]current target cell:1 / current target node:1 Ep:1 [200/391] Time 0.12 (0.13) Data 0.00 (0.00) Base [Loss 0.865 (0.900)  Prec@1 67.19 (68.35) Prec@5 98.44 (97.58)]
# *Train* [2022-10-27 08:41:44]current target cell:1 / current target node:1 Ep:1 [390/391] Time 0.12 (0.13) Data 0.00 (0.00) Base [Loss 0.801 (0.896)  Prec@1 72.50 (68.42) Prec@5 100.00 (97.58)]
# current target cell:1 / current target node:1 // Ep:1 searching : loss=0.90, accuracy@1=68.42%, accuracy@5=97.58%
# *Train* [2022-10-27 08:41:44]current target cell:1 / current target node:1 Ep:2 [000/391] Time 0.32 (0.32) Data 0.19 (0.19) Base [Loss 0.835 (0.835)  Prec@1 68.75 (68.75) Prec@5 98.44 (98.44)]
# *Train* [2022-10-27 08:42:10]current target cell:1 / current target node:1 Ep:2 [200/391] Time 0.12 (0.13) Data 0.00 (0.00) Base [Loss 1.156 (0.859)  Prec@1 60.94 (69.78) Prec@5 96.88 (97.73)]
# *Train* [2022-10-27 08:42:27]current target cell:1 / current target node:1 Ep:2 [390/391] Time 0.06 (0.11) Data 0.00 (0.00) Base [Loss 1.114 (0.858)  Prec@1 60.00 (69.78) Prec@5 97.50 (97.65)]
# current target cell:1 / current target node:1 // Ep:2 searching : loss=0.86, accuracy@1=69.78%, accuracy@5=97.65%
# Best one : Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|none~0|none~1|skip_connect~2|) with accuracy=66.60%, confidence=55.346%, sensitivity=0.058, robustness=-0.007, step_sim=99.956
# current target cell:1 / current target node:2
# *Train* [2022-10-27 08:42:32]current target cell:1 / current target node:2 Ep:0 [000/391] Time 0.30 (0.30) Data 0.21 (0.21) Base [Loss 2.616 (2.616)  Prec@1 15.62 (15.62) Prec@5 67.19 (67.19)]
# *Train* [2022-10-27 08:42:47]current target cell:1 / current target node:2 Ep:0 [200/391] Time 0.07 (0.08) Data 0.00 (0.00) Base [Loss 0.932 (0.945)  Prec@1 70.31 (67.27) Prec@5 96.88 (96.94)]
# *Train* [2022-10-27 08:43:07]current target cell:1 / current target node:2 Ep:0 [390/391] Time 0.06 (0.09) Data 0.00 (0.00) Base [Loss 1.229 (0.901)  Prec@1 57.50 (68.74) Prec@5 95.00 (97.34)]
# current target cell:1 / current target node:2 // Ep:0 searching : loss=0.90, accuracy@1=68.74%, accuracy@5=97.34%
# *Train* [2022-10-27 08:43:07]current target cell:1 / current target node:2 Ep:1 [000/391] Time 0.27 (0.27) Data 0.16 (0.16) Base [Loss 0.610 (0.610)  Prec@1 84.38 (84.38) Prec@5 100.00 (100.00)]
# *Train* [2022-10-27 08:43:35]current target cell:1 / current target node:2 Ep:1 [200/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.883 (0.846)  Prec@1 64.06 (70.86) Prec@5 98.44 (97.63)]
# *Train* [2022-10-27 08:44:01]current target cell:1 / current target node:2 Ep:1 [390/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 1.030 (0.832)  Prec@1 55.00 (71.12) Prec@5 100.00 (97.84)]
# current target cell:1 / current target node:2 // Ep:1 searching : loss=0.83, accuracy@1=71.12%, accuracy@5=97.84%
# *Train* [2022-10-27 08:44:01]current target cell:1 / current target node:2 Ep:2 [000/391] Time 0.28 (0.28) Data 0.19 (0.19) Base [Loss 1.040 (1.040)  Prec@1 60.94 (60.94) Prec@5 95.31 (95.31)]
# *Train* [2022-10-27 08:44:19]current target cell:1 / current target node:2 Ep:2 [200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.843 (0.808)  Prec@1 70.31 (71.66) Prec@5 95.31 (98.03)]
# *Train* [2022-10-27 08:44:35]current target cell:1 / current target node:2 Ep:2 [390/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.746 (0.801)  Prec@1 75.00 (71.98) Prec@5 97.50 (98.13)]
# current target cell:1 / current target node:2 // Ep:2 searching : loss=0.80, accuracy@1=71.98%, accuracy@5=98.13%
# Best one : Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|none~0|none~1|skip_connect~2|) with accuracy=72.27%, confidence=59.450%, sensitivity=0.071, robustness=-0.009, step_sim=99.946
# current target cell:1 / current target node:3
# *Train* [2022-10-27 08:44:50]current target cell:1 / current target node:3 Ep:0 [000/391] Time 0.38 (0.38) Data 0.17 (0.17) Base [Loss 3.043 (3.043)  Prec@1 20.31 (20.31) Prec@5 60.94 (60.94)]
# *Train* [2022-10-27 08:45:08]current target cell:1 / current target node:3 Ep:0 [200/391] Time 0.13 (0.09) Data 0.00 (0.00) Base [Loss 0.720 (0.863)  Prec@1 76.56 (70.33) Prec@5 98.44 (97.44)]
# *Train* [2022-10-27 08:45:28]current target cell:1 / current target node:3 Ep:0 [390/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 0.881 (0.836)  Prec@1 65.00 (71.29) Prec@5 95.00 (97.66)]
# current target cell:1 / current target node:3 // Ep:0 searching : loss=0.84, accuracy@1=71.29%, accuracy@5=97.66%
# *Train* [2022-10-27 08:45:28]current target cell:1 / current target node:3 Ep:1 [000/391] Time 0.31 (0.31) Data 0.16 (0.16) Base [Loss 0.686 (0.686)  Prec@1 78.12 (78.12) Prec@5 98.44 (98.44)]
# *Train* [2022-10-27 08:45:53]current target cell:1 / current target node:3 Ep:1 [200/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.799 (0.778)  Prec@1 68.75 (73.32) Prec@5 98.44 (98.13)]
# *Train* [2022-10-27 08:46:11]current target cell:1 / current target node:3 Ep:1 [390/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.695 (0.780)  Prec@1 80.00 (73.17) Prec@5 100.00 (98.12)]
# current target cell:1 / current target node:3 // Ep:1 searching : loss=0.78, accuracy@1=73.17%, accuracy@5=98.12%
# *Train* [2022-10-27 08:46:12]current target cell:1 / current target node:3 Ep:2 [000/391] Time 0.31 (0.31) Data 0.15 (0.15) Base [Loss 0.949 (0.949)  Prec@1 67.19 (67.19) Prec@5 95.31 (95.31)]
# *Train* [2022-10-27 08:46:32]current target cell:1 / current target node:3 Ep:2 [200/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 0.934 (0.767)  Prec@1 73.44 (73.75) Prec@5 96.88 (98.08)]
# *Train* [2022-10-27 08:46:58]current target cell:1 / current target node:3 Ep:2 [390/391] Time 0.13 (0.12) Data 0.00 (0.00) Base [Loss 0.790 (0.771)  Prec@1 75.00 (73.37) Prec@5 100.00 (98.19)]
# current target cell:1 / current target node:3 // Ep:2 searching : loss=0.77, accuracy@1=73.37%, accuracy@5=98.19%
# Best one : Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|none~0|none~1|skip_connect~2|) with accuracy=72.46%, confidence=61.238%, sensitivity=0.084, robustness=-0.011, step_sim=99.933
# current target cell:2 / current target node:1
# *Train* [2022-10-27 08:48:28]current target cell:2 / current target node:1 Ep:0 [000/391] Time 0.26 (0.26) Data 0.18 (0.18) Base [Loss 0.673 (0.673)  Prec@1 75.00 (75.00) Prec@5 100.00 (100.00)]
# *Train* [2022-10-27 08:48:42]current target cell:2 / current target node:1 Ep:0 [200/391] Time 0.07 (0.08) Data 0.00 (0.00) Base [Loss 0.692 (0.876)  Prec@1 76.56 (70.09) Prec@5 98.44 (97.22)]
# *Train* [2022-10-27 08:48:56]current target cell:2 / current target node:1 Ep:0 [390/391] Time 0.06 (0.07) Data 0.00 (0.00) Base [Loss 0.645 (0.823)  Prec@1 80.00 (71.67) Prec@5 100.00 (97.61)]
# current target cell:2 / current target node:1 // Ep:0 searching : loss=0.82, accuracy@1=71.67%, accuracy@5=97.61%
# *Train* [2022-10-27 08:48:57]current target cell:2 / current target node:1 Ep:1 [000/391] Time 0.29 (0.29) Data 0.15 (0.15) Base [Loss 0.718 (0.718)  Prec@1 73.44 (73.44) Prec@5 98.44 (98.44)]
# *Train* [2022-10-27 08:49:17]current target cell:2 / current target node:1 Ep:1 [200/391] Time 0.07 (0.10) Data 0.00 (0.00) Base [Loss 0.721 (0.751)  Prec@1 79.69 (73.61) Prec@5 98.44 (98.24)]
# *Train* [2022-10-27 08:49:31]current target cell:2 / current target node:1 Ep:1 [390/391] Time 0.06 (0.09) Data 0.00 (0.00) Base [Loss 0.759 (0.742)  Prec@1 77.50 (74.32) Prec@5 100.00 (98.28)]
# current target cell:2 / current target node:1 // Ep:1 searching : loss=0.74, accuracy@1=74.32%, accuracy@5=98.28%
# *Train* [2022-10-27 08:49:31]current target cell:2 / current target node:1 Ep:2 [000/391] Time 0.24 (0.24) Data 0.15 (0.15) Base [Loss 0.858 (0.858)  Prec@1 67.19 (67.19) Prec@5 98.44 (98.44)]

# %%
# for c in cells:
#     print(c.arch_cache)

for m in search_model.modules():
    if isinstance(m, SearchCell):
        print(m.arch_cache)
# Out:
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|none~0|none~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|nor_conv_1x1~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|)
# Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|none~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|avg_pool_3x3~2|)
#
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|none~0|none~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|nor_conv_1x1~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|)
# Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|none~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|avg_pool_3x3~2|)

# %% [markdown]
# # Train a found model

# %%
print(args)
args.save_dir = './tmp/train'
print(args)
# Out:
# Namespace(arch_nas_dataset=None, channel=16, config_path='../configs/nas-benchmark/algos/RANDOM.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=100, rand_seed=67474, save_dir='./tmp/train', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)
# Namespace(arch_nas_dataset=None, channel=16, config_path='../configs/nas-benchmark/algos/RANDOM.config', data_path='../cifar.python', dataset='cifar10', max_nodes=4, num_cells=5, print_freq=100, rand_seed=67474, save_dir='./tmp/train', search_space_name='nas-bench-201', select_num=100, track_running_stats=0, workers=4)

# %%
print(config)
# Out:
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=250, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))

# %%
logger = prepare_logger(args)

cifar_train_config_path = "./MY.config"
###
train_data, valid_data, xshape, class_num = get_datasets(xargs.dataset, xargs.data_path, -1)
config = load_config(cifar_train_config_path, {"class_num": class_num, "xshape": xshape}, logger)
search_loader, _, valid_loader = get_nas_search_loaders(train_data,
                                                        valid_data,
                                                        xargs.dataset,
                                                        "../configs/nas-benchmark/",
                                                        (config.batch_size, config.batch_size),
                                                        xargs.workers)
logger.log("||||||| {:10s} ||||||| Search-Loader-Num={:}, Valid-Loader-Num={:}, batch size={:}".format(
            xargs.dataset, len(search_loader), len(valid_loader), config.batch_size))
logger.log("||||||| {:10s} ||||||| Config={:}".format(xargs.dataset, config))

search_space = get_search_spaces("cell", xargs.search_space_name)
model_config = dict2config(
    {
        "name": "RANDOM",
        "C": xargs.channel,
        "N": xargs.num_cells,
        "max_nodes": xargs.max_nodes,
        "num_classes": class_num,
        "space": search_space,
        "affine": False,
        "track_running_stats": True, # true for eval
    },
    None,
)
search_model = get_cell_based_tiny_net(model_config)

### load
trained_output = torch.load("./output.pth")
search_model.load_state_dict(trained_output['model'], strict=False)
best_archs = trained_output['best_archs']
i=0
for m in search_model.modules():
    if isinstance(m, SearchCell):
        m.arch_cache = best_archs[i]
        i += 1
for m in network.modules():
    if isinstance(m, SearchCell):
        print(m.arch_cache)
###

w_optimizer, w_scheduler, criterion = get_optim_scheduler(search_model.parameters(), config)

logger.log("w-optimizer : {:}".format(w_optimizer))
logger.log("w-scheduler : {:}".format(w_scheduler))
logger.log("criterion   : {:}".format(criterion))

network, criterion = torch.nn.DataParallel(search_model).cuda(), criterion.cuda()

last_info, model_base_path, model_best_path = (
    logger.path("info"),
    logger.path("model"),
    logger.path("best"),
)

start_epoch, valid_accuracies, genotypes = 0, {"best": -1}, {}
# Out:
# Main Function with logger : Logger(dir=tmp/train, use-tf=False, writer=None)
# Arguments : -------------------------------
# arch_nas_dataset : None
# channel          : 16
# config_path      : ../configs/nas-benchmark/algos/RANDOM.config
# data_path        : ../cifar.python
# dataset          : cifar10
# max_nodes        : 4
# num_cells        : 5
# print_freq       : 100
# rand_seed        : 67474
# save_dir         : ./tmp/train
# search_space_name : nas-bench-201
# select_num       : 100
# track_running_stats : 0
# workers          : 4
# Python  Version  : 3.7.13 (default, Mar 29 2022, 02:18:16)  [GCC 7.5.0]
# Pillow  Version  : 9.0.1
# PyTorch Version  : 1.12.0
# cuDNN   Version  : 8302
# CUDA available   : True
# CUDA GPU numbers : 2
# CUDA_VISIBLE_DEVICES : None
# Files already downloaded and verified
# Files already downloaded and verified
# ./MY.config
# Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=50, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# ||||||| cifar10    ||||||| Search-Loader-Num=391, Valid-Loader-Num=391, batch size=64
# ||||||| cifar10    ||||||| Config=Configure(scheduler='cos', LR=0.025, eta_min=0.001, epochs=50, warmup=0, optim='SGD', decay=0.0005, momentum=0.9, nesterov=True, criterion='Softmax', batch_size=64, test_batch_size=512, class_num=10, xshape=(1, 3, 32, 32))
# _IncompatibleKeys(missing_keys=['cells.0.edges.1<-0.2.op.2.running_mean', 'cells.0.edges.1<-0.2.op.2.running_var', 'cells.0.edges.1<-0.2.op.2.num_batches_tracked', 'cells.0.edges.1<-0.3.op.2.running_mean', 'cells.0.edges.1<-0.3.op.2.running_var', 'cells.0.edges.1<-0.3.op.2.num_batches_tracked', 'cells.0.edges.2<-0.2.op.2.running_mean', 'cells.0.edges.2<-0.2.op.2.running_var', 'cells.0.edges.2<-0.2.op.2.num_batches_tracked', 'cells.0.edges.2<-0.3.op.2.running_mean', 'cells.0.edges.2<-0.3.op.2.running_var', 'cells.0.edges.2<-0.3.op.2.num_batches_tracked', 'cells.0.edges.2<-1.2.op.2.running_mean', 'cells.0.edges.2<-1.2.op.2.running_var', 'cells.0.edges.2<-1.2.op.2.num_batches_tracked', 'cells.0.edges.2<-1.3.op.2.running_mean', 'cells.0.edges.2<-1.3.op.2.running_var', 'cells.0.edges.2<-1.3.op.2.num_batches_tracked', 'cells.0.edges.3<-0.2.op.2.running_mean', 'cells.0.edges.3<-0.2.op.2.running_var', 'cells.0.edges.3<-0.2.op.2.num_batches_tracked', 'cells.0.edges.3<-0.3.op.2.running_mean', 'cells.0.edges.3<-0.3.op.2.running_var', 'cells.0.edges.3<-0.3.op.2.num_batches_tracked', 'cells.0.edges.3<-1.2.op.2.running_mean', 'cells.0.edges.3<-1.2.op.2.running_var', 'cells.0.edges.3<-1.2.op.2.num_batches_tracked', 'cells.0.edges.3<-1.3.op.2.running_mean', 'cells.0.edges.3<-1.3.op.2.running_var', 'cells.0.edges.3<-1.3.op.2.num_batches_tracked', 'cells.0.edges.3<-2.2.op.2.running_mean', 'cells.0.edges.3<-2.2.op.2.running_var', 'cells.0.edges.3<-2.2.op.2.num_batches_tracked', 'cells.0.edges.3<-2.3.op.2.running_mean', 'cells.0.edges.3<-2.3.op.2.running_var', 'cells.0.edges.3<-2.3.op.2.num_batches_tracked', 'cells.1.edges.1<-0.2.op.2.running_mean', 'cells.1.edges.1<-0.2.op.2.running_var', 'cells.1.edges.1<-0.2.op.2.num_batches_tracked', 'cells.1.edges.1<-0.3.op.2.running_mean', 'cells.1.edges.1<-0.3.op.2.running_var', 'cells.1.edges.1<-0.3.op.2.num_batches_tracked', 'cells.1.edges.2<-0.2.op.2.running_mean', 'cells.1.edges.2<-0.2.op.2.running_var', 'cells.1.edges.2<-0.2.op.2.num_batches_tracked', 'cells.1.edges.2<-0.3.op.2.running_mean', 'cells.1.edges.2<-0.3.op.2.running_var', 'cells.1.edges.2<-0.3.op.2.num_batches_tracked', 'cells.1.edges.2<-1.2.op.2.running_mean', 'cells.1.edges.2<-1.2.op.2.running_var', 'cells.1.edges.2<-1.2.op.2.num_batches_tracked', 'cells.1.edges.2<-1.3.op.2.running_mean', 'cells.1.edges.2<-1.3.op.2.running_var', 'cells.1.edges.2<-1.3.op.2.num_batches_tracked', 'cells.1.edges.3<-0.2.op.2.running_mean', 'cells.1.edges.3<-0.2.op.2.running_var', 'cells.1.edges.3<-0.2.op.2.num_batches_tracked', 'cells.1.edges.3<-0.3.op.2.running_mean', 'cells.1.edges.3<-0.3.op.2.running_var', 'cells.1.edges.3<-0.3.op.2.num_batches_tracked', 'cells.1.edges.3<-1.2.op.2.running_mean', 'cells.1.edges.3<-1.2.op.2.running_var', 'cells.1.edges.3<-1.2.op.2.num_batches_tracked', 'cells.1.edges.3<-1.3.op.2.running_mean', 'cells.1.edges.3<-1.3.op.2.running_var', 'cells.1.edges.3<-1.3.op.2.num_batches_tracked', 'cells.1.edges.3<-2.2.op.2.running_mean', 'cells.1.edges.3<-2.2.op.2.running_var', 'cells.1.edges.3<-2.2.op.2.num_batches_tracked', 'cells.1.edges.3<-2.3.op.2.running_mean', 'cells.1.edges.3<-2.3.op.2.running_var', 'cells.1.edges.3<-2.3.op.2.num_batches_tracked', 'cells.2.edges.1<-0.2.op.2.running_mean', 'cells.2.edges.1<-0.2.op.2.running_var', 'cells.2.edges.1<-0.2.op.2.num_batches_tracked', 'cells.2.edges.1<-0.3.op.2.running_mean', 'cells.2.edges.1<-0.3.op.2.running_var', 'cells.2.edges.1<-0.3.op.2.num_batches_tracked', 'cells.2.edges.2<-0.2.op.2.running_mean', 'cells.2.edges.2<-0.2.op.2.running_var', 'cells.2.edges.2<-0.2.op.2.num_batches_tracked', 'cells.2.edges.2<-0.3.op.2.running_mean', 'cells.2.edges.2<-0.3.op.2.running_var', 'cells.2.edges.2<-0.3.op.2.num_batches_tracked', 'cells.2.edges.2<-1.2.op.2.running_mean', 'cells.2.edges.2<-1.2.op.2.running_var', 'cells.2.edges.2<-1.2.op.2.num_batches_tracked', 'cells.2.edges.2<-1.3.op.2.running_mean', 'cells.2.edges.2<-1.3.op.2.running_var', 'cells.2.edges.2<-1.3.op.2.num_batches_tracked', 'cells.2 ...
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|skip_connect~1|+|skip_connect~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|none~0|skip_connect~1|+|none~0|none~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|nor_conv_1x1~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_1x1~2|)
# Structure(4 nodes with |skip_connect~0|+|skip_connect~0|skip_connect~1|+|nor_conv_3x3~0|none~1|skip_connect~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|avg_pool_3x3~1|+|nor_conv_3x3~0|avg_pool_3x3~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|skip_connect~1|+|nor_conv_3x3~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |avg_pool_3x3~0|+|none~0|skip_connect~1|+|none~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|nor_conv_1x1~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|nor_conv_3x3~0|nor_conv_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_1x1~0|+|nor_conv_3x3~0|avg_pool_3x3~1|+|nor_conv_1x1~0|nor_conv_3x3~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|nor_conv_1x1~0|nor_conv_1x1~1|+|none~0|none~1|avg_pool_3x3~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|avg_pool_3x3~0|skip_connect~1|+|avg_pool_3x3~0|nor_conv_3x3~1|nor_conv_3x3~2|)
# Structure(4 nodes with |skip_connect~0|+|avg_pool_3x3~0|nor_conv_1x1~1|+|nor_conv_3x3~0|nor_conv_3x3~1|skip_connect~2|)
# Structure(4 nodes with |nor_conv_3x3~0|+|skip_connect~0|nor_conv_1x1~1|+|skip_connect~0|none~1|avg_pool_3x3~2|)
# w-optimizer : SGD (
# Parameter Group 0
#     dampening: 0
#     foreach: None
#     initial_lr: 0.025
#     lr: 0.025
#     maximize: False
#     momentum: 0.9
#     nesterov: True
#     weight_decay: 0.0005
# )
# w-scheduler : CosineAnnealingLR(warmup=0, max-epoch=50, current::epoch=0, iter=0.00, type=cosine, T-max=50, eta-min=0.001)
# criterion   : CrossEntropyLoss()

# %%
def search_func_one_arch(xloader, network, criterion, scheduler, w_optimizer, epoch_str, print_freq, logger):
    data_time, batch_time = AverageMeter(), AverageMeter()
    base_losses, base_top1, base_top5 = AverageMeter(), AverageMeter(), AverageMeter()
    network.train()
    end = time.time()
    for step, (base_inputs, base_targets, arch_inputs, arch_targets) in enumerate(
        xloader
    ):
        scheduler.update(None, 1.0 * step / len(xloader))
        base_targets = base_targets.cuda(non_blocking=True)
        arch_targets = arch_targets.cuda(non_blocking=True)
        # measure data loading time
        data_time.update(time.time() - end)

        w_optimizer.zero_grad()
        _, logits = network(base_inputs)
        base_loss = criterion(logits, base_targets)
        base_loss.backward()
        nn.utils.clip_grad_norm_(network.parameters(), 5)
        w_optimizer.step()
        # record
        base_prec1, base_prec5 = obtain_accuracy(
            logits.data, base_targets.data, topk=(1, 5)
        )
        base_losses.update(base_loss.item(), base_inputs.size(0))
        base_top1.update(base_prec1.item(), base_inputs.size(0))
        base_top5.update(base_prec5.item(), base_inputs.size(0))

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if step % print_freq == 0 or step + 1 == len(xloader):
            Sstr = (
                "*SEARCH* "
                + time_string()
                + " [{:}][{:03d}/{:03d}]".format(epoch_str, step, len(xloader))
            )
            Tstr = "Time {batch_time.val:.2f} ({batch_time.avg:.2f}) Data {data_time.val:.2f} ({data_time.avg:.2f})".format(
                batch_time=batch_time, data_time=data_time
            )
            Wstr = "Base [Loss {loss.val:.3f} ({loss.avg:.3f})  Prec@1 {top1.val:.2f} ({top1.avg:.2f}) Prec@5 {top5.val:.2f} ({top5.avg:.2f})]".format(
                loss=base_losses, top1=base_top1, top5=base_top5
            )
            logger.log(Sstr + " " + Tstr + " " + Wstr)
    return base_losses.avg, base_top1.avg, base_top5.avg

def valid_func_one_arch(xloader, network, criterion):
    data_time, batch_time = AverageMeter(), AverageMeter()
    arch_losses, arch_top1, arch_top5 = AverageMeter(), AverageMeter(), AverageMeter()
    network.eval()
    end = time.time()
    with torch.no_grad():
        for step, (arch_inputs, arch_targets) in enumerate(xloader):
            arch_targets = arch_targets.cuda(non_blocking=True)
            # measure data loading time
            data_time.update(time.time() - end)
            # prediction

#             network.module.random_genotype_per_cell(True)
            _, logits = network(arch_inputs)
            arch_loss = criterion(logits, arch_targets)
            # record
            arch_prec1, arch_prec5 = obtain_accuracy(
                logits.data, arch_targets.data, topk=(1, 5)
            )
            arch_losses.update(arch_loss.item(), arch_inputs.size(0))
            arch_top1.update(arch_prec1.item(), arch_inputs.size(0))
            arch_top5.update(arch_prec5.item(), arch_inputs.size(0))
            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()
    return arch_losses.avg, arch_top1.avg, arch_top5.avg

# %%
start_time, search_time, epoch_time, total_epoch = (
    time.time(),
    AverageMeter(),
    AverageMeter(),
    config.epochs + config.warmup,
)
for epoch in range(0, total_epoch):
    w_scheduler.update(epoch, 0.0)
    need_time = "Time Left: {:}".format(
        convert_secs2time(epoch_time.val * (total_epoch - epoch), True)
    )
    epoch_str = "{:03d}-{:03d}".format(epoch, total_epoch)
    logger.log(
        "\n[Search the {:}-th epoch] {:}, LR={:}".format(
            epoch_str, need_time, min(w_scheduler.get_lr())
        )
    )

    # selected_arch = search_find_best(valid_loader, network, criterion, xargs.select_num)
    search_w_loss, search_w_top1, search_w_top5 = search_func_one_arch(
        search_loader,
        network,
        criterion,
        w_scheduler,
        w_optimizer,
        epoch_str,
        xargs.print_freq,
        logger,
    )
    search_time.update(time.time() - start_time)
    logger.log(
        "[{:}] searching : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%, time-cost={:.1f} s".format(
            epoch_str, search_w_loss, search_w_top1, search_w_top5, search_time.sum
        )
    )
    valid_a_loss, valid_a_top1, valid_a_top5 = valid_func_one_arch(
        valid_loader, network, criterion
    )
    logger.log(
        "[{:}] evaluate  : loss={:.2f}, accuracy@1={:.2f}%, accuracy@5={:.2f}%".format(
            epoch_str, valid_a_loss, valid_a_top1, valid_a_top5
        )
    )
    
    # check the best accuracy
    valid_accuracies[epoch] = valid_a_top1
    if valid_a_top1 > valid_accuracies["best"]:
        valid_accuracies["best"] = valid_a_top1
        find_best = True
    else:
        find_best = False

    # save checkpoint
    save_path = save_checkpoint(
        {
            "epoch": epoch + 1,
            "args": deepcopy(xargs),
            "search_model": search_model.state_dict(),
            "w_optimizer": w_optimizer.state_dict(),
            "w_scheduler": w_scheduler.state_dict(),
            "genotypes": genotypes,
            "valid_accuracies": valid_accuracies,
        },
        model_base_path,
        logger,
    )
    last_info = save_checkpoint(
        {
            "epoch": epoch + 1,
            "args": deepcopy(args),
            "last_checkpoint": save_path,
        },
        logger.path("info"),
        logger,
    )
    if find_best:
        logger.log(
            "<<<--->>> The {:}-th epoch : find the highest validation accuracy : {:.2f}%.".format(
                epoch_str, valid_a_top1
            )
        )
        copy_checkpoint(model_base_path, model_best_path, logger)
    if api is not None:
        logger.log("{:}".format(api.query_by_arch(genotypes[epoch], "200")))
    # measure elapsed time
    epoch_time.update(time.time() - start_time)
    start_time = time.time()

logger.close()
# Out:
# [Search the 000-050-th epoch] Time Left: [00:00:00], LR=0.025
# *SEARCH* [2022-10-28 01:45:43] [000-050][000/391] Time 0.36 (0.36) Data 0.21 (0.21) Base [Loss 0.494 (0.494)  Prec@1 82.81 (82.81) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-10-28 01:45:57] [000-050][100/391] Time 0.23 (0.15) Data 0.00 (0.00) Base [Loss 0.533 (0.451)  Prec@1 79.69 (84.50) Prec@5 98.44 (99.30)]
# *SEARCH* [2022-10-28 01:46:12] [000-050][200/391] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0

# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 002-050-th epoch : find the highest validation accuracy : 80.79%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 003-050-th epoch] Time Left: [00:58:06], LR=0.024787447008744266
# *SEARCH* [2022-10-28 01:49:36] [003-050][000/391] Time 0.27 (0.27) Data 0.18 (0.18) Base [Loss 0.383 (0.383)  Prec@1 84.38 (84.38) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 01:49:45] [003-050][100/391] Time 0.15 (0.09) Data 0.00 (0.00) Base [Loss 0.381 (0.447)  Prec@1 89.06 (84.48) Prec@5 100.00 (99.30)]
# *SEARCH* [2022-10-28 01:49:54] [003-050][200/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.167 (0.459)  Prec@1 93.75 (84.02) Prec@5 100.00 (99.33)]
# *SEARCH* [2022-10-28 01:50:03] [003-050][300/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.499 (0.456)  Prec@1 79.69 (84.18) Prec@5 100.00 (99.29)]
# *SEARCH* [2022-10-28 01:50:11] [003-050][390/391] Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.599 (0.460)  Prec@1 82.50 (84.09) Prec@5 100.00 (99.27)]
# [003-050] searching : loss=0.46, accuracy@1=84.09%, accuracy@5=99.27%, time-cost=195.5 s
# [003-050] evaluate  : loss=0.68, accuracy@1=77.94%, accuracy@5=98.28%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 004-050-th epoch] Time Left: [00:45:06], LR=0.024622997933543573
# *SEARCH* [2022-10-28 01:50:35] [004-050][000/391] Time 0.31 (0.31) Data 0.15 (0.15) Base [Loss 0.347 (0.347)  Prec@1 92.19 (92.19) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 01:50:49] [004-050][100/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.654 (0.451)  Prec@1 71.88 (84.59) Prec@5 98.44 (99.32)]
# *SEARCH* [2022-10-28 01:51:04] [004-050][200/391] Time 0.23 (0.14) Data 0.00 (0.00) Base [Loss 0.531 (0.455)  Prec@1 82.81 (84.34) Prec@5 100.00 (99.33)]
# *SEARCH* [2022-10-28 01:51:18] [004-050][300/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.709 (0.451)  Prec@1 78.12 (84.56) Prec@5 100.00 (99.34)]
# *SEARCH* [2022-10-28 01:51:28] [004-050][390/391] Time 0.07 (0.14) Data 0.00 (0.00) Base [Loss 0.325 (0.454)  Prec@1 87.50 (84.46) Prec@5 100.00 (99.32)]
# [004-050] searching : loss=0.45, accuracy@1=84.46%, accuracy@5=99.32%, time-cost=248.5 s
# [004-050] evaluate  : loss=0.57, accuracy@1=81.62%, accuracy@5=98.78%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 004-050-th epoch : find the highest validation accuracy : 81.62%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 005-050-th epoch] Time Left: [00:57:11], LR=0.024412678195541847
# *SEARCH* [2022-10-28 01:51:51] [005-050][000/391] Time 0.25 (0.25) Data 0.15 (0.15) Base [Loss 0.283 (0.283)  Prec@1 87.50 (87.50) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 01:52:00] [005-050][100/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.262 (0.438)  Prec@1 90.62 (85.04) Prec@5 100.00 (99.20)]
# *SEARCH* [2022-10-28 01:52:09] [005-050][200/391] Time 0.16 (0.09) Data 0.00 (0.00) Base [Loss 0.645 (0.440)  Prec@1 73.44 (84.91) Prec@5 98.44 (99.25)]
# *SEARCH* [2022-10-28 01:52:18] [005-050][300/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.522 (0.433)  Prec@1 78.12 (85.28) Prec@5 98.44 (99.29)]
# *SEARCH* [2022-10-28 01:52:27] [005-050][390/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.345 (0.444)  Prec@1 87.50 (84.82) Prec@5 100.00 (99.28)]
# [005-050] searching : loss=0.44, accuracy@1=84.82%, accuracy@5=99.28%, time-cost=284.0 s
# [005-050] evaluate  : loss=0.83, accuracy@1=75.46%, accuracy@5=97.75%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 006-050-th epoch] Time Left: [00:50:05], LR=0.02415731783065902
# *SEARCH* [2022-10-28 01:53:00] [006-050][000/391] Time 0.28 (0.28) Data 0.18 (0.18) Base [Loss 0.470 (0.470)  Prec@1 78.12 (78.12) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 01:53:09] [006-050][100/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.658 (0.450)  Prec@1 81.25 (84.24) Prec@5 96.88 (99.50)]
# *SEARCH* [2022-10-28 01:53:18] [006-050][200/391] Time 0.17 (0.09) Data 0.00 (0.00) Base [Loss 0.370 (0.445)  Prec@1 93.75 (84.50) Prec@5 98.44 (99.44)]
# *SEARCH* [2022-10-28 01:53:28] [006-050][300/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 0.466 (0.447)  Prec@1 84.38 (84.50) Prec@5 100.00 (99.39)]
# *SEARCH* [2022-10-28 01:53:37] [006-050][390/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 0.331 (0.451)  Prec@1 90.00 (84.43) Prec@5 100.00 (99.36)]
# [006-050] searching : loss=0.45, accuracy@1=84.43%, accuracy@5=99.36%, time-cost=321.8 s
# [006-050] evaluate  : loss=0.79, accuracy@1=75.90%, accuracy@5=97.29%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 007-050-th epoch] Time Left: [00:48:23], LR=0.023857924629592235
# *SEARCH* [2022-10-28 01:54:07] [007-050][000/391] Time 0.49 (0.49) Data 0.18 (0.18) Base [Loss 0.341 (0.341)  Prec@1 89.06 (89.06) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 01:54:23] [007-050][100/391] Time 0.15 (0.16) Data 0.00 (0.00) Base [Loss 0.609 (0.426)  Prec@1 81.25 (86.08) Prec@5 100.00 (99.40)]
# *SEARCH* [2022-10-28 01:54:39] [007-050][200/391] Time 0.15 (0.16) Data 0.00 (0.00) Base [Loss 0.274 (0.438)  Prec@1 92.19 (85.14) Prec@5 100.00 (99.42)]
# *SEARCH* [2022-10-28 01:54:55] [007-050][300/391] Time 0.15 (0.16) Data 0.00 (0.00) Base [Loss 0.425 (0.445)  Prec@1 84.38 (84.79) Prec@5 100.00 (99.40)]
Time 0.07 (0.09) Data 0.00 (0.00) Base [Loss 0.811 (0.417)  Prec@1 75.00 (85.66) Prec@5 95.00 (99.42)]
# [012-050] searching : loss=0.42, accuracy@1=85.66%, accuracy@5=99.42%, time-cost=596.7 s
# [012-050] evaluate  : loss=0.52, accuracy@1=82.36%, accuracy@5=99.02%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 012-050-th epoch : find the highest validation accuracy : 82.36%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 013-050-th epoch] Time Left: [00:36:19], LR=0.021214565271144264
# *SEARCH* [2022-10-28 02:01:36] [013-050][000/391] Time 0.31 (0.31) Data 0.15 (0.15) Base [Loss 0.273 (0.273)  Prec@1 90.62 (90.62) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:01:51] [013-050][100/391] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.276 (0.421)  Prec@1 89.06 (85.64) Prec@5 100.00 (99.43)]
# *SEARCH* [2022-10-28 02:02:03] [013-050][200/391] Time 0.08 (0.13) Data 0.00 (0.00) Base [Loss 0.422 (0.428)  Prec@1 87.50 (85.54) Prec@5 100.00 (99.38)]
# *SEARCH* [2022-10-28 02:02:12] [013-050][300/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.449 (0.420)  Prec@1 82.81 (85.86) Prec@5 100.00 (99.37)]
# *SEARCH* [2022-10-28 02:02:20] [013-050][390/391] Time 0.07 (0.11) Data 0.00 (0.00) Base [Loss 0.712 (0.422)  Prec@1 77.50 (85.71) Prec@5 97.50 (99.38)]
# [013-050] searching : loss=0.42, accuracy@1=85.71%, accuracy@5=99.38%, time-cost=641.0 s
# [013-050] evaluate  : loss=0.60, accuracy@1=80.81%, accuracy@5=98.82%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 014-050-th epoch] Time Left: [00:45:22], LR=0.020649087876984277
# *SEARCH* [2022-10-28 02:02:52] [014-050][000/391] Time 0.30 (0.30) Data 0.15 (0.15) Base [Loss 0.491 (0.491)  Prec@1 79.69 (79.69) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:03:06] [014-050][100/391] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.388 (0.391)  Prec@1 84.38 (86.14) Prec@5 100.00 (99.54)]
# *SEARCH* [2022-10-28 02:03:21] [014-050][200/391] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.559 (0.391)  Prec@1 79.69 (86.33) Prec@5 98.44 (99.53)]
# *SEARCH* [2022-10-28 02:03:35] [014-050][300/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.423 (0.393)  Prec@1 84.38 (86.24) Prec@5 100.00 (99.50)]
# *SEARCH* [2022-10-28 02:03:48] [014-050][390/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.323 (0.403)  Prec@1 92.50 (85.96) Prec@5 97.50 (99.46)]
# [014-050] searching : loss=0.40, accuracy@1=85.96%, accuracy@5=99.46%, time-cost=697.5 s
# [014-050] evaluate  : loss=0.57, accuracy@1=82.16%, accuracy@5=98.90%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 015-050-th epoch] Time Left: [00:52:43], LR=0.020053423027509683
# *SEARCH* [2022-10-28 02:04:22] [015-050][000/391] Time 0.25 (0.25) Data 0.15 (0.15) Base [Loss 0.480 (0.480)  Prec@1 82.81 (82.81) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:04:31] [015-050][100/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss 0.364 (0.387)  Prec@1 89.06 (86.63) Prec@5 100.00 (99.55)]
# *SEARCH* [2022-10-28 02:04:40] [015-050][200/391] Time 0.15 (0.09) Data 0.00 (0.00) Base [Loss 0.317 (0.390)  Prec@1 89.06 (86.48) Prec@5 100.00 (99.53)]
# *SEARCH* [2022-10-28 02:04:53] [015-050][300/391] Time 0.13 (0.10) Data 0.00 (0.00) Base [Loss 0.704 (0.399)  Prec@1 76.56 (86.33) Prec@5 98.44 (99.47)]
# *SEARCH* [2022-10-28 02:05:06] [015-050][390/391] Time 0.13 (0.11) Data 0.00 (0.00) Base [Loss 0.498 (0.404)  Prec@1 82.50 (86.10) Prec@5 97.50 (99.45)]
# [015-050] searching : loss=0.40, accuracy@1=86.10%, accuracy@5=99.45%, time-cost=741.4 s
# [015-050] evaluate  : loss=0.60, accuracy@1=81.12%, accuracy@5=98.74%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 016-050-th epoch] Time Left: [00:40:53], LR=0.01942992153974796
# *SEARCH* [2022-10-28 02:05:34] [016-050][000/391] Time 0.30 (0.30) Data 0.15 (0.15) Base [Loss 0.287 (0.287)  Prec@1 89.06 (89.06) Prec@5 98.44 (98.44)]
# *SEARCH* [2022-10-28 02:05:49] [016-050][100/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.320 (0.371)  Prec@1 90.62 (87.33) Prec@5 100.00 (99.61)]
# *SEARCH* [2022-10-28 02:06:03] [016-050][200/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.525 (0.378)  Prec@1 84.38 (87.03) Prec@5 96.88 (99.60)]
# *SEARCH* [2022-10-28 02:06:17] [016-050][300/391] Time 0.13 (0.14) Data 0.00 (0.00) Base [Loss 0.557 (0.377)  Prec@1 82.81 (86.99) Prec@5 98.44 (99.62)]
# *SEARCH* [2022-10-28 02:06:29] [016-050][390/391] Time 0.08 (0.14) Data 0.00 (0.00) Base [Loss 0.397 (0.384)  Prec@1 87.50 (86.84) Prec@5 100.00 (99.60)]
# [016-050] searching : loss=0.38, accuracy@1=86.84%, accuracy@5=99.60%, time-cost=796.5 s
# [016-050] evaluate  : loss=0.55, accuracy@1=82.43%, accuracy@5=99.10%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 016-050-th epoch : find the highest validation accuracy : 82.43%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 017-050-th epoch] Time Left: [00:43:09], LR=0.018781044089220583
# *SEARCH* [2022-10-28 02:06:53] [017-050][000/391] Time 0.26 (0.26) Data 0.15 (0.15) Base [Loss 0.403 (0.403)  Prec@1 87.50 (87.50) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02

# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 025-050-th epoch] Time Left: [00:37:29], LR=0.013000000000000001
# *SEARCH* [2022-10-28 02:17:29] [025-050][000/391] Time 0.39 (0.39) Data 0.22 (0.22) Base [Loss 0.174 (0.174)  Prec@1 92.19 (92.19) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:17:45] [025-050][100/391] Time 0.15 (0.16) Data 0.00 (0.00) Base [Loss 0.277 (0.318)  Prec@1 89.06 (88.99) Prec@5 100.00 (99.74)]
# *SEARCH* [2022-10-28 02:18:01] [025-050][200/391] Time 0.15 (0.16) Data 0.00 (0.00) Base [Loss 0.512 (0.329)  Prec@1 81.25 (88.88) Prec@5 100.00 (99.67)]
# *SEARCH* [2022-10-28 02:18:17] [025-050][300/391] Time 0.24 (0.16) Data 0.00 (0.00) Base [Loss 0.195 (0.330)  Prec@1 93.75 (88.74) Prec@5 100.00 (99.66)]
# *SEARCH* [2022-10-28 02:18:30] [025-050][390/391] Time 0.15 (0.16) Data 0.00 (0.00) Base [Loss 0.463 (0.327)  Prec@1 87.50 (88.81) Prec@5 100.00 (99.69)]
# [025-050] searching : loss=0.33, accuracy@1=88.81%, accuracy@5=99.69%, time-cost=1253.6 s
# [025-050] evaluate  : loss=0.48, accuracy@1=84.82%, accuracy@5=99.16%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 025-050-th epoch : find the highest validation accuracy : 84.82%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 026-050-th epoch] Time Left: [00:38:55], LR=0.01224651376564824
# *SEARCH* [2022-10-28 02:19:06] [026-050][000/391] Time 0.27 (0.27) Data 0.15 (0.15) Base [Loss 0.311 (0.311)  Prec@1 84.38 (84.38) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:19:16] [026-050][100/391] Time 0.17 (0.10) Data 0.00 (0.00) Base [Loss 0.278 (0.314)  Prec@1 89.06 (89.06) Prec@5 100.00 (99.64)]
# *SEARCH* [2022-10-28 02:19:25] [026-050][200/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.366 (0.314)  Prec@1 84.38 (89.08) Prec@5 100.00 (99.68)]
# *SEARCH* [2022-10-28 02:19:34] [026-050][300/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.437 (0.310)  Prec@1 82.81 (89.31) Prec@5 100.00 (99.70)]
# *SEARCH* [2022-10-28 02:19:43] [026-050][390/391] Time 0.09 (0.10) Data 0.00 (0.00) Base [Loss 0.643 (0.311)  Prec@1 77.50 (89.21) Prec@5 97.50 (99.71)]
# [026-050] searching : loss=0.31, accuracy@1=89.21%, accuracy@5=99.71%, time-cost=1291.1 s
# [026-050] evaluate  : loss=0.51, accuracy@1=83.59%, accuracy@5=99.28%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 027-050-th epoch] Time Left: [00:23:19], LR=0.01149600119722835
# *SEARCH* [2022-10-28 02:20:07] [027-050][000/391] Time 0.32 (0.32) Data 0.15 (0.15) Base [Loss 0.246 (0.246)  Prec@1 93.75 (93.75) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02
Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:26:57] [032-050][100/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 0.344 (0.240)  Prec@1 92.19 (91.82) Prec@5 98.44 (99.75)]
# *SEARCH* [2022-10-28 02:27:13] [032-050][200/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 0.224 (0.243)  Prec@1 92.19 (91.61) Prec@5 100.00 (99.74)]
# *SEARCH* [2022-10-28 02:27:27] [032-050][300/391] Time 0.09 (0.15) Data 0.00 (0.00) Base [Loss 0.177 (0.243)  Prec@1 95.31 (91.59) Prec@5 100.00 (99.76)]
# *SEARCH* [2022-10-28 02:27:36] [032-050][390/391] Time 0.08 (0.14) Data 0.00 (0.00) Base [Loss 0.292 (0.250)  Prec@1 85.00 (91.30) Prec@5 100.00 (99.78)]
# [032-050] searching : loss=0.25, accuracy@1=91.30%, accuracy@5=99.78%, time-cost=1597.9 s
# [032-050] evaluate  : loss=0.46, accuracy@1=85.62%, accuracy@5=99.43%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 032-050-th epoch : find the highest validation accuracy : 85.62%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 033-050-th epoch] Time Left: [00:21:43], LR=0.0072189559107794146
# *SEARCH* [2022-10-28 02:28:00] [033-050][000/391] Time 0.31 (0.31) Data 0.15 (0.15) Base [Loss 0.192 (0.192)  Prec@1 92.19 (92.19) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:28:12] [033-050][100/391] Time 0.09 (0.13) Data 0.00 (0.00) Base [Loss 0.219 (0.228)  Prec@1 95.31 (92.30) Prec@5 100.00 (99.91)]
# *SEARCH* [2022-10-28 02:28:24] [033-050][200/391] Time 0.23 (0.12) Data 0.00 (0.00) Base [Loss 0.297 (0.228)  Prec@1 93.75 (92.33) Prec@5 98.44 (99.91)]
# *SEARCH* [2022-10-28 02:28:38] [033-050][300/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.160 (0.233)  Prec@1 92.19 (92.11) Prec@5 100.00 (99.89)]
# *SEARCH* [2022-10-28 02:28:51] [033-050][390/391] Time 0.13 (0.13) Data 0.00 (0.00) Base [Loss 0.279 (0.232)  Prec@1 90.00 (92.16) Prec@5 100.00 (99.88)]
# [033-050] searching : loss=0.23, accuracy@1=92.16%, accuracy@5=99.88%, time-cost=1649.5 s
# [033-050] evaluate  : loss=0.43, accuracy@1=86.61%, accuracy@5=99.43%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 033-050-th epoch : find the highest validation accuracy : 86.61%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 034-050-th epoch] Time Left: [00:19:58], LR=0.006570078460252038
# *SEARCH* [2022-10-28 02:29:15] [034-050][000/391] Time 0.25 (0.25) Data 0.15 (0.15) Base [Loss 0.340 (0.340)  Prec@1 89.06 (89.06) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:29:25] [034-050][100/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0

# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 040-050-th epoch : find the highest validation accuracy : 87.98%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 041-050-th epoch] Time Left: [00:11:29], LR=0.002868064893975822
# *SEARCH* [2022-10-28 02:38:19] [041-050][000/391] Time 0.32 (0.32) Data 0.15 (0.15) Base [Loss 0.109 (0.109)  Prec@1 95.31 (95.31) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:38:35] [041-050][100/391] Time 0.14 (0.16) Data 0.00 (0.00) Base [Loss 0.128 (0.137)  Prec@1 95.31 (95.22) Prec@5 100.00 (99.97)]
# *SEARCH* [2022-10-28 02:38:50] [041-050][200/391] Time 0.14 (0.15) Data 0.00 (0.00) Base [Loss 0.186 (0.139)  Prec@1 93.75 (95.23) Prec@5 100.00 (99.96)]
# *SEARCH* [2022-10-28 02:39:05] [041-050][300/391] Time 0.23 (0.15) Data 0.00 (0.00) Base [Loss 0.240 (0.146)  Prec@1 89.06 (94.99) Prec@5 100.00 (99.97)]
# *SEARCH* [2022-10-28 02:39:18] [041-050][390/391] Time 0.23 (0.15) Data 0.00 (0.00) Base [Loss 0.111 (0.149)  Prec@1 97.50 (94.87) Prec@5 100.00 (99.97)]
# [041-050] searching : loss=0.15, accuracy@1=94.87%, accuracy@5=99.97%, time-cost=2062.6 s
# [041-050] evaluate  : loss=0.40, accuracy@1=88.01%, accuracy@5=99.47%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 041-050-th epoch : find the highest validation accuracy : 88.01%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 042-050-th epoch] Time Left: [00:12:34], LR=0.002484319839473637
# *SEARCH* [2022-10-28 02:39:54] [042-050][000/391] Time 0.28 (0.28) Data 0.18 (0.18) Base [Loss 0.169 (0.169)  Prec@1 96.88 (96.88) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:40:03] [042-050][100/391] Time 0.10 (0.10) Data 0.00 (0.00) Base [Loss 0.214 (0.133)  Prec@1 95.31 (95.53) Prec@5 100.00 (99.97)]
# *SEARCH* [2022-10-28 02:40:13] [042-050][200/391] Time 0.08 (0.10) Data 0.00 (0.00) Base [Loss 0.169 (0.137)  Prec@1 95.31 (95.43) Prec@5 100.00 (99.97)]
# *SEARCH* [2022-10-28 02:40:24] [042-050][300/391] Time 0.14 (0.10) Data 0.00 (0.00) Base [Loss 0.240 (0.135)  Prec@1 93.75 (95.50) Prec@5 100.00 (99.97)]
# *SEARCH* [2022-10-28 02:40:38] [042-050][390/391] Time 0.14 (0.11) Data 0.00 (0.00) Base [Loss 0.140 (0.137)  Prec@1 97.50 (95.42) Prec@5 100.00 (99.98)]
# [042-050] searching : loss=0.14, accuracy@1=95.42%, accuracy@5=99.98%, time-cost=2107.2 s
# [042-050] evaluate  : loss=0.40, accuracy@1=88.35%, accuracy@5=99.50%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 042-050-th epoch : find the highest validation accuracy : 88.35%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 043-050-th epoch] Time Left: [00:08:41], LR=0.002142075370407768
# *SEARCH* [2022-10-28 02:41:08] [043-050][000/391] Time 0.33 (0.33) Data 0.16 (0.16) Base [Loss 0.077 (0.077)  Prec@1 98.44 (98.44) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:41:24] [043-050][100/391] Time 0.14 (0.16) Data 0.00 (0.00) Base [Loss 0.077 (0.138)  Prec@1 95.31 (95.37) Prec@5 100.00 (99.97)]
# *SEARCH* [2022-10-28 02:41:36] [043-050][200/391] Time 0.09 (0.14) Data 0.00 (0.00) Base [Loss 0.096 (0.130)  Prec@1 98.44 (95.62) Prec@5 100.00 (99.96)]
# *SEARCH* [2022-10-28 02:41:45] [043-050][300/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.220 (0.131)  Prec@1 93.75 (95.51) Prec@5 100.00 (99.95)]
# *SEARCH* [2022-10-28 02:41:54] [043-050][390/391] Time 0.09 (0.12) Data 0.00 (0.00) Base [Loss 0.126 (0.130)  Prec@1 95.00 (95.59) Prec@5 100.00 (99.96)]
# [043-050] searching : loss=0.13, accuracy@1=95.59%, accuracy@5=99.96%, time-cost=2153.2 s
# [043-050] evaluate  : loss=0.39, accuracy@1=88.17%, accuracy@5=99.53%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 044-050-th epoch] Time Left: [00:06:55], LR=0.001842682169340984
# *SEARCH* [2022-10-28 02:42:17] [044-050][000/391] Time 0.31 (0.31) Data 0.15 (0.15) Base [Loss 0.170 (0.170)  Prec@1 95.31 (95.31) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:42:32] [044-050][100/391] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.116 (0.118)  Prec@1 95.31 (95.90) Prec@5 100.00 (99.97)]
# *SEARCH* [2022-10-28 02:42:46] [044-050][200/391] Time 0.13 (0.15) Data 0.00 (0.00) Base [Loss 0.210 (0.121)  Prec@1 92.19 (95.76) Prec@5 100.00 (99.98)]
# *SEARCH* [2022-10-28 02:43:01] [044-050][300/391] Time 0.22 (0.15) Data 0.00 (0.00) Base [Loss 0.144 (0.122)  Prec@1 96.88 (95.76) Prec@5 100.00 (99.98)]
# *SEARCH* [2022-10-28 02:43:11] [044-050][390/391] Time 0.15 (0.14) Data 0.00 (0.00) Base [Loss 0.253 (0.123)  Prec@1 95.00 (95.75) Prec@5 100.00 (99.97)]
# [044-050] searching : loss=0.12, accuracy@1=95.75%, accuracy@5=99.97%, time-cost=2206.7 s
# [044-050] evaluate  : loss=0.40, accuracy@1=88.25%, accuracy@5=99.52%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 045-050-th epoch] Time Left: [00:06:53], LR=0.0015873218044581577
# *SEARCH* [2022-10-28 02:43:40] [045-050][000/391] Time 0.25 (0.25) Data 0.15 (0.15) Base [Loss 0.038 (0.038)  Prec@1 100.00 (100.00) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:43:49] [045-050][100/391] Time 0.08 (0.09) Data 0.00 (0.00) Base [Loss
# *SEARCH* [2022-10-28 02:46:58] [047-050][390/391] Time 0.23 (0.15) Data 0.00 (0.00) Base [Loss 0.162 (0.110)  Prec@1 92.50 (96.38) Prec@5 100.00 (99.97)]
# [047-050] searching : loss=0.11, accuracy@1=96.38%, accuracy@5=99.97%, time-cost=2349.5 s
# [047-050] evaluate  : loss=0.39, accuracy@1=88.68%, accuracy@5=99.53%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
# <<<--->>> The 047-050-th epoch : find the highest validation accuracy : 88.68%.
# Find tmp/train/checkpoint/seed-67474-best.pth exist, delete is at first before saving
# copy the file from tmp/train/checkpoint/seed-67474-basic.pth into tmp/train/checkpoint/seed-67474-best.pth
#
# [Search the 048-050-th epoch] Time Left: [00:02:55], LR=0.0010946235842262668
# *SEARCH* [2022-10-28 02:47:26] [048-050][000/391] Time 0.35 (0.35) Data 0.15 (0.15) Base [Loss 0.124 (0.124)  Prec@1 93.75 (93.75) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:47:36] [048-050][100/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.062 (0.105)  Prec@1 96.88 (96.36) Prec@5 100.00 (99.94)]
# *SEARCH* [2022-10-28 02:47:47] [048-050][200/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.134 (0.106)  Prec@1 96.88 (96.38) Prec@5 100.00 (99.96)]
# *SEARCH* [2022-10-28 02:47:57] [048-050][300/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.105 (0.105)  Prec@1 95.31 (96.39) Prec@5 100.00 (99.95)]
# *SEARCH* [2022-10-28 02:48:10] [048-050][390/391] Time 0.24 (0.11) Data 0.00 (0.00) Base [Loss 0.100 (0.104)  Prec@1 100.00 (96.47) Prec@5 100.00 (99.95)]
# [048-050] searching : loss=0.10, accuracy@1=96.47%, accuracy@5=99.95%, time-cost=2394.4 s
# [048-050] evaluate  : loss=0.40, accuracy@1=88.52%, accuracy@5=99.53%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
#
# [Search the 049-050-th epoch] Time Left: [00:01:14], LR=0.0010236792588607412
# *SEARCH* [2022-10-28 02:48:40] [049-050][000/391] Time 0.32 (0.32) Data 0.15 (0.15) Base [Loss 0.052 (0.052)  Prec@1 98.44 (98.44) Prec@5 100.00 (100.00)]
# *SEARCH* [2022-10-28 02:48:53] [049-050][100/391] Time 0.10 (0.13) Data 0.00 (0.00) Base [Loss 0.162 (0.102)  Prec@1 93.75 (96.67) Prec@5 100.00 (99.95)]
# *SEARCH* [2022-10-28 02:49:03] [049-050][200/391] Time 0.08 (0.12) Data 0.00 (0.00) Base [Loss 0.125 (0.101)  Prec@1 95.31 (96.58) Prec@5 100.00 (99.97)]
# *SEARCH* [2022-10-28 02:49:13] [049-050][300/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.049 (0.100)  Prec@1 98.44 (96.67) Prec@5 100.00 (99.98)]
# *SEARCH* [2022-10-28 02:49:21] [049-050][390/391] Time 0.09 (0.11) Data 0.00 (0.00) Base [Loss 0.073 (0.100)  Prec@1 100.00 (96.71) Prec@5 100.00 (99.98)]
# [049-050] searching : loss=0.10, accuracy@1=96.71%, accuracy@5=99.98%, time-cost=2435.7 s
# [049-050] evaluate  : loss=0.40, accuracy@1=88.52%, accuracy@5=99.47%
# Find tmp/train/checkpoint/seed-67474-basic.pth exist, delete is at first before saving
# save checkpoint into tmp/train/checkpoint/seed-67474-basic.pth
# Find tmp/train/seed-67474-last-info.pth exist, delete is at first before saving
# save checkpoint into tmp/train/seed-67474-last-info.pth
